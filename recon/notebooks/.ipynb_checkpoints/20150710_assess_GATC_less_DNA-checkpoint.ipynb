# %% [markdown]
# # Setup

# %%
# %run _shared_setup.ipynb

import openpyxl
import locale
from Bio import SeqIO
import petlx.bio
# Out:
# python 3.4.1 |Anaconda 2.1.0 (x86_64)| (default, Sep 10 2014, 17:24:09)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# numpy 1.9.2
# scipy 0.14.0
# pandas 0.14.1
# numexpr 2.3.1
# pysam 0.8.3
# petl 1.0.10
# petlx 1.0.3
# vcf 0.6.7
# h5py 2.3.1
# tables 3.1.1
# vcfplt 0.8
# 384
# 5729
# 10

# %%
GATC_SEQ_DIRs = collections.OrderedDict()
GATC_SEQ_DIRs['Forward'] = '/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127'
GATC_SEQ_DIRs['Reverse'] = '/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139'
GATC_SEQ_DIRs['ForwardRep'] = '/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119'

CAPILLARY_SAMPLES_FN = '/data/plasmodium/pfalciparum/recon/data/processed/capillary/GATC_less_DNA.xlsx'
# !mkdir -p /data/plasmodium/pfalciparum/recon/data/processed/capillary

BAM_FILES_DIR = '/data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA'
GATC_BAM_FILES_FOFN = '/data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA/gatc_bams.%s.list'
# !mkdir -p {BAM_FILES_DIR}

VARIANT_FILES_DIR = '/data/plasmodium/pfalciparum/recon/data/processed/capillary/variants/GATC_less_DNA'
# !mkdir -p {VARIANT_FILES_DIR}
GATC_CAPILLARY_VCF_FN = "%s/gatc_capillary.%%s.vcf" % VARIANT_FILES_DIR
ILLUMINA_CALLS_EXCEL_FN = "%s/illumina_calls.xlsx" % VARIANT_FILES_DIR
SEQUENOM_CALLS_EXCEL_FN = "%s/sequenom_calls.xlsx" % VARIANT_FILES_DIR
CAPILLARY_CALLS_EXCEL_FN = "%s/capillary_calls.xlsx" % VARIANT_FILES_DIR
MERGED_CALLS_EXCEL_FN = "%s/merged_calls.xlsx" % VARIANT_FILES_DIR

SQNM_VCF_FN = DATA_DIR + '/Sqnm_data_DK1066_W1378_20150603.vcf.gz'
SAMPLES_FN = DATA_DIR + '/%s_capillary_samples_less_DNA.txt'

PLOT_DIR = '/Users/rpearson/Documents/projects/Recon/Slides/20150710_assess_GATC_less_DNA'
# !mkdir -p {PLOT_DIR}

# %%
# !mkdir -p {GATC_SEQ_DIRs['ForwardRep']}
# !cp /Users/rpearson/Dropbox/69d4b150f584e230336d8f66ba06851aafa903d4/WatchBox_1210119/* {GATC_SEQ_DIRs['ForwardRep']}/

# %%
SAMPLES_FN
# Out:
# '/data/plasmodium/pfalciparum/recon/sqnm_assay_test_1/%s_capillary_samples_less_DNA.txt'

# %% [markdown]
# # Parse sample details

# %%
def convert_to_fastq(seq_fn='/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/D07_PD0004-C-12891.fas',
                     fastq_fn=None, bad_qual_distance=None, qual_good=60, qual_bad=0):
    if fastq_fn is None:
        fastq_fn = seq_fn.replace('.fas', '.%s.fastq' % bad_qual_distance).replace('.seq', '.%s.fastq' % bad_qual_distance)
        
    # make fastq
    with open(seq_fn, "r") as fasta, open(fastq_fn, "w") as fastq:
        for record in SeqIO.parse(fasta, "fasta"):
            record.seq = record.seq.tomutable()
            record.letter_annotations["phred_quality"] = [qual_good] * len(record)
            if bad_qual_distance is not None:
                if bad_qual_distance==0:
                    for i in range(len(record)):
                        if record.seq[i].islower() or record.seq[i].upper()=='N':
                            record.letter_annotations["phred_quality"][i] = qual_bad
                elif bad_qual_distance==1:
                    for i in range(len(record)):
                        if i == 0:
                            if record.seq[i].islower() or record.seq[i+1].islower() or record.seq[i].upper()=='N':
                                record.letter_annotations["phred_quality"][i] = qual_bad
                        elif i == (len(record) - 1):
                            if record.seq[i].islower() or record.seq[i-1].islower() or record.seq[i].upper()=='N':
                                record.letter_annotations["phred_quality"][i] = qual_bad
                        else:
                            if record.seq[i].islower() or record.seq[i-1].islower() or record.seq[i+1].islower() or record.seq[i].upper()=='N':
                                record.letter_annotations["phred_quality"][i] = qual_bad
                        # Change N's to a, as bwa seems to ignore these and treat as deletion. These should have qual=0 and hence not get called as SNPs
                        if record.seq[i].upper()=='N':
                            record.seq[i] = 'a'
                elif bad_qual_distance==2:
                    for i in range(len(record)):
                        if i == 0:
                            if record.seq[i].islower() or record.seq[i+1].islower() or record.seq[i+2].islower() or record.seq[i].upper()=='N':
                                record.letter_annotations["phred_quality"][i] = qual_bad
                        if i == 1:
                            if record.seq[i].islower() or record.seq[i+1].islower() or record.seq[i-1].islower() or record.seq[i].upper()=='N':
                                record.letter_annotations["phred_quality"][i] = qual_bad
                        elif i == (len(record) - 1):
                            if record.seq[i].islower() or record.seq[i-1].islower() or record.seq[i-2].islower() or record.seq[i].upper()=='N':
                                record.letter_annotations["phred_quality"][i] = qual_bad
                        elif i == (len(record) - 2):
                            if record.seq[i].islower() or record.seq[i-1].islower() or record.seq[i+1].islower() or record.seq[i].upper()=='N':
                                record.letter_annotations["phred_quality"][i] = qual_bad
                        else:
                            if record.seq[i].islower() or record.seq[i-1].islower() or record.seq[i+1].islower() or record.seq[i-2].islower() or record.seq[i+2].islower() or record.seq[i].upper()=='N':
                                record.letter_annotations["phred_quality"][i] = qual_bad
                        # Change N's to a, as bwa seems to ignore these and treat as deletion. These should have qual=0 and hence not get called as SNPs
                        if record.seq[i].upper()=='N':
                            record.seq[i] = 'a'
                else:
                    print("Warning - can't handle bad_qual_distance=%s, assuming bad_qual_distance=None" % bad_qual_distance)
                        
            SeqIO.write(record, fastq, "fastq")
    
    return(fastq_fn)

convert_to_fastq()
# Out:
# '/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/D07_PD0004-C-12891.None.fastq'

# %%
convert_to_fastq(bad_qual_distance=0)
# Out:
# '/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/D07_PD0004-C-12891.0.fastq'

# %%
convert_to_fastq(bad_qual_distance=1)
# Out:
# '/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/D07_PD0004-C-12891.1.fastq'

# %%
convert_to_fastq(bad_qual_distance=2)
# Out:
# '/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/D07_PD0004-C-12891.2.fastq'

# %%
def sequence_length(seq_fn='/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/D07_PD0004-C-12891.fas'):
    return(len(SeqIO.read(open(seq_fn, "r"), "fasta").seq))
sequence_length()
# Out:
# 687

# %%
forward_fas_files = !ls {GATC_SEQ_DIRs['Forward']}/*.fas
reverse_fas_files = !ls {GATC_SEQ_DIRs['Reverse']}/*.fas
forward_rep_fas_files = !ls {GATC_SEQ_DIRs['ForwardRep']}/*.fas

# %%
tbl_gatc_metadata = (etl.wrap([[x] for x in forward_fas_files])
    .pushheader(['seq_fn'])
    .addfield('ox_code', lambda rec: rec[0].replace(GATC_SEQ_DIRs['Forward'], '').replace('-12891.fas', '')[5:])
    .replace('ox_code', 'PD0005-1', 'PD0005-01')
    .replace('ox_code', 'PH0883-C', 'PH0883-Cx')
    .addfield('primers', 'Forward')
    .addfield('seq_length', lambda rec: sequence_length(rec['seq_fn']))
).cat(
(etl.wrap([[x] for x in reverse_fas_files])
    .pushheader(['seq_fn'])
    .addfield('ox_code', lambda rec: rec[0].replace(GATC_SEQ_DIRs['Reverse'], '').replace('-12825seq2.fas', '')[5:])
    .replace('ox_code', 'PD0005-1', 'PD0005-01')
    .replace('ox_code', 'PH0883-C', 'PH0883-Cx')
    .addfield('primers', 'Reverse')
    .addfield('seq_length', lambda rec: sequence_length(rec['seq_fn']))
)).cat(
(etl.wrap([[x] for x in forward_rep_fas_files])
    .pushheader(['seq_fn'])
    .addfield('ox_code', lambda rec: rec[0].replace(GATC_SEQ_DIRs['ForwardRep'], '').replace('-12891.fas', '')[5:])
    .replace('ox_code', 'PD0005-1', 'PD0005-01')
    .replace('ox_code', 'PH0883-C', 'PH0883-Cx')
    .addfield('primers', 'ForwardRep')
    .addfield('seq_length', lambda rec: sequence_length(rec['seq_fn']))
)).sort('ox_code')
print(len(tbl_gatc_metadata.data()))
tbl_gatc_metadata.displayall(index_header=True)
# Out:
# 288
# <table class='petl'>
# <thead>
# <tr>
# <th>0|seq_fn</th>
# <th>1|ox_code</th>
# <th>2|primers</th>
# <th>3|seq_length</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/D07_PD0004-C-12891.fas</td>
# <td>PD0004-C</td>
# <td>Forward</td>
# <td style='text-align: right'>687</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/D07_PD0004-C-12825seq2.fas</td>
# <td>PD0004-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>533</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/D07_PD0004-C-12891.fas</td>
# <td>PD0004-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>942</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/D09_PD0005-1-12891.fas</td>
# <td>PD0005-01</td>
# <td>Forward</td>
# <td style='text-align: right'>672</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/D09_PD0005-1-12825seq2.fas</td>
# <td>PD0005-01</td>
# <td>Reverse</td>
# <td style='text-align: right'>496</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/D09_PD0005-1-12891.fas</td>
# <td>PD0005-01</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>967</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/D08_PD0005-C-12891.fas</td>
# <td>PD0005-C</td>
# <td>Forward</td>
# <td style='text-align: right'>655</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/D08_PD0005-C-12825seq2.fas</td>
# <td>PD0005-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>548</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/D08_PD0005-C-12891.fas</td>
# <td>PD0005-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>976</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/E04_PD0016-C-12891.fas</td>
# <td>PD0016-C</td>
# <td>Forward</td>
# <td style='text-align: right'>686</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/E04_PD0016-C-12825seq2.fas</td>
# <td>PD0016-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>512</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/E04_PD0016-C-12891.fas</td>
# <td>PD0016-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>978</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/E05_PD0031-C-12891.fas</td>
# <td>PD0031-C</td>
# <td>Forward</td>
# <td style='text-align: right'>569</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/E05_PD0031-C-12825seq2.fas</td>
# <td>PD0031-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>532</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/E05_PD0031-C-12891.fas</td>
# <td>PD0031-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>968</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/E06_PD0033-C-12891.fas</td>
# <td>PD0033-C</td>
# <td>Forward</td>
# <td style='text-align: right'>627</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/E06_PD0033-C-12825seq2.fas</td>
# <td>PD0033-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>538</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/E06_PD0033-C-12891.fas</td>
# <td>PD0033-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>975</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/E08_PD0037-C-12891.fas</td>
# <td>PD0037-C</td>
# <td>Forward</td>
# <td style='text-align: right'>869</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/E08_PD0037-C-12825seq2.fas</td>
# <td>PD0037-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>967</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/E08_PD0037-C-12891.fas</td>
# <td>PD0037-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>957</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/E09_PD0038-C-12891.fas</td>
# <td>PD0038-C</td>
# <td>Forward</td>
# <td style='text-align: right'>644</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/E09_PD0038-C-12825seq2.fas</td>
# <td>PD0038-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>583</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/E09_PD0038-C-12891.fas</td>
# <td>PD0038-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>0</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/E10_PD0048-C-12891.fas</td>
# <td>PD0048-C</td>
# <td>Forward</td>
# <td style='text-align: right'>576</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/E10_PD0048-C-12825seq2.fas</td>
# <td>PD0048-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>438</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/E10_PD0048-C-12891.fas</td>
# <td>PD0048-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>957</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/A07_PD0056-C-12891.fas</td>
# <td>PD0056-C</td>
# <td>Forward</td>
# <td style='text-align: right'>652</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/A07_PD0056-C-12825seq2.fas</td>
# <td>PD0056-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>552</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/A07_PD0056-C-12891.fas</td>
# <td>PD0056-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>962</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/E11_PD0058-C-12891.fas</td>
# <td>PD0058-C</td>
# <td>Forward</td>
# <td style='text-align: right'>654</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/E11_PD0058-C-12825seq2.fas</td>
# <td>PD0058-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>287</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/E11_PD0058-C-12891.fas</td>
# <td>PD0058-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>988</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/E12_PD0067-C-12891.fas</td>
# <td>PD0067-C</td>
# <td>Forward</td>
# <td style='text-align: right'>592</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/E12_PD0067-C-12825seq2.fas</td>
# <td>PD0067-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>538</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/E12_PD0067-C-12891.fas</td>
# <td>PD0067-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>1007</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/F01_PD0073-C-12891.fas</td>
# <td>PD0073-C</td>
# <td>Forward</td>
# <td style='text-align: right'>686</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/F01_PD0073-C-12825seq2.fas</td>
# <td>PD0073-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>579</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/F01_PD0073-C-12891.fas</td>
# <td>PD0073-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>997</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/F06_PD0075-C-12891.fas</td>
# <td>PD0075-C</td>
# <td>Forward</td>
# <td style='text-align: right'>605</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181139/F06_PD0075-C-12825seq2.fas</td>
# <td>PD0075-C</td>
# <td>Reverse</td>
# <td style='text-align: right'>288</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1210119/F06_PD0075-C-12891.fas</td>
# <td>PD0075-C</td>
# <td>ForwardRep</td>
# <td style='text-align: right'>965</td>
# </tr>
# <tr>
# <td>/data/plasmodium/pfalciparum

# %%
vcf_reader = vcf.Reader(filename=PGV4_VCF_FN)
pgv4_samples = etl.wrap([[x] for x in vcf_reader.samples]).pushheader(['ox_code']).addfield('is_in_pgv4_vcf', True)

# %%
tbl_sample_sets
# Out:
# +-------------+-------------------+-------------------+--------------+---------------------+-------------------+--------------------+------------------+
# | sample_code | source_code       | donor_source_code | country_code | 384_sample_set_code | 384_position_code | 96_sample_set_code | 96_position_code |
# +=============+===================+===================+==============+=====================+===================+====================+==================+
# | 'PH0043-C'  |            722519 |            722519 | 'KH'         | 'DK1066'            | 'A01'             | 'PH150527-1'       | 'A01'            |
# +-------------+-------------------+-------------------+--------------+---------------------+-------------------+--------------------+------------------+
# | 'PN0004-C'  | 'pfXUA010'        | 'pfXUA010'        | 'PG'         | 'DK1066'            | 'A02'             | 'PF150527-1'       | 'A01'            |
# +-------------+-------------------+-------------------+--------------+---------------------+-------------------+--------------------+------------------+
# | 'PH0457-CW' | 'PF860-2MACS_WGA' | 'PF860-2MACS'     | 'KH'         | 'DK1066'            | 'A03'             | 'PH150527-1'       | 'A02'            |
# +-------------+-------------------+-------------------+--------------+---------------------+-------------------+--------------------+------------------+
# | 'PN0005-C'  | 'pfXUA013'        | 'pfXUA013'        | 'PG'         | 'DK1066'            | 'A04'             | 'PF150527-1'       | 'A02'            |
# +-------------+-------------------+-------------------+--------------+---------------------+-------------------+--------------------+------------------+
# | 'PH0002-C'  | 'CP185'           | 'CP185'           | 'KH'         | 'DK1066'            | 'A05'             | 'PH150527-1'       | 'A03'            |
# +-------------+-------------------+-------------------+--------------+---------------------+-------------------+--------------------+------------------+
# ...

# %%
tbl_pgv4_sample_manifest
# Out:
# +-----+------------+---------+---------+-----------+----------------+---------------------+-------+---------+-----------+---------------+------------+-------------+----------------+---------+-----------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+-----------+------------+-------+
# | Num | Sample     | Release | Pf3k v3 | StudyCode | AlfrescoNumber | AlfrescoCode        | Study | Country | LabSample | LowTypability | PcaOutlier | IsDuplicate | ManualExlusion | Exclude | Duplicate | SolarisCountry | SolarisLocation                                         | Code                                                       | Fws               | Location | Region | Year | KhCluster | V3Clusters | Notes |
# +=====+============+=========+=========+===========+================+=====================+=======+=========+===========+===============+============+=============+================+=========+===========+================+=========================================================+============================================================+===================+==========+========+======+===========+============+=======+
# |   1 | 'PA0007-C' | '3_0'   | True    | 'RV_3606' |           1006 | '1006-PF-GM-CONWAY' | 'PF6' | 'GM'    | False     | False         | False      | False       | None           | False   | '-'       | 'GM'           | 'greater Banjul area, Royal Victoria Teaching Hospital' | 'GM_greater Banjul area, Royal Victoria Teaching Hospital' | 0.995549265848836 | 'Banjul' | 'GM'   | None | None      | None       | None  |
# +-----+------------+---------+---------+-----------+----------------+---------------------+-------+---------+-----------+---------------+------------+-------------+----------------+---------+-----------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+-----------+------------+-------+
# |   2 | 'PA0008-C' | '3_0'   | True    | 'RV_3614' |           1006 | '1006-PF-GM-CONWAY' | 'PF6' | 'GM'    | False     | False         | False      | False       | None           | False   | '-'       | 'GM'           | 'greater Banjul area, Royal Victoria Teaching Hospital' | 'GM_greater Banjul area, Royal Victoria Teaching Hospital' | 0.380544083595885 | 'Banjul' | 'GM'   | ''   | None      | None       | None  |
# +-----+------------+---------+---------+-----------+----------------+---------------------+-------+---------+-----------+---------------+------------+-------------+----------------+---------+-----------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+-----------+------------+-------+
# |   3 | 'PA0011-C' | '3_0'   | True    | 'RV_3642' |           1006 | '1006-PF-GM-CONWAY' | 'PF6' | 'GM'    | False     | False         | False      | False       | None           | False   | '-'       | 'GM'           | 'greater Banjul area, Royal Victoria Teaching Hospital' | 'GM_greater Banjul area, Royal Victoria Teaching Hospital' | 0.999316200656244 | 'Banjul' | 'GM'   | ''   | None      | None       | None  |
# +-----+------------+---------+---------+-----------+----------------+---------------------+-------+---------+-----------+---------------+------------+-------------+----------------+---------+-----------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+-----------+------------+-------+
# |   4 | 'PA0012-C' | '3_0'   | True    | 'RV_3650' |           1006 | '1006-PF-GM-CONWAY' | 'PF6' | 'GM'    | False     | False         | False      | False       | None           | False   | '-'       | 'GM'           | 'greater Banjul area, Royal Victoria Teaching Hospital' | 'GM_greater Banjul area, Royal Victoria Teaching Hospital' | 0.999922696134752 | 'Banjul' | 'GM'   | ''   | None      | None       | None  |
# +-----+------------+---------+---------+-----------+----------------+---------------------+-------+---------+-----------+---------------+------------+-------------+----------------+---------+-----------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+-----------+------------+-------+
# |   5 | 'PA0015-C' | '3_0'   | True    | 'RV_3687' |           1006 | '1006-PF-GM-CONWAY' | 'PF6' | 'GM'    | False     | False         | False      | False       | None           | False   | '-'       | 'GM'           | 'greater Banjul area, Royal Victoria Teaching Hospital' | 'GM_greater Banjul area, Royal Victoria Teaching Hospital' | 0.999552759064621 | 'Banjul' | 'GM'   | ''   | None      | None       | None  |
# +-----+------------+---------+---------+-----------+----------------+---------------------+-------+---------+-----------+---------------+------------+-------------+----------------+---------+-----------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+-----------+------------+-------+
# ...

# %%
pgv4_samples
# Out:
# +------------+----------------+
# | ox_code    | is_in_pgv4_vcf |
# +============+================+
# | 'PA0007-C' | True           |
# +------------+----------------+
# | 'PA0008-C' | True           |
# +------------+----------------+
# | 'PA0011-C' | True           |
# +------------+----------------+
# | 'PA0012-C' | True           |
# +------------+----------------+
# | 'PA0013-C' | True           |
# +------------+----------------+
# ...

# %%
tbl_capillary_samples = (
    tbl_gatc_metadata
    .cut(['ox_code'])
    .distinct('ox_code')
    .leftjoin(tbl_sample_sets, lkey='ox_code', rkey='sample_code')
    .addfield('have_sequenom_data', lambda rec: rec['source_code'] is not None)
    .cut(['ox_code', 'have_sequenom_data'])
    .leftjoin(pgv4_samples)
    .leftjoin(tbl_pgv4_sample_manifest.selecteq('Exclude', 0), lkey='ox_code', rkey='Sample')
    .leftjoin(tbl_pgv4_sample_manifest, lkey='ox_code', rkey='Sample')
#     .cut(['ox_code', 'company', 'have_sequenom_data', 'is_in_pgv4_vcf', 'Pf3k v3'])
    .cut(['ox_code', 'have_sequenom_data', 'is_in_pgv4_vcf', 'Fws'])
    .replace('have_sequenom_data', False, None)
#     .convert('Pf3k v3', bool)
#     .replace('Pf3k v3', False, None)
    .leftjoin(tbl_gatc_metadata.selecteq('primers', 'Forward').cut(['ox_code', 'seq_length']), lkey='ox_code', rkey='ox_code')
    .rename('seq_length', 'forward')
    .leftjoin(tbl_gatc_metadata.selecteq('primers', 'Reverse').cut(['ox_code', 'seq_length']), lkey='ox_code', rkey='ox_code')
    .rename('seq_length', 'reverse')
    .leftjoin(tbl_gatc_metadata.selecteq('primers', 'ForwardRep').cut(['ox_code', 'seq_length']), lkey='ox_code', rkey='ox_code')
    .rename('seq_length', 'forward_rep')
    .selectne('ox_code', 'WATER')
    .sort(['ox_code'])
)
print(len(tbl_capillary_samples.data()))
tbl_capillary_samples.displayall()
# Out:
# 94
# <table class='petl'>
# <thead>
# <tr>
# <th>ox_code</th>
# <th>have_sequenom_data</th>
# <th>is_in_pgv4_vcf</th>
# <th>Fws</th>
# <th>forward</th>
# <th>reverse</th>
# <th>forward_rep</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>PD0004-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998385281543281</td>
# <td style='text-align: right'>687</td>
# <td style='text-align: right'>533</td>
# <td style='text-align: right'>942</td>
# </tr>
# <tr>
# <td>PD0005-01</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998442149991529</td>
# <td style='text-align: right'>672</td>
# <td style='text-align: right'>496</td>
# <td style='text-align: right'>967</td>
# </tr>
# <tr>
# <td>PD0005-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998841156657223</td>
# <td style='text-align: right'>655</td>
# <td style='text-align: right'>548</td>
# <td style='text-align: right'>976</td>
# </tr>
# <tr>
# <td>PD0016-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.997186431841148</td>
# <td style='text-align: right'>686</td>
# <td style='text-align: right'>512</td>
# <td style='text-align: right'>978</td>
# </tr>
# <tr>
# <td>PD0031-C</td>
# <td>True</td>
# <td>True</td>
# <td>None</td>
# <td style='text-align: right'>569</td>
# <td style='text-align: right'>532</td>
# <td style='text-align: right'>968</td>
# </tr>
# <tr>
# <td>PD0033-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999893423316155</td>
# <td style='text-align: right'>627</td>
# <td style='text-align: right'>538</td>
# <td style='text-align: right'>975</td>
# </tr>
# <tr>
# <td>PD0037-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999824357043906</td>
# <td style='text-align: right'>869</td>
# <td style='text-align: right'>967</td>
# <td style='text-align: right'>957</td>
# </tr>
# <tr>
# <td>PD0038-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999307339884455</td>
# <td style='text-align: right'>644</td>
# <td style='text-align: right'>583</td>
# <td style='text-align: right'>0</td>
# </tr>
# <tr>
# <td>PD0048-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999475377583099</td>
# <td style='text-align: right'>576</td>
# <td style='text-align: right'>438</td>
# <td style='text-align: right'>957</td>
# </tr>
# <tr>
# <td>PD0056-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999693179921938</td>
# <td style='text-align: right'>652</td>
# <td style='text-align: right'>552</td>
# <td style='text-align: right'>962</td>
# </tr>
# <tr>
# <td>PD0058-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.99197218732048</td>
# <td style='text-align: right'>654</td>
# <td style='text-align: right'>287</td>
# <td style='text-align: right'>988</td>
# </tr>
# <tr>
# <td>PD0067-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999531377420861</td>
# <td style='text-align: right'>592</td>
# <td style='text-align: right'>538</td>
# <td style='text-align: right'>1007</td>
# </tr>
# <tr>
# <td>PD0073-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999860755634809</td>
# <td style='text-align: right'>686</td>
# <td style='text-align: right'>579</td>
# <td style='text-align: right'>997</td>
# </tr>
# <tr>
# <td>PD0075-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999881475613222</td>
# <td style='text-align: right'>605</td>
# <td style='text-align: right'>288</td>
# <td style='text-align: right'>965</td>
# </tr>
# <tr>
# <td>PD0079-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999796205662859</td>
# <td style='text-align: right'>855</td>
# <td style='text-align: right'>830</td>
# <td style='text-align: right'>973</td>
# </tr>
# <tr>
# <td>PD0090-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999559237489016</td>
# <td style='text-align: right'>678</td>
# <td style='text-align: right'>536</td>
# <td style='text-align: right'>1023</td>
# </tr>
# <tr>
# <td>PD0098-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999827638675597</td>
# <td style='text-align: right'>655</td>
# <td style='text-align: right'>414</td>
# <td style='text-align: right'>937</td>
# </tr>
# <tr>
# <td>PD0103-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999226807461138</td>
# <td style='text-align: right'>559</td>
# <td style='text-align: right'>477</td>
# <td style='text-align: right'>930</td>
# </tr>
# <tr>
# <td>PD0105-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998816115831722</td>
# <td style='text-align: right'>550</td>
# <td style='text-align: right'>518</td>
# <td style='text-align: right'>966</td>
# </tr>
# <tr>
# <td>PD0115-Cx</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999935799467668</td>
# <td style='text-align: right'>665</td>
# <td style='text-align: right'>609</td>
# <td style='text-align: right'>971</td>
# </tr>
# <tr>
# <td>PD0126-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999790367035822</td>
# <td style='text-align: right'>634</td>
# <td style='text-align: right'>543</td>
# <td style='text-align: right'>972</td>
# </tr>
# <tr>
# <td>PD0134-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999123092520746</td>
# <td style='text-align: right'>737</td>
# <td style='text-align: right'>585</td>
# <td style='text-align: right'>985</td>
# </tr>
# <tr>
# <td>PD0135-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998649507062687</td>
# <td style='text-align: right'>690</td>
# <td style='text-align: right'>536</td>
# <td style='text-align: right'>993</td>
# </tr>
# <tr>
# <td>PD0136-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998666349762291</td>
# <td style='text-align: right'>668</td>
# <td style='text-align: right'>285</td>
# <td style='text-align: right'>994</td>
# </tr>
# <tr>
# <td>PD0137-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.99921850908897</td>
# <td style='text-align: right'>648</td>
# <td style='text-align: right'>600</td>
# <td style='text-align: right'>967</td>
# </tr>
# <tr>
# <td>PD0459-Cx</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.994211471426755</td>
# <td style='text-align: right'>733</td>
# <td style='text-align: right'>619</td>
# <td style='text-align: right'>969</td>
# </tr>
# <tr>
# <td>PH0002-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998968100973498</td>
# <td style='text-align: right'>762</td>
# <td style='text-align: right'>530</td>
# <td style='text-align: right'>978</td>
# </tr>
# <tr>
# <td>PH0003-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998428500674172</td>
# <td style='text-align: right'>634</td>
# <td style='text-align: right'>546</td>
# <td style='text-align: right'>962</td>
# </tr>
# <tr>
# <td>PH0012-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998939320308897</td>
# <td style='text-align: right'>571</td>
# <td style='text-align: right'>539</td>
# <td style='text-align: right'>964</td>
# </tr>
# <tr>
# <td>PH0013-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998077232905215</td>
# <td style='text-align: right'>522</td>
# <td style='text-align: right'>284</td>
# <td style='text-align: right'>988</td>
# </tr>
# <tr>
# <td>PH0016-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998422467635336</td>
# <td style='text-align: right'>691</td>
# <td style='text-align: right'>281</td>
# <td style='text-align: right'>956</td>
# </tr>
# <tr>
# <td>PH0017-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.998716153071237</td>
# <td style='text-align: right'>626</td>
# <td style='text-align: right'>460</td>
# <td style='text-align: right'>983</td>
# </tr>
# <tr>
# <td>PH0020-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999094435575526</td>
# <td style='text-align: right'>671</td>
# <td style='text-align: right'>550</td>
# <td style='text-align: right'>963</td>
# </tr>
# <tr>
# <td>PH0022-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.99918067992222</td>
# <td style='text-align: right'>542</td>
# <td style='text-align: right'>475</td>
# <td style='text-align: right'>1003</td>
# </tr>
# <tr>
# <td>PH0024-C</td>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>0.999783416727883</td>
# <td style='text-align:

# %%
tbl_capillary_samples.selecteq('forward_rep', 0).cut('ox_code').displayall()
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>ox_code</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>PD0038-C</td>
# </tr>
# <tr>
# <td>PH0457-CW</td>
# </tr>
# <tr>
# <td>PH0462-C</td>
# </tr>
# <tr>
# <td>PH0464-CW</td>
# </tr>
# <tr>
# <td>PH0466-C</td>
# </tr>
# <tr>
# <td>PH0468-C</td>
# </tr>
# <tr>
# <td>PV0028-C</td>
# </tr>
# <tr>
# <td>PV0039-C</td>
# </tr>
# <tr>
# <td>PV0315-Cx</td>
# </tr>
# <tr>
# <td>PV0331-Cx</td>
# </tr>
# </tbody>
# </table>

# %%
np.min(tbl_capillary_samples.selectnotnone('Fws').values('Fws').array())
# Out:
# 0.99197218732047998

# %%
# sns.jointplot(tbl_capillary_samples.values('forward').array(), tbl_capillary_samples.values('reverse').array())
sns.jointplot('forward', 'reverse', tbl_capillary_samples.todataframe())
plt.savefig('%s/forward_vs_reverse.pdf' % PLOT_DIR, format='pdf')

# %%
# sns.jointplot(tbl_capillary_samples.values('forward').array(), tbl_capillary_samples.values('reverse').array())
sns.jointplot('forward', 'forward_rep', tbl_capillary_samples.todataframe())
plt.savefig('%s/forward_vs_rep.pdf' % PLOT_DIR, format='pdf')

# %%
# sns.jointplot(tbl_capillary_samples.values('forward').array(), tbl_capillary_samples.values('reverse').array())
sns.distplot(
    tbl_capillary_samples.addfield('Total length', lambda rec: rec['forward'] + rec['reverse']).values('Total length').array(),
    kde=False,
    bins=arange(200, 2000, 100),
    axlabel='Total length'
)
plt.savefig('%s/total_length_dist.pdf' % PLOT_DIR, format='pdf')

# %%
# sns.jointplot(tbl_capillary_samples.values('forward').array(), tbl_capillary_samples.values('reverse').array())
sns.distplot(
    tbl_capillary_samples.addfield('Total length', lambda rec: rec['forward_rep'] + rec['reverse']).values('Total length').array(),
    kde=False,
    bins=arange(200, 2000, 100),
    axlabel='Total length'
)
plt.savefig('%s/total_length_dist_rep.pdf' % PLOT_DIR, format='pdf')

# %%
tbl_capillary_samples.addfield('Covers full sequence', lambda rec: rec['forward_rep'] + rec['reverse'] >= 1012).valuecounts('Covers full sequence')
# Out:
# +----------------------+-------+---------------------+
# | Covers full sequence | count | frequency           |
# +======================+=======+=====================+
# | True                 |    84 |  0.8936170212765957 |
# +----------------------+-------+---------------------+
# | False                |    10 | 0.10638297872340426 |
# +----------------------+-------+---------------------+

# %%
tbl_capillary_samples.toxlsx(CAPILLARY_SAMPLES_FN)

# %%
def run_bwa(ox_code='PA0155-C', company='GATC', primers='Forward',
            seq_fn='/data/plasmodium/pfalciparum/recon/data/raw/capillary/GATC/1181127/D07_PD0004-C-12891.fas',
            bad_qual_distance=None):
    read_group_info = "@RG\tID:%s_%s_%s\tSM:%s_%s_%s\tPL:capillary" % (ox_code, company, primers, ox_code, primers, company)
    bam_fn = "%s/%s_%s_%s.%s.bam" % (BAM_FILES_DIR, ox_code, company, primers, bad_qual_distance)
    
    fastq_fn = convert_to_fastq(seq_fn, bad_qual_distance=bad_qual_distance)
    
    bwa_command = "%s mem -M -R '%s' %s \"%s\" 2> /dev/null | samtools view -bSh - > %s 2> /dev/null" % (
        BWA_EXE, read_group_info, REF_GENOME, fastq_fn, bam_fn
    )
    # !{bwa_command}
    
    samtools_command = "samtools sort %s %s" % (bam_fn, bam_fn.replace('.bam', ''))
    # !{samtools_command}
    
    samtools_command = "samtools index %s" % bam_fn
    # !{samtools_command}
    
    return(bam_fn)

# %%
run_bwa()
# Out:
# '/data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA/PA0155-C_GATC_Forward.None.bam'

# %%
run_bwa(ox_code='PH0883-Cx')
# Out:
# '/data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA/PH0883-Cx_GATC_Forward.None.bam'

# %%
for bad_qual_distance in [None, 0, 1, 2]:
    gatc_fofn = GATC_BAM_FILES_FOFN % bad_qual_distance
    fo = open(gatc_fofn, 'w')
    for rec in tbl_gatc_metadata.selectne('ox_code', 'WATER').data():
        bam_fn = run_bwa(rec[1], 'GATC', rec[2], rec[0], bad_qual_distance=bad_qual_distance)
        print(bam_fn, file=fo)
    fo.close()

# %%
# temp fix for PH0883-Cx
for bad_qual_distance in [None, 0, 1, 2]:
#     gatc_fofn = GATC_BAM_FILES_FOFN % bad_qual_distance
#     fo = open(gatc_fofn, 'w')
    for rec in tbl_gatc_metadata.selectne('ox_code', 'WATER').data():
        if rec[1] == 'PH0883-Cx':
            bam_fn = run_bwa(rec[1], 'GATC', rec[2], rec[0], bad_qual_distance=bad_qual_distance)
#             print(bam_fn, file=fo)
#     fo.close()

# %%
def call_variants(bam_fn=GATC_BAM_FILES_FOFN % None, vcf_fn=GATC_CAPILLARY_VCF_FN % None):
    gatk_command = "%s \
 -T UnifiedGenotyper \
 -R %s \
 -I %s \
 -L Pf3D7_13_v3:1724943-1725954 \
 -ploidy 1 \
 -stand_call_conf 0 \
 -stand_emit_conf 0 \
 --min_base_quality_score 40 \
 -o %s" % (GATK_EXE, REF_GENOME, bam_fn, vcf_fn)
#  -o %s > /dev/null 2>&1" % (GATK_EXE, REF_GENOME, bam_fn, vcf_fn)
    print(gatk_command)
    # !{gatk_command}

#  --genotype_likelihoods_model BOTH \
#  -minIndelCnt 1 \
#  --defaultBaseQualities 60 \

# %%
calling_runs = {
    'GATC':[GATC_BAM_FILES_FOFN, GATC_CAPILLARY_VCF_FN],
}
for calling_run in calling_runs:
    for bad_qual_distance in [None, 0, 1, 2]:
        print(calling_run, bad_qual_distance)
        call_variants(calling_runs[calling_run][0] % bad_qual_distance, calling_runs[calling_run][1] % bad_qual_distance)
# Out:
# GATC None
# java -jar /Users/rpearson/src/github/malariagen/methods-dev/recon/opt/gatk/GenomeAnalysisTK.jar  -T UnifiedGenotyper  -R /data/plasmodium/pfalciparum/recon/roamato/Pf3D7_v3/3D7_sorted.fa  -I /data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA/gatc_bams.None.list  -L Pf3D7_13_v3:1724943-1725954  -ploidy 1  -stand_call_conf 0  -stand_emit_conf 0  --min_base_quality_score 40  -o /data/plasmodium/pfalciparum/recon/data/processed/capillary/variants/GATC_less_DNA/gatc_capillary.None.vcf
# INFO  16:29:38,402 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:29:38,406 HelpFormatter - The Genome Analysis Toolkit (GATK) v3.4-0-g7e26428, Compiled 2015/05/15 03:25:41
# INFO  16:29:38,406 HelpFormatter - Copyright (c) 2010 The Broad Institute
# INFO  16:29:38,406 HelpFormatter - For support and documentation go to http://www.broadinstitute.org/gatk
# INFO  16:29:38,409 HelpFormatter - Program Args: -T UnifiedGenotyper -R /data/plasmodium/pfalciparum/recon/roamato/Pf3D7_v3/3D7_sorted.fa -I /data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA/gatc_bams.None.list -L Pf3D7_13_v3:1724943-1725954 -ploidy 1 -stand_call_conf 0 -stand_emit_conf 0 --min_base_quality_score 40 -o /data/plasmodium/pfalciparum/recon/data/processed/capillary/variants/GATC_less_DNA/gatc_capillary.None.vcf
# INFO  16:29:38,441 HelpFormatter - Executing as rpearson@dhcp215.well.ox.ac.uk on Mac OS X 10.10.3 x86_64; Java HotSpot(TM) 64-Bit Server VM 1.7.0_60-b19.
# INFO  16:29:38,441 HelpFormatter - Date/Time: 2015/07/10 16:29:38
# INFO  16:29:38,441 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:29:38,442 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:29:38,925 GenomeAnalysisEngine - Strictness is SILENT
# INFO  16:29:39,046 GenomeAnalysisEngine - Downsampling Settings: Method: BY_SAMPLE, Target Coverage: 250
# INFO  16:29:39,054 SAMDataSource$SAMReaders - Initializing SAMRecords in serial
# INFO  16:29:39,299 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.24 s, 50 of 282 in 0.24 s / 0.00 m (207.15 tasks/s).  232 remaining with est. completion in 1.12 s / 0.02 m
# INFO  16:29:39,442 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.14 s, 100 of 282 in 0.39 s / 0.01 m (257.81 tasks/s).  182 remaining with est. completion in 0.71 s / 0.01 m
# INFO  16:29:39,575 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.13 s, 150 of 282 in 0.52 s / 0.01 m (288.01 tasks/s).  132 remaining with est. completion in 0.46 s / 0.01 m
# INFO  16:29:39,750 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.17 s, 200 of 282 in 0.70 s / 0.01 m (287.54 tasks/s).  82 remaining with est. completion in 0.29 s / 0.00 m
# INFO  16:29:39,955 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.20 s, 250 of 282 in 0.90 s / 0.01 m (277.89 tasks/s).  32 remaining with est. completion in 0.12 s / 0.00 m
# INFO  16:29:40,090 SAMDataSource$SAMReaders - Done initializing BAM readers: total time 1.04
# INFO  16:29:40,239 IntervalUtils - Processing 1012 bp from intervals
# INFO  16:29:40,461 GenomeAnalysisEngine - Preparing for traversal over 282 BAM files
# INFO  16:29:40,667 GenomeAnalysisEngine - Done preparing for traversal
# INFO  16:29:40,668 ProgressMeter - [INITIALIZATION COMPLETE; STARTING PROCESSING]
# INFO  16:29:40,668 ProgressMeter -                 | processed |    time |    per 1M |           |   total | remaining
# INFO  16:29:40,669 ProgressMeter -        Location |     sites | elapsed |     sites | completed | runtime |   runtime
# INFO  16:29:40,710 StrandBiasTest - SAM/BAM data was found. Attempting to use read data to calculate strand bias annotations values.
# INFO  16:29:40,711 StrandBiasTest - SAM/BAM data was found. Attempting to use read data to calculate strand bias annotations values.
# INFO  16:29:43,984 ProgressMeter -            done      1012.0     3.0 s      54.6 m       98.8%     3.0 s       0.0 s
# INFO  16:29:43,985 ProgressMeter - Total runtime 3.32 secs, 0.06 min, 0.00 hours
# INFO  16:29:43,985 MicroScheduler - 0 reads were filtered out during the traversal out of approximately 272 total reads (0.00%)
# INFO  16:29:43,985 MicroScheduler -   -> 0 reads (0.00% of total) failing BadCigarFilter
# INFO  16:29:43,986 MicroScheduler -   -> 0 reads (0.00% of total) failing BadMateFilter
# INFO  16:29:43,986 MicroScheduler -   -> 0 reads (0.00% of total) failing DuplicateReadFilter
# INFO  16:29:43,986 MicroScheduler -   -> 0 reads (0.00% of total) failing FailsVendorQualityCheckFilter
# INFO  16:29:43,986 MicroScheduler -   -> 0 reads (0.00% of total) failing MalformedReadFilter
# INFO  16:29:43,986 MicroScheduler -   -> 0 reads (0.00% of total) failing MappingQualityUnavailableFilter
# INFO  16:29:43,987 MicroScheduler -   -> 0 reads (0.00% of total) failing NotPrimaryAlignmentFilter
# INFO  16:29:43,987 MicroScheduler -   -> 0 reads (0.00% of total) failing UnmappedReadFilter
# INFO  16:29:45,230 GATKRunReport - Uploaded run statistics report to AWS S3
# GATC 0
# java -jar /Users/rpearson/src/github/malariagen/methods-dev/recon/opt/gatk/GenomeAnalysisTK.jar  -T UnifiedGenotyper  -R /data/plasmodium/pfalciparum/recon/roamato/Pf3D7_v3/3D7_sorted.fa  -I /data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA/gatc_bams.0.list  -L Pf3D7_13_v3:1724943-1725954  -ploidy 1  -stand_call_conf 0  -stand_emit_conf 0  --min_base_quality_score 40  -o /data/plasmodium/pfalciparum/recon/data/processed/capillary/variants/GATC_less_DNA/gatc_capillary.0.vcf
# INFO  16:29:46,944 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:29:46,946 HelpFormatter - The Genome Analysis Toolkit (GATK) v3.4-0-g7e26428, Compiled 2015/05/15 03:25:41
# INFO  16:29:46,947 HelpFormatter - Copyright (c) 2010 The Broad Institute
# INFO  16:29:46,947 HelpFormatter - For support and documentation go to http://www.broadinstitute.org/gatk
# INFO  16:29:46,951 HelpFormatter - Program Args: -T UnifiedGenotyper -R /data/plasmodium/pfalciparum/recon/roamato/Pf3D7_v3/3D7_sorted.fa -I /data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA/gatc_bams.0.list -L Pf3D7_13_v3:1724943-1725954 -ploidy 1 -stand_call_conf 0 -stand_emit_conf 0 --min_base_quality_score 40 -o /data/plasmodium/pfalciparum/recon/data/processed/capillary/variants/GATC_less_DNA/gatc_capillary.0.vcf
# INFO  16:29:46,958 HelpFormatter - Executing as rpearson@dhcp215.well.ox.ac.uk on Mac OS X 10.10.3 x86_64; Java HotSpot(TM) 64-Bit Server VM 1.7.0_60-b19.
# INFO  16:29:46,958 HelpFormatter - Date/Time: 2015/07/10 16:29:46
# INFO  16:29:46,959 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:29:46,959 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:29:47,370 GenomeAnalysisEngine - Strictness is SILENT
# INFO  16:29:47,457 GenomeAnalysisEngine - Downsampling Settings: Method: BY_SAMPLE, Target Coverage: 250
# INFO  16:29:47,464 SAMDataSource$SAMReaders - Initializing SAMRecords in serial
# INFO  16:29:47,698 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.23 s, 50 of 282 in 0.23 s / 0.00 m (214.41 tasks/s).  232 remaining with est. completion in 1.08 s / 0.02 m
# INFO  16:29:47,839 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.14 s, 100 of 282 in 0.37 s / 0.01 m (266.98 tasks/s).  182 remaining with est. completion in 0.68 s / 0.01 m
# INFO  16:29:47,987 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.15 s, 150 of 282 in 0.52 s / 0.01 m (286.95 tasks/s).  132 remaining with est. completion in 0.46 s / 0.01 m
# INFO  16:29:48,135 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.15 s, 200 of 282 in 0.67 s / 0.01 m (298.39 tasks/s).  82 remaining with est. completion in 0.27 s / 0.00 m
# INFO  16:29:48,285 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.15 s, 250 of 282 in 0.82 s / 0.01 m (304.71 tasks/s).  32 remaining with est. completion in 0.11 s / 0.00 m
# INFO  16:29:48,361 SAMDataSource$SAMReaders - Done initializing BAM readers: total time 0.90
# INFO  16:29:48,489 IntervalUtils - Processing 1012 bp from intervals
# INFO  16:29:48,551 GenomeAnalysisEngine - Preparing for traversal over 282 BAM files
# INFO  16:29:48,734 GenomeAnalysisEngine - Done preparing for traversal
# INFO  16:29:48,734 ProgressMeter - [INITIALIZATION COMPLETE; STARTING PROCESSING]
# INFO  16:29:48,734 ProgressMeter -                 | processed |    time |    per 1M |           |   total | remaining
# INFO  16:29:48,735 ProgressMeter -        Location |     sites | elapsed |     sites | completed | runtime |   runtime
# INFO  16:29:48,771 StrandBiasTest - SAM/BAM data was found. Attempting to use read data to calculate strand bias annotations values.
# INFO  16:29:48,771 StrandBiasTest - SAM/BAM data was found. Attempting to use read data to calculate strand bias annotations values.
# INFO  16:29:51,735 ProgressMeter -            done      1012.0     3.0 s      49.4 m       98.8%     3.0 s       0.0 s
# INFO  16:29:51,735 ProgressMeter - Total runtime 3.00 secs, 0.05 min, 0.00 hours
# INFO  16:29:51,736 MicroScheduler - 0 reads were filtered out during the traversal out of approximately 272 total reads (0.00%)
# INFO  16:29:51,736 MicroScheduler -   -> 0 reads (0.00% of total) failing BadCigarFilter
# INFO  16:29:51,736 MicroScheduler -   -> 0 reads (0.00% of total) failing BadMateFilter
# INFO  16:29:51,736 MicroScheduler -   -> 0 reads (0.00% of total) failing DuplicateReadFilter
# INFO  16:29:51,736 MicroScheduler -   -> 0 reads (0.00% of total) failing FailsVendorQualityCheckFilter
# INFO  16:29:51,736 MicroScheduler -   -> 0 reads (0.00% of total) failing MalformedReadFilter
# INFO  16:29:51,737 MicroScheduler -   -> 0 reads (0.00% of total) failing MappingQualityUnavailableFilter
# INFO  16:29:51,737 MicroScheduler -   -> 0 reads (0.00% of total) failing NotPrimaryAlignmentFilter
# INFO  16:29:51,737 MicroScheduler -   -> 0 reads (0.00% of total) failing UnmappedReadFilter
# INFO  16:29:52,954 GATKRunReport - Uploaded run statistics report to AWS S3
# GATC 1
# java -jar /Users/rpearson/src/github/malariagen/methods-dev/recon/opt/gatk/GenomeAnalysisTK.jar  -T UnifiedGenotyper  -R /data/plasmodium/pfalciparum/recon/roamato/Pf3D7_v3/3D7_sorted.fa  -I /data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA/gatc_bams.1.list  -L Pf3D7_13_v3:1724943-1725954  -ploidy 1  -stand_call_conf 0  -stand_emit_conf 0  --min_base_quality_score 40  -o /data/plasmodium/pfalciparum/recon/data/processed/capillary/variants/GATC_less_DNA/gatc_capillary.1.vcf
# INFO  16:29:54,653 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:29:54,656 HelpFormatter - The Genome Analysis Toolkit (GATK) v3.4-0-g7e26428, Compiled 2015/05/15 03:25:41
# INFO  16:29:54,656 HelpFormatter - Copyright (c) 2010 The Broad Institute
# INFO  16:29:54,656 HelpFormatter - For support and documentation go to http://www.broadinstitute.org/gatk
# INFO  16:29:54,660 HelpFormatter - Program Args: -T UnifiedGenotyper -R /data/plasmodium/pfalciparum/recon/roamato/Pf3D7_v3/3D7_sorted.fa -I /data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA/gatc_bams.1.list -L Pf3D7_13_v3:1724943-1725954 -ploidy 1 -stand_call_conf 0 -stand_emit_conf 0 --min_base_quality_score 40 -o /data/plasmodium/pfalciparum/recon/data/processed/capillary/variants/GATC_less_DNA/gatc_capillary.1.vcf
# INFO  16:29:54,668 HelpFormatter - Executing as rpearson@dhcp215.well.ox.ac.uk on Mac OS X 10.10.3 x86_64; Java HotSpot(TM) 64-Bit Server VM 1.7.0_60-b19.
# INFO  16:29:54,668 HelpFormatter - Date/Time: 2015/07/10 16:29:54
# INFO  16:29:54,668 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:29:54,668 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:29:55,177 GenomeAnalysisEngine - Strictness is SILENT
# INFO  16:29:55,277 GenomeAnalysisEngine - Downsampling Settings: Method: BY_SAMPLE, Target Coverage: 250
# INFO  16:29:55,285 SAMDataSource$SAMReaders - Initializing SAMRecords in serial
# INFO  16:29:55,506 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.22 s, 50 of 282 in 0.22 s / 0.00 m (227.41 tasks/s).  232 remaining with est. completion in 1.02 s / 0.02 m
# INFO  16:29:55,633 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.13 s, 100 of 282 in 0.35 s / 0.01 m (287.87 tasks/s).  182 remaining with est. completion in 0.63 s / 0.01 m
# INFO  16:29:55,757 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.12 s, 150 of 282 in 0.47 s / 0.01 m (318.12 tasks/s).  132 remaining with est. completion in 0.41 s / 0.01 m
# INFO  16:29:55,880 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.12 s, 200 of 282 in 0.60 s / 0.01 m (336.13 tasks/s).  82 remaining with est. completion in 0.24 s / 0.00 m
# INFO  16:29:56,027 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.15 s, 250 of 282 in 0.74 s / 0.01 m (337.10 tasks/s).  32 remaining with est. completion in 0.09 s / 0.00 m
# INFO  16:29:56,083 SAMDataSource$SAMReaders - Done initializing BAM readers: total time 0.80
# INFO  16:29:56,190 IntervalUtils - Processing 1012 bp from intervals
# INFO  16:29:56,240 GenomeAnalysisEngine - Preparing for traversal over 282 BAM files
# INFO  16:29:56,387 GenomeAnalysisEngine - Done preparing for traversal
# INFO  16:29:56,387 ProgressMeter - [INITIALIZATION COMPLETE; STARTING PROCESSING]
# INFO  16:29:56,388 ProgressMeter -                 | processed |    time |    per 1M |           |   total | remaining
# INFO  16:29:56,388 ProgressMeter -        Location |     sites | elapsed |     sites | completed | runtime |   runtime
# INFO  16:29:56,418 StrandBiasTest - SAM/BAM data was found. Attempting to use read data to calculate strand bias annotations values.
# INFO  16:29:56,418 StrandBiasTest - SAM/BAM data was found. Attempting to use read data to calculate strand bias annotations values.
# INFO  16:29:59,072 ProgressMeter -            done      1012.0     2.0 s      44.2 m       98.8%     2.0 s       0.0 s
# INFO  16:29:59,072 ProgressMeter - Total runtime 2.68 secs, 0.04 min, 0.00 hours
# INFO  16:29:59,073 MicroScheduler - 0 reads were filtered out during the traversal out of approximately 272 total reads (0.00%)
# INFO  16:29:59,073 MicroScheduler -   -> 0 reads (0.00% of total) failing BadCigarFilter
# INFO  16:29:59,073 MicroScheduler -   -> 0 reads (0.00% of total) failing BadMateFilter
# INFO  16:29:59,073 MicroScheduler -   -> 0 reads (0.00% of total) failing DuplicateReadFilter
# INFO  16:29:59,073 MicroScheduler -   -> 0 reads (0.00% of total) failing FailsVendorQualityCheckFilter
# INFO  16:29:59,074 MicroScheduler -   -> 0 reads (0.00% of total) failing MalformedReadFilter
# INFO  16:29:59,074 MicroScheduler -   -> 0 reads (0.00% of total) failing MappingQualityUnavailableFilter
# INFO  16:29:59,074 MicroScheduler -   -> 0 reads (0.00% of total) failing NotPrimaryAlignmentFilter
# INFO  16:29:59,074 MicroScheduler -   -> 0 reads (0.00% of total) failing UnmappedReadFilter
# INFO  16:30:00,133 GATKRunReport - Uploaded run statistics report to AWS S3
# GATC 2
# java -jar /Users/rpearson/src/github/malariagen/methods-dev/recon/opt/gatk/GenomeAnalysisTK.jar  -T UnifiedGenotyper  -R /data/plasmodium/pfalciparum/recon/roamato/Pf3D7_v3/3D7_sorted.fa  -I /data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA/gatc_bams.2.list  -L Pf3D7_13_v3:1724943-1725954  -ploidy 1  -stand_call_conf 0  -stand_emit_conf 0  --min_base_quality_score 40  -o /data/plasmodium/pfalciparum/recon/data/processed/capillary/variants/GATC_less_DNA/gatc_capillary.2.vcf
# INFO  16:30:01,733 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:30:01,735 HelpFormatter - The Genome Analysis Toolkit (GATK) v3.4-0-g7e26428, Compiled 2015/05/15 03:25:41
# INFO  16:30:01,735 HelpFormatter - Copyright (c) 2010 The Broad Institute
# INFO  16:30:01,735 HelpFormatter - For support and documentation go to http://www.broadinstitute.org/gatk
# INFO  16:30:01,738 HelpFormatter - Program Args: -T UnifiedGenotyper -R /data/plasmodium/pfalciparum/recon/roamato/Pf3D7_v3/3D7_sorted.fa -I /data/plasmodium/pfalciparum/recon/data/processed/capillary/bams/GATC_less_DNA/gatc_bams.2.list -L Pf3D7_13_v3:1724943-1725954 -ploidy 1 -stand_call_conf 0 -stand_emit_conf 0 --min_base_quality_score 40 -o /data/plasmodium/pfalciparum/recon/data/processed/capillary/variants/GATC_less_DNA/gatc_capillary.2.vcf
# INFO  16:30:01,744 HelpFormatter - Executing as rpearson@dhcp215.well.ox.ac.uk on Mac OS X 10.10.3 x86_64; Java HotSpot(TM) 64-Bit Server VM 1.7.0_60-b19.
# INFO  16:30:01,744 HelpFormatter - Date/Time: 2015/07/10 16:30:01
# INFO  16:30:01,745 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:30:01,745 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:30:02,152 GenomeAnalysisEngine - Strictness is SILENT
# INFO  16:30:02,243 GenomeAnalysisEngine - Downsampling Settings: Method: BY_SAMPLE, Target Coverage: 250
# INFO  16:30:02,249 SAMDataSource$SAMReaders - Initializing SAMRecords in serial
# INFO  16:30:02,447 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.20 s, 50 of 282 in 0.20 s / 0.00 m (254.04 tasks/s).  232 remaining with est. completion in 0.91 s / 0.02 m
# INFO  16:30:02,571 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.12 s, 100 of 282 in 0.32 s / 0.01 m (311.05 tasks/s).  182 remaining with est. completion in 0.59 s / 0.01 m
# INFO  16:30:02,690 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.12 s, 150 of 282 in 0.44 s / 0.01 m (340.65 tasks/s).  132 remaining with est. completion in 0.39 s / 0.01 m
# INFO  16:30:02,817 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.13 s, 200 of 282 in 0.57 s / 0.01 m (352.17 tasks/s).  82 remaining with est. completion in 0.23 s / 0.00 m
# INFO  16:30:02,948 SAMDataSource$SAMReaders - Init 50 BAMs in last 0.13 s, 250 of 282 in 0.70 s / 0.01 m (358.21 tasks/s).  32 remaining with est. completion in 0.09 s / 0.00 m
# INFO  16:30:03,009 SAMDataSource$SAMReaders - Done initializing BAM readers: total time 0.76
# INFO  16:30:03,135 IntervalUtils - Processing 1012 bp from intervals
# INFO  16:30:03,190 GenomeAnalysisEngine - Preparing for traversal over 282 BAM files
# INFO  16:30:03,340 GenomeAnalysisEngine - Done preparing for traversal
# INFO  16:30:03,340 ProgressMeter - [INITIALIZATION COMPLETE; STARTING PROCESSING]
# INFO  16:30:03,341 ProgressMeter -                 | processed |    time |    per 1M |           |   total | remaining
# INFO  16:30:03,341 ProgressMeter -        Location |     sites | elapsed |     sites | completed | runtime |   runtime
# INFO  16:30:03,371 StrandBiasTest - SAM/BAM data was found. Attempting to use read data to calculate strand bias annotations values.
# INFO  16:30:03,371 StrandBiasTest - SAM/BAM data was found. Attempting to use read data to calculate strand bias annotations values.
# INFO  16:30:06,021 ProgressMeter -            done      1012.0     2.0 s      44.1 m       98.8%     2.0 s       0.0 s
# INFO  16:30:06,021 ProgressMeter - Total runtime 2.68 secs, 0.04 min, 0.00 hours
# INFO  16:30:06,022 MicroScheduler - 0 reads were filtered out during the traversal out of approximately 272 total reads (0.00%)
# INFO  16:30:06,022 MicroScheduler -   -> 0 reads (0.00% of total) failing BadCigarFilter
# INFO  16:30:06,022 MicroScheduler -   -> 0 reads (0.00% of total) failing BadMateFilter
# INFO  16:30:06,022 MicroScheduler -   -> 0 reads (0.00% of total) failing DuplicateReadFilter
# INFO  16:30:06,023 MicroScheduler -   -> 0 reads (0.00% of total) failing FailsVendorQualityCheckFilter
# INFO  16:30:06,023 MicroScheduler -   -> 0 reads (0.00% of total) failing MalformedReadFilter
# INFO  16:30:06,023 MicroScheduler -   -> 0 reads (0.00% of total) failing MappingQualityUnavailableFilter
# INFO  16:30:06,024 MicroScheduler -   -> 0 reads (0.00% of total) failing NotPrimaryAlignmentFilter
# INFO  16:30:06,024 MicroScheduler -   -> 0 reads (0.00% of total) failing UnmappedReadFilter
# INFO  16:30:07,147 GATKRunReport - Uploaded run statistics report to AWS S3

# %% [markdown]
# # Create table of capillary calls

# %%
wb = openpyxl.Workbook(optimized_write=True, encoding=locale.getpreferredencoding())

tbl_capillary_calls = collections.OrderedDict()
for callset in ['GATC']:
    tbl_capillary_calls[callset] = collections.OrderedDict()
    for bad_qual_distance in [2, 1, 0, None]:
        tbl_capillary_calls[callset][str(bad_qual_distance)] = (etl
            .fromvcf(calling_runs[callset][1] % bad_qual_distance)
            .vcfmeltsamples()
            .vcfunpackcall()
            .cut(['CHROM', 'POS', 'REF', 'ALT', 'SAMPLE', 'GT'])
            .addfield('variant', lambda rec: "%s__%s__%s__%s" % (rec['CHROM'], rec['POS'], rec['REF'], rec['ALT']))
            .pivot('variant', 'SAMPLE', 'GT', max)
        )
        print(callset, bad_qual_distance)
        ws = wb.create_sheet(title="%s_%s" % (callset, str(bad_qual_distance)))
        for row in tbl_capillary_calls[callset][str(bad_qual_distance)]:
            ws.append(row)
        tbl_capillary_calls[callset][str(bad_qual_distance)].displayall()

wb.save(CAPILLARY_CALLS_EXCEL_FN)
# Out:
# GATC 2
# <table class='petl'>
# <thead>
# <tr>
# <th>variant</th>
# <th>PD0004-C_ForwardRep_GATC</th>
# <th>PD0004-C_Forward_GATC</th>
# <th>PD0004-C_Reverse_GATC</th>
# <th>PD0005-01_ForwardRep_GATC</th>
# <th>PD0005-01_Forward_GATC</th>
# <th>PD0005-01_Reverse_GATC</th>
# <th>PD0005-C_ForwardRep_GATC</th>
# <th>PD0005-C_Forward_GATC</th>
# <th>PD0005-C_Reverse_GATC</th>
# <th>PD0016-C_ForwardRep_GATC</th>
# <th>PD0016-C_Forward_GATC</th>
# <th>PD0016-C_Reverse_GATC</th>
# <th>PD0031-C_ForwardRep_GATC</th>
# <th>PD0031-C_Forward_GATC</th>
# <th>PD0031-C_Reverse_GATC</th>
# <th>PD0033-C_ForwardRep_GATC</th>
# <th>PD0033-C_Forward_GATC</th>
# <th>PD0033-C_Reverse_GATC</th>
# <th>PD0037-C_ForwardRep_GATC</th>
# <th>PD0037-C_Forward_GATC</th>
# <th>PD0037-C_Reverse_GATC</th>
# <th>PD0038-C_ForwardRep_GATC</th>
# <th>PD0038-C_Forward_GATC</th>
# <th>PD0038-C_Reverse_GATC</th>
# <th>PD0048-C_ForwardRep_GATC</th>
# <th>PD0048-C_Forward_GATC</th>
# <th>PD0048-C_Reverse_GATC</th>
# <th>PD0056-C_ForwardRep_GATC</th>
# <th>PD0056-C_Forward_GATC</th>
# <th>PD0056-C_Reverse_GATC</th>
# <th>PD0058-C_ForwardRep_GATC</th>
# <th>PD0058-C_Forward_GATC</th>
# <th>PD0058-C_Reverse_GATC</th>
# <th>PD0067-C_ForwardRep_GATC</th>
# <th>PD0067-C_Forward_GATC</th>
# <th>PD0067-C_Reverse_GATC</th>
# <th>PD0073-C_ForwardRep_GATC</th>
# <th>PD0073-C_Forward_GATC</th>
# <th>PD0073-C_Reverse_GATC</th>
# <th>PD0075-C_ForwardRep_GATC</th>
# <th>PD0075-C_Forward_GATC</th>
# <th>PD0075-C_Reverse_GATC</th>
# <th>PD0079-C_ForwardRep_GATC</th>
# <th>PD0079-C_Forward_GATC</th>
# <th>PD0079-C_Reverse_GATC</th>
# <th>PD0090-C_ForwardRep_GATC</th>
# <th>PD0090-C_Forward_GATC</th>
# <th>PD0090-C_Reverse_GATC</th>
# <th>PD0098-C_ForwardRep_GATC</th>
# <th>PD0098-C_Forward_GATC</th>
# <th>PD0098-C_Reverse_GATC</th>
# <th>PD0103-C_ForwardRep_GATC</th>
# <th>PD0103-C_Forward_GATC</th>
# <th>PD0103-C_Reverse_GATC</th>
# <th>PD0105-C_ForwardRep_GATC</th>
# <th>PD0105-C_Forward_GATC</th>
# <th>PD0105-C_Reverse_GATC</th>
# <th>PD0115-Cx_ForwardRep_GATC</th>
# <th>PD0115-Cx_Forward_GATC</th>
# <th>PD0115-Cx_Reverse_GATC</th>
# <th>PD0126-C_ForwardRep_GATC</th>
# <th>PD0126-C_Forward_GATC</th>
# <th>PD0126-C_Reverse_GATC</th>
# <th>PD0134-C_ForwardRep_GATC</th>
# <th>PD0134-C_Forward_GATC</th>
# <th>PD0134-C_Reverse_GATC</th>
# <th>PD0135-C_ForwardRep_GATC</th>
# <th>PD0135-C_Forward_GATC</th>
# <th>PD0135-C_Reverse_GATC</th>
# <th>PD0136-C_ForwardRep_GATC</th>
# <th>PD0136-C_Forward_GATC</th>
# <th>PD0136-C_Reverse_GATC</th>
# <th>PD0137-C_ForwardRep_GATC</th>
# <th>PD0137-C_Forward_GATC</th>
# <th>PD0137-C_Reverse_GATC</th>
# <th>PD0459-Cx_ForwardRep_GATC</th>
# <th>PD0459-Cx_Forward_GATC</th>
# <th>PD0459-Cx_Reverse_GATC</th>
# <th>PH0002-C_ForwardRep_GATC</th>
# <th>PH0002-C_Forward_GATC</th>
# <th>PH0002-C_Reverse_GATC</th>
# <th>PH0003-C_ForwardRep_GATC</th>
# <th>PH0003-C_Forward_GATC</th>
# <th>PH0003-C_Reverse_GATC</th>
# <th>PH0012-C_ForwardRep_GATC</th>
# <th>PH0012-C_Forward_GATC</th>
# <th>PH0012-C_Reverse_GATC</th>
# <th>PH0013-C_ForwardRep_GATC</th>
# <th>PH0013-C_Forward_GATC</th>
# <th>PH0013-C_Reverse_GATC</th>
# <th>PH0016-C_ForwardRep_GATC</th>
# <th>PH0016-C_Forward_GATC</th>
# <th>PH0016-C_Reverse_GATC</th>
# <th>PH0017-C_ForwardRep_GATC</th>
# <th>PH0017-C_Forward_GATC</th>
# <th>PH0017-C_Reverse_GATC</th>
# <th>PH0020-C_ForwardRep_GATC</th>
# <th>PH0020-C_Forward_GATC</th>
# <th>PH0020-C_Reverse_GATC</th>
# <th>PH0022-C_ForwardRep_GATC</th>
# <th>PH0022-C_Forward_GATC</th>
# <th>PH0022-C_Reverse_GATC</th>
# <th>PH0024-C_ForwardRep_GATC</th>
# <th>PH0024-C_Forward_GATC</th>
# <th>PH0024-C_Reverse_GATC</th>
# <th>PH0027-C_ForwardRep_GATC</th>
# <th>PH0027-C_Forward_GATC</th>
# <th>PH0027-C_Reverse_GATC</th>
# <th>PH0028-Cx_ForwardRep_GATC</th>
# <th>PH0028-Cx_Forward_GATC</th>
# <th>PH0028-Cx_Reverse_GATC</th>
# <th>PH0029-Cx_ForwardRep_GATC</th>
# <th>PH0029-Cx_Forward_GATC</th>
# <th>PH0029-Cx_Reverse_GATC</th>
# <th>PH0042-C_ForwardRep_GATC</th>
# <th>PH0042-C_Forward_GATC</th>
# <th>PH0042-C_Reverse_GATC</th>
# <th>PH0043-C_ForwardRep_GATC</th>
# <th>PH0043-C_Forward_GATC</th>
# <th>PH0043-C_Reverse_GATC</th>
# <th>PH0209-C_ForwardRep_GATC</th>
# <th>PH0209-C_Forward_GATC</th>
# <th>PH0209-C_Reverse_GATC</th>
# <th>PH0212-C_ForwardRep_GATC</th>
# <th>PH0212-C_Forward_GATC</th>
# <th>PH0212-C_Reverse_GATC</th>
# <th>PH0218-C_ForwardRep_GATC</th>
# <th>PH0218-C_Forward_GATC</th>
# <th>PH0218-C_Reverse_GATC</th>
# <th>PH0221-C_ForwardRep_GATC</th>
# <th>PH0221-C_Forward_GATC</th>
# <th>PH0221-C_Reverse_GATC</th>
# <th>PH0224-C_ForwardRep_GATC</th>
# <th>PH0224-C_Forward_GATC</th>
# <th>PH0224-C_Reverse_GATC</th>
# <th>PH0225-C_ForwardRep_GATC</th>
# <th>PH0225-C_Forward_GATC</th>
# <th>PH0225-C_Reverse_GATC</th>
# <th>PH0232-C_ForwardRep_GATC</th>
# <th>PH0232-C_Forward_GATC</th>
# <th>PH0232-C_Reverse_GATC</th>
# <th>PH0234-C_ForwardRep_GATC</th>
# <th>PH0234-C_Forward_GATC</th>
# <th>PH0234-C_Reverse_GATC</th>
# <th>PH0235-C_ForwardRep_GATC</th>
# <th>PH0235-C_Forward_GATC</th>
# <th>PH0235-C_Reverse_GATC</th>
# <th>PH0236-C_ForwardRep_GATC</th>
# <th>PH0236-C_Forward_GATC</th>
# <th>PH0236-C_Reverse_GATC</th>
# <th>PH0284-C_ForwardRep_GATC</th>
# <th>PH0284-C_Forward_GATC</th>
# <th>PH0284-C_Reverse_GATC</th>
# <th>PH0303-CW_ForwardRep_GATC</th>
# <th>PH0303-CW_Forward_GATC</th>
# <th>PH0303-CW_Reverse_GATC</th>
# <th>PH0326-C_ForwardRep_GATC</th>
# <th>PH0326-C_Forward_GATC</th>
# <th>PH0326-C_Reverse_GATC</th>
# <th>PH0337-C_ForwardRep_GATC</th>
# <th>PH0337-C_Forward_GATC</th>
# <th>PH0337-C_Reverse_GATC</th>
# <th>PH0349-C_ForwardRep_GATC</th>
# <th>PH0349-C_Forward_GATC</th>
# <th>PH0349-C_Reverse_GATC</th>
# <th>PH0375-C_ForwardRep_GATC</th>
# <th>PH0375-C_Forward_GATC</th>
# <th>PH0375-C_Reverse_GATC</th>
# <th>PH0456-C_ForwardRep_GATC</th>
# <th>PH0456-C_Forward_GATC</th>
# <th>PH0456-C_Reverse_GATC</th>
# <th>PH0457-CW_ForwardRep_GATC</th>
# <th>PH0457-CW_Forward_GATC</th>
# <th>PH0457-CW_Reverse_GATC</th>
# <th>PH0458-CW_ForwardRep_GATC</th>
# <th>PH0458-CW_Forward_GATC</th>
# <th>PH0458-CW_Reverse_GATC</th>
# <th>PH0460-C_ForwardRep_GATC</th>
# <th>PH0460-C_Forward_GATC</th>
# <th>PH0460-C_Reverse_GATC</th>
# <th>PH0462-C_ForwardRep_GATC</th>
# <th>PH0462-C_Forward_GATC</th>
# <th>PH0462-C_Reverse_GATC</th>
# <th>PH0463-C_ForwardRep_GATC</th>
# <th>PH0463-C_Forward_GATC</th>
# <th>PH0463-C_Reverse_GATC</th>
# <th>PH0464-CW_ForwardRep_GATC</th>
# <th>PH0464-CW_Forward_GATC</th>
# <th>PH0464-CW_Reverse_GATC</th>
# <th>PH0466-C_ForwardRep_GATC</th>
# <th>PH0466-C_Forward_GATC</th>
# <th>PH0466-C_Reverse_GATC</th>
# <th>PH0467-CW_ForwardRep_GATC</th>
# <th>PH0467-CW_Forward_GATC</th>
# <th>PH0467-CW_Reverse_GATC</th>
# <th>PH0468-C_ForwardRep_GATC</th>
# <th>PH0468-C_Forward_GATC</th>
# <th>PH0468-C_Reverse_GATC</th>
# <th>PH0474-CW_ForwardRep_GATC</th>
# <th>PH0474-CW_Forward_GATC</th>
# <th>PH0474-CW_Reverse_GATC</th>
# <th>PH0485-C_ForwardRep_GATC</th>
# <th>PH0485-C_Forward_GATC</th>
# <th>PH0485-C_Reverse_GATC</th>
# <th>PH0500-CW_ForwardRep_GATC</th>
# <th>PH0500-CW_Forward_GATC</th>
# <th>PH0500-CW_Reverse_GATC</th>
# <th>PH0501-CW_ForwardRep_GATC</th>
# <th>PH0501-CW_Forward_GATC</th>
# <th>PH0501-CW_Reverse_GATC</th>
# <th>PH0773-Cx_ForwardRep_GATC</th>
# <th>PH0773-Cx_Forward_GATC</th>
# <th>PH0773-Cx_Reverse_GATC</th>
# <th>PH0860-Cx_ForwardRep_GATC</th>
# <th>PH0860-Cx_Forward_GATC</th>
# <th>PH0860-Cx_Reverse_GATC</th>
# <th>PH0883-Cx_ForwardRep_GATC</th>
# <th>PH0883-Cx_Forward_GATC</th>
# <th>PH0883-Cx_Reverse_GATC</th>
# <th>PH0891-Cx_ForwardRep_GATC</th>
# <th>PH0891-Cx_Forward_GATC</th>
# <th>PH0891-Cx_Reverse_GATC</th>
# <th>PH0942-Cx_ForwardRep_GATC</th>
# <th>PH0942-Cx_Forward_GATC</th>
# <th>PH0942-Cx_Reverse_GATC</th>
# <th>PH0959-Cx_ForwardRep_GATC</th>
# <th>PH0959-Cx_Forward_GATC</th>
# <th>PH0959-Cx_Reverse_GATC</th>
# <th>PH0961-Cx_ForwardRep_GATC</th>
# <th>PH0961-Cx_Forward_GATC</th>
# <th>PH0961-Cx_Reverse_GATC</th>
# <th>PH0966-Cx_ForwardRep_GATC</th>
# <th>PH0966-Cx_Forward_GATC</th>
# <th>PH0966-Cx_Reverse_GATC</th>
# <th>PH0971-C_ForwardRep_GATC</th>
# <th>PH0971-C_Forward_GATC</th>
# <th>PH0971-C_Reverse_GATC</th>
# <th>PV0002-C_ForwardRep_GATC</th>
# <th>PV0002-C_Forward_GATC</th>
# <th>PV0002-C_Reverse_GATC</th>
# <th>PV0004-C_ForwardRep_GATC</th>
# <th>PV0004-C_Forward_GATC</th>
# <th>PV0004-C_Reverse_GATC</th>
# <th>PV0006-C_ForwardRep_GATC</th>
# <th>PV0006-C_Forward_GATC</th>
# <th>PV0006-C_Reverse_GATC</th>
# <th>PV0014-C_F
# GATC 1
# <table class='petl'>
# <thead>
# <tr>
# <th>variant</th>
# <th>PD0004-C_ForwardRep_GATC</th>
# <th>PD0004-C_Forward_GATC</th>
# <th>PD0004-C_Reverse_GATC</th>
# <th>PD0005-01_ForwardRep_GATC</th>
# <th>PD0005-01_Forward_GATC</th>
# <th>PD0005-01_Reverse_GATC</th>
# <th>PD0005-C_ForwardRep_GATC</th>
# <th>PD0005-C_Forward_GATC</th>
# <th>PD0005-C_Reverse_GATC</th>
# <th>PD0016-C_ForwardRep_GATC</th>
# <th>PD0016-C_Forward_GATC</th>
# <th>PD0016-C_Reverse_GATC</th>
# <th>PD0031-C_ForwardRep_GATC</th>
# <th>PD0031-C_Forward_GATC</th>
# <th>PD0031-C_Reverse_GATC</th>
# <th>PD0033-C_ForwardRep_GATC</th>
# <th>PD0033-C_Forward_GATC</th>
# <th>PD0033-C_Reverse_GATC</th>
# <th>PD0037-C_ForwardRep_GATC</th>
# <th>PD0037-C_Forward_GATC</th>
# <th>PD0037-C_Reverse_GATC</th>
# <th>PD0038-C_ForwardRep_GATC</th>
# <th>PD0038-C_Forward_GATC</th>
# <th>PD0038-C_Reverse_GATC</th>
# <th>PD0048-C_ForwardRep_GATC</th>
# <th>PD0048-C_Forward_GATC</th>
# <th>PD0048-C_Reverse_GATC</th>
# <th>PD0056-C_ForwardRep_GATC</th>
# <th>PD0056-C_Forward_GATC</th>
# <th>PD0056-C_Reverse_GATC</th>
# <th>PD0058-C_ForwardRep_GATC</th>
# <th>PD0058-C_Forward_GATC</th>
# <th>PD0058-C_Reverse_GATC</th>
# <th>PD0067-C_ForwardRep_GATC</th>
# <th>PD0067-C_Forward_GATC</th>
# <th>PD0067-C_Reverse_GATC</th>
# <th>PD0073-C_ForwardRep_GATC</th>
# <th>PD0073-C_Forward_GATC</th>
# <th>PD0073-C_Reverse_GATC</th>
# <th>PD0075-C_ForwardRep_GATC</th>
# <th>PD0075-C_Forward_GATC</th>
# <th>PD0075-C_Reverse_GATC</th>
# <th>PD0079-C_ForwardRep_GATC</th>
# <th>PD0079-C_Forward_GATC</th>
# <th>PD0079-C_Reverse_GATC</th>
# <th>PD0090-C_ForwardRep_GATC</th>
# <th>PD0090-C_Forward_GATC</th>
# <th>PD0090-C_Reverse_GATC</th>
# <th>PD0098-C_ForwardRep_GATC</th>
# <th>PD0098-C_Forward_GATC</th>
# <th>PD0098-C_Reverse_GATC</th>
# <th>PD0103-C_ForwardRep_GATC</th>
# <th>PD0103-C_Forward_GATC</th>
# <th>PD0103-C_Reverse_GATC</th>
# <th>PD0105-C_ForwardRep_GATC</th>
# <th>PD0105-C_Forward_GATC</th>
# <th>PD0105-C_Reverse_GATC</th>
# <th>PD0115-Cx_ForwardRep_GATC</th>
# <th>PD0115-Cx_Forward_GATC</th>
# <th>PD0115-Cx_Reverse_GATC</th>
# <th>PD0126-C_ForwardRep_GATC</th>
# <th>PD0126-C_Forward_GATC</th>
# <th>PD0126-C_Reverse_GATC</th>
# <th>PD0134-C_ForwardRep_GATC</th>
# <th>PD0134-C_Forward_GATC</th>
# <th>PD0134-C_Reverse_GATC</th>
# <th>PD0135-C_ForwardRep_GATC</th>
# <th>PD0135-C_Forward_GATC</th>
# <th>PD0135-C_Reverse_GATC</th>
# <th>PD0136-C_ForwardRep_GATC</th>
# <th>PD0136-C_Forward_GATC</th>
# <th>PD0136-C_Reverse_GATC</th>
# <th>PD0137-C_ForwardRep_GATC</th>
# <th>PD0137-C_Forward_GATC</th>
# <th>PD0137-C_Reverse_GATC</th>
# <th>PD0459-Cx_ForwardRep_GATC</th>
# <th>PD0459-Cx_Forward_GATC</th>
# <th>PD0459-Cx_Reverse_GATC</th>
# <th>PH0002-C_ForwardRep_GATC</th>
# <th>PH0002-C_Forward_GATC</th>
# <th>PH0002-C_Reverse_GATC</th>
# <th>PH0003-C_ForwardRep_GATC</th>
# <th>PH0003-C_Forward_GATC</th>
# <th>PH0003-C_Reverse_GATC</th>
# <th>PH0012-C_ForwardRep_GATC</th>
# <th>PH0012-C_Forward_GATC</th>
# <th>PH0012-C_Reverse_GATC</th>
# <th>PH0013-C_ForwardRep_GATC</th>
# <th>PH0013-C_Forward_GATC</th>
# <th>PH0013-C_Reverse_GATC</th>
# <th>PH0016-C_ForwardRep_GATC</th>
# <th>PH0016-C_Forward_GATC</th>
# <th>PH0016-C_Reverse_GATC</th>
# <th>PH0017-C_ForwardRep_GATC</th>
# <th>PH0017-C_Forward_GATC</th>
# <th>PH0017-C_Reverse_GATC</th>
# <th>PH0020-C_ForwardRep_GATC</th>
# <th>PH0020-C_Forward_GATC</th>
# <th>PH0020-C_Reverse_GATC</th>
# <th>PH0022-C_ForwardRep_GATC</th>
# <th>PH0022-C_Forward_GATC</th>
# <th>PH0022-C_Reverse_GATC</th>
# <th>PH0024-C_ForwardRep_GATC</th>
# <th>PH0024-C_Forward_GATC</th>
# <th>PH0024-C_Reverse_GATC</th>
# <th>PH0027-C_ForwardRep_GATC</th>
# <th>PH0027-C_Forward_GATC</th>
# <th>PH0027-C_Reverse_GATC</th>
# <th>PH0028-Cx_ForwardRep_GATC</th>
# <th>PH0028-Cx_Forward_GATC</th>
# <th>PH0028-Cx_Reverse_GATC</th>
# <th>PH0029-Cx_ForwardRep_GATC</th>
# <th>PH0029-Cx_Forward_GATC</th>
# <th>PH0029-Cx_Reverse_GATC</th>
# <th>PH0042-C_ForwardRep_GATC</th>
# <th>PH0042-C_Forward_GATC</th>
# <th>PH0042-C_Reverse_GATC</th>
# <th>PH0043-C_ForwardRep_GATC</th>
# <th>PH0043-C_Forward_GATC</th>
# <th>PH0043-C_Reverse_GATC</th>
# <th>PH0209-C_ForwardRep_GATC</th>
# <th>PH0209-C_Forward_GATC</th>
# <th>PH0209-C_Reverse_GATC</th>
# <th>PH0212-C_ForwardRep_GATC</th>
# <th>PH0212-C_Forward_GATC</th>
# <th>PH0212-C_Reverse_GATC</th>
# <th>PH0218-C_ForwardRep_GATC</th>
# <th>PH0218-C_Forward_GATC</th>
# <th>PH0218-C_Reverse_GATC</th>
# <th>PH0221-C_ForwardRep_GATC</th>
# <th>PH0221-C_Forward_GATC</th>
# <th>PH0221-C_Reverse_GATC</th>
# <th>PH0224-C_ForwardRep_GATC</th>
# <th>PH0224-C_Forward_GATC</th>
# <th>PH0224-C_Reverse_GATC</th>
# <th>PH0225-C_ForwardRep_GATC</th>
# <th>PH0225-C_Forward_GATC</th>
# <th>PH0225-C_Reverse_GATC</th>
# <th>PH0232-C_ForwardRep_GATC</th>
# <th>PH0232-C_Forward_GATC</th>
# <th>PH0232-C_Reverse_GATC</th>
# <th>PH0234-C_ForwardRep_GATC</th>
# <th>PH0234-C_Forward_GATC</th>
# <th>PH0234-C_Reverse_GATC</th>
# <th>PH0235-C_ForwardRep_GATC</th>
# <th>PH0235-C_Forward_GATC</th>
# <th>PH0235-C_Reverse_GATC</th>
# <th>PH0236-C_ForwardRep_GATC</th>
# <th>PH0236-C_Forward_GATC</th>
# <th>PH0236-C_Reverse_GATC</th>
# <th>PH0284-C_ForwardRep_GATC</th>
# <th>PH0284-C_Forward_GATC</th>
# <th>PH0284-C_Reverse_GATC</th>
# <th>PH0303-CW_ForwardRep_GATC</th>
# <th>PH0303-CW_Forward_GATC</th>
# <th>PH0303-CW_Reverse_GATC</th>
# <th>PH0326-C_ForwardRep_GATC</th>
# <th>PH0326-C_Forward_GATC</th>
# <th>PH0326-C_Reverse_GATC</th>
# <th>PH0337-C_ForwardRep_GATC</th>
# <th>PH0337-C_Forward_GATC</th>
# <th>PH0337-C_Reverse_GATC</th>
# <th>PH0349-C_ForwardRep_GATC</th>
# <th>PH0349-C_Forward_GATC</th>
# <th>PH0349-C_Reverse_GATC</th>
# <th>PH0375-C_ForwardRep_GATC</th>
# <th>PH0375-C_Forward_GATC</th>
# <th>PH0375-C_Reverse_GATC</th>
# <th>PH0456-C_ForwardRep_GATC</th>
# <th>PH0456-C_Forward_GATC</th>
# <th>PH0456-C_Reverse_GATC</th>
# <th>PH0457-CW_ForwardRep_GATC</th>
# <th>PH0457-CW_Forward_GATC</th>
# <th>PH0457-CW_Reverse_GATC</th>
# <th>PH0458-CW_ForwardRep_GATC</th>
# <th>PH0458-CW_Forward_GATC</th>
# <th>PH0458-CW_Reverse_GATC</th>
# <th>PH0460-C_ForwardRep_GATC</th>
# <th>PH0460-C_Forward_GATC</th>
# <th>PH0460-C_Reverse_GATC</th>
# <th>PH0462-C_ForwardRep_GATC</th>
# <th>PH0462-C_Forward_GATC</th>
# <th>PH0462-C_Reverse_GATC</th>
# <th>PH0463-C_ForwardRep_GATC</th>
# <th>PH0463-C_Forward_GATC</th>
# <th>PH0463-C_Reverse_GATC</th>
# <th>PH0464-CW_ForwardRep_GATC</th>
# <th>PH0464-CW_Forward_GATC</th>
# <th>PH0464-CW_Reverse_GATC</th>
# <th>PH0466-C_ForwardRep_GATC</th>
# <th>PH0466-C_Forward_GATC</th>
# <th>PH0466-C_Reverse_GATC</th>
# <th>PH0467-CW_ForwardRep_GATC</th>
# <th>PH0467-CW_Forward_GATC</th>
# <th>PH0467-CW_Reverse_GATC</th>
# <th>PH0468-C_ForwardRep_GATC</th>
# <th>PH0468-C_Forward_GATC</th>
# <th>PH0468-C_Reverse_GATC</th>
# <th>PH0474-CW_ForwardRep_GATC</th>
# <th>PH0474-CW_Forward_GATC</th>
# <th>PH0474-CW_Reverse_GATC</th>
# <th>PH0485-C_ForwardRep_GATC</th>
# <th>PH0485-C_Forward_GATC</th>
# <th>PH0485-C_Reverse_GATC</th>
# <th>PH0500-CW_ForwardRep_GATC</th>
# <th>PH0500-CW_Forward_GATC</th>
# <th>PH0500-CW_Reverse_GATC</th>
# <th>PH0501-CW_ForwardRep_GATC</th>
# <th>PH0501-CW_Forward_GATC</th>
# <th>PH0501-CW_Reverse_GATC</th>
# <th>PH0773-Cx_ForwardRep_GATC</th>
# <th>PH0773-Cx_Forward_GATC</th>
# <th>PH0773-Cx_Reverse_GATC</th>
# <th>PH0860-Cx_ForwardRep_GATC</th>
# <th>PH0860-Cx_Forward_GATC</th>
# <th>PH0860-Cx_Reverse_GATC</th>
# <th>PH0883-Cx_ForwardRep_GATC</th>
# <th>PH0883-Cx_Forward_GATC</th>
# <th>PH0883-Cx_Reverse_GATC</th>
# <th>PH0891-Cx_ForwardRep_GATC</th>
# <th>PH0891-Cx_Forward_GATC</th>
# <th>PH0891-Cx_Reverse_GATC</th>
# <th>PH0942-Cx_ForwardRep_GATC</th>
# <th>PH0942-Cx_Forward_GATC</th>
# <th>PH0942-Cx_Reverse_GATC</th>
# <th>PH0959-Cx_ForwardRep_GATC</th>
# <th>PH0959-Cx_Forward_GATC</th>
# <th>PH0959-Cx_Reverse_GATC</th>
# <th>PH0961-Cx_ForwardRep_GATC</th>
# <th>PH0961-Cx_Forward_GATC</th>
# <th>PH0961-Cx_Reverse_GATC</th>
# <th>PH0966-Cx_ForwardRep_GATC</th>
# <th>PH0966-Cx_Forward_GATC</th>
# <th>PH0966-Cx_Reverse_GATC</th>
# <th>PH0971-C_ForwardRep_GATC</th>
# <th>PH0971-C_Forward_GATC</th>
# <th>PH0971-C_Reverse_GATC</th>
# <th>PV0002-C_ForwardRep_GATC</th>
# <th>PV0002-C_Forward_GATC</th>
# <th>PV0002-C_Reverse_GATC</th>
# <th>PV0004-C_ForwardRep_GATC</th>
# <th>PV0004-C_Forward_GATC</th>
# <th>PV0004-C_Reverse_GATC</th>
# <th>PV0006-C_ForwardRep_GATC</th>
# <th>PV0006-C_Forward_GATC</th>
# <th>PV0006-C_Reverse_GATC</th>
# <th>PV0014-C_F
# GATC 0
# <table class='petl'>
# <thead>
# <tr>
# <th>variant</th>
# <th>PD0004-C_ForwardRep_GATC</th>
# <th>PD0004-C_Forward_GATC</th>
# <th>PD0004-C_Reverse_GATC</th>
# <th>PD0005-01_ForwardRep_GATC</th>
# <th>PD0005-01_Forward_GATC</th>
# <th>PD0005-01_Reverse_GATC</th>
# <th>PD0005-C_ForwardRep_GATC</th>
# <th>PD0005-C_Forward_GATC</th>
# <th>PD0005-C_Reverse_GATC</th>
# <th>PD0016-C_ForwardRep_GATC</th>
# <th>PD0016-C_Forward_GATC</th>
# <th>PD0016-C_Reverse_GATC</th>
# <th>PD0031-C_ForwardRep_GATC</th>
# <th>PD0031-C_Forward_GATC</th>
# <th>PD0031-C_Reverse_GATC</th>
# <th>PD0033-C_ForwardRep_GATC</th>
# <th>PD0033-C_Forward_GATC</th>
# <th>PD0033-C_Reverse_GATC</th>
# <th>PD0037-C_ForwardRep_GATC</th>
# <th>PD0037-C_Forward_GATC</th>
# <th>PD0037-C_Reverse_GATC</th>
# <th>PD0038-C_ForwardRep_GATC</th>
# <th>PD0038-C_Forward_GATC</th>
# <th>PD0038-C_Reverse_GATC</th>
# <th>PD0048-C_ForwardRep_GATC</th>
# <th>PD0048-C_Forward_GATC</th>
# <th>PD0048-C_Reverse_GATC</th>
# <th>PD0056-C_ForwardRep_GATC</th>
# <th>PD0056-C_Forward_GATC</th>
# <th>PD0056-C_Reverse_GATC</th>
# <th>PD0058-C_ForwardRep_GATC</th>
# <th>PD0058-C_Forward_GATC</th>
# <th>PD0058-C_Reverse_GATC</th>
# <th>PD0067-C_ForwardRep_GATC</th>
# <th>PD0067-C_Forward_GATC</th>
# <th>PD0067-C_Reverse_GATC</th>
# <th>PD0073-C_ForwardRep_GATC</th>
# <th>PD0073-C_Forward_GATC</th>
# <th>PD0073-C_Reverse_GATC</th>
# <th>PD0075-C_ForwardRep_GATC</th>
# <th>PD0075-C_Forward_GATC</th>
# <th>PD0075-C_Reverse_GATC</th>
# <th>PD0079-C_ForwardRep_GATC</th>
# <th>PD0079-C_Forward_GATC</th>
# <th>PD0079-C_Reverse_GATC</th>
# <th>PD0090-C_ForwardRep_GATC</th>
# <th>PD0090-C_Forward_GATC</th>
# <th>PD0090-C_Reverse_GATC</th>
# <th>PD0098-C_ForwardRep_GATC</th>
# <th>PD0098-C_Forward_GATC</th>
# <th>PD0098-C_Reverse_GATC</th>
# <th>PD0103-C_ForwardRep_GATC</th>
# <th>PD0103-C_Forward_GATC</th>
# <th>PD0103-C_Reverse_GATC</th>
# <th>PD0105-C_ForwardRep_GATC</th>
# <th>PD0105-C_Forward_GATC</th>
# <th>PD0105-C_Reverse_GATC</th>
# <th>PD0115-Cx_ForwardRep_GATC</th>
# <th>PD0115-Cx_Forward_GATC</th>
# <th>PD0115-Cx_Reverse_GATC</th>
# <th>PD0126-C_ForwardRep_GATC</th>
# <th>PD0126-C_Forward_GATC</th>
# <th>PD0126-C_Reverse_GATC</th>
# <th>PD0134-C_ForwardRep_GATC</th>
# <th>PD0134-C_Forward_GATC</th>
# <th>PD0134-C_Reverse_GATC</th>
# <th>PD0135-C_ForwardRep_GATC</th>
# <th>PD0135-C_Forward_GATC</th>
# <th>PD0135-C_Reverse_GATC</th>
# <th>PD0136-C_ForwardRep_GATC</th>
# <th>PD0136-C_Forward_GATC</th>
# <th>PD0136-C_Reverse_GATC</th>
# <th>PD0137-C_ForwardRep_GATC</th>
# <th>PD0137-C_Forward_GATC</th>
# <th>PD0137-C_Reverse_GATC</th>
# <th>PD0459-Cx_ForwardRep_GATC</th>
# <th>PD0459-Cx_Forward_GATC</th>
# <th>PD0459-Cx_Reverse_GATC</th>
# <th>PH0002-C_ForwardRep_GATC</th>
# <th>PH0002-C_Forward_GATC</th>
# <th>PH0002-C_Reverse_GATC</th>
# <th>PH0003-C_ForwardRep_GATC</th>
# <th>PH0003-C_Forward_GATC</th>
# <th>PH0003-C_Reverse_GATC</th>
# <th>PH0012-C_ForwardRep_GATC</th>
# <th>PH0012-C_Forward_GATC</th>
# <th>PH0012-C_Reverse_GATC</th>
# <th>PH0013-C_ForwardRep_GATC</th>
# <th>PH0013-C_Forward_GATC</th>
# <th>PH0013-C_Reverse_GATC</th>
# <th>PH0016-C_ForwardRep_GATC</th>
# <th>PH0016-C_Forward_GATC</th>
# <th>PH0016-C_Reverse_GATC</th>
# <th>PH0017-C_ForwardRep_GATC</th>
# <th>PH0017-C_Forward_GATC</th>
# <th>PH0017-C_Reverse_GATC</th>
# <th>PH0020-C_ForwardRep_GATC</th>
# <th>PH0020-C_Forward_GATC</th>
# <th>PH0020-C_Reverse_GATC</th>
# <th>PH0022-C_ForwardRep_GATC</th>
# <th>PH0022-C_Forward_GATC</th>
# <th>PH0022-C_Reverse_GATC</th>
# <th>PH0024-C_ForwardRep_GATC</th>
# <th>PH0024-C_Forward_GATC</th>
# <th>PH0024-C_Reverse_GATC</th>
# <th>PH0027-C_ForwardRep_GATC</th>
# <th>PH0027-C_Forward_GATC</th>
# <th>PH0027-C_Reverse_GATC</th>
# <th>PH0028-Cx_ForwardRep_GATC</th>
# <th>PH0028-Cx_Forward_GATC</th>
# <th>PH0028-Cx_Reverse_GATC</th>
# <th>PH0029-Cx_ForwardRep_GATC</th>
# <th>PH0029-Cx_Forward_GATC</th>
# <th>PH0029-Cx_Reverse_GATC</th>
# <th>PH0042-C_ForwardRep_GATC</th>
# <th>PH0042-C_Forward_GATC</th>
# <th>PH0042-C_Reverse_GATC</th>
# <th>PH0043-C_ForwardRep_GATC</th>
# <th>PH0043-C_Forward_GATC</th>
# <th>PH0043-C_Reverse_GATC</th>
# <th>PH0209-C_ForwardRep_GATC</th>
# <th>PH0209-C_Forward_GATC</th>
# <th>PH0209-C_Reverse_GATC</th>
# <th>PH0212-C_ForwardRep_GATC</th>
# <th>PH0212-C_Forward_GATC</th>
# <th>PH0212-C_Reverse_GATC</th>
# <th>PH0218-C_ForwardRep_GATC</th>
# <th>PH0218-C_Forward_GATC</th>
# <th>PH0218-C_Reverse_GATC</th>
# <th>PH0221-C_ForwardRep_GATC</th>
# <th>PH0221-C_Forward_GATC</th>
# <th>PH0221-C_Reverse_GATC</th>
# <th>PH0224-C_ForwardRep_GATC</th>
# <th>PH0224-C_Forward_GATC</th>
# <th>PH0224-C_Reverse_GATC</th>
# <th>PH0225-C_ForwardRep_GATC</th>
# <th>PH0225-C_Forward_GATC</th>
# <th>PH0225-C_Reverse_GATC</th>
# <th>PH0232-C_ForwardRep_GATC</th>
# <th>PH0232-C_Forward_GATC</th>
# <th>PH0232-C_Reverse_GATC</th>
# <th>PH0234-C_ForwardRep_GATC</th>
# <th>PH0234-C_Forward_GATC</th>
# <th>PH0234-C_Reverse_GATC</th>
# <th>PH0235-C_ForwardRep_GATC</th>
# <th>PH0235-C_Forward_GATC</th>
# <th>PH0235-C_Reverse_GATC</th>
# <th>PH0236-C_ForwardRep_GATC</th>
# <th>PH0236-C_Forward_GATC</th>
# <th>PH0236-C_Reverse_GATC</th>
# <th>PH0284-C_ForwardRep_GATC</th>
# <th>PH0284-C_Forward_GATC</th>
# <th>PH0284-C_Reverse_GATC</th>
# <th>PH0303-CW_ForwardRep_GATC</th>
# <th>PH0303-CW_Forward_GATC</th>
# <th>PH0303-CW_Reverse_GATC</th>
# <th>PH0326-C_ForwardRep_GATC</th>
# <th>PH0326-C_Forward_GATC</th>
# <th>PH0326-C_Reverse_GATC</th>
# <th>PH0337-C_ForwardRep_GATC</th>
# <th>PH0337-C_Forward_GATC</th>
# <th>PH0337-C_Reverse_GATC</th>
# <th>PH0349-C_ForwardRep_GATC</th>
# <th>PH0349-C_Forward_GATC</th>
# <th>PH0349-C_Reverse_GATC</th>
# <th>PH0375-C_ForwardRep_GATC</th>
# <th>PH0375-C_Forward_GATC</th>
# <th>PH0375-C_Reverse_GATC</th>
# <th>PH0456-C_ForwardRep_GATC</th>
# <th>PH0456-C_Forward_GATC</th>
# <th>PH0456-C_Reverse_GATC</th>
# <th>PH0457-CW_ForwardRep_GATC</th>
# <th>PH0457-CW_Forward_GATC</th>
# <th>PH0457-CW_Reverse_GATC</th>
# <th>PH0458-CW_ForwardRep_GATC</th>
# <th>PH0458-CW_Forward_GATC</th>
# <th>PH0458-CW_Reverse_GATC</th>
# <th>PH0460-C_ForwardRep_GATC</th>
# <th>PH0460-C_Forward_GATC</th>
# <th>PH0460-C_Reverse_GATC</th>
# <th>PH0462-C_ForwardRep_GATC</th>
# <th>PH0462-C_Forward_GATC</th>
# <th>PH0462-C_Reverse_GATC</th>
# <th>PH0463-C_ForwardRep_GATC</th>
# <th>PH0463-C_Forward_GATC</th>
# <th>PH0463-C_Reverse_GATC</th>
# <th>PH0464-CW_ForwardRep_GATC</th>
# <th>PH0464-CW_Forward_GATC</th>
# <th>PH0464-CW_Reverse_GATC</th>
# <th>PH0466-C_ForwardRep_GATC</th>
# <th>PH0466-C_Forward_GATC</th>
# <th>PH0466-C_Reverse_GATC</th>
# <th>PH0467-CW_ForwardRep_GATC</th>
# <th>PH0467-CW_Forward_GATC</th>
# <th>PH0467-CW_Reverse_GATC</th>
# <th>PH0468-C_ForwardRep_GATC</th>
# <th>PH0468-C_Forward_GATC</th>
# <th>PH0468-C_Reverse_GATC</th>
# <th>PH0474-CW_ForwardRep_GATC</th>
# <th>PH0474-CW_Forward_GATC</th>
# <th>PH0474-CW_Reverse_GATC</th>
# <th>PH0485-C_ForwardRep_GATC</th>
# <th>PH0485-C_Forward_GATC</th>
# <th>PH0485-C_Reverse_GATC</th>
# <th>PH0500-CW_ForwardRep_GATC</th>
# <th>PH0500-CW_Forward_GATC</th>
# <th>PH0500-CW_Reverse_GATC</th>
# <th>PH0501-CW_ForwardRep_GATC</th>
# <th>PH0501-CW_Forward_GATC</th>
# <th>PH0501-CW_Reverse_GATC</th>
# <th>PH0773-Cx_ForwardRep_GATC</th>
# <th>PH0773-Cx_Forward_GATC</th>
# <th>PH0773-Cx_Reverse_GATC</th>
# <th>PH0860-Cx_ForwardRep_GATC</th>
# <th>PH0860-Cx_Forward_GATC</th>
# <th>PH0860-Cx_Reverse_GATC</th>
# <th>PH0883-Cx_ForwardRep_GATC</th>
# <th>PH0883-Cx_Forward_GATC</th>
# <th>PH0883-Cx_Reverse_GATC</th>
# <th>PH0891-Cx_ForwardRep_GATC</th>
# <th>PH0891-Cx_Forward_GATC</th>
# <th>PH0891-Cx_Reverse_GATC</th>
# <th>PH0942-Cx_ForwardRep_GATC</th>
# <th>PH0942-Cx_Forward_GATC</th>
# <th>PH0942-Cx_Reverse_GATC</th>
# <th>PH0959-Cx_ForwardRep_GATC</th>
# <th>PH0959-Cx_Forward_GATC</th>
# <th>PH0959-Cx_Reverse_GATC</th>
# <th>PH0961-Cx_ForwardRep_GATC</th>
# <th>PH0961-Cx_Forward_GATC</th>
# <th>PH0961-Cx_Reverse_GATC</th>
# <th>PH0966-Cx_ForwardRep_GATC</th>
# <th>PH0966-Cx_Forward_GATC</th>
# <th>PH0966-Cx_Reverse_GATC</th>
# <th>PH0971-C_ForwardRep_GATC</th>
# <th>PH0971-C_Forward_GATC</th>
# <th>PH0971-C_Reverse_GATC</th>
# <th>PV0002-C_ForwardRep_GATC</th>
# <th>PV0002-C_Forward_GATC</th>
# <th>PV0002-C_Reverse_GATC</th>
# <th>PV0004-C_ForwardRep_GATC</th>
# <th>PV0004-C_Forward_GATC</th>
# <th>PV0004-C_Reverse_GATC</th>
# <th>PV0006-C_ForwardRep_GATC</th>
# <th>PV0006-C_Forward_GATC</th>
# <th>PV0006-C_Reverse_GATC</th>
# <th>PV0014-C_F
# GATC None
# <table class='petl'>
# <thead>
# <tr>
# <th>variant</th>
# <th>PD0004-C_ForwardRep_GATC</th>
# <th>PD0004-C_Forward_GATC</th>
# <th>PD0004-C_Reverse_GATC</th>
# <th>PD0005-01_ForwardRep_GATC</th>
# <th>PD0005-01_Forward_GATC</th>
# <th>PD0005-01_Reverse_GATC</th>
# <th>PD0005-C_ForwardRep_GATC</th>
# <th>PD0005-C_Forward_GATC</th>
# <th>PD0005-C_Reverse_GATC</th>
# <th>PD0016-C_ForwardRep_GATC</th>
# <th>PD0016-C_Forward_GATC</th>
# <th>PD0016-C_Reverse_GATC</th>
# <th>PD0031-C_ForwardRep_GATC</th>
# <th>PD0031-C_Forward_GATC</th>
# <th>PD0031-C_Reverse_GATC</th>
# <th>PD0033-C_ForwardRep_GATC</th>
# <th>PD0033-C_Forward_GATC</th>
# <th>PD0033-C_Reverse_GATC</th>
# <th>PD0037-C_ForwardRep_GATC</th>
# <th>PD0037-C_Forward_GATC</th>
# <th>PD0037-C_Reverse_GATC</th>
# <th>PD0038-C_ForwardRep_GATC</th>
# <th>PD0038-C_Forward_GATC</th>
# <th>PD0038-C_Reverse_GATC</th>
# <th>PD0048-C_ForwardRep_GATC</th>
# <th>PD0048-C_Forward_GATC</th>
# <th>PD0048-C_Reverse_GATC</th>
# <th>PD0056-C_ForwardRep_GATC</th>
# <th>PD0056-C_Forward_GATC</th>
# <th>PD0056-C_Reverse_GATC</th>
# <th>PD0058-C_ForwardRep_GATC</th>
# <th>PD0058-C_Forward_GATC</th>
# <th>PD0058-C_Reverse_GATC</th>
# <th>PD0067-C_ForwardRep_GATC</th>
# <th>PD0067-C_Forward_GATC</th>
# <th>PD0067-C_Reverse_GATC</th>
# <th>PD0073-C_ForwardRep_GATC</th>
# <th>PD0073-C_Forward_GATC</th>
# <th>PD0073-C_Reverse_GATC</th>
# <th>PD0075-C_ForwardRep_GATC</th>
# <th>PD0075-C_Forward_GATC</th>
# <th>PD0075-C_Reverse_GATC</th>
# <th>PD0079-C_ForwardRep_GATC</th>
# <th>PD0079-C_Forward_GATC</th>
# <th>PD0079-C_Reverse_GATC</th>
# <th>PD0090-C_ForwardRep_GATC</th>
# <th>PD0090-C_Forward_GATC</th>
# <th>PD0090-C_Reverse_GATC</th>
# <th>PD0098-C_ForwardRep_GATC</th>
# <th>PD0098-C_Forward_GATC</th>
# <th>PD0098-C_Reverse_GATC</th>
# <th>PD0103-C_ForwardRep_GATC</th>
# <th>PD0103-C_Forward_GATC</th>
# <th>PD0103-C_Reverse_GATC</th>
# <th>PD0105-C_ForwardRep_GATC</th>
# <th>PD0105-C_Forward_GATC</th>
# <th>PD0105-C_Reverse_GATC</th>
# <th>PD0115-Cx_ForwardRep_GATC</th>
# <th>PD0115-Cx_Forward_GATC</th>
# <th>PD0115-Cx_Reverse_GATC</th>
# <th>PD0126-C_ForwardRep_GATC</th>
# <th>PD0126-C_Forward_GATC</th>
# <th>PD0126-C_Reverse_GATC</th>
# <th>PD0134-C_ForwardRep_GATC</th>
# <th>PD0134-C_Forward_GATC</th>
# <th>PD0134-C_Reverse_GATC</th>
# <th>PD0135-C_ForwardRep_GATC</th>
# <th>PD0135-C_Forward_GATC</th>
# <th>PD0135-C_Reverse_GATC</th>
# <th>PD0136-C_ForwardRep_GATC</th>
# <th>PD0136-C_Forward_GATC</th>
# <th>PD0136-C_Reverse_GATC</th>
# <th>PD0137-C_ForwardRep_GATC</th>
# <th>PD0137-C_Forward_GATC</th>
# <th>PD0137-C_Reverse_GATC</th>
# <th>PD0459-Cx_ForwardRep_GATC</th>
# <th>PD0459-Cx_Forward_GATC</th>
# <th>PD0459-Cx_Reverse_GATC</th>
# <th>PH0002-C_ForwardRep_GATC</th>
# <th>PH0002-C_Forward_GATC</th>
# <th>PH0002-C_Reverse_GATC</th>
# <th>PH0003-C_ForwardRep_GATC</th>
# <th>PH0003-C_Forward_GATC</th>
# <th>PH0003-C_Reverse_GATC</th>
# <th>PH0012-C_ForwardRep_GATC</th>
# <th>PH0012-C_Forward_GATC</th>
# <th>PH0012-C_Reverse_GATC</th>
# <th>PH0013-C_ForwardRep_GATC</th>
# <th>PH0013-C_Forward_GATC</th>
# <th>PH0013-C_Reverse_GATC</th>
# <th>PH0016-C_ForwardRep_GATC</th>
# <th>PH0016-C_Forward_GATC</th>
# <th>PH0016-C_Reverse_GATC</th>
# <th>PH0017-C_ForwardRep_GATC</th>
# <th>PH0017-C_Forward_GATC</th>
# <th>PH0017-C_Reverse_GATC</th>
# <th>PH0020-C_ForwardRep_GATC</th>
# <th>PH0020-C_Forward_GATC</th>
# <th>PH0020-C_Reverse_GATC</th>
# <th>PH0022-C_ForwardRep_GATC</th>
# <th>PH0022-C_Forward_GATC</th>
# <th>PH0022-C_Reverse_GATC</th>
# <th>PH0024-C_ForwardRep_GATC</th>
# <th>PH0024-C_Forward_GATC</th>
# <th>PH0024-C_Reverse_GATC</th>
# <th>PH0027-C_ForwardRep_GATC</th>
# <th>PH0027-C_Forward_GATC</th>
# <th>PH0027-C_Reverse_GATC</th>
# <th>PH0028-Cx_ForwardRep_GATC</th>
# <th>PH0028-Cx_Forward_GATC</th>
# <th>PH0028-Cx_Reverse_GATC</th>
# <th>PH0029-Cx_ForwardRep_GATC</th>
# <th>PH0029-Cx_Forward_GATC</th>
# <th>PH0029-Cx_Reverse_GATC</th>
# <th>PH0042-C_ForwardRep_GATC</th>
# <th>PH0042-C_Forward_GATC</th>
# <th>PH0042-C_Reverse_GATC</th>
# <th>PH0043-C_ForwardRep_GATC</th>
# <th>PH0043-C_Forward_GATC</th>
# <th>PH0043-C_Reverse_GATC</th>
# <th>PH0209-C_ForwardRep_GATC</th>
# <th>PH0209-C_Forward_GATC</th>
# <th>PH0209-C_Reverse_GATC</th>
# <th>PH0212-C_ForwardRep_GATC</th>
# <th>PH0212-C_Forward_GATC</th>
# <th>PH0212-C_Reverse_GATC</th>
# <th>PH0218-C_ForwardRep_GATC</th>
# <th>PH0218-C_Forward_GATC</th>
# <th>PH0218-C_Reverse_GATC</th>
# <th>PH0221-C_ForwardRep_GATC</th>
# <th>PH0221-C_Forward_GATC</th>
# <th>PH0221-C_Reverse_GATC</th>
# <th>PH0224-C_ForwardRep_GATC</th>
# <th>PH0224-C_Forward_GATC</th>
# <th>PH0224-C_Reverse_GATC</th>
# <th>PH0225-C_ForwardRep_GATC</th>
# <th>PH0225-C_Forward_GATC</th>
# <th>PH0225-C_Reverse_GATC</th>
# <th>PH0232-C_ForwardRep_GATC</th>
# <th>PH0232-C_Forward_GATC</th>
# <th>PH0232-C_Reverse_GATC</th>
# <th>PH0234-C_ForwardRep_GATC</th>
# <th>PH0234-C_Forward_GATC</th>
# <th>PH0234-C_Reverse_GATC</th>
# <th>PH0235-C_ForwardRep_GATC</th>
# <th>PH0235-C_Forward_GATC</th>
# <th>PH0235-C_Reverse_GATC</th>
# <th>PH0236-C_ForwardRep_GATC</th>
# <th>PH0236-C_Forward_GATC</th>
# <th>PH0236-C_Reverse_GATC</th>
# <th>PH0284-C_ForwardRep_GATC</th>
# <th>PH0284-C_Forward_GATC</th>
# <th>PH0284-C_Reverse_GATC</th>
# <th>PH0303-CW_ForwardRep_GATC</th>
# <th>PH0303-CW_Forward_GATC</th>
# <th>PH0303-CW_Reverse_GATC</th>
# <th>PH0326-C_ForwardRep_GATC</th>
# <th>PH0326-C_Forward_GATC</th>
# <th>PH0326-C_Reverse_GATC</th>
# <th>PH0337-C_ForwardRep_GATC</th>
# <th>PH0337-C_Forward_GATC</th>
# <th>PH0337-C_Reverse_GATC</th>
# <th>PH0349-C_ForwardRep_GATC</th>
# <th>PH0349-C_Forward_GATC</th>
# <th>PH0349-C_Reverse_GATC</th>
# <th>PH0375-C_ForwardRep_GATC</th>
# <th>PH0375-C_Forward_GATC</th>
# <th>PH0375-C_Reverse_GATC</th>
# <th>PH0456-C_ForwardRep_GATC</th>
# <th>PH0456-C_Forward_GATC</th>
# <th>PH0456-C_Reverse_GATC</th>
# <th>PH0457-CW_ForwardRep_GATC</th>
# <th>PH0457-CW_Forward_GATC</th>
# <th>PH0457-CW_Reverse_GATC</th>
# <th>PH0458-CW_ForwardRep_GATC</th>
# <th>PH0458-CW_Forward_GATC</th>
# <th>PH0458-CW_Reverse_GATC</th>
# <th>PH0460-C_ForwardRep_GATC</th>
# <th>PH0460-C_Forward_GATC</th>
# <th>PH0460-C_Reverse_GATC</th>
# <th>PH0462-C_ForwardRep_GATC</th>
# <th>PH0462-C_Forward_GATC</th>
# <th>PH0462-C_Reverse_GATC</th>
# <th>PH0463-C_ForwardRep_GATC</th>
# <th>PH0463-C_Forward_GATC</th>
# <th>PH0463-C_Reverse_GATC</th>
# <th>PH0464-CW_ForwardRep_GATC</th>
# <th>PH0464-CW_Forward_GATC</th>
# <th>PH0464-CW_Reverse_GATC</th>
# <th>PH0466-C_ForwardRep_GATC</th>
# <th>PH0466-C_Forward_GATC</th>
# <th>PH0466-C_Reverse_GATC</th>
# <th>PH0467-CW_ForwardRep_GATC</th>
# <th>PH0467-CW_Forward_GATC</th>
# <th>PH0467-CW_Reverse_GATC</th>
# <th>PH0468-C_ForwardRep_GATC</th>
# <th>PH0468-C_Forward_GATC</th>
# <th>PH0468-C_Reverse_GATC</th>
# <th>PH0474-CW_ForwardRep_GATC</th>
# <th>PH0474-CW_Forward_GATC</th>
# <th>PH0474-CW_Reverse_GATC</th>
# <th>PH0485-C_ForwardRep_GATC</th>
# <th>PH0485-C_Forward_GATC</th>
# <th>PH0485-C_Reverse_GATC</th>
# <th>PH0500-CW_ForwardRep_GATC</th>
# <th>PH0500-CW_Forward_GATC</th>
# <th>PH0500-CW_Reverse_GATC</th>
# <th>PH0501-CW_ForwardRep_GATC</th>
# <th>PH0501-CW_Forward_GATC</th>
# <th>PH0501-CW_Reverse_GATC</th>
# <th>PH0773-Cx_ForwardRep_GATC</th>
# <th>PH0773-Cx_Forward_GATC</th>
# <th>PH0773-Cx_Reverse_GATC</th>
# <th>PH0860-Cx_ForwardRep_GATC</th>
# <th>PH0860-Cx_Forward_GATC</th>
# <th>PH0860-Cx_Reverse_GATC</th>
# <th>PH0883-Cx_ForwardRep_GATC</th>
# <th>PH0883-Cx_Forward_GATC</th>
# <th>PH0883-Cx_Reverse_GATC</th>
# <th>PH0891-Cx_ForwardRep_GATC</th>
# <th>PH0891-Cx_Forward_GATC</th>
# <th>PH0891-Cx_Reverse_GATC</th>
# <th>PH0942-Cx_ForwardRep_GATC</th>
# <th>PH0942-Cx_Forward_GATC</th>
# <th>PH0942-Cx_Reverse_GATC</th>
# <th>PH0959-Cx_ForwardRep_GATC</th>
# <th>PH0959-Cx_Forward_GATC</th>
# <th>PH0959-Cx_Reverse_GATC</th>
# <th>PH0961-Cx_ForwardRep_GATC</th>
# <th>PH0961-Cx_Forward_GATC</th>
# <th>PH0961-Cx_Reverse_GATC</th>
# <th>PH0966-Cx_ForwardRep_GATC</th>
# <th>PH0966-Cx_Forward_GATC</th>
# <th>PH0966-Cx_Reverse_GATC</th>
# <th>PH0971-C_ForwardRep_GATC</th>
# <th>PH0971-C_Forward_GATC</th>
# <th>PH0971-C_Reverse_GATC</th>
# <th>PV0002-C_ForwardRep_GATC</th>
# <th>PV0002-C_Forward_GATC</th>
# <th>PV0002-C_Reverse_GATC</th>
# <th>PV0004-C_ForwardRep_GATC</th>
# <th>PV0004-C_Forward_GATC</th>
# <th>PV0004-C_Reverse_GATC</th>
# <th>PV0006-C_ForwardRep_GATC</th>
# <th>PV0006-C_Forward_GATC</th>
# <th>PV0006-C_Reverse_GATC</th>
# <th>PV0014-C_F

# %%
for callset in ['GATC']:
    for bad_qual_distance in [None, 0, 1, 2]:
        print(callset, bad_qual_distance, len(tbl_capillary_calls[callset][str(bad_qual_distance)]))
# Out:
# GATC None 33
# GATC 0 13
# GATC 1 9
# GATC 2 9

# %% [markdown]
# # Create table of merged calls from capillary, illumina and sequenom

# %%
SQNM_VCF_FN
# Out:
# '/data/plasmodium/pfalciparum/recon/sqnm_assay_test_1/Sqnm_data_DK1066_W1378_20150603.vcf.gz'

# %%
tbl_capillary_samples
# Out:
# +-------------+--------------------+----------------+-------------------+---------+---------+-------------+
# | ox_code     | have_sequenom_data | is_in_pgv4_vcf | Fws               | forward | reverse | forward_rep |
# +=============+====================+================+===================+=========+=========+=============+
# | 'PD0004-C'  | True               | True           | 0.998385281543281 |     687 |     533 |         942 |
# +-------------+--------------------+----------------+-------------------+---------+---------+-------------+
# | 'PD0005-01' | True               | True           | 0.998442149991529 |     672 |     496 |         967 |
# +-------------+--------------------+----------------+-------------------+---------+---------+-------------+
# | 'PD0005-C'  | True               | True           | 0.998841156657223 |     655 |     548 |         976 |
# +-------------+--------------------+----------------+-------------------+---------+---------+-------------+
# | 'PD0016-C'  | True               | True           | 0.997186431841148 |     686 |     512 |         978 |
# +-------------+--------------------+----------------+-------------------+---------+---------+-------------+
# | 'PD0031-C'  | True               | True           | None              |     569 |     532 |         968 |
# +-------------+--------------------+----------------+-------------------+---------+---------+-------------+
# ...

# %%
wb = openpyxl.Workbook(optimized_write=True, encoding=locale.getpreferredencoding())

tbl_sequenom_calls = collections.OrderedDict()
callsets = collections.OrderedDict()
callsets['GATC'] = ['GATC']
# callsets['SB'] = ['Source_Bioscience']
# callsets['all'] = ['GATC', 'Source_Bioscience']
# callsets = {'GATC':['GATC'], 'SB':['Source_Bioscience'], 'all':['GATC', 'Source_Bioscience']}

for callset in callsets:
    tbl_sequenom_calls[callset] = (etl
        .fromvcf(SQNM_VCF_FN)
#         .select(lambda rec: rec['CHROM']=='Pf3D7_13_v3' and rec['POS'] >= 1724843 and rec['POS'] <= 1725958)
        .select(lambda rec: rec['CHROM']=='Pf3D7_13_v3' and rec['POS'] >= 1724943 and rec['POS'] <= 1725954)
        .vcfmeltsamples()
        .vcfunpackcall()
        .cut(['CHROM', 'POS', 'REF', 'ALT', 'SAMPLE', 'GT'])
        .addfield('variant', lambda rec: "%s__%s__%s__%s" % (rec['CHROM'], rec['POS'], rec['REF'], rec['ALT']))
        .selectin('SAMPLE', tbl_capillary_samples.values('ox_code'))
        .convert('SAMPLE', lambda val: "%s__SQNM" % val)
        .pivot('variant', 'SAMPLE', 'GT', max)
    )
    print(callset)
    ws = wb.create_sheet(title="%s" % (callset))
    for row in tbl_sequenom_calls[callset]:
        ws.append(row)
    tbl_sequenom_calls[callset].displayall()

wb.save(SEQUENOM_CALLS_EXCEL_FN)
# Out:
# GATC
# <table class='petl'>
# <thead>
# <tr>
# <th>variant</th>
# <th>PD0004-C__SQNM</th>
# <th>PD0005-01__SQNM</th>
# <th>PD0005-C__SQNM</th>
# <th>PD0016-C__SQNM</th>
# <th>PD0031-C__SQNM</th>
# <th>PD0033-C__SQNM</th>
# <th>PD0037-C__SQNM</th>
# <th>PD0038-C__SQNM</th>
# <th>PD0048-C__SQNM</th>
# <th>PD0056-C__SQNM</th>
# <th>PD0058-C__SQNM</th>
# <th>PD0067-C__SQNM</th>
# <th>PD0073-C__SQNM</th>
# <th>PD0075-C__SQNM</th>
# <th>PD0079-C__SQNM</th>
# <th>PD0090-C__SQNM</th>
# <th>PD0098-C__SQNM</th>
# <th>PD0103-C__SQNM</th>
# <th>PD0105-C__SQNM</th>
# <th>PD0115-Cx__SQNM</th>
# <th>PD0126-C__SQNM</th>
# <th>PD0134-C__SQNM</th>
# <th>PD0135-C__SQNM</th>
# <th>PD0136-C__SQNM</th>
# <th>PD0137-C__SQNM</th>
# <th>PD0459-Cx__SQNM</th>
# <th>PH0002-C__SQNM</th>
# <th>PH0003-C__SQNM</th>
# <th>PH0012-C__SQNM</th>
# <th>PH0013-C__SQNM</th>
# <th>PH0016-C__SQNM</th>
# <th>PH0017-C__SQNM</th>
# <th>PH0020-C__SQNM</th>
# <th>PH0022-C__SQNM</th>
# <th>PH0024-C__SQNM</th>
# <th>PH0027-C__SQNM</th>
# <th>PH0028-Cx__SQNM</th>
# <th>PH0029-Cx__SQNM</th>
# <th>PH0042-C__SQNM</th>
# <th>PH0043-C__SQNM</th>
# <th>PH0209-C__SQNM</th>
# <th>PH0212-C__SQNM</th>
# <th>PH0218-C__SQNM</th>
# <th>PH0221-C__SQNM</th>
# <th>PH0224-C__SQNM</th>
# <th>PH0225-C__SQNM</th>
# <th>PH0232-C__SQNM</th>
# <th>PH0234-C__SQNM</th>
# <th>PH0235-C__SQNM</th>
# <th>PH0236-C__SQNM</th>
# <th>PH0284-C__SQNM</th>
# <th>PH0303-CW__SQNM</th>
# <th>PH0326-C__SQNM</th>
# <th>PH0337-C__SQNM</th>
# <th>PH0349-C__SQNM</th>
# <th>PH0375-C__SQNM</th>
# <th>PH0456-C__SQNM</th>
# <th>PH0457-CW__SQNM</th>
# <th>PH0458-CW__SQNM</th>
# <th>PH0460-C__SQNM</th>
# <th>PH0462-C__SQNM</th>
# <th>PH0463-C__SQNM</th>
# <th>PH0464-CW__SQNM</th>
# <th>PH0466-C__SQNM</th>
# <th>PH0467-CW__SQNM</th>
# <th>PH0468-C__SQNM</th>
# <th>PH0474-CW__SQNM</th>
# <th>PH0485-C__SQNM</th>
# <th>PH0500-CW__SQNM</th>
# <th>PH0501-CW__SQNM</th>
# <th>PH0773-Cx__SQNM</th>
# <th>PH0860-Cx__SQNM</th>
# <th>PH0891-Cx__SQNM</th>
# <th>PH0942-Cx__SQNM</th>
# <th>PH0959-Cx__SQNM</th>
# <th>PH0961-Cx__SQNM</th>
# <th>PH0966-Cx__SQNM</th>
# <th>PH0971-C__SQNM</th>
# <th>PV0002-C__SQNM</th>
# <th>PV0004-C__SQNM</th>
# <th>PV0006-C__SQNM</th>
# <th>PV0014-C__SQNM</th>
# <th>PV0018-C__SQNM</th>
# <th>PV0028-C__SQNM</th>
# <th>PV0039-C__SQNM</th>
# <th>PV0048-C__SQNM</th>
# <th>PV0249-Cx__SQNM</th>
# <th>PV0308-Cx__SQNM</th>
# <th>PV0315-Cx__SQNM</th>
# <th>PV0331-Cx__SQNM</th>
# <th>QE0393-Cx__SQNM</th>
# <th>QE0403-Cx__SQNM</th>
# <th>QE0405-Cx__SQNM</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Pf3D7_13_v3__1725259__C__[T]</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1725382__C__[G]</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1725521__A__[G]</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# </tr>
# </tbody>
# </table>

# %%
PGV4_VCF_FN
# Out:
# '/nfs/team112_internal/production_files/Pf/4_0/pf_4_0_20140712_vfp1.newCoverageFilters_pass_5_99.5.HyperHet.vcf.gz'

# %%
vcf_reader = vcf.Reader(filename=PGV4_VCF_FN)
pgv4_samples_array = np.array(vcf_reader.samples)
# capillary_samples = tbl_capillary_samples.values('ox_code').array()
gatc_capillary_samples = tbl_capillary_samples.values('ox_code').array()
# sb_capillary_samples = tbl_capillary_samples.selecteq('company', 'Source_Bioscience').values('ox_code').array()

# common_samples = np.array(np.intersect1d(capillary_samples, pgv4_samples_array), dtype=[('sample', '<U45')])
gatc_common_samples = np.array(np.intersect1d(gatc_capillary_samples, pgv4_samples_array), dtype=[('sample', '<U45')])
# sb_common_samples = np.array(np.intersect1d(sb_capillary_samples, pgv4_samples_array), dtype=[('sample', '<U45')])
# etl.fromarray(common_samples).data().totsv(SAMPLES_FN % 'all')
etl.fromarray(gatc_common_samples).data().totsv(SAMPLES_FN % 'GATC')
# etl.fromarray(sb_common_samples).data().totsv(SAMPLES_FN % 'SB')

# %%
len(tbl_capillary_samples.data())
# Out:
# 94

# %%
tbl_capillary_samples.valuecounts('is_in_pgv4_vcf')
# Out:
# +----------------+-------+-----------+
# | is_in_pgv4_vcf | count | frequency |
# +================+=======+===========+
# | True           |    94 |       1.0 |
# +----------------+-------+-----------+

# %%
tbl_capillary_samples.selectnone('is_in_pgv4_vcf')
# Out:
# +---------+--------------------+----------------+-----+---------+---------+-------------+
# | ox_code | have_sequenom_data | is_in_pgv4_vcf | Fws | forward | reverse | forward_rep |
# +=========+====================+================+=====+=========+=========+=============+

# %%
SAMPLES_FN
# Out:
# '/data/plasmodium/pfalciparum/recon/sqnm_assay_test_1/%s_capillary_samples_less_DNA.txt'

# %%
for callset in ['GATC']:
    output_fn = "%s/pgv4_gatk_subset_to_kelch13_less_DNA_%s.vcf.gz" % (DATA_DIR, callset)
    samples_fn = SAMPLES_FN % callset
    # !{GATK_EXE} -T SelectVariants \
        -R {REF_GENOME} \
        -V {PGV4_VCF_FN} \
        -L Pf3D7_13_v3:1724943-1725954 \
        -o {output_fn} \
        --sample_file {samples_fn} \
        --unsafe LENIENT_VCF_PROCESSING
        
#         -L Pf3D7_13_v3:1724843-1725958 \
# Out:
# INFO  16:31:39,703 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:31:39,704 HelpFormatter - The Genome Analysis Toolkit (GATK) v3.4-0-g7e26428, Compiled 2015/05/15 03:25:41
# INFO  16:31:39,705 HelpFormatter - Copyright (c) 2010 The Broad Institute
# INFO  16:31:39,705 HelpFormatter - For support and documentation go to http://www.broadinstitute.org/gatk
# INFO  16:31:39,708 HelpFormatter - Program Args: -T SelectVariants -R /data/plasmodium/pfalciparum/recon/roamato/Pf3D7_v3/3D7_sorted.fa -V /nfs/team112_internal/production_files/Pf/4_0/pf_4_0_20140712_vfp1.newCoverageFilters_pass_5_99.5.HyperHet.vcf.gz -L Pf3D7_13_v3:1724943-1725954 -o /data/plasmodium/pfalciparum/recon/sqnm_assay_test_1/pgv4_gatk_subset_to_kelch13_less_DNA_GATC.vcf.gz --sample_file /data/plasmodium/pfalciparum/recon/sqnm_assay_test_1/GATC_capillary_samples_less_DNA.txt --unsafe LENIENT_VCF_PROCESSING
# INFO  16:31:39,714 HelpFormatter - Executing as rpearson@dhcp215.well.ox.ac.uk on Mac OS X 10.10.3 x86_64; Java HotSpot(TM) 64-Bit Server VM 1.7.0_60-b19.
# INFO  16:31:39,714 HelpFormatter - Date/Time: 2015/07/10 16:31:39
# INFO  16:31:39,714 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:31:39,714 HelpFormatter - --------------------------------------------------------------------------------
# INFO  16:31:40,162 GenomeAnalysisEngine - Strictness is SILENT
# INFO  16:31:40,271 GenomeAnalysisEngine - Downsampling Settings: Method: BY_SAMPLE, Target Coverage: 1000
# INFO  16:31:40,351 IntervalUtils - Processing 1012 bp from intervals
# WARN  16:31:40,352 IndexDictionaryUtils - Track variant doesn't have a sequence dictionary built in, skipping dictionary validation
# INFO  16:31:40,416 GenomeAnalysisEngine - Preparing for traversal
# INFO  16:31:40,416 GenomeAnalysisEngine - Done preparing for traversal
# INFO  16:31:40,417 ProgressMeter - [INITIALIZATION COMPLETE; STARTING PROCESSING]
# INFO  16:31:40,417 ProgressMeter -                 | processed |    time |    per 1M |           |   total | remaining
# INFO  16:31:40,418 ProgressMeter -        Location |     sites | elapsed |     sites | completed | runtime |   runtime
# INFO  16:31:40,449 SelectVariants - Including sample 'PD0004-C'
# INFO  16:31:40,450 SelectVariants - Including sample 'PD0005-01'
# INFO  16:31:40,450 SelectVariants - Including sample 'PD0005-C'
# INFO  16:31:40,450 SelectVariants - Including sample 'PD0016-C'
# INFO  16:31:40,451 SelectVariants - Including sample 'PD0031-C'
# INFO  16:31:40,451 SelectVariants - Including sample 'PD0033-C'
# INFO  16:31:40,451 SelectVariants - Including sample 'PD0037-C'
# INFO  16:31:40,452 SelectVariants - Including sample 'PD0038-C'
# INFO  16:31:40,452 SelectVariants - Including sample 'PD0048-C'
# INFO  16:31:40,452 SelectVariants - Including sample 'PD0056-C'
# INFO  16:31:40,452 SelectVariants - Including sample 'PD0058-C'
# INFO  16:31:40,452 SelectVariants - Including sample 'PD0067-C'
# INFO  16:31:40,453 SelectVariants - Including sample 'PD0073-C'
# INFO  16:31:40,453 SelectVariants - Including sample 'PD0075-C'
# INFO  16:31:40,453 SelectVariants - Including sample 'PD0079-C'
# INFO  16:31:40,453 SelectVariants - Including sample 'PD0090-C'
# INFO  16:31:40,454 SelectVariants - Including sample 'PD0098-C'
# INFO  16:31:40,454 SelectVariants - Including sample 'PD0103-C'
# INFO  16:31:40,454 SelectVariants - Including sample 'PD0105-C'
# INFO  16:31:40,454 SelectVariants - Including sample 'PD0115-Cx'
# INFO  16:31:40,454 SelectVariants - Including sample 'PD0126-C'
# INFO  16:31:40,454 SelectVariants - Including sample 'PD0134-C'
# INFO  16:31:40,454 SelectVariants - Including sample 'PD0135-C'
# INFO  16:31:40,454 SelectVariants - Including sample 'PD0136-C'
# INFO  16:31:40,455 SelectVariants - Including sample 'PD0137-C'
# INFO  16:31:40,455 SelectVariants - Including sample 'PD0459-Cx'
# INFO  16:31:40,455 SelectVariants - Including sample 'PH0002-C'
# INFO  16:31:40,455 SelectVariants - Including sample 'PH0003-C'
# INFO  16:31:40,455 SelectVariants - Including sample 'PH0012-C'
# INFO  16:31:40,455 SelectVariants - Including sample 'PH0013-C'
# INFO  16:31:40,456 SelectVariants - Including sample 'PH0016-C'
# INFO  16:31:40,456 SelectVariants - Including sample 'PH0017-C'
# INFO  16:31:40,456 SelectVariants - Including sample 'PH0020-C'
# INFO  16:31:40,456 SelectVariants - Including sample 'PH0022-C'
# INFO  16:31:40,456 SelectVariants - Including sample 'PH0024-C'
# INFO  16:31:40,457 SelectVariants - Including sample 'PH0027-C'
# INFO  16:31:40,457 SelectVariants - Including sample 'PH0028-Cx'
# INFO  16:31:40,457 SelectVariants - Including sample 'PH0029-Cx'
# INFO  16:31:40,457 SelectVariants - Including sample 'PH0042-C'
# INFO  16:31:40,457 SelectVariants - Including sample 'PH0043-C'
# INFO  16:31:40,458 SelectVariants - Including sample 'PH0209-C'
# INFO  16:31:40,458 SelectVariants - Including sample 'PH0212-C'
# INFO  16:31:40,458 SelectVariants - Including sample 'PH0218-C'
# INFO  16:31:40,458 SelectVariants - Including sample 'PH0221-C'
# INFO  16:31:40,458 SelectVariants - Including sample 'PH0224-C'
# INFO  16:31:40,458 SelectVariants - Including sample 'PH0225-C'
# INFO  16:31:40,458 SelectVariants - Including sample 'PH0232-C'
# INFO  16:31:40,459 SelectVariants - Including sample 'PH0234-C'
# INFO  16:31:40,459 SelectVariants - Including sample 'PH0235-C'
# INFO  16:31:40,459 SelectVariants - Including sample 'PH0236-C'
# INFO  16:31:40,459 SelectVariants - Including sample 'PH0284-C'
# INFO  16:31:40,459 SelectVariants - Including sample 'PH0303-CW'
# INFO  16:31:40,459 SelectVariants - Including sample 'PH0326-C'
# INFO  16:31:40,459 SelectVariants - Including sample 'PH0337-C'
# INFO  16:31:40,460 SelectVariants - Including sample 'PH0349-C'
# INFO  16:31:40,460 SelectVariants - Including sample 'PH0375-C'
# INFO  16:31:40,460 SelectVariants - Including sample 'PH0456-C'
# INFO  16:31:40,460 SelectVariants - Including sample 'PH0457-CW'
# INFO  16:31:40,460 SelectVariants - Including sample 'PH0458-CW'
# INFO  16:31:40,460 SelectVariants - Including sample 'PH0460-C'
# INFO  16:31:40,461 SelectVariants - Including sample 'PH0462-C'
# INFO  16:31:40,461 SelectVariants - Including sample 'PH0463-C'
# INFO  16:31:40,461 SelectVariants - Including sample 'PH0464-CW'
# INFO  16:31:40,461 SelectVariants - Including sample 'PH0466-C'
# INFO  16:31:40,461 SelectVariants - Including sample 'PH0467-CW'
# INFO  16:31:40,461 SelectVariants - Including sample 'PH0468-C'
# INFO  16:31:40,461 SelectVariants - Including sample 'PH0474-CW'
# INFO  16:31:40,461 SelectVariants - Including sample 'PH0485-C'
# INFO  16:31:40,462 SelectVariants - Including sample 'PH0500-CW'
# INFO  16:31:40,462 SelectVariants - Including sample 'PH0501-CW'
# INFO  16:31:40,462 SelectVariants - Including sample 'PH0773-Cx'
# INFO  16:31:40,462 SelectVariants - Including sample 'PH0860-Cx'
# INFO  16:31:40,462 SelectVariants - Including sample 'PH0883-Cx'
# INFO  16:31:40,462 SelectVariants - Including sample 'PH0891-Cx'
# INFO  16:31:40,462 SelectVariants - Including sample 'PH0942-Cx'
# INFO  16:31:40,463 SelectVariants - Including sample 'PH0959-Cx'
# INFO  16:31:40,463 SelectVariants - Including sample 'PH0961-Cx'
# INFO  16:31:40,463 SelectVariants - Including sample 'PH0966-Cx'
# INFO  16:31:40,463 SelectVariants - Including sample 'PH0971-C'
# INFO  16:31:40,463 SelectVariants - Including sample 'PV0002-C'
# INFO  16:31:40,463 SelectVariants - Including sample 'PV0004-C'
# INFO  16:31:40,464 SelectVariants - Including sample 'PV0006-C'
# INFO  16:31:40,464 SelectVariants - Including sample 'PV0014-C'
# INFO  16:31:40,464 SelectVariants - Including sample 'PV0018-C'
# INFO  16:31:40,464 SelectVariants - Including sample 'PV0028-C'
# INFO  16:31:40,464 SelectVariants - Including sample 'PV0039-C'
# INFO  16:31:40,464 SelectVariants - Including sample 'PV0048-C'
# INFO  16:31:40,465 SelectVariants - Including sample 'PV0249-Cx'
# INFO  16:31:40,465 SelectVariants - Including sample 'PV0308-Cx'
# INFO  16:31:40,465 SelectVariants - Including sample 'PV0315-Cx'
# INFO  16:31:40,465 SelectVariants - Including sample 'PV0331-Cx'
# INFO  16:31:40,465 SelectVariants - Including sample 'QE0393-Cx'
# INFO  16:31:40,465 SelectVariants - Including sample 'QE0403-Cx'
# INFO  16:31:40,466 SelectVariants - Including sample 'QE0405-Cx'
# INFO  16:31:44,189 SelectVariants - 109 records processed.
# INFO  16:31:44,202 ProgressMeter -            done       109.0     3.0 s       9.6 h       86.1%     3.0 s       0.0 s
# INFO  16:31:44,202 ProgressMeter - Total runtime 3.79 secs, 0.06 min, 0.00 hours
# INFO  16:31:46,607 GATKRunReport - Uploaded run statistics report to AWS S3

# %%
etl.fromvcf("%s/pgv4_gatk_subset_to_kelch13_less_DNA_GATC.vcf.gz" % (DATA_DIR))
# Out:
# +---------------+---------+------+-----+-----+------+------------+---------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------- ...
# | CHROM         | POS     | ID   | REF | ALT | QUAL | FILTER     | INFO                                                                                                                            | PD0004-C                                                                            | PD0005-01                                                                           | PD0005-C                                                                            | PD0016-C                                                                            | PD0031-C                                                                           | PD0033-C                                                                            | PD0037-C                                                                            | PD0038-C                                                                            | PD0048-C                                                                            | PD0056-C                                                                            | PD0058-C                                                                            | PD0067-C                                                                               | PD0073-C                                                                              | PD0075-C                                                                            | PD0079-C                                                                              | PD0090-C                                                                              | PD0098-C                                                                              | PD0103-C                                                                            | PD0105-C                                                                            | PD0115-Cx                                                                               | PD0126-C                                                                               | PD0134-C                                                                               | PD0135-C                                                                               | PD0136-C                                                                               | PD0137-C                                                                                | PD0459-Cx                                                                              | PH0002-C                                                                            | PH0003-C                                                                            | PH0012-C                                                                              | PH0013-C                                                                            | PH0016-C                                                                            | PH0017-C                                                                            | PH0020-C                                                                          | PH0022-C                                                                                | PH0024-C                                                                            | PH0027-C                                                                            | PH0028-Cx                                                                            | PH0029-Cx                                                                               | PH0042-C                                                                           | PH0043-C                                                                              | PH0209-C                                                                            | PH0212-C                                                                            | PH0218-C                                                                            | PH0221-C                                                       ...
# +===============+=========+======+=====+=====+======+============+=================================================================================================================================+=====================================================================================+=====================================================================================+=====================================================================================+=====================================================================================+====================================================================================+=====================================================================================+=====================================================================================+=====================================================================================+=====================================================================================+=====================================================================================+=====================================================================================+========================================================================================+=======================================================================================+=====================================================================================+=======================================================================================+=======================================================================================+=======================================================================================+=====================================================================================+=====================================================================================+=========================================================================================+========================================================================================+========================================================================================+========================================================================================+========================================================================================+=========================================================================================+========================================================================================+=====================================================================================+=====================================================================================+=======================================================================================+=====================================================================================+=====================================================================================+=====================================================================================+===================================================================================+=========================================================================================+=====================================================================================+=====================================================================================+======================================================================================+=========================================================================================+====================================================================================+=======================================================================================+=====================================================================================+=====================================================================================+=====================================================================================+=============================================================== ...
# | 'Pf3D7_13_v3' | 1724969 | None | 'T' | [C] | None | ['MinAlt'] | {'UQ': 17, 'AF': [0.0], 'AC': [0], 'DP': 7348, 'CODING': True, 'NS': 4852, 'AN': 0, 'AD': [350118, 31], 'RegionType': 'Core'}   | Call(sample=PD0004-C, CallData(GT=None, AD=[15, 0], DF=[8, 0], DP=15, DR=[7, 0]))   | Call(sample=PD0005-01, CallData(GT=None, AD=[70, 0], DF=[70, 0], DP=70, DR=[0, 0])) | Call(sample=PD0005-C, CallData(GT=None, AD=[69, 0], DF=[52, 0], DP=69, DR=[17, 0])) | Call(sample=PD0016-C, CallData(GT=None, AD=[69, 0], DF=[28, 0], DP=69, DR=[41, 0])) | Call(sample=PD0031-C, CallData(GT=None, AD=[15, 0], DF=[12, 0], DP=15, DR=[3, 0])) | Call(sample=PD0033-C, CallData(GT=None, AD=[42, 0], DF=[23, 0], DP=42, DR=[19, 0])) | Call(sample=PD0037-C, CallData(GT=None, AD=[57, 0], DF=[20, 0], DP=57, DR=[37, 0])) | Call(sample=PD0038-C, CallData(GT=None, AD=[47, 0], DF=[9, 0], DP=47, DR=[38, 0]))  | Call(sample=PD0048-C, CallData(GT=None, AD=[69, 0], DF=[12, 0], DP=69, DR=[57, 0])) | Call(sample=PD0056-C, CallData(GT=None, AD=[94, 0], DF=[29, 0], DP=94, DR=[65, 0])) | Call(sample=PD0058-C, CallData(GT=None, AD=[37, 0], DF=[14, 0], DP=37, DR=[23, 0])) | Call(sample=PD0067-C, CallData(GT=None, AD=[142, 0], DF=[46, 0], DP=142, DR=[96, 0]))  | Call(sample=PD0073-C, CallData(GT=None, AD=[123, 0], DF=[43, 0], DP=123, DR=[80, 0])) | Call(sample=PD0075-C, CallData(GT=None, AD=[81, 0], DF=[29, 0], DP=81, DR=[52, 0])) | Call(sample=PD0079-C, CallData(GT=None, AD=[88, 0], DF=[20, 0], DP=88, DR=[68, 0]))   | Call(sample=PD0090-C, CallData(GT=None, AD=[120, 0], DF=[53, 0], DP=120, DR=[67, 0])) | Call(sample=PD0098-C, CallData(GT=None, AD=[122, 0], DF=[45, 0], DP=122, DR=[77, 0])) | Call(sample=PD0103-C, CallData(GT=None, AD=[75, 0], DF=[17, 0], DP=75, DR=[58, 0])) | Call(sample=PD0105-C, CallData(GT=None, AD=[71, 0], DF=[15, 0], DP=71, DR=[56, 0])) | Call(sample=PD0115-Cx, CallData(GT=None, AD=[184, 0], DF=[54, 0], DP=184, DR=[130, 0])) | Call(sample=PD0126-C, CallData(GT=None, AD=[165, 0], DF=[140, 0], DP=165, DR=[25, 0])) | Call(sample=PD0134-C, CallData(GT=None, AD=[172, 0], DF=[116, 0], DP=172, DR=[56, 0])) | Call(sample=PD0135-C, CallData(GT=None, AD=[167, 0], DF=[79, 0], DP=167, DR=[88, 0]))  | Call(sample=PD0136-C, CallData(GT=None, AD=[147, 0], DF=[20, 0], DP=147, DR=[127, 0])) | Call(sample=PD0137-C, CallData(GT=None, AD=[346, 0], DF=[140, 0], DP=346, DR=[206, 0])) | Call(sample=PD0459-Cx, CallData(GT=None, AD=[165, 0], DF=[77, 0], DP=165, DR=[88, 0])) | Call(sample=PH0002-C, CallData(GT=None, AD=[49, 0], DF=[21, 0], DP=49, DR=[28, 0])) | Call(sample=PH0003-C, CallData(GT=None, AD=[82, 0], DF=[45, 0], DP=82, DR=[37, 0])) | Call(sample=PH0012-C, CallData(GT=None, AD=[79, 0], DF=[53, 0], DP=79, DR=[26, 0]))   | Call(sample=PH0013-C, CallData(GT=None, AD=[36, 0], DF=[13, 0], DP=36, DR=[23, 0])) | Call(sample=PH0016-C, CallData(GT=None, AD=[27, 0], DF=[10, 0], DP=27, DR=[17, 0])) | Call(sample=PH0017-C, CallData(GT=None, AD=[73, 0], DF=[31, 0], DP=73, DR=[42, 0])) | Call(sample=PH0020-C, CallData(GT=None, AD=[10, 0], DF=[4, 0], DP=10, DR=[6, 0])) | Call(sample=PH0022-C, CallData(GT=None, AD=[555, 0], DF=[271, 0], DP=555, DR=[284, 0])) | Call(sample=PH0024-C, CallData(GT=None, AD=[52, 0], DF=[14, 0], DP=52, DR=[38, 0])) | Call(sample=PH0027-C, CallData(GT=None, AD=[17, 0], DF=[10, 0], DP=17, DR=[7, 0]))  | Call(sample=PH0028-Cx, CallData(GT=None, AD=[15, 0], DF=[3, 0], DP=15, DR=[12, 0]))  | Call(sample=PH0029-Cx, CallData(GT=None, AD=[164, 0], DF=[114, 0], DP=164, DR=[50, 0])) | Call(sample=PH0042-C, CallData(GT=None, AD=[6, 0], DF=[6, 0], DP=6, DR=[0, 0]))    | Call(sample=PH0043-C, CallData(GT=None, AD=[103, 0], DF=[39, 0], DP=103, DR=[64, 0])) | Call(sample=PH0209-C, CallData(GT=None, AD=[74, 0], DF=[62, 0], DP=74, DR=[12, 0])) | Call(sample=PH0212-C, CallData(GT=None, AD=[80, 0], DF=[64, 0], DP=80, DR=[16, 0])) | Call(sample=PH0218-C, CallData(GT=None, AD=[44, 0], DF=[11, 0], DP=44, DR=[33, 0])) | Call(sample=PH0221-C, CallData(GT=None, AD=[30, 0], DF=[11, 0] ...
# +---------------+---------+------+-----+-----+------+------------+---------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------- ...
# | 'Pf3D7_13_v3' | 1724970 | None | 'G' | [A] | None | []         | {'UQ': 17, 'AF': [0.0], 'AC': [0], 'DP': 7719, 'CODING': True, 'NS': 4855, 'AN': 0, 'AD': [363893, 97], 'RegionType': 'Core'}   | Call(sample=PD0004-C, CallData(GT=None, AD=[21, 0], DF=[12, 0], DP=21, DR=[9, 0]))  | Call(sample=PD0005-01, CallData(GT=None, AD=[74, 0], DF=[74, 0], DP=74, DR=[0, 0])) | Call(sample=PD0005-C, CallData(GT=None, AD=[71, 0], DF=[47, 0], DP=71, DR=[24, 0])) | Call(sample=PD0016-C, CallData(GT=None, AD=[70, 0], DF=[32, 0], DP=70, DR=[38, 0])) | Call(sample=PD0031-C, CallData(GT=None, AD=[14, 0], DF=[11, 0], DP=14, DR=[3, 0])) | Call(sample=PD0033-C, CallData(GT=None, AD=[42, 0], DF=[23, 0], DP=42, DR=[19, 0])) | Call(sample=PD0037-C, CallData(GT=None, AD=[56, 0], DF=[27, 0], DP=56, DR=[29, 0])) | Call(sample=PD0038-C, CallData(GT=None, AD=[47, 0], DF=[11, 0], DP=47, DR=[36, 0])) | Call(sample=PD0048-C, CallData(GT=None, AD=[77, 0], DF=[21, 0], DP=77, DR=[56, 0])) | Call(sample=PD0056-C, CallData(GT=None, AD=[97, 0], DF=[34, 0], DP=97, DR=[63, 0])) | Call(sample=PD0058-C, CallData(GT=None, AD=[41, 0], DF=[15, 0], DP=41, DR=[26, 0])) | Call(sample=PD0067-C, CallData(GT=None, AD=[171, 0], DF=[64, 0], DP=171, DR=[107, 0])) | Call(sample=PD0073-C, CallData(GT=None, AD=[121, 0], DF=[47, 0], DP=121, DR=[74, 0])) | Call(sample=PD0075-C, CallData(GT=None, AD=[81, 0], DF=[31, 0], DP=81, DR=[50, 0])) | Call(sample=PD0079-C, CallData(GT=None, AD=[98, 0], DF=[31, 0], DP=98, DR=[67, 0]))   | Call(sample=PD0090-C, CallData(GT=None, AD=[124, 0], DF=[56, 0], DP=124, DR=[68, 0])) | Call(sample=PD0098-C, CallData(GT=None, AD=[121, 0], DF=[46, 0], DP=121, DR=[75, 0])) | Call(sample=PD0103-C, CallData(GT=None, AD=[88, 0], DF=[27, 0], DP=88, DR=[61, 0])) | Call(sample=PD0105-C, CallData(GT=None, AD=[68, 0], DF=[19, 0], DP=68, DR=[49, 0])) | Call(sample=PD0115-Cx, CallData(GT=None, AD=[182, 0], DF=[51, 0], DP=182, DR=[131, 0])) | Call(sample=PD0126-C, CallData(GT=None, AD=[170, 0], DF=[142, 0], DP=170, DR=[28, 0])) | Call(sample=PD0134-C, CallData(GT=None, AD=[173, 0], DF=[118, 0], DP=173, DR=[55, 0])) | Call(sample=PD0135-C, CallData(GT=None, AD=[172, 0], DF=[81, 0], DP=172, DR=[91, 0]))  | Call(sample=PD0136-C, CallData(GT=None, AD=[168, 0], DF=[33, 0], DP=168, DR=[135, 0])) | Call(sample=PD0137-C, CallData(GT=None, AD=[361, 0], DF=[145, 0], DP=361, DR=[216, 0])) | Call(sample=PD0459-Cx, CallData(GT=None, AD=[173, 0], DF=[79, 0], DP=173, DR=[94, 0])) | Call(sample=PH0002-C, CallData(GT=None, AD=[50, 0], DF=[17, 0], DP=50, DR=[33, 0])) | Call(sample=PH0003-C, CallData(GT=None, AD=[80, 0], DF=[35, 0], DP=80, DR=[45, 0])) | Call(sample=PH0012-C, CallData(GT=None, AD=[105, 0], DF=[73, 0], DP=105, DR=[32, 0])) | Call(sample=PH0013-C, CallData(GT=None, AD=[37, 0], DF=[14, 0], DP=37, DR=[23, 0])) | Call(sample=PH0016-C, CallData(GT=None, AD=[29, 0], DF=[8, 0], DP=29, DR=[21, 0]))  | Call(sample=PH0017-C, CallData(GT=None, AD=[73, 0], DF=[27, 0], DP=73, DR=[46, 0])) | Call(sample=PH0020-C, CallData(GT=None, AD=[11, 0], DF=[2, 0], DP=11, DR=[9, 0])) | Call(sample=PH0022-C, CallData(GT=None, AD=[594, 0], DF=[312, 0], DP=594, DR=[282, 0])) | Call(sample=PH0024-C, CallData(GT=None, AD=[49, 0], DF=[19, 0], DP=49, DR=[30, 0])) | Call(sample=PH0027-C, CallData(GT=None, AD=[22, 0], DF=[16, 0], DP=22, DR=[6, 0]))  | Call(sample=PH0028-Cx, CallData(GT=None, AD=[21, 0], DF=[11, 0], DP=21, DR=[10, 0])) | Call(sample=PH0029-Cx, CallData(GT=None, AD=[176, 0], DF=[123, 0], DP=176, DR=[53, 0])) | Call(sample=PH0042-C, CallData(GT=None, AD=[7, 0], DF=[7, 0], DP=7, DR=[0, 0]))    | Call(sample=PH0043-C, CallData(GT=None, AD=[104, 0], DF=[41, 0], DP=104, DR=[63, 0])) | Call(sample=PH0209-C, CallData(GT=None, AD=[76, 0], DF=[64, 0], DP=76, DR=[12, 0])) | Call(sample=PH0212-C, CallData(GT=None, AD=[84, 0], DF=[67, 0], DP=84, DR=[17, 0])) | Call(sample=PH0218-C, CallData(GT=None, AD=[45, 0], DF=[11, 0], DP=45, DR=[34, 0])) | Call(sample=PH0221-C, CallData(GT=None, AD=[32, 0], DF=[13, 0] ...
# +---------------+---------+------+-----+-----+------+------------+---------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------- ...
# | 'Pf3D7_13_v3' | 1724972 | None | 'C' | [A] | None | []         | {'UQ': 14, 'AF': [0.0], 'AC': [0], 'DP': 7871, 'CODING': True, 'NS': 4852, 'AN': 0, 'AD': [365472, 139], 'RegionType': 'Core'}  | Call(sample=PD0004-C, CallData(GT=None, AD=[26, 0], DF=[10, 0], DP=26, DR=[16, 0])) | Call(sample=PD0005-01, CallData(GT=None, AD=[77, 0], DF=[77, 0], DP=77, DR=[0, 0])) | Call(sample=PD0005-C, CallData(GT=None, AD=[79, 0], DF=[54, 0], DP=79, DR=[25, 0])) | Call(sample=PD0016-C, CallData(GT=None, AD=[73, 0], DF=[37, 0], DP=73, DR=[36, 0])) | Call(sample=PD0031-C, CallData(GT=None, AD=[18, 0], DF=[13, 0], DP=18, DR=[5, 0])) | Call(sample=PD0033-C, CallData(GT=None, AD=[48, 0], DF=[25, 0], DP=48, DR=[23, 0])) | Call(sample=PD0037-C, CallData(GT=None, AD=[62, 0], DF=[22, 0], DP=62, DR=[40, 0])) | Call(sample=PD0038-C, CallData(GT=None, AD=[49, 0], DF=[18, 0], DP=49, DR=[31, 0])) | Call(sample=PD0048-C, CallData(GT=None, AD=[83, 0], DF=[21, 0], DP=83, DR=[62, 0])) | Call(sample=PD0056-C, CallData(GT=None, AD=[97, 0], DF=[28, 0], DP=97, DR=[69, 0])) | Call(sample=PD0058-C, CallData(GT=None, AD=[42, 0], DF=[14, 0], DP=42, DR=[28, 0])) | Call(sample=PD0067-C, CallData(GT=None, AD=[168, 0], DF=[57, 0], DP=168, DR=[111, 0])) | Call(sample=PD0073-C, CallData(GT=None, AD=[136, 0], DF=[47, 0], DP=136, DR=[89, 0])) | Call(sample=PD0075-C, CallData(GT=None, AD=[84, 0], DF=[33, 0], DP=84, DR=[51, 0])) | Call(sample=PD0079-C, CallData(GT=None, AD=[108, 0], DF=[32, 0], DP=108, DR=[76, 0])) | Call(sample=PD0090-C, CallData(GT=None, AD=[122, 0], DF=[58, 0], DP=122, DR=[64, 0])) | Call(sample=PD0098-C, CallData(GT=None, AD=[120, 0], DF=[46, 0], DP=120, DR=[74, 0])) | Call(sample=PD0103-C, CallData(GT=None, AD=[84, 0], DF=[25, 0], DP=84, DR=[59, 0])) | Call(sample=PD0105-C, CallData(GT=None, AD=[73, 0], DF=[18, 0], DP=73, DR=[55, 0])) | Call(sample=PD0115-Cx, CallData(GT=None, AD=[187, 0], DF=[65, 0], DP=187, DR=[122, 0])) | Call(sample=PD0126-C, CallData(GT=None, AD=[171, 0], DF=[144, 0], DP=171, DR=[27, 0])) | Call(sample=PD0134-C, CallData(GT=None, AD=[174, 0], DF=[119, 0], DP=174, DR=[55, 0])) | Call(sample=PD0135-C, CallData(GT=None, AD=[182, 0], DF=[89, 0], DP=182, DR=[93, 0]))  | Call(sample=PD0136-C, CallData(GT=None, AD=[163, 0], DF=[30, 0], DP=163, DR=[133, 0])) | Call(sample=PD0137-C, CallData(GT=None, AD=[370, 0], DF=[138, 0], DP=370, DR=[232, 0])) | Call(sample=PD0459-Cx, CallData(GT=None, AD=[175, 0], DF=[82, 0], DP=175, DR=[93, 0])) | Call(sample=PH0002-C, CallData(GT=None, AD=[52, 0], DF=[21, 0], DP=52, DR=[31, 0])) | Call(sample=PH0003-C, CallData(GT=None, AD=[87, 0], DF=[41, 0], DP=87, DR=[46, 0])) | Call(sample=PH0012-C, CallData(GT=None, AD=[109, 0], DF=[61, 0], DP=109, DR=[48, 0])) | Call(sample=PH0013-C, CallData(GT=None, AD=[39, 0], DF=[15, 0], DP=39, DR=[24, 0])) | Call(sample=PH0016-C, CallData(GT=None, AD=[27, 0], DF=[9, 0], DP=27, DR=[18, 0]))  | Call(sample=PH0017-C, CallData(GT=None, AD=[71, 0], DF=[30, 0], DP=71, DR=[41, 0])) | Call(sample=PH0020-C, CallData(GT=None, AD=[10, 0], DF=[4, 0], DP=10, DR=[6, 0])) | Call(sample=PH0022-C, CallData(GT=None, AD=[629, 0], DF=[317, 0], DP=629, DR=[312, 0])) | Call(sample=PH0024-C, CallData(GT=None, AD=[54, 0], DF=[16, 0], DP=54, DR=[38, 0])) | Call(sample=PH0027-C, CallData(GT=None, AD=[19, 0], DF=[11, 0], DP=19, DR=[8, 0]))  | Call(sample=PH0028-Cx, CallData(GT=None, AD=[24, 0], DF=[9, 0], DP=24, DR=[15, 0]))  | Call(sample=PH0029-Cx, CallData(GT=None, AD=[186, 0], DF=[129, 0], DP=186, DR=[57, 0])) | Call(sample=PH0042-C, CallData(GT=None, AD=[9, 0], DF=[9, 0], DP=9, DR=[0, 0]))    | Call(sample=PH0043-C, CallData(GT=None, AD=[105, 0], DF=[42, 0], DP=105, DR=[63, 0])) | Call(sample=PH0209-C, CallData(GT=None, AD=[76, 0], DF=[63, 0], DP=76, DR=[13, 0])) | Call(sample=PH0212-C, CallData(GT=None, AD=[84, 0], DF=[67, 0], DP=84, DR=[17, 0])) | Call(sample=PH0218-C, CallData(GT=None, AD=[46, 0], DF=[12, 0], DP=46, DR=[34, 0])) | Call(sample=PH0221-C, CallData(GT=None, AD=[33, 0], DF=[13, 0] ...
# +---------------+---------+------+-----+-----+------+------------+---------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------- ...
# | 'Pf3D7_13_v3' | 1724974 | None | 'G' | [A] | None | []         | {'UQ': 15, 'AF': [0.0], 'AC': [0], 'DP': 7857, 'CODING': True, 'NS': 4850, 'AN': 0, 'AD': [363702, 1220], 'RegionType': 'Core'} | Call(sample=PD0004-C, CallData(GT=None, AD=[30, 0], DF=[16, 0], DP=30, DR=[14, 0])) | Call(sample=PD0005-01, CallData(GT=None, AD=[82, 0], DF=[82, 0], DP=82, DR=[0, 0])) | Call(sample=PD0005-C, CallData(GT=None, AD=[72, 0], DF=[45, 0], DP=72, DR=[27, 0])) | Call(sample=PD0016-C, CallData(GT=None, AD=[83, 0], DF=[36, 0], DP=83, DR=[47, 0])) | Call(sample=PD0031-C, CallData(GT=None, AD=[18, 0], DF=[14, 0], DP=18, DR=[4, 0])) | Call(sample=PD0033-C, CallData(GT=None, AD=[48, 0], DF=[25, 0], DP=48, DR=[23, 0])) | Call(sample=PD0037-C, CallData(GT=None, AD=[67, 0], DF=[25, 0], DP=67, DR=[42, 0])) | Call(sample=PD0038-C, CallData(GT=None, AD=[49, 0], DF=[16, 0], DP=49, DR=[33, 0])) | Call(sample=PD0048-C, CallData(GT=None, AD=[84, 0], DF=[22, 0], DP=84, DR=[62, 0])) | Call(sample=PD0056-C, CallData(GT=None, AD=[96, 0], DF=[30, 0], DP=96, DR=[66, 0])) | Call(sample=PD0058-C, CallData(GT=None, AD=[41, 0], DF=[14, 0], DP=41, DR=[27, 0])) | Call(sample=PD0067-C, CallData(GT=None, AD=[165, 0], DF=[58, 0], DP=165, DR=[107, 0])) | Call(sample=PD0073-C, CallData(GT=None, AD=[126, 0], DF=[47, 0], DP=126, DR=[79, 0])) | Call(sample=PD0075-C, CallData(GT=None, AD=[84, 0], DF=[33, 0], DP=84, DR=[51, 0])) | Call(sample=PD0079-C, CallData(GT=None, AD=[99, 0], DF=[28, 0], DP=99, DR=[71, 0]))   | Call(sample=PD0090-C, CallData(GT=None, AD=[125, 0], DF=[59, 0], DP=125, DR=[66, 0])) | Call(sample=PD0098-C, CallData(GT=None, AD=[120, 0], DF=[42, 0], DP=120, DR=[78, 0])) | Call(sample=PD0103-C, CallData(GT=None, AD=[84, 0], DF=[26, 0], DP=84, DR=[58, 0])) | Call(sample=PD0105-C, CallData(GT=None, AD=[78, 0], DF=[21, 0], DP=78, DR=[57, 0])) | Call(sample=PD0115-Cx, CallData(GT=None, AD=[192, 0], DF=[60, 0], DP=192, DR=[132, 0])) | Call(sample=PD0126-C, CallData(GT=None, AD=[175, 0], DF=[148, 0], DP=175, DR=[27, 0])) | Call(sample=PD0134-C, CallData(GT=None, AD=[183, 0], DF=[124, 0], DP=183, DR=[59, 0])) | Call(sample=PD0135-C, CallData(GT=None, AD=[182, 0], DF=[77, 0], DP=182, DR=[105, 0])) | Call(sample=PD0136-C, CallData(GT=None, AD=[159, 0], DF=[28, 0], DP=159, DR=[131, 0])) | Call(sample=PD0137-C, CallData(GT=None, AD=[371, 0], DF=[128, 0], DP=371, DR=[243, 0])) | Call(sample=PD0459-Cx, CallData(GT=None, AD=[173, 0], DF=[83, 0], DP=173, DR=[90, 0])) | Call(sample=PH0002-C, CallData(GT=None, AD=[48, 0], DF=[17, 0], DP=48, DR=[31, 0])) | Call(sample=PH0003-C, CallData(GT=None, AD=[88, 0], DF=[38, 0], DP=88, DR=[50, 0])) | Call(sample=PH0012-C, CallData(GT=None, AD=[120, 0], DF=[78, 0], DP=120, DR=[42, 0])) | Call(sample=PH0013-C, CallData(GT=None, AD=[38, 0], DF=[15, 0], DP=38, DR=[23, 0])) | Call(sample=PH0016-C, CallData(GT=None, AD=[30, 0], DF=[14, 0], DP=30, DR=[16, 0])) | Call(sample=PH0017-C, CallData(GT=None, AD=[76, 0], DF=[28, 0], DP=76, DR=[48, 0])) | Call(sample=PH0020-C, CallData(GT=None, AD=[15, 0], DF=[8, 0], DP=15, DR=[7, 0])) | Call(sample=PH0022-C, CallData(GT=None, AD=[614, 1], DF=[310, 0], DP=615, DR=[304, 1])) | Call(sample=PH0024-C, CallData(GT=None, AD=[48, 0], DF=[13, 0], DP=48, DR=[35, 0])) | Call(sample=PH0027-C, CallData(GT=None, AD=[23, 0], DF=[12, 0], DP=23, DR=[11, 0])) | Call(sample=PH0028-Cx, CallData(GT=None, AD=[28, 0], DF=[14, 0], DP=28, DR=[14, 0])) | Call(sample=PH0029-Cx, CallData(GT=None, AD=[186, 0], DF=[126, 0], DP=186, DR=[60, 0])) | Call(sample=PH0042-C, CallData(GT=None, AD=[11, 0], DF=[11, 0], DP=11, DR=[0, 0])) | Call(sample=PH0043-C, CallData(GT=None, AD=[101, 0], DF=[37, 0], DP=101, DR=[64, 0])) | Call(sample=PH0209-C, CallData(GT=None, AD=[73, 0], DF=[60, 0], DP=73, DR=[13, 0])) | Call(sample=PH0212-C, CallData(GT=None, AD=[82, 0], DF=[65, 0], DP=82, DR=[17, 0])) | Call(sample=PH0218-C, CallData(GT=None, AD=[48, 0], DF=[12, 0], DP=48, DR=[36, 0])) | Call(sample=PH0221-C, CallData(GT=None, AD=[30, 0], DF=[12, 0] ...
# +---------------+---------+------+-----+-----+------+------------+---------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------- ...
# | 'Pf3D7_13_v3' | 1724975 | None | 'C' | [G] | None | ['MinAlt'] | {'UQ': 16, 'AF': [0.0], 'AC': [0], 'DP': 7024, 'CODING': True, 'NS': 4843, 'AN': 0, 'AD': [346630, 32], 'RegionType': 'Core'}   | Call(sample=PD0004-C, CallData(GT=None, AD=[27, 0], DF=[3, 0], DP=27, DR=[24, 0]))  | Call(sample=PD0005-01, CallData(GT=None, AD=[47, 0], DF=[47, 0], DP=47, DR=[0, 0])) | Call(sample=PD0005-C, CallData(GT=None, AD=[56, 0], DF=[35, 0], DP=56, DR=[21, 0])) | Call(sample=PD0016-C, CallData(GT=None, AD=[54, 0], DF=[19, 0], DP=54, DR=[35, 0])) | Call(sample=PD0031-C, CallData(GT=None, AD=[18, 0], DF=[10, 0], DP=18, DR=[8, 0])) | Call(sample=PD0033-C, CallData(GT=None, AD=[40, 0], DF=[16, 0], DP=40, DR=[24, 0])) | Call(sample=PD0037-C, CallData(GT=None, AD=[57, 0], DF=[15, 0], DP=57, DR=[42, 0])) | Call(sample=PD0038-C, CallData(GT=None, AD=[50, 0], DF=[9, 0], DP=50, DR=[41, 0]))  | Call(sample=PD0048-C, CallData(GT=None, AD=[80, 0], DF=[17, 0], DP=80, DR=[63, 0])) | Call(sample=PD0056-C, CallData(GT=None, AD=[85, 0], DF=[15, 0], DP=85, DR=[70, 0])) | Call(sample=PD0058-C, CallData(GT=None, AD=[38, 0], DF=[9, 0], DP=38, DR=[29, 0]))  | Call(sample=PD0067-C, CallData(GT=None, AD=[143, 0], DF=[33, 0], DP=143, DR=[110, 0])) | Call(sample=PD0073-C, CallData(GT=None, AD=[105, 0], DF=[19, 0], DP=105, DR=[86, 0])) | Call(sample=PD0075-C, CallData(GT=None, AD=[77, 0], DF=[25, 0], DP=77, DR=[52, 0])) | Call(sample=PD0079-C, CallData(GT=None, AD=[97, 0], DF=[24, 0], DP=97, DR=[73, 0]))   | Call(sample=PD0090-C, CallData(GT=None, AD=[106, 0], DF=[42, 0], DP=106, DR=[64, 0])) | Call(sample=PD0098-C, CallData(GT=None, AD=[105, 0], DF=[29, 0], DP=105, DR=[76, 0])) | Call(sample=PD0103-C, CallData(GT=None, AD=[74, 0], DF=[16, 0], DP=74, DR=[58, 0])) | Call(sample=PD0105-C, CallData(GT=None, AD=[59, 0], DF=[10, 0], DP=59, DR=[49, 0])) | Call(sample=PD0115-Cx, CallData(GT=None, AD=[162, 0], DF=[35, 0], DP=162, DR=[127, 0])) | Call(sample=PD0126-C, CallData(GT=None, AD=[170, 0], DF=[144, 0], DP=170, DR=[26, 0])) | Call(sample=PD0134-C, CallData(GT=None, AD=[173, 0], DF=[111, 0], DP=173, DR=[62, 0])) | Call(sample=PD0135-C, CallData(GT=None, AD=[143, 1], DF=[40, 1], DP=144, DR=[103, 0])) | Call(sample=PD0136-C, CallData(GT=None, AD=[157, 0], DF=[18, 0], DP=157, DR=[139, 0])) | Call(sample=PD0137-C, CallData(GT=None, AD=[336, 1], DF=[80, 1], DP=337, DR=[256, 0]))  | Call(sample=PD0459-Cx, CallData(GT=None, AD=[171, 0], DF=[81, 0], DP=171, DR=[90, 0])) | Call(sample=PH0002-C, CallData(GT=None, AD=[38, 0], DF=[10, 0], DP=38, DR=[28, 0])) | Call(sample=PH0003-C, CallData(GT=None, AD=[75, 0], DF=[27, 0], DP=75, DR=[48, 0])) | Call(sample=PH0012-C, CallData(GT=None, AD=[83, 0], DF=[34, 0], DP=83, DR=[49, 0]))   | Call(sample=PH0013-C, CallData(GT=None, AD=[30, 0], DF=[7, 0], DP=30, DR=[23, 0]))  | Call(sample=PH0016-C, CallData(GT=None, AD=[25, 0], DF=[10, 0], DP=25, DR=[15, 0])) | Call(sample=PH0017-C, CallData(GT=None, AD=[59, 0], DF=[18, 0], DP=59, DR=[41, 0])) | Call(sample=PH0020-C, CallData(GT=None, AD=[12, 0], DF=[5, 0], DP=12, DR=[7, 0])) | Call(sample=PH0022-C, CallData(GT=None, AD=[479, 0], DF=[167, 0], DP=479, DR=[312, 0])) | Call(sample=PH0024-C, CallData(GT=None, AD=[48, 0], DF=[8, 0], DP=48, DR=[40, 0]))  | Call(sample=PH0027-C, CallData(GT=None, AD=[29, 0], DF=[14, 0], DP=29, DR=[15, 0])) | Call(sample=PH0028-Cx, CallData(GT=None, AD=[27, 0], DF=[13, 0], DP=27, DR=[14, 0])) | Call(sample=PH0029-Cx, CallData(GT=None, AD=[146, 0], DF=[83, 0], DP=146, DR=[63, 0]))  | Call(sample=PH0042-C, CallData(GT=None, AD=[6, 0], DF=[6, 0], DP=6, DR=[0, 0]))    | Call(sample=PH0043-C, CallData(GT=None, AD=[86, 0], DF=[25, 0], DP=86, DR=[61, 0]))   | Call(sample=PH0209-C, CallData(GT=None, AD=[63, 0], DF=[48, 0], DP=63, DR=[15, 0])) | Call(sample=PH0212-C, CallData(GT=None, AD=[70, 0], DF=[54, 0], DP=70, DR=[16, 0])) | Call(sample=PH0218-C, CallData(GT=None, AD=[40, 0], DF=[4, 0], DP=40, DR=[36, 0]))  | Call(sample=PH0221-C, CallData(GT=None, AD=[20, 0], DF=[3, 0], ...
# +---------------+---------+------+-----+-----+------+------------+---------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+--------------------------------------------------------------- ...
# ...

# %%
tbl_illumina_calls = (etl
    .fromvcf("%s/pgv4_gatk_subset_to_kelch13_less_DNA_GATC.vcf.gz" % (DATA_DIR))
    .vcfmeltsamples()
    .vcfunpackcall()
    .cut(['CHROM', 'POS', 'REF', 'ALT', 'SAMPLE', 'AD'])
    .addfield('variant', lambda rec: "%s__%s__%s__%s" % (rec['CHROM'], rec['POS'], rec['REF'], rec['ALT']))
    .pivot('variant', 'SAMPLE', 'AD', max)
)
tbl_illumina_calls.displayall()
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>variant</th>
# <th>PD0004-C</th>
# <th>PD0005-01</th>
# <th>PD0005-C</th>
# <th>PD0016-C</th>
# <th>PD0031-C</th>
# <th>PD0033-C</th>
# <th>PD0037-C</th>
# <th>PD0038-C</th>
# <th>PD0048-C</th>
# <th>PD0056-C</th>
# <th>PD0058-C</th>
# <th>PD0067-C</th>
# <th>PD0073-C</th>
# <th>PD0075-C</th>
# <th>PD0079-C</th>
# <th>PD0090-C</th>
# <th>PD0098-C</th>
# <th>PD0103-C</th>
# <th>PD0105-C</th>
# <th>PD0115-Cx</th>
# <th>PD0126-C</th>
# <th>PD0134-C</th>
# <th>PD0135-C</th>
# <th>PD0136-C</th>
# <th>PD0137-C</th>
# <th>PD0459-Cx</th>
# <th>PH0002-C</th>
# <th>PH0003-C</th>
# <th>PH0012-C</th>
# <th>PH0013-C</th>
# <th>PH0016-C</th>
# <th>PH0017-C</th>
# <th>PH0020-C</th>
# <th>PH0022-C</th>
# <th>PH0024-C</th>
# <th>PH0027-C</th>
# <th>PH0028-Cx</th>
# <th>PH0029-Cx</th>
# <th>PH0042-C</th>
# <th>PH0043-C</th>
# <th>PH0209-C</th>
# <th>PH0212-C</th>
# <th>PH0218-C</th>
# <th>PH0221-C</th>
# <th>PH0224-C</th>
# <th>PH0225-C</th>
# <th>PH0232-C</th>
# <th>PH0234-C</th>
# <th>PH0235-C</th>
# <th>PH0236-C</th>
# <th>PH0284-C</th>
# <th>PH0303-CW</th>
# <th>PH0326-C</th>
# <th>PH0337-C</th>
# <th>PH0349-C</th>
# <th>PH0375-C</th>
# <th>PH0456-C</th>
# <th>PH0457-CW</th>
# <th>PH0458-CW</th>
# <th>PH0460-C</th>
# <th>PH0462-C</th>
# <th>PH0463-C</th>
# <th>PH0464-CW</th>
# <th>PH0466-C</th>
# <th>PH0467-CW</th>
# <th>PH0468-C</th>
# <th>PH0474-CW</th>
# <th>PH0485-C</th>
# <th>PH0500-CW</th>
# <th>PH0501-CW</th>
# <th>PH0773-Cx</th>
# <th>PH0860-Cx</th>
# <th>PH0883-Cx</th>
# <th>PH0891-Cx</th>
# <th>PH0942-Cx</th>
# <th>PH0959-Cx</th>
# <th>PH0961-Cx</th>
# <th>PH0966-Cx</th>
# <th>PH0971-C</th>
# <th>PV0002-C</th>
# <th>PV0004-C</th>
# <th>PV0006-C</th>
# <th>PV0014-C</th>
# <th>PV0018-C</th>
# <th>PV0028-C</th>
# <th>PV0039-C</th>
# <th>PV0048-C</th>
# <th>PV0249-Cx</th>
# <th>PV0308-Cx</th>
# <th>PV0315-Cx</th>
# <th>PV0331-Cx</th>
# <th>QE0393-Cx</th>
# <th>QE0403-Cx</th>
# <th>QE0405-Cx</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Pf3D7_13_v3__1724969__T__[C]</td>
# <td>[15, 0]</td>
# <td>[70, 0]</td>
# <td>[69, 0]</td>
# <td>[69, 0]</td>
# <td>[15, 0]</td>
# <td>[42, 0]</td>
# <td>[57, 0]</td>
# <td>[47, 0]</td>
# <td>[69, 0]</td>
# <td>[94, 0]</td>
# <td>[37, 0]</td>
# <td>[142, 0]</td>
# <td>[123, 0]</td>
# <td>[81, 0]</td>
# <td>[88, 0]</td>
# <td>[120, 0]</td>
# <td>[122, 0]</td>
# <td>[75, 0]</td>
# <td>[71, 0]</td>
# <td>[184, 0]</td>
# <td>[165, 0]</td>
# <td>[172, 0]</td>
# <td>[167, 0]</td>
# <td>[147, 0]</td>
# <td>[346, 0]</td>
# <td>[165, 0]</td>
# <td>[49, 0]</td>
# <td>[82, 0]</td>
# <td>[79, 0]</td>
# <td>[36, 0]</td>
# <td>[27, 0]</td>
# <td>[73, 0]</td>
# <td>[10, 0]</td>
# <td>[555, 0]</td>
# <td>[52, 0]</td>
# <td>[17, 0]</td>
# <td>[15, 0]</td>
# <td>[164, 0]</td>
# <td>[6, 0]</td>
# <td>[103, 0]</td>
# <td>[74, 0]</td>
# <td>[80, 0]</td>
# <td>[44, 0]</td>
# <td>[30, 0]</td>
# <td>[31, 0]</td>
# <td>[22, 0]</td>
# <td>[31, 0]</td>
# <td>[14, 0]</td>
# <td>[17, 0]</td>
# <td>[21, 0]</td>
# <td>[22, 0]</td>
# <td>[39, 0]</td>
# <td>[87, 0]</td>
# <td>[37, 0]</td>
# <td>[28, 0]</td>
# <td>[41, 0]</td>
# <td>[22, 0]</td>
# <td>[19, 0]</td>
# <td>[21, 0]</td>
# <td>[20, 0]</td>
# <td>[31, 0]</td>
# <td>[31, 0]</td>
# <td>[89, 0]</td>
# <td>[20, 0]</td>
# <td>[20, 0]</td>
# <td>[22, 0]</td>
# <td>[34, 0]</td>
# <td>[33, 0]</td>
# <td>[63, 0]</td>
# <td>[105, 0]</td>
# <td>[106, 0]</td>
# <td>[32, 0]</td>
# <td>[8, 0]</td>
# <td>[247, 0]</td>
# <td>[20, 0]</td>
# <td>[16, 0]</td>
# <td>[24, 0]</td>
# <td>[19, 0]</td>
# <td>[26, 0]</td>
# <td>[19, 0]</td>
# <td>[47, 0]</td>
# <td>[40, 0]</td>
# <td>[24, 0]</td>
# <td>[39, 0]</td>
# <td>[112, 0]</td>
# <td>[98, 0]</td>
# <td>[90, 0]</td>
# <td>[135, 0]</td>
# <td>[145, 0]</td>
# <td>[195, 0]</td>
# <td>[138, 0]</td>
# <td>[197, 0]</td>
# <td>[164, 0]</td>
# <td>[239, 0]</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1724970__G__[A]</td>
# <td>[21, 0]</td>
# <td>[74, 0]</td>
# <td>[71, 0]</td>
# <td>[70, 0]</td>
# <td>[14, 0]</td>
# <td>[42, 0]</td>
# <td>[56, 0]</td>
# <td>[47, 0]</td>
# <td>[77, 0]</td>
# <td>[97, 0]</td>
# <td>[41, 0]</td>
# <td>[171, 0]</td>
# <td>[121, 0]</td>
# <td>[81, 0]</td>
# <td>[98, 0]</td>
# <td>[124, 0]</td>
# <td>[121, 0]</td>
# <td>[88, 0]</td>
# <td>[68, 0]</td>
# <td>[182, 0]</td>
# <td>[170, 0]</td>
# <td>[173, 0]</td>
# <td>[172, 0]</td>
# <td>[168, 0]</td>
# <td>[361, 0]</td>
# <td>[173, 0]</td>
# <td>[50, 0]</td>
# <td>[80, 0]</td>
# <td>[105, 0]</td>
# <td>[37, 0]</td>
# <td>[29, 0]</td>
# <td>[73, 0]</td>
# <td>[11, 0]</td>
# <td>[594, 0]</td>
# <td>[49, 0]</td>
# <td>[22, 0]</td>
# <td>[21, 0]</td>
# <td>[176, 0]</td>
# <td>[7, 0]</td>
# <td>[104, 0]</td>
# <td>[76, 0]</td>
# <td>[84, 0]</td>
# <td>[45, 0]</td>
# <td>[32, 0]</td>
# <td>[31, 0]</td>
# <td>[21, 0]</td>
# <td>[30, 0]</td>
# <td>[14, 0]</td>
# <td>[17, 0]</td>
# <td>[21, 0]</td>
# <td>[22, 0]</td>
# <td>[38, 0]</td>
# <td>[90, 0]</td>
# <td>[37, 0]</td>
# <td>[26, 0]</td>
# <td>[40, 0]</td>
# <td>[21, 0]</td>
# <td>[21, 0]</td>
# <td>[21, 0]</td>
# <td>[19, 0]</td>
# <td>[30, 0]</td>
# <td>[33, 0]</td>
# <td>[94, 0]</td>
# <td>[20, 0]</td>
# <td>[21, 0]</td>
# <td>[23, 0]</td>
# <td>[40, 0]</td>
# <td>[32, 0]</td>
# <td>[69, 0]</td>
# <td>[101, 0]</td>
# <td>[109, 0]</td>
# <td>[34, 0]</td>
# <td>[8, 0]</td>
# <td>[264, 0]</td>
# <td>[20, 0]</td>
# <td>[15, 0]</td>
# <td>[27, 0]</td>
# <td>[20, 0]</td>
# <td>[30, 0]</td>
# <td>[19, 0]</td>
# <td>[51, 0]</td>
# <td>[39, 0]</td>
# <td>[26, 0]</td>
# <td>[41, 0]</td>
# <td>[129, 0]</td>
# <td>[106, 0]</td>
# <td>[99, 0]</td>
# <td>[138, 0]</td>
# <td>[151, 0]</td>
# <td>[210, 0]</td>
# <td>[143, 0]</td>
# <td>[204, 0]</td>
# <td>[178, 0]</td>
# <td>[250, 0]</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1724972__C__[A]</td>
# <td>[26, 0]</td>
# <td>[77, 0]</td>
# <td>[79, 0]</td>
# <td>[73, 0]</td>
# <td>[18, 0]</td>
# <td>[48, 0]</td>
# <td>[62, 0]</td>
# <td>[49, 0]</td>
# <td>[83, 0]</td>
# <td>[97, 0]</td>
# <td>[42, 0]</td>
# <td>[168, 0]</td>
# <td>[136, 0]</td>
# <td>[84, 0]</td>
# <td>[108, 0]</td>
# <td>[122, 0]</td>
# <td>[120, 0]</td>
# <td>[84, 0]</td>
# <td>[73, 0]</td>
# <td>[187, 0]</td>
# <td>[171, 0]</td>
# <td>[174, 0]</td>
# <td>[182, 0]</td>
# <td>[163, 0]</td>
# <td>[370, 0]</td>
# <td>[175, 0]</td>
# <td>[52, 0]</td>
# <td>[87, 0]</td>
# <td>[109, 0]</td>
# <td>[39, 0]</td>
# <td>[27, 0]</td>
# <td>[71, 0]</td>
# <td>[10, 0]</td>
# <td>[629, 0]</td>
# <td>[54, 0]</td>
# <td>[19, 0]</td>
# <td>[24, 0]</td>
# <td>[186, 0]</td>
# <td>[9, 0]</td>
# <td>[105, 0]</td>
# <td>[76, 0]</td>
# <td>[84, 0]</td>
# <td>[46, 0]</td>
# <td>[33, 0]</td>
# <td>[31, 0]</td>
# <td>[24, 0]</td>
# <td>[27, 0]</td>
# <td>[14, 0]</td>
# <td>[17, 0]</td>
# <td>[18, 0]</td>
# <td>[21, 0]</td>
# <td>[41, 0]</td>
# <td>[92, 0]</td>
# <td>[36, 0]</td>
# <td>[26, 0]</td>
# <td>[41, 0]</td>
# <td>[21, 0]</td>
# <td>[19, 0]</td>
# <td>[21, 0]</td>
# <td>[22, 0]</td>
# <td>[28, 0]</td>
# <td>[32, 0]</td>
# <td>[86, 0]</td>
# <td>[21, 0]</td>
# <td>[18, 0]</td>
# <td>[20, 0]</td>
# <td>[39, 0]</td>
# <td>[32, 0]</td>
# <td>[66, 0]</td>
# <td>[105, 0]</td>
# <td>[109, 0]</td>
# <td>[34, 0]</td>
# <td>[7, 0]</td>
# <td>[263, 0]</td>
# <td>[18, 0]</td>
# <td>[17, 0]</td>
# <td>[27, 0]</td>
# <td>[18, 0]</td>
# <td>[31, 0]</td>
# <td>[22, 0]</td>
# <td>[49, 0]</td>
# <td>[41, 0]</td>
# <td>[24, 0]</td>
# <td>[42, 0]</td>
# <td>[132, 0]</td>
# <td>[108, 1]</td>
# <td>[106, 0]</td>
# <td>[139, 0]</td>
# <td>[150, 0]</td>
# <td>[208, 0]</td>
# <td>[148, 0]</td>
# <td>[206, 0]</td>
# <td>[173, 0]</td>
# <td>[249, 0]</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1724974__G__[A]</td>
# <td>[30, 0]</td>
# <td>[82, 0]</td>
# <td>[72, 0]</td>
# <td>[83, 0]</td>
# <td>[18, 0]</td>
# <td>[48, 0]</td>
# <td>[67, 0]</td>
# <td>[49, 0]</td>
# <td>[84, 0]</td>
# <td>[96, 0]</td>
# <td>[41, 0]</td>
# <td>[165, 0]</td>
# <td>[126, 0]</td>
# <td>[84, 0]</td>
# <td>[99, 0]</td>
# <td>[125, 0]</td>
# <td>[120, 0]</td>
# <td>[84, 0]</td>
# <td>[78, 0]</td>
# <td>[192, 0]</td>
# <td>[175, 0]</td>
# <td>[183, 0]</td>
# <td>[182, 0]</td>
# <td>[159, 0]</td>
# <td>[371, 0]</td>
# <td>[173, 0]</td>
# <td>[48, 0]</td>
# <td>[88, 0]</td>
# <td>[120, 0]</td>
# <td>[38, 0]</td>
# <td>[30, 0]</td>
# <td>[76, 0]</td>
# <td>[15, 0]</td>
# <td>[614, 1]</td>
# <td>[48, 0]</td>
# <td>[23, 0]</td>
# <td>[28, 0]</td>
# <td>[186, 0]</td>
# <td>[11, 0]</td>
# <td>[101, 0]</td>
# <td>[73, 0]</td>
# <td>[82, 0]</td>
# <td>[48, 0]</td>
# <td>[30, 0]</td>
# <td>[29, 0]</td>
# <td>[26, 0]</td>
# <td>[28, 0]</td>
# <td>[16, 0]</td>
# <td>[18, 0]</td>
# <td>[16, 0]</td>
# <td>[18, 0]</td>
# <td>[39, 0]</td>
# <td>[85, 0]</td>
# <td>[32, 0]</td>
# <td>[29, 0]</td>
# <td>[37, 0]</td>
# <td>[21, 0]</td>
# <td>[20, 0]</td>
# <td>[22, 0]</td>
# <td>[24, 0]</td>
# <td>[27, 0]</td>
# <td>[32, 0]</td>
# <td>[88, 0]</td>
# <td>[17, 0]</td>
# <td>[18, 0]</td>
# <td>[19, 0]</td>
# <td>[40, 0

# %%
def determine_GT(AD):
    if sum(AD) < 5:
        return(None)
    if len(AD) == 3:
        if AD[0] > 1 and AD[1] > 1:
            return("0/1")
        if AD[0] > 1 and AD[2] > 1:
            return("0/2")
        if AD[1] > 1 and AD[2] > 1:
            return("1/2")
    if(AD[0] > 1 and AD[1] > 1):
        return("0/1")
    if(AD[0] <= 1 and AD[1] > 1):
        return("1/1")
    if(AD[0] > 1 and AD[1] <= 1):
        return("0/0")
    else:
        return("unknown")

# %%
def is_variable(rec):
    if all([val in ['0/0', None] for val in np.array(rec)[1:]]):
        return False
    else:
        return True

# %%
wb = openpyxl.Workbook(optimized_write=True, encoding=locale.getpreferredencoding())

tbl_illumina_calls = collections.OrderedDict()
tbl_illumina_ADs = collections.OrderedDict()
for callset in ['GATC']:
    tbl_illumina_calls[callset] = (etl
        .fromvcf("%s/pgv4_gatk_subset_to_kelch13_less_DNA_%s.vcf.gz" % (DATA_DIR, callset))
        .vcfmeltsamples()
        .vcfunpackcall()
        .cut(['CHROM', 'POS', 'REF', 'ALT', 'SAMPLE', 'AD'])
        .addfield('variant', lambda rec: "%s__%s__%s__%s" % (rec['CHROM'], rec['POS'], rec['REF'], rec['ALT']))
        .addfield('GT', lambda rec: determine_GT(rec['AD']))
        .convert('SAMPLE', lambda val: "%s__ILMN" % val)
        .selectnotnone('GT')
        .pivot('variant', 'SAMPLE', 'GT', max)
        .select(is_variable)
    )
    ws = wb.create_sheet(title="GT_%s" % (callset))
    for row in tbl_illumina_calls[callset]:
        ws.append(row)
    tbl_illumina_calls[callset].displayall()

    tbl_illumina_ADs[callset] = (etl
        .fromvcf("%s/pgv4_gatk_subset_to_kelch13_less_DNA_%s.vcf.gz" % (DATA_DIR, callset))
        .vcfmeltsamples()
        .vcfunpackcall()
        .cut(['CHROM', 'POS', 'REF', 'ALT', 'SAMPLE', 'AD'])
        .addfield('variant', lambda rec: "%s__%s__%s__%s" % (rec['CHROM'], rec['POS'], rec['REF'], rec['ALT']))
        .convert('SAMPLE', lambda val: "%s__ILMN" % val)
        .convert('AD', str)
        .pivot('variant', 'SAMPLE', 'AD', max)
        .selectin('variant', tbl_illumina_calls[callset].values('variant'))
    )
    ws = wb.create_sheet(title="AD_%s" % (callset))
    for row in tbl_illumina_ADs[callset]:
        ws.append(row)
    tbl_illumina_ADs[callset].displayall()

wb.save(ILLUMINA_CALLS_EXCEL_FN)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>variant</th>
# <th>PD0004-C__ILMN</th>
# <th>PD0005-01__ILMN</th>
# <th>PD0005-C__ILMN</th>
# <th>PD0016-C__ILMN</th>
# <th>PD0031-C__ILMN</th>
# <th>PD0033-C__ILMN</th>
# <th>PD0037-C__ILMN</th>
# <th>PD0038-C__ILMN</th>
# <th>PD0048-C__ILMN</th>
# <th>PD0056-C__ILMN</th>
# <th>PD0058-C__ILMN</th>
# <th>PD0067-C__ILMN</th>
# <th>PD0073-C__ILMN</th>
# <th>PD0075-C__ILMN</th>
# <th>PD0079-C__ILMN</th>
# <th>PD0090-C__ILMN</th>
# <th>PD0098-C__ILMN</th>
# <th>PD0103-C__ILMN</th>
# <th>PD0105-C__ILMN</th>
# <th>PD0115-Cx__ILMN</th>
# <th>PD0126-C__ILMN</th>
# <th>PD0134-C__ILMN</th>
# <th>PD0135-C__ILMN</th>
# <th>PD0136-C__ILMN</th>
# <th>PD0137-C__ILMN</th>
# <th>PD0459-Cx__ILMN</th>
# <th>PH0002-C__ILMN</th>
# <th>PH0003-C__ILMN</th>
# <th>PH0012-C__ILMN</th>
# <th>PH0013-C__ILMN</th>
# <th>PH0016-C__ILMN</th>
# <th>PH0017-C__ILMN</th>
# <th>PH0020-C__ILMN</th>
# <th>PH0022-C__ILMN</th>
# <th>PH0024-C__ILMN</th>
# <th>PH0027-C__ILMN</th>
# <th>PH0028-Cx__ILMN</th>
# <th>PH0029-Cx__ILMN</th>
# <th>PH0042-C__ILMN</th>
# <th>PH0043-C__ILMN</th>
# <th>PH0209-C__ILMN</th>
# <th>PH0212-C__ILMN</th>
# <th>PH0218-C__ILMN</th>
# <th>PH0221-C__ILMN</th>
# <th>PH0224-C__ILMN</th>
# <th>PH0225-C__ILMN</th>
# <th>PH0232-C__ILMN</th>
# <th>PH0234-C__ILMN</th>
# <th>PH0235-C__ILMN</th>
# <th>PH0236-C__ILMN</th>
# <th>PH0284-C__ILMN</th>
# <th>PH0303-CW__ILMN</th>
# <th>PH0326-C__ILMN</th>
# <th>PH0337-C__ILMN</th>
# <th>PH0349-C__ILMN</th>
# <th>PH0375-C__ILMN</th>
# <th>PH0456-C__ILMN</th>
# <th>PH0457-CW__ILMN</th>
# <th>PH0458-CW__ILMN</th>
# <th>PH0460-C__ILMN</th>
# <th>PH0462-C__ILMN</th>
# <th>PH0463-C__ILMN</th>
# <th>PH0464-CW__ILMN</th>
# <th>PH0466-C__ILMN</th>
# <th>PH0467-CW__ILMN</th>
# <th>PH0468-C__ILMN</th>
# <th>PH0474-CW__ILMN</th>
# <th>PH0485-C__ILMN</th>
# <th>PH0500-CW__ILMN</th>
# <th>PH0501-CW__ILMN</th>
# <th>PH0773-Cx__ILMN</th>
# <th>PH0860-Cx__ILMN</th>
# <th>PH0883-Cx__ILMN</th>
# <th>PH0891-Cx__ILMN</th>
# <th>PH0942-Cx__ILMN</th>
# <th>PH0959-Cx__ILMN</th>
# <th>PH0961-Cx__ILMN</th>
# <th>PH0966-Cx__ILMN</th>
# <th>PH0971-C__ILMN</th>
# <th>PV0002-C__ILMN</th>
# <th>PV0004-C__ILMN</th>
# <th>PV0006-C__ILMN</th>
# <th>PV0014-C__ILMN</th>
# <th>PV0018-C__ILMN</th>
# <th>PV0028-C__ILMN</th>
# <th>PV0039-C__ILMN</th>
# <th>PV0048-C__ILMN</th>
# <th>PV0249-Cx__ILMN</th>
# <th>PV0308-Cx__ILMN</th>
# <th>PV0315-Cx__ILMN</th>
# <th>PV0331-Cx__ILMN</th>
# <th>QE0393-Cx__ILMN</th>
# <th>QE0403-Cx__ILMN</th>
# <th>QE0405-Cx__ILMN</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Pf3D7_13_v3__1725247__T__[A]</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>None</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1725259__C__[T]</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1725274__C__[T]</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1725316__C__[T]</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>1/1</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1725340__G__[A]</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0</td>
# <td>0/0
# <table class='petl'>
# <thead>
# <tr>
# <th>variant</th>
# <th>PD0004-C__ILMN</th>
# <th>PD0005-01__ILMN</th>
# <th>PD0005-C__ILMN</th>
# <th>PD0016-C__ILMN</th>
# <th>PD0031-C__ILMN</th>
# <th>PD0033-C__ILMN</th>
# <th>PD0037-C__ILMN</th>
# <th>PD0038-C__ILMN</th>
# <th>PD0048-C__ILMN</th>
# <th>PD0056-C__ILMN</th>
# <th>PD0058-C__ILMN</th>
# <th>PD0067-C__ILMN</th>
# <th>PD0073-C__ILMN</th>
# <th>PD0075-C__ILMN</th>
# <th>PD0079-C__ILMN</th>
# <th>PD0090-C__ILMN</th>
# <th>PD0098-C__ILMN</th>
# <th>PD0103-C__ILMN</th>
# <th>PD0105-C__ILMN</th>
# <th>PD0115-Cx__ILMN</th>
# <th>PD0126-C__ILMN</th>
# <th>PD0134-C__ILMN</th>
# <th>PD0135-C__ILMN</th>
# <th>PD0136-C__ILMN</th>
# <th>PD0137-C__ILMN</th>
# <th>PD0459-Cx__ILMN</th>
# <th>PH0002-C__ILMN</th>
# <th>PH0003-C__ILMN</th>
# <th>PH0012-C__ILMN</th>
# <th>PH0013-C__ILMN</th>
# <th>PH0016-C__ILMN</th>
# <th>PH0017-C__ILMN</th>
# <th>PH0020-C__ILMN</th>
# <th>PH0022-C__ILMN</th>
# <th>PH0024-C__ILMN</th>
# <th>PH0027-C__ILMN</th>
# <th>PH0028-Cx__ILMN</th>
# <th>PH0029-Cx__ILMN</th>
# <th>PH0042-C__ILMN</th>
# <th>PH0043-C__ILMN</th>
# <th>PH0209-C__ILMN</th>
# <th>PH0212-C__ILMN</th>
# <th>PH0218-C__ILMN</th>
# <th>PH0221-C__ILMN</th>
# <th>PH0224-C__ILMN</th>
# <th>PH0225-C__ILMN</th>
# <th>PH0232-C__ILMN</th>
# <th>PH0234-C__ILMN</th>
# <th>PH0235-C__ILMN</th>
# <th>PH0236-C__ILMN</th>
# <th>PH0284-C__ILMN</th>
# <th>PH0303-CW__ILMN</th>
# <th>PH0326-C__ILMN</th>
# <th>PH0337-C__ILMN</th>
# <th>PH0349-C__ILMN</th>
# <th>PH0375-C__ILMN</th>
# <th>PH0456-C__ILMN</th>
# <th>PH0457-CW__ILMN</th>
# <th>PH0458-CW__ILMN</th>
# <th>PH0460-C__ILMN</th>
# <th>PH0462-C__ILMN</th>
# <th>PH0463-C__ILMN</th>
# <th>PH0464-CW__ILMN</th>
# <th>PH0466-C__ILMN</th>
# <th>PH0467-CW__ILMN</th>
# <th>PH0468-C__ILMN</th>
# <th>PH0474-CW__ILMN</th>
# <th>PH0485-C__ILMN</th>
# <th>PH0500-CW__ILMN</th>
# <th>PH0501-CW__ILMN</th>
# <th>PH0773-Cx__ILMN</th>
# <th>PH0860-Cx__ILMN</th>
# <th>PH0883-Cx__ILMN</th>
# <th>PH0891-Cx__ILMN</th>
# <th>PH0942-Cx__ILMN</th>
# <th>PH0959-Cx__ILMN</th>
# <th>PH0961-Cx__ILMN</th>
# <th>PH0966-Cx__ILMN</th>
# <th>PH0971-C__ILMN</th>
# <th>PV0002-C__ILMN</th>
# <th>PV0004-C__ILMN</th>
# <th>PV0006-C__ILMN</th>
# <th>PV0014-C__ILMN</th>
# <th>PV0018-C__ILMN</th>
# <th>PV0028-C__ILMN</th>
# <th>PV0039-C__ILMN</th>
# <th>PV0048-C__ILMN</th>
# <th>PV0249-Cx__ILMN</th>
# <th>PV0308-Cx__ILMN</th>
# <th>PV0315-Cx__ILMN</th>
# <th>PV0331-Cx__ILMN</th>
# <th>QE0393-Cx__ILMN</th>
# <th>QE0403-Cx__ILMN</th>
# <th>QE0405-Cx__ILMN</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Pf3D7_13_v3__1725247__T__[A]</td>
# <td>[59, 0]</td>
# <td>[178, 0]</td>
# <td>[96, 0]</td>
# <td>[85, 0]</td>
# <td>[14, 0]</td>
# <td>[40, 0]</td>
# <td>[255, 0]</td>
# <td>[126, 0]</td>
# <td>[118, 0]</td>
# <td>[159, 0]</td>
# <td>[190, 0]</td>
# <td>[405, 0]</td>
# <td>[194, 0]</td>
# <td>[118, 0]</td>
# <td>[151, 0]</td>
# <td>[119, 0]</td>
# <td>[116, 0]</td>
# <td>[129, 0]</td>
# <td>[111, 0]</td>
# <td>[355, 0]</td>
# <td>[318, 0]</td>
# <td>[245, 0]</td>
# <td>[479, 0]</td>
# <td>[397, 0]</td>
# <td>[1723, 0]</td>
# <td>[146, 0]</td>
# <td>[45, 0]</td>
# <td>[92, 0]</td>
# <td>[136, 0]</td>
# <td>[45, 0]</td>
# <td>[35, 0]</td>
# <td>[76, 0]</td>
# <td>[30, 0]</td>
# <td>[1013, 0]</td>
# <td>[104, 0]</td>
# <td>[164, 0]</td>
# <td>[236, 0]</td>
# <td>[639, 0]</td>
# <td>[35, 0]</td>
# <td>[153, 0]</td>
# <td>[193, 0]</td>
# <td>[299, 0]</td>
# <td>[74, 0]</td>
# <td>[38, 0]</td>
# <td>[46, 0]</td>
# <td>[48, 0]</td>
# <td>[40, 0]</td>
# <td>[26, 0]</td>
# <td>[16, 0]</td>
# <td>[29, 0]</td>
# <td>[37, 0]</td>
# <td>[82, 0]</td>
# <td>[110, 0]</td>
# <td>[62, 0]</td>
# <td>[37, 0]</td>
# <td>[64, 0]</td>
# <td>[58, 0]</td>
# <td>[49, 0]</td>
# <td>[52, 0]</td>
# <td>[50, 0]</td>
# <td>[43, 0]</td>
# <td>[57, 0]</td>
# <td>[197, 0]</td>
# <td>[53, 0]</td>
# <td>[36, 0]</td>
# <td>[43, 0]</td>
# <td>[58, 0]</td>
# <td>[60, 0]</td>
# <td>[0, 76]</td>
# <td>[117, 0]</td>
# <td>[132, 0]</td>
# <td>[24, 0]</td>
# <td>[4, 0]</td>
# <td>[293, 0]</td>
# <td>[24, 0]</td>
# <td>[17, 0]</td>
# <td>[26, 0]</td>
# <td>[18, 0]</td>
# <td>[17, 0]</td>
# <td>[70, 0]</td>
# <td>[118, 0]</td>
# <td>[104, 0]</td>
# <td>[20, 0]</td>
# <td>[44, 0]</td>
# <td>[135, 0]</td>
# <td>[141, 0]</td>
# <td>[104, 0]</td>
# <td>[133, 0]</td>
# <td>[153, 0]</td>
# <td>[255, 0]</td>
# <td>[135, 0]</td>
# <td>[226, 0]</td>
# <td>[168, 0]</td>
# <td>[259, 0]</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1725259__C__[T]</td>
# <td>[85, 0]</td>
# <td>[219, 0]</td>
# <td>[129, 0]</td>
# <td>[89, 1]</td>
# <td>[21, 0]</td>
# <td>[46, 0]</td>
# <td>[313, 0]</td>
# <td>[158, 0]</td>
# <td>[155, 0]</td>
# <td>[193, 0]</td>
# <td>[264, 0]</td>
# <td>[432, 0]</td>
# <td>[222, 0]</td>
# <td>[114, 0]</td>
# <td>[141, 0]</td>
# <td>[118, 0]</td>
# <td>[125, 0]</td>
# <td>[135, 0]</td>
# <td>[119, 1]</td>
# <td>[298, 0]</td>
# <td>[296, 0]</td>
# <td>[231, 0]</td>
# <td>[434, 0]</td>
# <td>[370, 0]</td>
# <td>[1674, 0]</td>
# <td>[150, 0]</td>
# <td>[0, 44]</td>
# <td>[101, 0]</td>
# <td>[157, 0]</td>
# <td>[39, 0]</td>
# <td>[52, 0]</td>
# <td>[88, 0]</td>
# <td>[20, 0]</td>
# <td>[1250, 0]</td>
# <td>[133, 0]</td>
# <td>[149, 0]</td>
# <td>[211, 0]</td>
# <td>[710, 0]</td>
# <td>[27, 0]</td>
# <td>[178, 0]</td>
# <td>[183, 0]</td>
# <td>[0, 225]</td>
# <td>[0, 60]</td>
# <td>[0, 34]</td>
# <td>[0, 42]</td>
# <td>[0, 40]</td>
# <td>[43, 0]</td>
# <td>[28, 0]</td>
# <td>[19, 0]</td>
# <td>[0, 25]</td>
# <td>[0, 30]</td>
# <td>[87, 0]</td>
# <td>[114, 0]</td>
# <td>[0, 58]</td>
# <td>[36, 0]</td>
# <td>[56, 0]</td>
# <td>[55, 0]</td>
# <td>[0, 41]</td>
# <td>[0, 42]</td>
# <td>[0, 40]</td>
# <td>[43, 0]</td>
# <td>[0, 56]</td>
# <td>[192, 0]</td>
# <td>[49, 0]</td>
# <td>[0, 34]</td>
# <td>[45, 0]</td>
# <td>[0, 53]</td>
# <td>[0, 49]</td>
# <td>[81, 0]</td>
# <td>[0, 101]</td>
# <td>[134, 0]</td>
# <td>[0, 23]</td>
# <td>[5, 0]</td>
# <td>[0, 281]</td>
# <td>[23, 0]</td>
# <td>[0, 15]</td>
# <td>[0, 26]</td>
# <td>[0, 12]</td>
# <td>[17, 0]</td>
# <td>[63, 0]</td>
# <td>[101, 0]</td>
# <td>[100, 0]</td>
# <td>[18, 0]</td>
# <td>[48, 0]</td>
# <td>[0, 112]</td>
# <td>[155, 0]</td>
# <td>[123, 0]</td>
# <td>[142, 0]</td>
# <td>[161, 0]</td>
# <td>[265, 0]</td>
# <td>[126, 0]</td>
# <td>[232, 0]</td>
# <td>[179, 0]</td>
# <td>[263, 0]</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1725274__C__[T]</td>
# <td>[72, 0]</td>
# <td>[238, 0]</td>
# <td>[160, 0]</td>
# <td>[105, 0]</td>
# <td>[25, 0]</td>
# <td>[48, 0]</td>
# <td>[315, 0]</td>
# <td>[187, 0]</td>
# <td>[189, 0]</td>
# <td>[195, 0]</td>
# <td>[308, 2]</td>
# <td>[461, 0]</td>
# <td>[203, 0]</td>
# <td>[111, 0]</td>
# <td>[132, 0]</td>
# <td>[114, 0]</td>
# <td>[136, 0]</td>
# <td>[137, 0]</td>
# <td>[124, 0]</td>
# <td>[301, 0]</td>
# <td>[295, 0]</td>
# <td>[224, 0]</td>
# <td>[445, 0]</td>
# <td>[337, 0]</td>
# <td>[1745, 1]</td>
# <td>[157, 0]</td>
# <td>[57, 0]</td>
# <td>[93, 0]</td>
# <td>[153, 0]</td>
# <td>[42, 0]</td>
# <td>[45, 0]</td>
# <td>[93, 0]</td>
# <td>[22, 0]</td>
# <td>[1374, 0]</td>
# <td>[123, 0]</td>
# <td>[142, 0]</td>
# <td>[177, 0]</td>
# <td>[798, 0]</td>
# <td>[26, 0]</td>
# <td>[183, 0]</td>
# <td>[189, 0]</td>
# <td>[239, 0]</td>
# <td>[79, 0]</td>
# <td>[38, 0]</td>
# <td>[53, 0]</td>
# <td>[51, 0]</td>
# <td>[41, 0]</td>
# <td>[25, 0]</td>
# <td>[19, 0]</td>
# <td>[28, 0]</td>
# <td>[33, 0]</td>
# <td>[77, 0]</td>
# <td>[119, 0]</td>
# <td>[62, 0]</td>
# <td>[41, 0]</td>
# <td>[58, 0]</td>
# <td>[52, 0]</td>
# <td>[46, 0]</td>
# <td>[53, 0]</td>
# <td>[48, 0]</td>
# <td>[45, 0]</td>
# <td>[56, 0]</td>
# <td>[160, 0]</td>
# <td>[48, 0]</td>
# <td>[35, 0]</td>
# <td>[36, 0]</td>
# <td>[57, 0]</td>
# <td>[51, 0]</td>
# <td>[86, 0]</td>
# <td>[105, 0]</td>
# <td>[145, 0]</td>
# <td>[26, 0]</td>
# <td>[5, 0]</td>
# <td>[313, 0]</td>
# <td>[23, 0]</td>
# <td>[13, 0]</td>
# <td>[29, 0]</td>
# <td>[16, 0]</td>
# <td>[17, 0]</td>
# <td>[59, 0]</td>
# <td>[85, 0]</td>
# <td>[99, 0]</td>
# <td>[19, 0]</td>
# <td>[52, 0]</td>
# <td>[133, 0]</td>
# <td>[153, 0]</td>
# <td>[126, 0]</td>
# <td>[139, 0]</td>
# <td>[156, 0]</td>
# <td>[280, 0]</td>
# <td>[117, 0]</td>
# <td>[242, 0]</td>
# <td>[183, 0]</td>
# <td>[271, 0]</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3__1725316__C__[T]</td>
# <td>[87, 0]</td>
# <td>[211, 0]</td>
# <td>[146, 0]</td>
# <td>[103, 0]</td>
# <td>[16, 0]</td>
# <td>[53, 0]</td>
# <td>[291, 0]</td>
# <td>[175, 0]</td>
# <td>[162, 0]</td>
# <td>[179, 0]</td>
# <td>[239, 0]</td>
# <td>[456, 0]</td>
# <td>[200, 0]</td>
# <td>[94, 0]</td>
# <td>[0, 114]</td>
# <td>[116, 0]</td>
# <td>[129, 0]</td>
# <td>[137, 0]</td>
# <td>[104, 0]</td>
# <td>[330, 0]</td>
# <td>[0, 274]</td>
# <td>[246, 0]</td>
# <td>[478, 0]</td>
# <td>[305, 0]</td>
# <td>[1950, 0]</td>
# <td>[162, 0]</td>
# <td>[60, 0]</td>
# <td>[102, 0]</td>
# <td>[204, 0]

# %%
# Find which SNPs cannot be genotyped in which samples
(etl
    .fromvcf("%s/pgv4_gatk_subset_to_kelch13_less_DNA_GATC.vcf.gz" % (DATA_DIR))
    .vcfmeltsamples()
    .vcfunpackcall()
    .cut(['CHROM', 'POS', 'REF', 'ALT', 'SAMPLE', 'AD'])
    .addfield('variant', lambda rec: "%s__%s__%s__%s" % (rec['CHROM'], rec['POS'], rec['REF'], rec['ALT']))
    .addfield('GT', lambda rec: determine_GT(rec['AD']))
    .convert('SAMPLE', lambda val: "%s__ILMN" % val)
    .selectnone('GT')
).displayall()
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>CHROM</th>
# <th>POS</th>
# <th>REF</th>
# <th>ALT</th>
# <th>SAMPLE</th>
# <th>AD</th>
# <th>variant</th>
# <th>GT</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725033</td>
# <td>T</td>
# <td>[A]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725033__T__[A]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725221</td>
# <td>T</td>
# <td>[A]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725221__T__[A]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725233</td>
# <td>C</td>
# <td>[T]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725233__C__[T]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725247</td>
# <td>T</td>
# <td>[A]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725247__T__[A]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725440</td>
# <td>C</td>
# <td>[T]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725440__C__[T]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725528</td>
# <td>A</td>
# <td>[G]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725528__A__[G]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725662</td>
# <td>A</td>
# <td>[T]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725662__A__[T]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725669</td>
# <td>T</td>
# <td>[A]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[3, 0]</td>
# <td>Pf3D7_13_v3__1725669__T__[A]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725671</td>
# <td>G</td>
# <td>[A]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725671__G__[A]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725672</td>
# <td>G</td>
# <td>[A]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725672__G__[A]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725673</td>
# <td>A</td>
# <td>[C]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725673__A__[C]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725676</td>
# <td>G</td>
# <td>[A]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[3, 0]</td>
# <td>Pf3D7_13_v3__1725676__G__[A]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725678</td>
# <td>T</td>
# <td>[C]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725678__T__[C]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725684</td>
# <td>T</td>
# <td>[A]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[2, 0]</td>
# <td>Pf3D7_13_v3__1725684__T__[A]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725690</td>
# <td>A</td>
# <td>[T]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[2, 0]</td>
# <td>Pf3D7_13_v3__1725690__A__[T]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725711</td>
# <td>C</td>
# <td>[G]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725711__C__[G]</td>
# <td>None</td>
# </tr>
# <tr>
# <td>Pf3D7_13_v3</td>
# <td style='text-align: right'>1725841</td>
# <td>A</td>
# <td>[G]</td>
# <td>PH0883-Cx__ILMN</td>
# <td>[4, 0]</td>
# <td>Pf3D7_13_v3__1725841__A__[G]</td>
# <td>None</td>
# </tr>
# </tbody>
# </table>

# %%
wb = openpyxl.Workbook(optimized_write=True, encoding=locale.getpreferredencoding())

tbl_merged_calls = collections.OrderedDict()
for callset in ['GATC']:
    tbl_merged_calls[callset] = collections.OrderedDict()
    for bad_qual_distance in [2, 1, 0, None]:
        tbl_merged_calls[callset][str(bad_qual_distance)] = (
            tbl_capillary_calls[callset][str(bad_qual_distance)]
            .outerjoin(tbl_sequenom_calls[callset])
            .outerjoin(tbl_illumina_calls[callset])
            .rename('variant', 'Concat_variant')
        )
        tbl_merged_calls[callset][str(bad_qual_distance)] = tbl_merged_calls[callset][str(bad_qual_distance)].cut(sort(tbl_merged_calls[callset][str(bad_qual_distance)].header()).tolist())
        ws = wb.create_sheet(title="%s_%s" % (callset, str(bad_qual_distance)))
        for row in tbl_merged_calls[callset][str(bad_qual_distance)]:
            ws.append(row)
        print(callset, str(bad_qual_distance))
        tbl_merged_calls[callset][str(bad_qual_distance)].displayall()

wb.save(MERGED_CALLS_EXCEL_FN)
# Out:
# GATC 2
# <table class='petl'>
# <thead>
# <tr>
# <th>Concat_variant</th>
# <th>PD0004-C_ForwardRep_GATC</th>
# <th>PD0004-C_Forward_GATC</th>
# <th>PD0004-C_Reverse_GATC</th>
# <th>PD0004-C__ILMN</th>
# <th>PD0004-C__SQNM</th>
# <th>PD0005-01_ForwardRep_GATC</th>
# <th>PD0005-01_Forward_GATC</th>
# <th>PD0005-01_Reverse_GATC</th>
# <th>PD0005-01__ILMN</th>
# <th>PD0005-01__SQNM</th>
# <th>PD0005-C_ForwardRep_GATC</th>
# <th>PD0005-C_Forward_GATC</th>
# <th>PD0005-C_Reverse_GATC</th>
# <th>PD0005-C__ILMN</th>
# <th>PD0005-C__SQNM</th>
# <th>PD0016-C_ForwardRep_GATC</th>
# <th>PD0016-C_Forward_GATC</th>
# <th>PD0016-C_Reverse_GATC</th>
# <th>PD0016-C__ILMN</th>
# <th>PD0016-C__SQNM</th>
# <th>PD0031-C_ForwardRep_GATC</th>
# <th>PD0031-C_Forward_GATC</th>
# <th>PD0031-C_Reverse_GATC</th>
# <th>PD0031-C__ILMN</th>
# <th>PD0031-C__SQNM</th>
# <th>PD0033-C_ForwardRep_GATC</th>
# <th>PD0033-C_Forward_GATC</th>
# <th>PD0033-C_Reverse_GATC</th>
# <th>PD0033-C__ILMN</th>
# <th>PD0033-C__SQNM</th>
# <th>PD0037-C_ForwardRep_GATC</th>
# <th>PD0037-C_Forward_GATC</th>
# <th>PD0037-C_Reverse_GATC</th>
# <th>PD0037-C__ILMN</th>
# <th>PD0037-C__SQNM</th>
# <th>PD0038-C_ForwardRep_GATC</th>
# <th>PD0038-C_Forward_GATC</th>
# <th>PD0038-C_Reverse_GATC</th>
# <th>PD0038-C__ILMN</th>
# <th>PD0038-C__SQNM</th>
# <th>PD0048-C_ForwardRep_GATC</th>
# <th>PD0048-C_Forward_GATC</th>
# <th>PD0048-C_Reverse_GATC</th>
# <th>PD0048-C__ILMN</th>
# <th>PD0048-C__SQNM</th>
# <th>PD0056-C_ForwardRep_GATC</th>
# <th>PD0056-C_Forward_GATC</th>
# <th>PD0056-C_Reverse_GATC</th>
# <th>PD0056-C__ILMN</th>
# <th>PD0056-C__SQNM</th>
# <th>PD0058-C_ForwardRep_GATC</th>
# <th>PD0058-C_Forward_GATC</th>
# <th>PD0058-C_Reverse_GATC</th>
# <th>PD0058-C__ILMN</th>
# <th>PD0058-C__SQNM</th>
# <th>PD0067-C_ForwardRep_GATC</th>
# <th>PD0067-C_Forward_GATC</th>
# <th>PD0067-C_Reverse_GATC</th>
# <th>PD0067-C__ILMN</th>
# <th>PD0067-C__SQNM</th>
# <th>PD0073-C_ForwardRep_GATC</th>
# <th>PD0073-C_Forward_GATC</th>
# <th>PD0073-C_Reverse_GATC</th>
# <th>PD0073-C__ILMN</th>
# <th>PD0073-C__SQNM</th>
# <th>PD0075-C_ForwardRep_GATC</th>
# <th>PD0075-C_Forward_GATC</th>
# <th>PD0075-C_Reverse_GATC</th>
# <th>PD0075-C__ILMN</th>
# <th>PD0075-C__SQNM</th>
# <th>PD0079-C_ForwardRep_GATC</th>
# <th>PD0079-C_Forward_GATC</th>
# <th>PD0079-C_Reverse_GATC</th>
# <th>PD0079-C__ILMN</th>
# <th>PD0079-C__SQNM</th>
# <th>PD0090-C_ForwardRep_GATC</th>
# <th>PD0090-C_Forward_GATC</th>
# <th>PD0090-C_Reverse_GATC</th>
# <th>PD0090-C__ILMN</th>
# <th>PD0090-C__SQNM</th>
# <th>PD0098-C_ForwardRep_GATC</th>
# <th>PD0098-C_Forward_GATC</th>
# <th>PD0098-C_Reverse_GATC</th>
# <th>PD0098-C__ILMN</th>
# <th>PD0098-C__SQNM</th>
# <th>PD0103-C_ForwardRep_GATC</th>
# <th>PD0103-C_Forward_GATC</th>
# <th>PD0103-C_Reverse_GATC</th>
# <th>PD0103-C__ILMN</th>
# <th>PD0103-C__SQNM</th>
# <th>PD0105-C_ForwardRep_GATC</th>
# <th>PD0105-C_Forward_GATC</th>
# <th>PD0105-C_Reverse_GATC</th>
# <th>PD0105-C__ILMN</th>
# <th>PD0105-C__SQNM</th>
# <th>PD0115-Cx_ForwardRep_GATC</th>
# <th>PD0115-Cx_Forward_GATC</th>
# <th>PD0115-Cx_Reverse_GATC</th>
# <th>PD0115-Cx__ILMN</th>
# <th>PD0115-Cx__SQNM</th>
# <th>PD0126-C_ForwardRep_GATC</th>
# <th>PD0126-C_Forward_GATC</th>
# <th>PD0126-C_Reverse_GATC</th>
# <th>PD0126-C__ILMN</th>
# <th>PD0126-C__SQNM</th>
# <th>PD0134-C_ForwardRep_GATC</th>
# <th>PD0134-C_Forward_GATC</th>
# <th>PD0134-C_Reverse_GATC</th>
# <th>PD0134-C__ILMN</th>
# <th>PD0134-C__SQNM</th>
# <th>PD0135-C_ForwardRep_GATC</th>
# <th>PD0135-C_Forward_GATC</th>
# <th>PD0135-C_Reverse_GATC</th>
# <th>PD0135-C__ILMN</th>
# <th>PD0135-C__SQNM</th>
# <th>PD0136-C_ForwardRep_GATC</th>
# <th>PD0136-C_Forward_GATC</th>
# <th>PD0136-C_Reverse_GATC</th>
# <th>PD0136-C__ILMN</th>
# <th>PD0136-C__SQNM</th>
# <th>PD0137-C_ForwardRep_GATC</th>
# <th>PD0137-C_Forward_GATC</th>
# <th>PD0137-C_Reverse_GATC</th>
# <th>PD0137-C__ILMN</th>
# <th>PD0137-C__SQNM</th>
# <th>PD0459-Cx_ForwardRep_GATC</th>
# <th>PD0459-Cx_Forward_GATC</th>
# <th>PD0459-Cx_Reverse_GATC</th>
# <th>PD0459-Cx__ILMN</th>
# <th>PD0459-Cx__SQNM</th>
# <th>PH0002-C_ForwardRep_GATC</th>
# <th>PH0002-C_Forward_GATC</th>
# <th>PH0002-C_Reverse_GATC</th>
# <th>PH0002-C__ILMN</th>
# <th>PH0002-C__SQNM</th>
# <th>PH0003-C_ForwardRep_GATC</th>
# <th>PH0003-C_Forward_GATC</th>
# <th>PH0003-C_Reverse_GATC</th>
# <th>PH0003-C__ILMN</th>
# <th>PH0003-C__SQNM</th>
# <th>PH0012-C_ForwardRep_GATC</th>
# <th>PH0012-C_Forward_GATC</th>
# <th>PH0012-C_Reverse_GATC</th>
# <th>PH0012-C__ILMN</th>
# <th>PH0012-C__SQNM</th>
# <th>PH0013-C_ForwardRep_GATC</th>
# <th>PH0013-C_Forward_GATC</th>
# <th>PH0013-C_Reverse_GATC</th>
# <th>PH0013-C__ILMN</th>
# <th>PH0013-C__SQNM</th>
# <th>PH0016-C_ForwardRep_GATC</th>
# <th>PH0016-C_Forward_GATC</th>
# <th>PH0016-C_Reverse_GATC</th>
# <th>PH0016-C__ILMN</th>
# <th>PH0016-C__SQNM</th>
# <th>PH0017-C_ForwardRep_GATC</th>
# <th>PH0017-C_Forward_GATC</th>
# <th>PH0017-C_Reverse_GATC</th>
# <th>PH0017-C__ILMN</th>
# <th>PH0017-C__SQNM</th>
# <th>PH0020-C_ForwardRep_GATC</th>
# <th>PH0020-C_Forward_GATC</th>
# <th>PH0020-C_Reverse_GATC</th>
# <th>PH0020-C__ILMN</th>
# <th>PH0020-C__SQNM</th>
# <th>PH0022-C_ForwardRep_GATC</th>
# <th>PH0022-C_Forward_GATC</th>
# <th>PH0022-C_Reverse_GATC</th>
# <th>PH0022-C__ILMN</th>
# <th>PH0022-C__SQNM</th>
# <th>PH0024-C_ForwardRep_GATC</th>
# <th>PH0024-C_Forward_GATC</th>
# <th>PH0024-C_Reverse_GATC</th>
# <th>PH0024-C__ILMN</th>
# <th>PH0024-C__SQNM</th>
# <th>PH0027-C_ForwardRep_GATC</th>
# <th>PH0027-C_Forward_GATC</th>
# <th>PH0027-C_Reverse_GATC</th>
# <th>PH0027-C__ILMN</th>
# <th>PH0027-C__SQNM</th>
# <th>PH0028-Cx_ForwardRep_GATC</th>
# <th>PH0028-Cx_Forward_GATC</th>
# <th>PH0028-Cx_Reverse_GATC</th>
# <th>PH0028-Cx__ILMN</th>
# <th>PH0028-Cx__SQNM</th>
# <th>PH0029-Cx_ForwardRep_GATC</th>
# <th>PH0029-Cx_Forward_GATC</th>
# <th>PH0029-Cx_Reverse_GATC</th>
# <th>PH0029-Cx__ILMN</th>
# <th>PH0029-Cx__SQNM</th>
# <th>PH0042-C_ForwardRep_GATC</th>
# <th>PH0042-C_Forward_GATC</th>
# <th>PH0042-C_Reverse_GATC</th>
# <th>PH0042-C__ILMN</th>
# <th>PH0042-C__SQNM</th>
# <th>PH0043-C_ForwardRep_GATC</th>
# <th>PH0043-C_Forward_GATC</th>
# <th>PH0043-C_Reverse_GATC</th>
# <th>PH0043-C__ILMN</th>
# <th>PH0043-C__SQNM</th>
# <th>PH0209-C_ForwardRep_GATC</th>
# <th>PH0209-C_Forward_GATC</th>
# <th>PH0209-C_Reverse_GATC</th>
# <th>PH0209-C__ILMN</th>
# <th>PH0209-C__SQNM</th>
# <th>PH0212-C_ForwardRep_GATC</th>
# <th>PH0212-C_Forward_GATC</th>
# <th>PH0212-C_Reverse_GATC</th>
# <th>PH0212-C__ILMN</th>
# <th>PH0212-C__SQNM</th>
# <th>PH0218-C_ForwardRep_GATC</th>
# <th>PH0218-C_Forward_GATC</th>
# <th>PH0218-C_Reverse_GATC</th>
# <th>PH0218-C__ILMN</th>
# <th>PH0218-C__SQNM</th>
# <th>PH0221-C_ForwardRep_GATC</th>
# <th>PH0221-C_Forward_GATC</th>
# <th>PH0221-C_Reverse_GATC</th>
# <th>PH0221-C__ILMN</th>
# <th>PH0221-C__SQNM</th>
# <th>PH0224-C_ForwardRep_GATC</th>
# <th>PH0224-C_Forward_GATC</th>
# <th>PH0224-C_Reverse_GATC</th>
# <th>PH0224-C__ILMN</th>
# <th>PH0224-C__SQNM</th>
# <th>PH0225-C_ForwardRep_GATC</th>
# <th>PH0225-C_Forward_GATC</th>
# <th>PH0225-C_Reverse_GATC</th>
# <th>PH0225-C__ILMN</th>
# <th>PH0225-C__SQNM</th>
# <th>PH0232-C_ForwardRep_GATC</th>
# <th>PH0232-C_Forward_GATC</th>
# <th>PH0232-C_Reverse_GATC</th>
# <th>PH0232-C__ILMN</th>
# <th>PH0232-C__SQNM</th>
# <th>PH0234-C_ForwardRep_GATC</th>
# <th>PH0234-C_Forward_GATC</th>
# <th>PH0234-C_Reverse_GATC</th>
# <th>PH0234-C__ILMN</th>
# <th>PH0234-C__SQNM</th>
# <th>PH0235-C_ForwardRep_GATC</th>
# <th>PH0235-C_Forward_GATC</th>
# <th>PH0235-C_Reverse_GATC</th>
# <th>PH0235-C__ILMN</th>
# <th>PH0235-C__SQNM</th>
# <th>PH0236-C_ForwardRep_GATC</th>
# <th>PH0236-C_Forward_GATC</th>
# <th>PH0236-C_Reverse_GATC</th>
# <th>PH0236-C__ILMN</th>
# <th>PH0236-C__SQNM</th>
# <th>PH0284-C_ForwardRep_GATC</th>
# <th>PH0284-C_Forward_GATC</th>
# <th>PH0284-C_Reverse_GATC</th>
# <th>PH0284-C__ILMN</th>
# <th>PH0284-C__SQNM</th>
# <th>PH0303-CW_ForwardRep_GATC</th>
# <th>PH0303-CW_Forward_GATC</th>
# <th>PH0303-CW_Reverse_GATC</th>
# <th>PH0303-CW__ILMN</th>
# <th>PH0303-CW__SQNM</th>
# <th>PH0326-C_ForwardRep_GATC</th>
# <th>PH0326-C_Forward_GATC</th>
# <th>PH0326-C_Reverse_GATC</th>
# <th>PH0326-C__ILMN</th>
# <th>PH0326-C__SQNM</th>
# <th>PH0337-C_ForwardRep_GATC</th>
# <th>PH0337-C_Forward_GATC</th>
# <th>PH0337-C_Reverse_GATC</th>
# <th>PH0337-C__ILMN</th>
# <th>PH0337-C__SQNM</th>
# <th>PH0349-C_ForwardRep_GATC</th>
# <th>PH0349-C_Forward_GATC</th>
# <th>PH0349-C_Reverse_GATC</th>
# <th>PH0349-C__ILMN</th>
# <th>PH0349-C__SQ
# GATC 1
# <table class='petl'>
# <thead>
# <tr>
# <th>Concat_variant</th>
# <th>PD0004-C_ForwardRep_GATC</th>
# <th>PD0004-C_Forward_GATC</th>
# <th>PD0004-C_Reverse_GATC</th>
# <th>PD0004-C__ILMN</th>
# <th>PD0004-C__SQNM</th>
# <th>PD0005-01_ForwardRep_GATC</th>
# <th>PD0005-01_Forward_GATC</th>
# <th>PD0005-01_Reverse_GATC</th>
# <th>PD0005-01__ILMN</th>
# <th>PD0005-01__SQNM</th>
# <th>PD0005-C_ForwardRep_GATC</th>
# <th>PD0005-C_Forward_GATC</th>
# <th>PD0005-C_Reverse_GATC</th>
# <th>PD0005-C__ILMN</th>
# <th>PD0005-C__SQNM</th>
# <th>PD0016-C_ForwardRep_GATC</th>
# <th>PD0016-C_Forward_GATC</th>
# <th>PD0016-C_Reverse_GATC</th>
# <th>PD0016-C__ILMN</th>
# <th>PD0016-C__SQNM</th>
# <th>PD0031-C_ForwardRep_GATC</th>
# <th>PD0031-C_Forward_GATC</th>
# <th>PD0031-C_Reverse_GATC</th>
# <th>PD0031-C__ILMN</th>
# <th>PD0031-C__SQNM</th>
# <th>PD0033-C_ForwardRep_GATC</th>
# <th>PD0033-C_Forward_GATC</th>
# <th>PD0033-C_Reverse_GATC</th>
# <th>PD0033-C__ILMN</th>
# <th>PD0033-C__SQNM</th>
# <th>PD0037-C_ForwardRep_GATC</th>
# <th>PD0037-C_Forward_GATC</th>
# <th>PD0037-C_Reverse_GATC</th>
# <th>PD0037-C__ILMN</th>
# <th>PD0037-C__SQNM</th>
# <th>PD0038-C_ForwardRep_GATC</th>
# <th>PD0038-C_Forward_GATC</th>
# <th>PD0038-C_Reverse_GATC</th>
# <th>PD0038-C__ILMN</th>
# <th>PD0038-C__SQNM</th>
# <th>PD0048-C_ForwardRep_GATC</th>
# <th>PD0048-C_Forward_GATC</th>
# <th>PD0048-C_Reverse_GATC</th>
# <th>PD0048-C__ILMN</th>
# <th>PD0048-C__SQNM</th>
# <th>PD0056-C_ForwardRep_GATC</th>
# <th>PD0056-C_Forward_GATC</th>
# <th>PD0056-C_Reverse_GATC</th>
# <th>PD0056-C__ILMN</th>
# <th>PD0056-C__SQNM</th>
# <th>PD0058-C_ForwardRep_GATC</th>
# <th>PD0058-C_Forward_GATC</th>
# <th>PD0058-C_Reverse_GATC</th>
# <th>PD0058-C__ILMN</th>
# <th>PD0058-C__SQNM</th>
# <th>PD0067-C_ForwardRep_GATC</th>
# <th>PD0067-C_Forward_GATC</th>
# <th>PD0067-C_Reverse_GATC</th>
# <th>PD0067-C__ILMN</th>
# <th>PD0067-C__SQNM</th>
# <th>PD0073-C_ForwardRep_GATC</th>
# <th>PD0073-C_Forward_GATC</th>
# <th>PD0073-C_Reverse_GATC</th>
# <th>PD0073-C__ILMN</th>
# <th>PD0073-C__SQNM</th>
# <th>PD0075-C_ForwardRep_GATC</th>
# <th>PD0075-C_Forward_GATC</th>
# <th>PD0075-C_Reverse_GATC</th>
# <th>PD0075-C__ILMN</th>
# <th>PD0075-C__SQNM</th>
# <th>PD0079-C_ForwardRep_GATC</th>
# <th>PD0079-C_Forward_GATC</th>
# <th>PD0079-C_Reverse_GATC</th>
# <th>PD0079-C__ILMN</th>
# <th>PD0079-C__SQNM</th>
# <th>PD0090-C_ForwardRep_GATC</th>
# <th>PD0090-C_Forward_GATC</th>
# <th>PD0090-C_Reverse_GATC</th>
# <th>PD0090-C__ILMN</th>
# <th>PD0090-C__SQNM</th>
# <th>PD0098-C_ForwardRep_GATC</th>
# <th>PD0098-C_Forward_GATC</th>
# <th>PD0098-C_Reverse_GATC</th>
# <th>PD0098-C__ILMN</th>
# <th>PD0098-C__SQNM</th>
# <th>PD0103-C_ForwardRep_GATC</th>
# <th>PD0103-C_Forward_GATC</th>
# <th>PD0103-C_Reverse_GATC</th>
# <th>PD0103-C__ILMN</th>
# <th>PD0103-C__SQNM</th>
# <th>PD0105-C_ForwardRep_GATC</th>
# <th>PD0105-C_Forward_GATC</th>
# <th>PD0105-C_Reverse_GATC</th>
# <th>PD0105-C__ILMN</th>
# <th>PD0105-C__SQNM</th>
# <th>PD0115-Cx_ForwardRep_GATC</th>
# <th>PD0115-Cx_Forward_GATC</th>
# <th>PD0115-Cx_Reverse_GATC</th>
# <th>PD0115-Cx__ILMN</th>
# <th>PD0115-Cx__SQNM</th>
# <th>PD0126-C_ForwardRep_GATC</th>
# <th>PD0126-C_Forward_GATC</th>
# <th>PD0126-C_Reverse_GATC</th>
# <th>PD0126-C__ILMN</th>
# <th>PD0126-C__SQNM</th>
# <th>PD0134-C_ForwardRep_GATC</th>
# <th>PD0134-C_Forward_GATC</th>
# <th>PD0134-C_Reverse_GATC</th>
# <th>PD0134-C__ILMN</th>
# <th>PD0134-C__SQNM</th>
# <th>PD0135-C_ForwardRep_GATC</th>
# <th>PD0135-C_Forward_GATC</th>
# <th>PD0135-C_Reverse_GATC</th>
# <th>PD0135-C__ILMN</th>
# <th>PD0135-C__SQNM</th>
# <th>PD0136-C_ForwardRep_GATC</th>
# <th>PD0136-C_Forward_GATC</th>
# <th>PD0136-C_Reverse_GATC</th>
# <th>PD0136-C__ILMN</th>
# <th>PD0136-C__SQNM</th>
# <th>PD0137-C_ForwardRep_GATC</th>
# <th>PD0137-C_Forward_GATC</th>
# <th>PD0137-C_Reverse_GATC</th>
# <th>PD0137-C__ILMN</th>
# <th>PD0137-C__SQNM</th>
# <th>PD0459-Cx_ForwardRep_GATC</th>
# <th>PD0459-Cx_Forward_GATC</th>
# <th>PD0459-Cx_Reverse_GATC</th>
# <th>PD0459-Cx__ILMN</th>
# <th>PD0459-Cx__SQNM</th>
# <th>PH0002-C_ForwardRep_GATC</th>
# <th>PH0002-C_Forward_GATC</th>
# <th>PH0002-C_Reverse_GATC</th>
# <th>PH0002-C__ILMN</th>
# <th>PH0002-C__SQNM</th>
# <th>PH0003-C_ForwardRep_GATC</th>
# <th>PH0003-C_Forward_GATC</th>
# <th>PH0003-C_Reverse_GATC</th>
# <th>PH0003-C__ILMN</th>
# <th>PH0003-C__SQNM</th>
# <th>PH0012-C_ForwardRep_GATC</th>
# <th>PH0012-C_Forward_GATC</th>
# <th>PH0012-C_Reverse_GATC</th>
# <th>PH0012-C__ILMN</th>
# <th>PH0012-C__SQNM</th>
# <th>PH0013-C_ForwardRep_GATC</th>
# <th>PH0013-C_Forward_GATC</th>
# <th>PH0013-C_Reverse_GATC</th>
# <th>PH0013-C__ILMN</th>
# <th>PH0013-C__SQNM</th>
# <th>PH0016-C_ForwardRep_GATC</th>
# <th>PH0016-C_Forward_GATC</th>
# <th>PH0016-C_Reverse_GATC</th>
# <th>PH0016-C__ILMN</th>
# <th>PH0016-C__SQNM</th>
# <th>PH0017-C_ForwardRep_GATC</th>
# <th>PH0017-C_Forward_GATC</th>
# <th>PH0017-C_Reverse_GATC</th>
# <th>PH0017-C__ILMN</th>
# <th>PH0017-C__SQNM</th>
# <th>PH0020-C_ForwardRep_GATC</th>
# <th>PH0020-C_Forward_GATC</th>
# <th>PH0020-C_Reverse_GATC</th>
# <th>PH0020-C__ILMN</th>
# <th>PH0020-C__SQNM</th>
# <th>PH0022-C_ForwardRep_GATC</th>
# <th>PH0022-C_Forward_GATC</th>
# <th>PH0022-C_Reverse_GATC</th>
# <th>PH0022-C__ILMN</th>
# <th>PH0022-C__SQNM</th>
# <th>PH0024-C_ForwardRep_GATC</th>
# <th>PH0024-C_Forward_GATC</th>
# <th>PH0024-C_Reverse_GATC</th>
# <th>PH0024-C__ILMN</th>
# <th>PH0024-C__SQNM</th>
# <th>PH0027-C_ForwardRep_GATC</th>
# <th>PH0027-C_Forward_GATC</th>
# <th>PH0027-C_Reverse_GATC</th>
# <th>PH0027-C__ILMN</th>
# <th>PH0027-C__SQNM</th>
# <th>PH0028-Cx_ForwardRep_GATC</th>
# <th>PH0028-Cx_Forward_GATC</th>
# <th>PH0028-Cx_Reverse_GATC</th>
# <th>PH0028-Cx__ILMN</th>
# <th>PH0028-Cx__SQNM</th>
# <th>PH0029-Cx_ForwardRep_GATC</th>
# <th>PH0029-Cx_Forward_GATC</th>
# <th>PH0029-Cx_Reverse_GATC</th>
# <th>PH0029-Cx__ILMN</th>
# <th>PH0029-Cx__SQNM</th>
# <th>PH0042-C_ForwardRep_GATC</th>
# <th>PH0042-C_Forward_GATC</th>
# <th>PH0042-C_Reverse_GATC</th>
# <th>PH0042-C__ILMN</th>
# <th>PH0042-C__SQNM</th>
# <th>PH0043-C_ForwardRep_GATC</th>
# <th>PH0043-C_Forward_GATC</th>
# <th>PH0043-C_Reverse_GATC</th>
# <th>PH0043-C__ILMN</th>
# <th>PH0043-C__SQNM</th>
# <th>PH0209-C_ForwardRep_GATC</th>
# <th>PH0209-C_Forward_GATC</th>
# <th>PH0209-C_Reverse_GATC</th>
# <th>PH0209-C__ILMN</th>
# <th>PH0209-C__SQNM</th>
# <th>PH0212-C_ForwardRep_GATC</th>
# <th>PH0212-C_Forward_GATC</th>
# <th>PH0212-C_Reverse_GATC</th>
# <th>PH0212-C__ILMN</th>
# <th>PH0212-C__SQNM</th>
# <th>PH0218-C_ForwardRep_GATC</th>
# <th>PH0218-C_Forward_GATC</th>
# <th>PH0218-C_Reverse_GATC</th>
# <th>PH0218-C__ILMN</th>
# <th>PH0218-C__SQNM</th>
# <th>PH0221-C_ForwardRep_GATC</th>
# <th>PH0221-C_Forward_GATC</th>
# <th>PH0221-C_Reverse_GATC</th>
# <th>PH0221-C__ILMN</th>
# <th>PH0221-C__SQNM</th>
# <th>PH0224-C_ForwardRep_GATC</th>
# <th>PH0224-C_Forward_GATC</th>
# <th>PH0224-C_Reverse_GATC</th>
# <th>PH0224-C__ILMN</th>
# <th>PH0224-C__SQNM</th>
# <th>PH0225-C_ForwardRep_GATC</th>
# <th>PH0225-C_Forward_GATC</th>
# <th>PH0225-C_Reverse_GATC</th>
# <th>PH0225-C__ILMN</th>
# <th>PH0225-C__SQNM</th>
# <th>PH0232-C_ForwardRep_GATC</th>
# <th>PH0232-C_Forward_GATC</th>
# <th>PH0232-C_Reverse_GATC</th>
# <th>PH0232-C__ILMN</th>
# <th>PH0232-C__SQNM</th>
# <th>PH0234-C_ForwardRep_GATC</th>
# <th>PH0234-C_Forward_GATC</th>
# <th>PH0234-C_Reverse_GATC</th>
# <th>PH0234-C__ILMN</th>
# <th>PH0234-C__SQNM</th>
# <th>PH0235-C_ForwardRep_GATC</th>
# <th>PH0235-C_Forward_GATC</th>
# <th>PH0235-C_Reverse_GATC</th>
# <th>PH0235-C__ILMN</th>
# <th>PH0235-C__SQNM</th>
# <th>PH0236-C_ForwardRep_GATC</th>
# <th>PH0236-C_Forward_GATC</th>
# <th>PH0236-C_Reverse_GATC</th>
# <th>PH0236-C__ILMN</th>
# <th>PH0236-C__SQNM</th>
# <th>PH0284-C_ForwardRep_GATC</th>
# <th>PH0284-C_Forward_GATC</th>
# <th>PH0284-C_Reverse_GATC</th>
# <th>PH0284-C__ILMN</th>
# <th>PH0284-C__SQNM</th>
# <th>PH0303-CW_ForwardRep_GATC</th>
# <th>PH0303-CW_Forward_GATC</th>
# <th>PH0303-CW_Reverse_GATC</th>
# <th>PH0303-CW__ILMN</th>
# <th>PH0303-CW__SQNM</th>
# <th>PH0326-C_ForwardRep_GATC</th>
# <th>PH0326-C_Forward_GATC</th>
# <th>PH0326-C_Reverse_GATC</th>
# <th>PH0326-C__ILMN</th>
# <th>PH0326-C__SQNM</th>
# <th>PH0337-C_ForwardRep_GATC</th>
# <th>PH0337-C_Forward_GATC</th>
# <th>PH0337-C_Reverse_GATC</th>
# <th>PH0337-C__ILMN</th>
# <th>PH0337-C__SQNM</th>
# <th>PH0349-C_ForwardRep_GATC</th>
# <th>PH0349-C_Forward_GATC</th>
# <th>PH0349-C_Reverse_GATC</th>
# <th>PH0349-C__ILMN</th>
# <th>PH0349-C__SQ
# GATC 0
# <table class='petl'>
# <thead>
# <tr>
# <th>Concat_variant</th>
# <th>PD0004-C_ForwardRep_GATC</th>
# <th>PD0004-C_Forward_GATC</th>
# <th>PD0004-C_Reverse_GATC</th>
# <th>PD0004-C__ILMN</th>
# <th>PD0004-C__SQNM</th>
# <th>PD0005-01_ForwardRep_GATC</th>
# <th>PD0005-01_Forward_GATC</th>
# <th>PD0005-01_Reverse_GATC</th>
# <th>PD0005-01__ILMN</th>
# <th>PD0005-01__SQNM</th>
# <th>PD0005-C_ForwardRep_GATC</th>
# <th>PD0005-C_Forward_GATC</th>
# <th>PD0005-C_Reverse_GATC</th>
# <th>PD0005-C__ILMN</th>
# <th>PD0005-C__SQNM</th>
# <th>PD0016-C_ForwardRep_GATC</th>
# <th>PD0016-C_Forward_GATC</th>
# <th>PD0016-C_Reverse_GATC</th>
# <th>PD0016-C__ILMN</th>
# <th>PD0016-C__SQNM</th>
# <th>PD0031-C_ForwardRep_GATC</th>
# <th>PD0031-C_Forward_GATC</th>
# <th>PD0031-C_Reverse_GATC</th>
# <th>PD0031-C__ILMN</th>
# <th>PD0031-C__SQNM</th>
# <th>PD0033-C_ForwardRep_GATC</th>
# <th>PD0033-C_Forward_GATC</th>
# <th>PD0033-C_Reverse_GATC</th>
# <th>PD0033-C__ILMN</th>
# <th>PD0033-C__SQNM</th>
# <th>PD0037-C_ForwardRep_GATC</th>
# <th>PD0037-C_Forward_GATC</th>
# <th>PD0037-C_Reverse_GATC</th>
# <th>PD0037-C__ILMN</th>
# <th>PD0037-C__SQNM</th>
# <th>PD0038-C_ForwardRep_GATC</th>
# <th>PD0038-C_Forward_GATC</th>
# <th>PD0038-C_Reverse_GATC</th>
# <th>PD0038-C__ILMN</th>
# <th>PD0038-C__SQNM</th>
# <th>PD0048-C_ForwardRep_GATC</th>
# <th>PD0048-C_Forward_GATC</th>
# <th>PD0048-C_Reverse_GATC</th>
# <th>PD0048-C__ILMN</th>
# <th>PD0048-C__SQNM</th>
# <th>PD0056-C_ForwardRep_GATC</th>
# <th>PD0056-C_Forward_GATC</th>
# <th>PD0056-C_Reverse_GATC</th>
# <th>PD0056-C__ILMN</th>
# <th>PD0056-C__SQNM</th>
# <th>PD0058-C_ForwardRep_GATC</th>
# <th>PD0058-C_Forward_GATC</th>
# <th>PD0058-C_Reverse_GATC</th>
# <th>PD0058-C__ILMN</th>
# <th>PD0058-C__SQNM</th>
# <th>PD0067-C_ForwardRep_GATC</th>
# <th>PD0067-C_Forward_GATC</th>
# <th>PD0067-C_Reverse_GATC</th>
# <th>PD0067-C__ILMN</th>
# <th>PD0067-C__SQNM</th>
# <th>PD0073-C_ForwardRep_GATC</th>
# <th>PD0073-C_Forward_GATC</th>
# <th>PD0073-C_Reverse_GATC</th>
# <th>PD0073-C__ILMN</th>
# <th>PD0073-C__SQNM</th>
# <th>PD0075-C_ForwardRep_GATC</th>
# <th>PD0075-C_Forward_GATC</th>
# <th>PD0075-C_Reverse_GATC</th>
# <th>PD0075-C__ILMN</th>
# <th>PD0075-C__SQNM</th>
# <th>PD0079-C_ForwardRep_GATC</th>
# <th>PD0079-C_Forward_GATC</th>
# <th>PD0079-C_Reverse_GATC</th>
# <th>PD0079-C__ILMN</th>
# <th>PD0079-C__SQNM</th>
# <th>PD0090-C_ForwardRep_GATC</th>
# <th>PD0090-C_Forward_GATC</th>
# <th>PD0090-C_Reverse_GATC</th>
# <th>PD0090-C__ILMN</th>
# <th>PD0090-C__SQNM</th>
# <th>PD0098-C_ForwardRep_GATC</th>
# <th>PD0098-C_Forward_GATC</th>
# <th>PD0098-C_Reverse_GATC</th>
# <th>PD0098-C__ILMN</th>
# <th>PD0098-C__SQNM</th>
# <th>PD0103-C_ForwardRep_GATC</th>
# <th>PD0103-C_Forward_GATC</th>
# <th>PD0103-C_Reverse_GATC</th>
# <th>PD0103-C__ILMN</th>
# <th>PD0103-C__SQNM</th>
# <th>PD0105-C_ForwardRep_GATC</th>
# <th>PD0105-C_Forward_GATC</th>
# <th>PD0105-C_Reverse_GATC</th>
# <th>PD0105-C__ILMN</th>
# <th>PD0105-C__SQNM</th>
# <th>PD0115-Cx_ForwardRep_GATC</th>
# <th>PD0115-Cx_Forward_GATC</th>
# <th>PD0115-Cx_Reverse_GATC</th>
# <th>PD0115-Cx__ILMN</th>
# <th>PD0115-Cx__SQNM</th>
# <th>PD0126-C_ForwardRep_GATC</th>
# <th>PD0126-C_Forward_GATC</th>
# <th>PD0126-C_Reverse_GATC</th>
# <th>PD0126-C__ILMN</th>
# <th>PD0126-C__SQNM</th>
# <th>PD0134-C_ForwardRep_GATC</th>
# <th>PD0134-C_Forward_GATC</th>
# <th>PD0134-C_Reverse_GATC</th>
# <th>PD0134-C__ILMN</th>
# <th>PD0134-C__SQNM</th>
# <th>PD0135-C_ForwardRep_GATC</th>
# <th>PD0135-C_Forward_GATC</th>
# <th>PD0135-C_Reverse_GATC</th>
# <th>PD0135-C__ILMN</th>
# <th>PD0135-C__SQNM</th>
# <th>PD0136-C_ForwardRep_GATC</th>
# <th>PD0136-C_Forward_GATC</th>
# <th>PD0136-C_Reverse_GATC</th>
# <th>PD0136-C__ILMN</th>
# <th>PD0136-C__SQNM</th>
# <th>PD0137-C_ForwardRep_GATC</th>
# <th>PD0137-C_Forward_GATC</th>
# <th>PD0137-C_Reverse_GATC</th>
# <th>PD0137-C__ILMN</th>
# <th>PD0137-C__SQNM</th>
# <th>PD0459-Cx_ForwardRep_GATC</th>
# <th>PD0459-Cx_Forward_GATC</th>
# <th>PD0459-Cx_Reverse_GATC</th>
# <th>PD0459-Cx__ILMN</th>
# <th>PD0459-Cx__SQNM</th>
# <th>PH0002-C_ForwardRep_GATC</th>
# <th>PH0002-C_Forward_GATC</th>
# <th>PH0002-C_Reverse_GATC</th>
# <th>PH0002-C__ILMN</th>
# <th>PH0002-C__SQNM</th>
# <th>PH0003-C_ForwardRep_GATC</th>
# <th>PH0003-C_Forward_GATC</th>
# <th>PH0003-C_Reverse_GATC</th>
# <th>PH0003-C__ILMN</th>
# <th>PH0003-C__SQNM</th>
# <th>PH0012-C_ForwardRep_GATC</th>
# <th>PH0012-C_Forward_GATC</th>
# <th>PH0012-C_Reverse_GATC</th>
# <th>PH0012-C__ILMN</th>
# <th>PH0012-C__SQNM</th>
# <th>PH0013-C_ForwardRep_GATC</th>
# <th>PH0013-C_Forward_GATC</th>
# <th>PH0013-C_Reverse_GATC</th>
# <th>PH0013-C__ILMN</th>
# <th>PH0013-C__SQNM</th>
# <th>PH0016-C_ForwardRep_GATC</th>
# <th>PH0016-C_Forward_GATC</th>
# <th>PH0016-C_Reverse_GATC</th>
# <th>PH0016-C__ILMN</th>
# <th>PH0016-C__SQNM</th>
# <th>PH0017-C_ForwardRep_GATC</th>
# <th>PH0017-C_Forward_GATC</th>
# <th>PH0017-C_Reverse_GATC</th>
# <th>PH0017-C__ILMN</th>
# <th>PH0017-C__SQNM</th>
# <th>PH0020-C_ForwardRep_GATC</th>
# <th>PH0020-C_Forward_GATC</th>
# <th>PH0020-C_Reverse_GATC</th>
# <th>PH0020-C__ILMN</th>
# <th>PH0020-C__SQNM</th>
# <th>PH0022-C_ForwardRep_GATC</th>
# <th>PH0022-C_Forward_GATC</th>
# <th>PH0022-C_Reverse_GATC</th>
# <th>PH0022-C__ILMN</th>
# <th>PH0022-C__SQNM</th>
# <th>PH0024-C_ForwardRep_GATC</th>
# <th>PH0024-C_Forward_GATC</th>
# <th>PH0024-C_Reverse_GATC</th>
# <th>PH0024-C__ILMN</th>
# <th>PH0024-C__SQNM</th>
# <th>PH0027-C_ForwardRep_GATC</th>
# <th>PH0027-C_Forward_GATC</th>
# <th>PH0027-C_Reverse_GATC</th>
# <th>PH0027-C__ILMN</th>
# <th>PH0027-C__SQNM</th>
# <th>PH0028-Cx_ForwardRep_GATC</th>
# <th>PH0028-Cx_Forward_GATC</th>
# <th>PH0028-Cx_Reverse_GATC</th>
# <th>PH0028-Cx__ILMN</th>
# <th>PH0028-Cx__SQNM</th>
# <th>PH0029-Cx_ForwardRep_GATC</th>
# <th>PH0029-Cx_Forward_GATC</th>
# <th>PH0029-Cx_Reverse_GATC</th>
# <th>PH0029-Cx__ILMN</th>
# <th>PH0029-Cx__SQNM</th>
# <th>PH0042-C_ForwardRep_GATC</th>
# <th>PH0042-C_Forward_GATC</th>
# <th>PH0042-C_Reverse_GATC</th>
# <th>PH0042-C__ILMN</th>
# <th>PH0042-C__SQNM</th>
# <th>PH0043-C_ForwardRep_GATC</th>
# <th>PH0043-C_Forward_GATC</th>
# <th>PH0043-C_Reverse_GATC</th>
# <th>PH0043-C__ILMN</th>
# <th>PH0043-C__SQNM</th>
# <th>PH0209-C_ForwardRep_GATC</th>
# <th>PH0209-C_Forward_GATC</th>
# <th>PH0209-C_Reverse_GATC</th>
# <th>PH0209-C__ILMN</th>
# <th>PH0209-C__SQNM</th>
# <th>PH0212-C_ForwardRep_GATC</th>
# <th>PH0212-C_Forward_GATC</th>
# <th>PH0212-C_Reverse_GATC</th>
# <th>PH0212-C__ILMN</th>
# <th>PH0212-C__SQNM</th>
# <th>PH0218-C_ForwardRep_GATC</th>
# <th>PH0218-C_Forward_GATC</th>
# <th>PH0218-C_Reverse_GATC</th>
# <th>PH0218-C__ILMN</th>
# <th>PH0218-C__SQNM</th>
# <th>PH0221-C_ForwardRep_GATC</th>
# <th>PH0221-C_Forward_GATC</th>
# <th>PH0221-C_Reverse_GATC</th>
# <th>PH0221-C__ILMN</th>
# <th>PH0221-C__SQNM</th>
# <th>PH0224-C_ForwardRep_GATC</th>
# <th>PH0224-C_Forward_GATC</th>
# <th>PH0224-C_Reverse_GATC</th>
# <th>PH0224-C__ILMN</th>
# <th>PH0224-C__SQNM</th>
# <th>PH0225-C_ForwardRep_GATC</th>
# <th>PH0225-C_Forward_GATC</th>
# <th>PH0225-C_Reverse_GATC</th>
# <th>PH0225-C__ILMN</th>
# <th>PH0225-C__SQNM</th>
# <th>PH0232-C_ForwardRep_GATC</th>
# <th>PH0232-C_Forward_GATC</th>
# <th>PH0232-C_Reverse_GATC</th>
# <th>PH0232-C__ILMN</th>
# <th>PH0232-C__SQNM</th>
# <th>PH0234-C_ForwardRep_GATC</th>
# <th>PH0234-C_Forward_GATC</th>
# <th>PH0234-C_Reverse_GATC</th>
# <th>PH0234-C__ILMN</th>
# <th>PH0234-C__SQNM</th>
# <th>PH0235-C_ForwardRep_GATC</th>
# <th>PH0235-C_Forward_GATC</th>
# <th>PH0235-C_Reverse_GATC</th>
# <th>PH0235-C__ILMN</th>
# <th>PH0235-C__SQNM</th>
# <th>PH0236-C_ForwardRep_GATC</th>
# <th>PH0236-C_Forward_GATC</th>
# <th>PH0236-C_Reverse_GATC</th>
# <th>PH0236-C__ILMN</th>
# <th>PH0236-C__SQNM</th>
# <th>PH0284-C_ForwardRep_GATC</th>
# <th>PH0284-C_Forward_GATC</th>
# <th>PH0284-C_Reverse_GATC</th>
# <th>PH0284-C__ILMN</th>
# <th>PH0284-C__SQNM</th>
# <th>PH0303-CW_ForwardRep_GATC</th>
# <th>PH0303-CW_Forward_GATC</th>
# <th>PH0303-CW_Reverse_GATC</th>
# <th>PH0303-CW__ILMN</th>
# <th>PH0303-CW__SQNM</th>
# <th>PH0326-C_ForwardRep_GATC</th>
# <th>PH0326-C_Forward_GATC</th>
# <th>PH0326-C_Reverse_GATC</th>
# <th>PH0326-C__ILMN</th>
# <th>PH0326-C__SQNM</th>
# <th>PH0337-C_ForwardRep_GATC</th>
# <th>PH0337-C_Forward_GATC</th>
# <th>PH0337-C_Reverse_GATC</th>
# <th>PH0337-C__ILMN</th>
# <th>PH0337-C__SQNM</th>
# <th>PH0349-C_ForwardRep_GATC</th>
# <th>PH0349-C_Forward_GATC</th>
# <th>PH0349-C_Reverse_GATC</th>
# <th>PH0349-C__ILMN</th>
# <th>PH0349-C__SQ
# GATC None
# <table class='petl'>
# <thead>
# <tr>
# <th>Concat_variant</th>
# <th>PD0004-C_ForwardRep_GATC</th>
# <th>PD0004-C_Forward_GATC</th>
# <th>PD0004-C_Reverse_GATC</th>
# <th>PD0004-C__ILMN</th>
# <th>PD0004-C__SQNM</th>
# <th>PD0005-01_ForwardRep_GATC</th>
# <th>PD0005-01_Forward_GATC</th>
# <th>PD0005-01_Reverse_GATC</th>
# <th>PD0005-01__ILMN</th>
# <th>PD0005-01__SQNM</th>
# <th>PD0005-C_ForwardRep_GATC</th>
# <th>PD0005-C_Forward_GATC</th>
# <th>PD0005-C_Reverse_GATC</th>
# <th>PD0005-C__ILMN</th>
# <th>PD0005-C__SQNM</th>
# <th>PD0016-C_ForwardRep_GATC</th>
# <th>PD0016-C_Forward_GATC</th>
# <th>PD0016-C_Reverse_GATC</th>
# <th>PD0016-C__ILMN</th>
# <th>PD0016-C__SQNM</th>
# <th>PD0031-C_ForwardRep_GATC</th>
# <th>PD0031-C_Forward_GATC</th>
# <th>PD0031-C_Reverse_GATC</th>
# <th>PD0031-C__ILMN</th>
# <th>PD0031-C__SQNM</th>
# <th>PD0033-C_ForwardRep_GATC</th>
# <th>PD0033-C_Forward_GATC</th>
# <th>PD0033-C_Reverse_GATC</th>
# <th>PD0033-C__ILMN</th>
# <th>PD0033-C__SQNM</th>
# <th>PD0037-C_ForwardRep_GATC</th>
# <th>PD0037-C_Forward_GATC</th>
# <th>PD0037-C_Reverse_GATC</th>
# <th>PD0037-C__ILMN</th>
# <th>PD0037-C__SQNM</th>
# <th>PD0038-C_ForwardRep_GATC</th>
# <th>PD0038-C_Forward_GATC</th>
# <th>PD0038-C_Reverse_GATC</th>
# <th>PD0038-C__ILMN</th>
# <th>PD0038-C__SQNM</th>
# <th>PD0048-C_ForwardRep_GATC</th>
# <th>PD0048-C_Forward_GATC</th>
# <th>PD0048-C_Reverse_GATC</th>
# <th>PD0048-C__ILMN</th>
# <th>PD0048-C__SQNM</th>
# <th>PD0056-C_ForwardRep_GATC</th>
# <th>PD0056-C_Forward_GATC</th>
# <th>PD0056-C_Reverse_GATC</th>
# <th>PD0056-C__ILMN</th>
# <th>PD0056-C__SQNM</th>
# <th>PD0058-C_ForwardRep_GATC</th>
# <th>PD0058-C_Forward_GATC</th>
# <th>PD0058-C_Reverse_GATC</th>
# <th>PD0058-C__ILMN</th>
# <th>PD0058-C__SQNM</th>
# <th>PD0067-C_ForwardRep_GATC</th>
# <th>PD0067-C_Forward_GATC</th>
# <th>PD0067-C_Reverse_GATC</th>
# <th>PD0067-C__ILMN</th>
# <th>PD0067-C__SQNM</th>
# <th>PD0073-C_ForwardRep_GATC</th>
# <th>PD0073-C_Forward_GATC</th>
# <th>PD0073-C_Reverse_GATC</th>
# <th>PD0073-C__ILMN</th>
# <th>PD0073-C__SQNM</th>
# <th>PD0075-C_ForwardRep_GATC</th>
# <th>PD0075-C_Forward_GATC</th>
# <th>PD0075-C_Reverse_GATC</th>
# <th>PD0075-C__ILMN</th>
# <th>PD0075-C__SQNM</th>
# <th>PD0079-C_ForwardRep_GATC</th>
# <th>PD0079-C_Forward_GATC</th>
# <th>PD0079-C_Reverse_GATC</th>
# <th>PD0079-C__ILMN</th>
# <th>PD0079-C__SQNM</th>
# <th>PD0090-C_ForwardRep_GATC</th>
# <th>PD0090-C_Forward_GATC</th>
# <th>PD0090-C_Reverse_GATC</th>
# <th>PD0090-C__ILMN</th>
# <th>PD0090-C__SQNM</th>
# <th>PD0098-C_ForwardRep_GATC</th>
# <th>PD0098-C_Forward_GATC</th>
# <th>PD0098-C_Reverse_GATC</th>
# <th>PD0098-C__ILMN</th>
# <th>PD0098-C__SQNM</th>
# <th>PD0103-C_ForwardRep_GATC</th>
# <th>PD0103-C_Forward_GATC</th>
# <th>PD0103-C_Reverse_GATC</th>
# <th>PD0103-C__ILMN</th>
# <th>PD0103-C__SQNM</th>
# <th>PD0105-C_ForwardRep_GATC</th>
# <th>PD0105-C_Forward_GATC</th>
# <th>PD0105-C_Reverse_GATC</th>
# <th>PD0105-C__ILMN</th>
# <th>PD0105-C__SQNM</th>
# <th>PD0115-Cx_ForwardRep_GATC</th>
# <th>PD0115-Cx_Forward_GATC</th>
# <th>PD0115-Cx_Reverse_GATC</th>
# <th>PD0115-Cx__ILMN</th>
# <th>PD0115-Cx__SQNM</th>
# <th>PD0126-C_ForwardRep_GATC</th>
# <th>PD0126-C_Forward_GATC</th>
# <th>PD0126-C_Reverse_GATC</th>
# <th>PD0126-C__ILMN</th>
# <th>PD0126-C__SQNM</th>
# <th>PD0134-C_ForwardRep_GATC</th>
# <th>PD0134-C_Forward_GATC</th>
# <th>PD0134-C_Reverse_GATC</th>
# <th>PD0134-C__ILMN</th>
# <th>PD0134-C__SQNM</th>
# <th>PD0135-C_ForwardRep_GATC</th>
# <th>PD0135-C_Forward_GATC</th>
# <th>PD0135-C_Reverse_GATC</th>
# <th>PD0135-C__ILMN</th>
# <th>PD0135-C__SQNM</th>
# <th>PD0136-C_ForwardRep_GATC</th>
# <th>PD0136-C_Forward_GATC</th>
# <th>PD0136-C_Reverse_GATC</th>
# <th>PD0136-C__ILMN</th>
# <th>PD0136-C__SQNM</th>
# <th>PD0137-C_ForwardRep_GATC</th>
# <th>PD0137-C_Forward_GATC</th>
# <th>PD0137-C_Reverse_GATC</th>
# <th>PD0137-C__ILMN</th>
# <th>PD0137-C__SQNM</th>
# <th>PD0459-Cx_ForwardRep_GATC</th>
# <th>PD0459-Cx_Forward_GATC</th>
# <th>PD0459-Cx_Reverse_GATC</th>
# <th>PD0459-Cx__ILMN</th>
# <th>PD0459-Cx__SQNM</th>
# <th>PH0002-C_ForwardRep_GATC</th>
# <th>PH0002-C_Forward_GATC</th>
# <th>PH0002-C_Reverse_GATC</th>
# <th>PH0002-C__ILMN</th>
# <th>PH0002-C__SQNM</th>
# <th>PH0003-C_ForwardRep_GATC</th>
# <th>PH0003-C_Forward_GATC</th>
# <th>PH0003-C_Reverse_GATC</th>
# <th>PH0003-C__ILMN</th>
# <th>PH0003-C__SQNM</th>
# <th>PH0012-C_ForwardRep_GATC</th>
# <th>PH0012-C_Forward_GATC</th>
# <th>PH0012-C_Reverse_GATC</th>
# <th>PH0012-C__ILMN</th>
# <th>PH0012-C__SQNM</th>
# <th>PH0013-C_ForwardRep_GATC</th>
# <th>PH0013-C_Forward_GATC</th>
# <th>PH0013-C_Reverse_GATC</th>
# <th>PH0013-C__ILMN</th>
# <th>PH0013-C__SQNM</th>
# <th>PH0016-C_ForwardRep_GATC</th>
# <th>PH0016-C_Forward_GATC</th>
# <th>PH0016-C_Reverse_GATC</th>
# <th>PH0016-C__ILMN</th>
# <th>PH0016-C__SQNM</th>
# <th>PH0017-C_ForwardRep_GATC</th>
# <th>PH0017-C_Forward_GATC</th>
# <th>PH0017-C_Reverse_GATC</th>
# <th>PH0017-C__ILMN</th>
# <th>PH0017-C__SQNM</th>
# <th>PH0020-C_ForwardRep_GATC</th>
# <th>PH0020-C_Forward_GATC</th>
# <th>PH0020-C_Reverse_GATC</th>
# <th>PH0020-C__ILMN</th>
# <th>PH0020-C__SQNM</th>
# <th>PH0022-C_ForwardRep_GATC</th>
# <th>PH0022-C_Forward_GATC</th>
# <th>PH0022-C_Reverse_GATC</th>
# <th>PH0022-C__ILMN</th>
# <th>PH0022-C__SQNM</th>
# <th>PH0024-C_ForwardRep_GATC</th>
# <th>PH0024-C_Forward_GATC</th>
# <th>PH0024-C_Reverse_GATC</th>
# <th>PH0024-C__ILMN</th>
# <th>PH0024-C__SQNM</th>
# <th>PH0027-C_ForwardRep_GATC</th>
# <th>PH0027-C_Forward_GATC</th>
# <th>PH0027-C_Reverse_GATC</th>
# <th>PH0027-C__ILMN</th>
# <th>PH0027-C__SQNM</th>
# <th>PH0028-Cx_ForwardRep_GATC</th>
# <th>PH0028-Cx_Forward_GATC</th>
# <th>PH0028-Cx_Reverse_GATC</th>
# <th>PH0028-Cx__ILMN</th>
# <th>PH0028-Cx__SQNM</th>
# <th>PH0029-Cx_ForwardRep_GATC</th>
# <th>PH0029-Cx_Forward_GATC</th>
# <th>PH0029-Cx_Reverse_GATC</th>
# <th>PH0029-Cx__ILMN</th>
# <th>PH0029-Cx__SQNM</th>
# <th>PH0042-C_ForwardRep_GATC</th>
# <th>PH0042-C_Forward_GATC</th>
# <th>PH0042-C_Reverse_GATC</th>
# <th>PH0042-C__ILMN</th>
# <th>PH0042-C__SQNM</th>
# <th>PH0043-C_ForwardRep_GATC</th>
# <th>PH0043-C_Forward_GATC</th>
# <th>PH0043-C_Reverse_GATC</th>
# <th>PH0043-C__ILMN</th>
# <th>PH0043-C__SQNM</th>
# <th>PH0209-C_ForwardRep_GATC</th>
# <th>PH0209-C_Forward_GATC</th>
# <th>PH0209-C_Reverse_GATC</th>
# <th>PH0209-C__ILMN</th>
# <th>PH0209-C__SQNM</th>
# <th>PH0212-C_ForwardRep_GATC</th>
# <th>PH0212-C_Forward_GATC</th>
# <th>PH0212-C_Reverse_GATC</th>
# <th>PH0212-C__ILMN</th>
# <th>PH0212-C__SQNM</th>
# <th>PH0218-C_ForwardRep_GATC</th>
# <th>PH0218-C_Forward_GATC</th>
# <th>PH0218-C_Reverse_GATC</th>
# <th>PH0218-C__ILMN</th>
# <th>PH0218-C__SQNM</th>
# <th>PH0221-C_ForwardRep_GATC</th>
# <th>PH0221-C_Forward_GATC</th>
# <th>PH0221-C_Reverse_GATC</th>
# <th>PH0221-C__ILMN</th>
# <th>PH0221-C__SQNM</th>
# <th>PH0224-C_ForwardRep_GATC</th>
# <th>PH0224-C_Forward_GATC</th>
# <th>PH0224-C_Reverse_GATC</th>
# <th>PH0224-C__ILMN</th>
# <th>PH0224-C__SQNM</th>
# <th>PH0225-C_ForwardRep_GATC</th>
# <th>PH0225-C_Forward_GATC</th>
# <th>PH0225-C_Reverse_GATC</th>
# <th>PH0225-C__ILMN</th>
# <th>PH0225-C__SQNM</th>
# <th>PH0232-C_ForwardRep_GATC</th>
# <th>PH0232-C_Forward_GATC</th>
# <th>PH0232-C_Reverse_GATC</th>
# <th>PH0232-C__ILMN</th>
# <th>PH0232-C__SQNM</th>
# <th>PH0234-C_ForwardRep_GATC</th>
# <th>PH0234-C_Forward_GATC</th>
# <th>PH0234-C_Reverse_GATC</th>
# <th>PH0234-C__ILMN</th>
# <th>PH0234-C__SQNM</th>
# <th>PH0235-C_ForwardRep_GATC</th>
# <th>PH0235-C_Forward_GATC</th>
# <th>PH0235-C_Reverse_GATC</th>
# <th>PH0235-C__ILMN</th>
# <th>PH0235-C__SQNM</th>
# <th>PH0236-C_ForwardRep_GATC</th>
# <th>PH0236-C_Forward_GATC</th>
# <th>PH0236-C_Reverse_GATC</th>
# <th>PH0236-C__ILMN</th>
# <th>PH0236-C__SQNM</th>
# <th>PH0284-C_ForwardRep_GATC</th>
# <th>PH0284-C_Forward_GATC</th>
# <th>PH0284-C_Reverse_GATC</th>
# <th>PH0284-C__ILMN</th>
# <th>PH0284-C__SQNM</th>
# <th>PH0303-CW_ForwardRep_GATC</th>
# <th>PH0303-CW_Forward_GATC</th>
# <th>PH0303-CW_Reverse_GATC</th>
# <th>PH0303-CW__ILMN</th>
# <th>PH0303-CW__SQNM</th>
# <th>PH0326-C_ForwardRep_GATC</th>
# <th>PH0326-C_Forward_GATC</th>
# <th>PH0326-C_Reverse_GATC</th>
# <th>PH0326-C__ILMN</th>
# <th>PH0326-C__SQNM</th>
# <th>PH0337-C_ForwardRep_GATC</th>
# <th>PH0337-C_Forward_GATC</th>
# <th>PH0337-C_Reverse_GATC</th>
# <th>PH0337-C__ILMN</th>
# <th>PH0337-C__SQNM</th>
# <th>PH0349-C_ForwardRep_GATC</th>
# <th>PH0349-C_Forward_GATC</th>
# <th>PH0349-C_Reverse_GATC</th>
# <th>PH0349-C__ILMN</th>
# <th>PH0349-C__SQ

# %%
MERGED_CALLS_EXCEL_FN
# Out:
# '/data/plasmodium/pfalciparum/recon/data/processed/capillary/variants/GATC_less_DNA/merged_calls.xlsx'

# %%
# finding position of het call in PA0155-C (00AJ08.fas)
# blasted against 3D7
# start at pos 8 in read which maps to 1724996 in NCBI ref
# pos 1724996 in NCBI is 1724965 in our ref 

1724996 - 31
# Out:
# 1724965

# %%
# sanity check missed call in PH0227-C at 1725259
# should be at 1725290 with NCBI ref
1725259 + 31
# Out:
# 1725290
