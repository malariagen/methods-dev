# %%
# %run standard_imports.ipynb
# Out:
# numpy 1.9.0
# scipy 0.14.0
# pandas 0.14.1
# numexpr 2.3.1
# pysam 0.8.3
# petl 1.0.2
# petlx 1.0.3
# h5py 2.3.1
# tables 3.1.1
# vcfplt 0.8

# %%
rob_metadata_fn = '/Users/rpearson/src/github/malariagen/methods-dev/meta/Pf/PGV4_mk5.xlsx'
sampling_date_fn = '/Users/rpearson/src/github/malariagen/methods-dev/meta/Pf/20150519/all_sampling_date.txt'
output_fn = '/Users/rpearson/src/github/malariagen/methods-dev/meta/Pf/20150519/PGV4_mk5_sampling_date.xlsx'

# %%
rob_metadata = petl.io.xlsx.fromxlsx(rob_metadata_fn, 'PGV4.0')
sample_date = petl.io.csv.fromtsv(sampling_date_fn)

# %%
rob_metadata.display(2)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>Num</th>
# <th>Sample</th>
# <th>Release</th>
# <th>Pf3k v3</th>
# <th>StudyCode</th>
# <th>AlfrescoNumber</th>
# <th>AlfrescoCode</th>
# <th>Study</th>
# <th>Country</th>
# <th>LabSample</th>
# <th>LowTypability</th>
# <th>PcaOutlier</th>
# <th>IsDuplicate</th>
# <th>ManualExlusion</th>
# <th>Exclude</th>
# <th>Duplicate</th>
# <th>SolarisCountry</th>
# <th>SolarisLocation</th>
# <th>Code</th>
# <th>Fws</th>
# <th>Location</th>
# <th>Region</th>
# <th>Year</th>
# <th>KhCluster</th>
# <th>V3Clusters</th>
# <th>hasArtHalflife</th>
# <th>ArtHalfLife</th>
# <th>Notes</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='text-align: right'>1</td>
# <td>PA0007-C</td>
# <td>3_0</td>
# <td>True</td>
# <td>RV_3606</td>
# <td style='text-align: right'>1006</td>
# <td>1006-PF-GM-CONWAY</td>
# <td>PF6</td>
# <td>GM</td>
# <td>=NOT(ISNA(VLOOKUP(G2,LabStudies!B:B,1,FALSE)))</td>
# <td>=IF(ISNA(VLOOKUP(B2,Typability!B:I,7,FALSE)),TRUE,VLOOKUP(B2,Typability!B:I,7,FALSE))</td>
# <td>False</td>
# <td>=IF(ISNA(VLOOKUP(B2,Duplicates!A:B,2,FALSE)),FALSE,VLOOKUP(B2,Duplicates!A:B,2,FALSE))</td>
# <td>None</td>
# <td>=OR(J2:N2)</td>
# <td>-</td>
# <td>GM</td>
# <td>greater Banjul area, Royal Victoria Teaching Hospital</td>
# <td>GM_greater Banjul area, Royal Victoria Teaching Hospital</td>
# <td>=VLOOKUP(B2,SampleFws!A:B,2,FALSE)</td>
# <td>Banjul</td>
# <td>GM</td>
# <td>None</td>
# <td>None</td>
# <td>None</td>
# <td>False</td>
# <td>None</td>
# <td>None</td>
# </tr>
# <tr>
# <td style='text-align: right'>2</td>
# <td>PA0008-C</td>
# <td>3_0</td>
# <td>True</td>
# <td>RV_3614</td>
# <td style='text-align: right'>1006</td>
# <td>1006-PF-GM-CONWAY</td>
# <td>PF6</td>
# <td>GM</td>
# <td>=NOT(ISNA(VLOOKUP(G3,LabStudies!B:B,1,FALSE)))</td>
# <td>=IF(ISNA(VLOOKUP(B3,Typability!B:I,7,FALSE)),TRUE,VLOOKUP(B3,Typability!B:I,7,FALSE))</td>
# <td>False</td>
# <td>=IF(ISNA(VLOOKUP(B3,Duplicates!A:B,2,FALSE)),FALSE,VLOOKUP(B3,Duplicates!A:B,2,FALSE))</td>
# <td>None</td>
# <td>=</td>
# <td>-</td>
# <td>GM</td>
# <td>greater Banjul area, Royal Victoria Teaching Hospital</td>
# <td>GM_greater Banjul area, Royal Victoria Teaching Hospital</td>
# <td>=VLOOKUP(B3,SampleFws!A:B,2,FALSE)</td>
# <td>Banjul</td>
# <td>GM</td>
# <td></td>
# <td>None</td>
# <td>None</td>
# <td>False</td>
# <td>None</td>
# <td>None</td>
# </tr>
# </tbody>
# </table>
# <p><strong>...</strong></p>

# %%
sample_date.tail(2)
# Out:
# +------------+-------------------+---------------+
# | ox_code    | solaris_sample_id | sampling_date |
# +============+===================+===============+
# | 'WT3333-C' | '9372'            | 'NULL'        |
# +------------+-------------------+---------------+
# | 'WT3334-C' | '9373'            | 'NULL'        |
# +------------+-------------------+---------------+

# %%
output_table = (rob_metadata
    .leftjoin(sample_date, lkey='Sample', rkey='ox_code')
)

# %%
(output_table
    .selectne('sampling_date', 'NULL')
    .selectne('sampling_date', None)
    .selectne('Year', '')
    .selectne('Year', None)
    )
# Out:
# +------+-------------+---------+---------+-------------+----------------+----------------------+---------+---------+-----------------------------------------------------+-----------------------------------------------------------------------------------------------+------------+------------------------------------------------------------------------------------------------+----------------+---------+-----------+----------------+-------------------------+----------------------------+-----------------------------------------+-----------+--------+------+-----------+------------+----------------+-------------+-------+-------------------+---------------+
# | Num  | Sample      | Release | Pf3k v3 | StudyCode   | AlfrescoNumber | AlfrescoCode         | Study   | Country | LabSample                                           | LowTypability                                                                                 | PcaOutlier | IsDuplicate                                                                                    | ManualExlusion | Exclude | Duplicate | SolarisCountry | SolarisLocation         | Code                       | Fws                                     | Location  | Region | Year | KhCluster | V3Clusters | hasArtHalflife | ArtHalfLife | Notes | solaris_sample_id | sampling_date |
# +======+=============+=========+=========+=============+================+======================+=========+=========+=====================================================+===============================================================================================+============+================================================================================================+================+=========+===========+================+=========================+============================+=========================================+===========+========+======+===========+============+================+=============+=======+===================+===============+
# | 4320 | 'PD0465-Cx' | '3_1'   | False   | 'TH004-008' |           1052 | '1052-PF-TRAC-WHITE' | 'TRAC1' | 'TH'    | '=NOT(ISNA(VLOOKUP(G4321,LabStudies!B:B,1,FALSE)))' | '=IF(ISNA(VLOOKUP(B4321,Typability!B:I,7,FALSE)),TRUE,VLOOKUP(B4321,Typability!B:I,7,FALSE))' | False      | '=IF(ISNA(VLOOKUP(B4321,Duplicates!A:B,2,FALSE)),FALSE,VLOOKUP(B4321,Duplicates!A:B,2,FALSE))' | None           | '='     | '-'       | 'TH'           | 'Mae Sot, Tak Province' | 'TH_Mae Sot, Tak Province' | '=VLOOKUP(B4321,SampleFws!A:B,2,FALSE)' | 'Mae Sot' | 'WTH'  | 2011 | None      | None       | None           | None        | None  | '35342'           | '2011-06-23'  |
# +------+-------------+---------+---------+-------------+----------------+----------------------+---------+---------+-----------------------------------------------------+-----------------------------------------------------------------------------------------------+------------+------------------------------------------------------------------------------------------------+----------------+---------+-----------+----------------+-------------------------+----------------------------+-----------------------------------------+-----------+--------+------+-----------+------------+----------------+-------------+-------+-------------------+---------------+
# | 3805 | 'PD0626-C'  | '3_1'   | True    | 'TH004-016' |           1052 | '1052-PF-TRAC-WHITE' | 'TRAC1' | 'TH'    | '=NOT(ISNA(VLOOKUP(G3806,LabStudies!B:B,1,FALSE)))' | '=IF(ISNA(VLOOKUP(B3806,Typability!B:I,7,FALSE)),TRUE,VLOOKUP(B3806,Typability!B:I,7,FALSE))' | False      | '=IF(ISNA(VLOOKUP(B3806,Duplicates!A:B,2,FALSE)),FALSE,VLOOKUP(B3806,Duplicates!A:B,2,FALSE))' | None           | '='     | '-'       | 'TH'           | 'Mae Sot, Tak Province' | 'TH_Mae Sot, Tak Province' | '=VLOOKUP(B3806,SampleFws!A:B,2,FALSE)' | 'Mae Sot' | 'WTH'  | 2011 | None      | None       | None           | None        | None  | '35343'           | '2011-07-11'  |
# +------+-------------+---------+---------+-------------+----------------+----------------------+---------+---------+-----------------------------------------------------+-----------------------------------------------------------------------------------------------+------------+------------------------------------------------------------------------------------------------+----------------+---------+-----------+----------------+-------------------------+----------------------------+-----------------------------------------+-----------+--------+------+-----------+------------+----------------+-------------+-------+-------------------+---------------+
# | 4321 | 'PD0627-C'  | '3_1'   | True    | 'TH004-017' |           1052 | '1052-PF-TRAC-WHITE' | 'TRAC1' | 'TH'    | '=NOT(ISNA(VLOOKUP(G4322,LabStudies!B:B,1,FALSE)))' | '=IF(ISNA(VLOOKUP(B4322,Typability!B:I,7,FALSE)),TRUE,VLOOKUP(B4322,Typability!B:I,7,FALSE))' | False      | '=IF(ISNA(VLOOKUP(B4322,Duplicates!A:B,2,FALSE)),FALSE,VLOOKUP(B4322,Duplicates!A:B,2,FALSE))' | None           | '='     | '-'       | 'TH'           | 'Mae Sot, Tak Province' | 'TH_Mae Sot, Tak Province' | '=VLOOKUP(B4322,SampleFws!A:B,2,FALSE)' | 'Mae Sot' | 'WTH'  | 2011 | None      | None       | None           | None        | None  | '35344'           | '2011-07-21'  |
# +------+-------------+---------+---------+-------------+----------------+----------------------+---------+---------+-----------------------------------------------------+-----------------------------------------------------------------------------------------------+------------+------------------------------------------------------------------------------------------------+----------------+---------+-----------+----------------+-------------------------+----------------------------+-----------------------------------------+-----------+--------+------+-----------+------------+----------------+-------------+-------+-------------------+---------------+
# | 3806 | 'PD0629-C'  | '3_1'   | True    | 'TH004-028' |           1052 | '1052-PF-TRAC-WHITE' | 'TRAC1' | 'TH'    | '=NOT(ISNA(VLOOKUP(G3807,LabStudies!B:B,1,FALSE)))' | '=IF(ISNA(VLOOKUP(B3807,Typability!B:I,7,FALSE)),TRUE,VLOOKUP(B3807,Typability!B:I,7,FALSE))' | False      | '=IF(ISNA(VLOOKUP(B3807,Duplicates!A:B,2,FALSE)),FALSE,VLOOKUP(B3807,Duplicates!A:B,2,FALSE))' | None           | '='     | '-'       | 'TH'           | 'Mae Sot, Tak Province' | 'TH_Mae Sot, Tak Province' | '=VLOOKUP(B3807,SampleFws!A:B,2,FALSE)' | 'Mae Sot' | 'WTH'  | 2011 | None      | None       | None           | None        | None  | '35346'           | '2011-11-21'  |
# +------+-------------+---------+---------+-------------+----------------+----------------------+---------+---------+-----------------------------------------------------+-----------------------------------------------------------------------------------------------+------------+------------------------------------------------------------------------------------------------+----------------+---------+-----------+----------------+-------------------------+----------------------------+-----------------------------------------+-----------+--------+------+-----------+------------+----------------+-------------+-------+-------------------+---------------+
# | 3807 | 'PD0630-C'  | '3_1'   | True    | 'TH004-030' |           1052 | '1052-PF-TRAC-WHITE' | 'TRAC1' | 'TH'    | '=NOT(ISNA(VLOOKUP(G3808,LabStudies!B:B,1,FALSE)))' | '=IF(ISNA(VLOOKUP(B3808,Typability!B:I,7,FALSE)),TRUE,VLOOKUP(B3808,Typability!B:I,7,FALSE))' | False      | '=IF(ISNA(VLOOKUP(B3808,Duplicates!A:B,2,FALSE)),FALSE,VLOOKUP(B3808,Duplicates!A:B,2,FALSE))' | None           | '='     | '-'       | 'TH'           | 'Mae Sot, Tak Province' | 'TH_Mae Sot, Tak Province' | '=VLOOKUP(B3808,SampleFws!A:B,2,FALSE)' | 'Mae Sot' | 'WTH'  | 2011 | None      | None       | None           | None        | None  | '35347'           | '2011-12-12'  |
# +------+-------------+---------+---------+-------------+----------------+----------------------+---------+---------+-----------------------------------------------------+-----------------------------------------------------------------------------------------------+------------+------------------------------------------------------------------------------------------------+----------------+---------+-----------+----------------+-------------------------+----------------------------+-----------------------------------------+-----------+--------+------+-----------+------------+----------------+-------------+-------+-------------------+---------------+
# ...

# %%
(output_table
    .selectne('sampling_date', 'NULL')
    .selectne('sampling_date', None)
    .selectne('Year', '')
    .selectne('Year', None)
    .addfield('dates_concat', lambda rec: str(rec['Year']) + '_' + rec['sampling_date'][0:4])
    .valuecounts('dates_concat')
    .displayall()
)
print(len(output_table
    .selectne('sampling_date', 'NULL')
    .selectne('sampling_date', None)
    .selectne('Year', '')
    .selectne('Year', None)
)-1)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>dates_concat</th>
# <th>count</th>
# <th>frequency</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>2011_2011</td>
# <td style='text-align: right'>121</td>
# <td style='text-align: right'>0.29156626506024097</td>
# </tr>
# <tr>
# <td>2012_2013</td>
# <td style='text-align: right'>116</td>
# <td style='text-align: right'>0.27951807228915665</td>
# </tr>
# <tr>
# <td>2011_2012</td>
# <td style='text-align: right'>100</td>
# <td style='text-align: right'>0.24096385542168675</td>
# </tr>
# <tr>
# <td>2013_2012</td>
# <td style='text-align: right'>32</td>
# <td style='text-align: right'>0.07710843373493977</td>
# </tr>
# <tr>
# <td>2012_2012</td>
# <td style='text-align: right'>15</td>
# <td style='text-align: right'>0.03614457831325301</td>
# </tr>
# <tr>
# <td>2010_2010</td>
# <td style='text-align: right'>10</td>
# <td style='text-align: right'>0.024096385542168676</td>
# </tr>
# <tr>
# <td>2009_2010</td>
# <td style='text-align: right'>9</td>
# <td style='text-align: right'>0.021686746987951807</td>
# </tr>
# <tr>
# <td>2008_2010</td>
# <td style='text-align: right'>5</td>
# <td style='text-align: right'>0.012048192771084338</td>
# </tr>
# <tr>
# <td>2011_2013</td>
# <td style='text-align: right'>4</td>
# <td style='text-align: right'>0.00963855421686747</td>
# </tr>
# <tr>
# <td>2012_2011</td>
# <td style='text-align: right'>3</td>
# <td style='text-align: right'>0.007228915662650603</td>
# </tr>
# </tbody>
# </table>
# 415

# %%
(output_table
    .selectne('Year', '')
    .selectne('Year', None)
    .valuecounts('Year')
    .displayall()
)
print(len(output_table
    .selectne('Year', '')
    .selectne('Year', None)
    )-1
)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>Year</th>
# <th>count</th>
# <th>frequency</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='text-align: right'>2011</td>
# <td style='text-align: right'>756</td>
# <td style='text-align: right'>0.48</td>
# </tr>
# <tr>
# <td style='text-align: right'>2012</td>
# <td style='text-align: right'>267</td>
# <td style='text-align: right'>0.16952380952380952</td>
# </tr>
# <tr>
# <td style='text-align: right'>2010</td>
# <td style='text-align: right'>188</td>
# <td style='text-align: right'>0.11936507936507937</td>
# </tr>
# <tr>
# <td style='text-align: right'>2008</td>
# <td style='text-align: right'>184</td>
# <td style='text-align: right'>0.11682539682539683</td>
# </tr>
# <tr>
# <td style='text-align: right'>2007</td>
# <td style='text-align: right'>44</td>
# <td style='text-align: right'>0.027936507936507936</td>
# </tr>
# <tr>
# <td style='text-align: right'>2013</td>
# <td style='text-align: right'>40</td>
# <td style='text-align: right'>0.025396825396825397</td>
# </tr>
# <tr>
# <td style='text-align: right'>2003</td>
# <td style='text-align: right'>25</td>
# <td style='text-align: right'>0.015873015873015872</td>
# </tr>
# <tr>
# <td style='text-align: right'>2005</td>
# <td style='text-align: right'>24</td>
# <td style='text-align: right'>0.015238095238095238</td>
# </tr>
# <tr>
# <td style='text-align: right'>2009</td>
# <td style='text-align: right'>24</td>
# <td style='text-align: right'>0.015238095238095238</td>
# </tr>
# <tr>
# <td style='text-align: right'>2004</td>
# <td style='text-align: right'>14</td>
# <td style='text-align: right'>0.008888888888888889</td>
# </tr>
# <tr>
# <td style='text-align: right'>2002</td>
# <td style='text-align: right'>4</td>
# <td style='text-align: right'>0.0025396825396825397</td>
# </tr>
# <tr>
# <td style='text-align: right'>2001</td>
# <td style='text-align: right'>3</td>
# <td style='text-align: right'>0.0019047619047619048</td>
# </tr>
# <tr>
# <td style='text-align: right'>2006</td>
# <td style='text-align: right'>2</td>
# <td style='text-align: right'>0.0012698412698412698</td>
# </tr>
# </tbody>
# </table>
# 1575

# %%
(output_table
    .selectne('sampling_date', 'NULL')
    .selectne('sampling_date', None)
    .addfield('dates_concat', lambda rec: rec['sampling_date'][0:4])
    .valuecounts('dates_concat')
    .displayall()
)
print(len(output_table
    .selectne('sampling_date', 'NULL')
    .selectne('sampling_date', None)
)-1)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>dates_concat</th>
# <th>count</th>
# <th>frequency</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>2013</td>
# <td style='text-align: right'>866</td>
# <td style='text-align: right'>0.2999653619674402</td>
# </tr>
# <tr>
# <td>2012</td>
# <td style='text-align: right'>622</td>
# <td style='text-align: right'>0.21544856252164876</td>
# </tr>
# <tr>
# <td>2008</td>
# <td style='text-align: right'>325</td>
# <td style='text-align: right'>0.11257360581918947</td>
# </tr>
# <tr>
# <td>2011</td>
# <td style='text-align: right'>286</td>
# <td style='text-align: right'>0.09906477312088674</td>
# </tr>
# <tr>
# <td>2010</td>
# <td style='text-align: right'>214</td>
# <td style='text-align: right'>0.07412538967786629</td>
# </tr>
# <tr>
# <td>2014</td>
# <td style='text-align: right'>212</td>
# <td style='text-align: right'>0.07343262902667129</td>
# </tr>
# <tr>
# <td>2009</td>
# <td style='text-align: right'>117</td>
# <td style='text-align: right'>0.04052649809490821</td>
# </tr>
# <tr>
# <td>2003</td>
# <td style='text-align: right'>58</td>
# <td style='text-align: right'>0.02009005888465535</td>
# </tr>
# <tr>
# <td>2002</td>
# <td style='text-align: right'>51</td>
# <td style='text-align: right'>0.01766539660547281</td>
# </tr>
# <tr>
# <td>2004</td>
# <td style='text-align: right'>49</td>
# <td style='text-align: right'>0.016972635954277795</td>
# </tr>
# <tr>
# <td>2001</td>
# <td style='text-align: right'>37</td>
# <td style='text-align: right'>0.012816072047107724</td>
# </tr>
# <tr>
# <td>2007</td>
# <td style='text-align: right'>30</td>
# <td style='text-align: right'>0.010391409767925183</td>
# </tr>
# <tr>
# <td>2006</td>
# <td style='text-align: right'>8</td>
# <td style='text-align: right'>0.0027710426047800486</td>
# </tr>
# <tr>
# <td>2005</td>
# <td style='text-align: right'>6</td>
# <td style='text-align: right'>0.0020782819535850364</td>
# </tr>
# <tr>
# <td>2000</td>
# <td style='text-align: right'>4</td>
# <td style='text-align: right'>0.0013855213023900243</td>
# </tr>
# <tr>
# <td>1999</td>
# <td style='text-align: right'>1</td>
# <td style='text-align: right'>0.00034638032559750607</td>
# </tr>
# <tr>
# <td>2017</td>
# <td style='text-align: right'>1</td>
# <td style='text-align: right'>0.00034638032559750607</td>
# </tr>
# </tbody>
# </table>
# 2887

# %%
petl.io.xlsx.toxlsx(output_table, output_fn, 'PGV4.0')
