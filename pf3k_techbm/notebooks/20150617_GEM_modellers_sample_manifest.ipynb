# %% [markdown]
# # Setup

# %%
# %run _shared_setup.ipynb
# Out:
# python 3.4.1 |Anaconda 2.1.0 (x86_64)| (default, Sep 10 2014, 17:24:09)
# [GCC 4.2.1 (Apple Inc. build 5577)]
# numpy 1.9.2
# scipy 0.14.0
# pandas 0.14.1
# numexpr 2.3.1
# pysam 0.8.3
# petl 1.0.10
# petlx 1.0.3
# vcf 0.6.7
# h5py 2.3.1
# tables 3.1.1
# vcfplt 0.8
# tbl_pgv_metadata length = 5729
# tbl_pgv_locations length = 102
# tbl_pf3k_metadata length = 2512
# tbl_pf_solaris length = 10879

# %% [markdown]
# # Setup

# %%
SAMPLE_MANIFEST_FN = '../../meta/Pf/Pf3k_release3_modellers_sample_manifest.txt'
# LOCATIONS_FN = '../../meta/Pf/Pf3k_release3_modellers_locations.txt'
LOCATIONS_FN = '../../meta/Pf/Pf3k_release3_panoptes_locations.txt'

FIELDS_OF_INTEREST = ['Sample', 'YearOfCollection', 'samplingSite', 'Fws', 'PercentCallableGATK']

# %% [markdown]
# # Create table

# %%
tbl_merged_samples = (tbl_pgv_metadata
    .outerjoin(tbl_pf3k_metadata, lkey='Sample', rkey='sample_id')
    .addfield('collectionYear', lambda rec: determine_year(rec['collectionDate']))
    .leftjoin(tbl_pf_solaris, lkey='Sample', rkey='oxcode')
)
print(len(tbl_merged_samples.data()))
tbl_merged_samples
# Out:
# 5866
# +------------+---------+---------+----------------+---------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+--------+--------------+--------------+----------------+-------------------+-------------------+--------------+---------------------+----------------+------------+-------------+---------------------------------------+---------------------+---------------------------------------+-------------------------------------+
# | Sample     | Pf3k v3 | Exclude | AlfrescoNumber | Country | SolarisCountry | SolarisLocation                                         | Code                                                       | Fws               | Location | Region | Year | study  | country      | samplingSite | collectionDate | basesof5xCoverage | averageReadLength | meanCoverage | PercentCallableGATK | collectionYear | ox_code    | oxford_code | creation_date                         | Dna_Extraction_date | sample_creation_date                  | contribution_arrival_date           |
# +============+=========+=========+================+=========+================+=========================================================+============================================================+===================+==========+========+======+========+==============+==============+================+===================+===================+==============+=====================+================+============+=============+=======================================+=====================+=======================================+=====================================+
# | 'PA0007-C' | True    | False   |           1006 | 'GM'    | 'GM'           | 'greater Banjul area, Royal Victoria Teaching Hospital' | 'GM_greater Banjul area, Royal Victoria Teaching Hospital' | 0.995549265848836 | 'Banjul' | 'GM'   | None | '1006' | 'The Gambia' | 'GM_Coastal' | ''             | '20226914.0'      | '76.0'            | '74.27'      | '76.58'             | None           | 'PA0007-C' | 'PA0007-C'  | datetime.datetime(2009, 12, 16, 0, 0) | None                | datetime.datetime(2009, 12, 16, 0, 0) | datetime.datetime(2009, 9, 8, 0, 0) |
# +------------+---------+---------+----------------+---------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+--------+--------------+--------------+----------------+-------------------+-------------------+--------------+---------------------+----------------+------------+-------------+---------------------------------------+---------------------+---------------------------------------+-------------------------------------+
# | 'PA0008-C' | True    | False   |           1006 | 'GM'    | 'GM'           | 'greater Banjul area, Royal Victoria Teaching Hospital' | 'GM_greater Banjul area, Royal Victoria Teaching Hospital' | 0.380544083595885 | 'Banjul' | 'GM'   | None | '1006' | 'The Gambia' | 'GM_Coastal' | ''             | '22873797.0'      | '76.0'            | '96.81'      | '90.33'             | None           | 'PA0008-C' | 'PA0008-C'  | datetime.datetime(2009, 12, 16, 0, 0) | None                | datetime.datetime(2009, 12, 16, 0, 0) | datetime.datetime(2009, 9, 8, 0, 0) |
# +------------+---------+---------+----------------+---------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+--------+--------------+--------------+----------------+-------------------+-------------------+--------------+---------------------+----------------+------------+-------------+---------------------------------------+---------------------+---------------------------------------+-------------------------------------+
# | 'PA0011-C' | True    | False   |           1006 | 'GM'    | 'GM'           | 'greater Banjul area, Royal Victoria Teaching Hospital' | 'GM_greater Banjul area, Royal Victoria Teaching Hospital' | 0.999316200656244 | 'Banjul' | 'GM'   | None | '1006' | 'The Gambia' | 'GM_Coastal' | ''             | '22798857.0'      | '76.0'            | '149.59'     | '90.6'              | None           | 'PA0011-C' | 'PA0011-C'  | datetime.datetime(2009, 12, 16, 0, 0) | None                | datetime.datetime(2009, 12, 16, 0, 0) | datetime.datetime(2009, 9, 8, 0, 0) |
# +------------+---------+---------+----------------+---------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+--------+--------------+--------------+----------------+-------------------+-------------------+--------------+---------------------+----------------+------------+-------------+---------------------------------------+---------------------+---------------------------------------+-------------------------------------+
# | 'PA0012-C' | True    | False   |           1006 | 'GM'    | 'GM'           | 'greater Banjul area, Royal Victoria Teaching Hospital' | 'GM_greater Banjul area, Royal Victoria Teaching Hospital' | 0.999922696134752 | 'Banjul' | 'GM'   | None | '1006' | 'The Gambia' | 'GM_Coastal' | ''             | '22430685.0'      | '76.0'            | '95.02'      | '88.97'             | None           | 'PA0012-C' | 'PA0012-C'  | datetime.datetime(2009, 12, 16, 0, 0) | None                | datetime.datetime(2009, 12, 16, 0, 0) | datetime.datetime(2009, 9, 8, 0, 0) |
# +------------+---------+---------+----------------+---------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+--------+--------------+--------------+----------------+-------------------+-------------------+--------------+---------------------+----------------+------------+-------------+---------------------------------------+---------------------+---------------------------------------+-------------------------------------+
# | 'PA0013-C' | False   | False   |           1006 | 'GM'    | 'GM'           | 'greater Banjul area, Royal Victoria Teaching Hospital' | 'GM_greater Banjul area, Royal Victoria Teaching Hospital' | 0.998507818570216 | 'Banjul' | 'GM'   | None | None   | None         | None         | None           | None              | None              | None         | None                | None           | 'PA0013-C' | 'PA0013-C'  | datetime.datetime(2009, 12, 16, 0, 0) | None                | datetime.datetime(2009, 12, 16, 0, 0) | datetime.datetime(2009, 9, 8, 0, 0) |
# +------------+---------+---------+----------------+---------+----------------+---------------------------------------------------------+------------------------------------------------------------+-------------------+----------+--------+------+--------+--------------+--------------+----------------+-------------------+-------------------+--------------+---------------------+----------------+------------+-------------+---------------------------------------+---------------------+---------------------------------------+-------------------------------------+
# ...

# %%
tbl_merged_samples.valuecounts('Pf3k v3', 'Exclude').displayall()
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>Pf3k v3</th>
# <th>Exclude</th>
# <th>count</th>
# <th>frequency</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>True</td>
# <td>False</td>
# <td style='text-align: right'>2072</td>
# <td style='text-align: right'>0.3532219570405728</td>
# </tr>
# <tr>
# <td>False</td>
# <td>True</td>
# <td style='text-align: right'>1938</td>
# <td style='text-align: right'>0.3303784520968292</td>
# </tr>
# <tr>
# <td>False</td>
# <td>False</td>
# <td style='text-align: right'>1416</td>
# <td style='text-align: right'>0.24139106716672348</td>
# </tr>
# <tr>
# <td>True</td>
# <td>True</td>
# <td style='text-align: right'>303</td>
# <td style='text-align: right'>0.05165359699965905</td>
# </tr>
# <tr>
# <td>None</td>
# <td>None</td>
# <td style='text-align: right'>137</td>
# <td style='text-align: right'>0.02335492669621548</td>
# </tr>
# </tbody>
# </table>

# %%
def determine_year_of_collection(rec):
    if rec['collectionYear'] is None:
        if rec['Year'] is None:
            return '<%s' % determine_year(str(rec['creation_date']))
        else:
            return(rec['Year'])
    else:
        return(rec['collectionYear'])

# %%
tbl_usable_samples = (tbl_merged_samples
    .select(lambda rec: (rec['Pf3k v3'] == True and rec['Exclude'] == False) or (rec['Pf3k v3'] is None))
    .addfield('YearOfCollection', determine_year_of_collection)
    .cut(FIELDS_OF_INTEREST)
)

# %%
print(len(tbl_usable_samples.data()))
# Out:
# 2209

# %%
tbl_usable_samples
# Out:
# +------------+------------------+--------------+-------------------+---------------------+
# | Sample     | YearOfCollection | samplingSite | Fws               | PercentCallableGATK |
# +============+==================+==============+===================+=====================+
# | 'PA0007-C' | '<2009'          | 'GM_Coastal' | 0.995549265848836 | '76.58'             |
# +------------+------------------+--------------+-------------------+---------------------+
# | 'PA0008-C' | '<2009'          | 'GM_Coastal' | 0.380544083595885 | '90.33'             |
# +------------+------------------+--------------+-------------------+---------------------+
# | 'PA0011-C' | '<2009'          | 'GM_Coastal' | 0.999316200656244 | '90.6'              |
# +------------+------------------+--------------+-------------------+---------------------+
# | 'PA0012-C' | '<2009'          | 'GM_Coastal' | 0.999922696134752 | '88.97'             |
# +------------+------------------+--------------+-------------------+---------------------+
# | 'PA0015-C' | '<2009'          | 'GM_Coastal' | 0.999552759064621 | '90.8'              |
# +------------+------------------+--------------+-------------------+---------------------+
# ...

# %%
print(np.sum(tbl_usable_samples.valuecounts('YearOfCollection').values('count').array()))
tbl_usable_samples.valuecounts('YearOfCollection').displayall()
# Out:
# 2209
# <table class='petl'>
# <thead>
# <tr>
# <th>YearOfCollection</th>
# <th>count</th>
# <th>frequency</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='text-align: right'>2011</td>
# <td style='text-align: right'>480</td>
# <td style='text-align: right'>0.2172928927116342</td>
# </tr>
# <tr>
# <td><2011</td>
# <td style='text-align: right'>294</td>
# <td style='text-align: right'>0.13309189678587596</td>
# </tr>
# <tr>
# <td>2012</td>
# <td style='text-align: right'>196</td>
# <td style='text-align: right'>0.08872793119058398</td>
# </tr>
# <tr>
# <td>2011</td>
# <td style='text-align: right'>188</td>
# <td style='text-align: right'>0.0851063829787234</td>
# </tr>
# <tr>
# <td><2010</td>
# <td style='text-align: right'>179</td>
