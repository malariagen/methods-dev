# %%
# %run _standard_imports.ipynb
# Out:
# python 3.4.5 |Anaconda 2.2.0 (64-bit)| (default, Jul  2 2016, 17:47:47)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# numpy 1.11.1
# scipy 0.18.0
# pandas 0.19.0
# numexpr 2.6.1
# pysam 0.9.1.4
# petl 1.1.0
# petlx 1.0.3
# vcf 0.6.8
# vcfnp 2.3.0.dev0
# h5py 2.4.0
# tables 3.1.1

# %%
scratch_dir = "/lustre/scratch109/malaria/rp7/data/methods-dev/builds/Pf6.0/20161117_GRC_from_VCF"
output_dir = "/nfs/team112_internal/rp7/data/methods-dev/builds/Pf6.0/20161117_GRC_from_VCF"
# !mkdir -p {scratch_dir}
# !mkdir -p {output_dir}

ref_fasta_fn = "%s/Pfalciparum.genome.fasta" % scratch_dir
vcf_file_format = "/nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_%s.combined.filtered.vcf.gz"

# See 20161115_run_Olivo_GRC.ipynb
grc_properties_fn = '/nfs/team112_internal/rp7/data/methods-dev/builds/Pf6.0/20161117_run_Olivo_GRC/grc/grc.properties'

grc_from_vcf_fn = "%s/Pf_6_GRC_from_vcf.xlsx" % output_dir

# %%
grc_from_vcf_fn
# Out:
# '/nfs/team112_internal/rp7/data/methods-dev/builds/Pf6.0/20161115_GRC_from_VCF/Pf_6_GRC_from_vcf.xlsx'

# %%
# !cp /nfs/users/nfs_r/rp7/pf_60_mergelanes.txt {bam_fn}

# %%
# !cp /lustre/scratch116/malaria/pfalciparum/resources/Pfalciparum.genome.fasta {ref_fasta_fn}

# %%
def call_haplotypes(target_name='crt_72-76', chrom='Pf3D7_07_v3', start=403612, end=403626, strand='+',
    samples=None, positions_with_missingness=[403620, 403621], ref_fasta_fn=ref_fasta_fn, vcf_fn=None,
    verbose=True, show_genotypes=False
):
    
    from pyfasta import Fasta
    from Bio.Seq import Seq
    
    if vcf_fn is None:
        vcf_fn = vcf_file_format % chrom
    
    ref_sequence = Seq(Fasta(ref_fasta_fn)[chrom][start-1:end])
    vcf_reader = vcf.Reader(filename=vcf_fn)
    if samples is None:
        samples = vcf_reader.samples
    sample_sequences = collections.OrderedDict()
    sample_offsets = collections.OrderedDict()
    PID = collections.OrderedDict()
    non_phased_het_seen = collections.OrderedDict()
    genotype = collections.OrderedDict()
    num_missing = collections.OrderedDict()
    num_called = collections.OrderedDict()
    for sample in samples:
        sample_sequences[sample] = [ref_sequence.tomutable(), ref_sequence.tomutable()]
        sample_offsets[sample] = [0, 0]
        PID[sample] = ''
        non_phased_het_seen[sample] = False
        genotype[sample] = ''
        num_missing[sample] = 0
        num_called[sample] = 0

    for record in vcf_reader.fetch(chrom, start-1, end):
        if verbose:
            print(record, record.FILTER)
        for sample in samples:
            if show_genotypes:
                print(record.genotype(sample))
            GT = record.genotype(sample)['GT']
            POS = record.POS - start
            if GT == './.':
                if not record.POS in positions_with_missingness:
                    num_missing[sample] += 1
            else:
                num_called[sample] += 1
                if GT != '0/0':
                    if GT[0] != GT[2]: # heterozygous call
                        if 'PGT' in record.genotype(sample).data._fields:
                            is_unphased = (record.genotype(sample)['PGT'] is None)
                        else:
                            is_unphased = True
                        if non_phased_het_seen[sample]:
                            print("Sample %s unphased het followed by het" % sample)
                            genotype[sample] = 'X'
                        if is_unphased:
                            non_phased_het_seen[sample] = True
                        else:
                            if PID[sample] == '':
                                PID[sample] = record.genotype(sample)['PID']
                            else:
                                if record.genotype(sample)['PID'] != PID[sample]:
                                    print("Sample %s two PIDs" % sample)
                                    genotype[sample] = '?'
                            if record.genotype(sample)['PGT'] == '1|0':
                                GT = GT[2] + '/' + GT[0]

                    for i, sample_offset in enumerate(sample_offsets[sample]):
                        alleles = [record.REF] + record.ALT
                        GTint = int(GT[i*2])
                        REF_len = len(record.REF)
                        ALT_len = len(alleles[GTint])
                        if alleles[GTint] != '*':
                            sample_sequences[sample][i][POS+sample_offsets[sample][i]:(POS+sample_offsets[sample][i]+REF_len)] = alleles[GTint]
                            sample_offsets[sample][i] = sample_offset + (len(alleles[GTint]) - len(record.REF))

    for sample in samples:
        if(show_genotypes):
            print(sample_sequences[sample])
        if genotype[sample] == '':
            if num_missing[sample] > 0:
                genotype[sample] = '-'
            else:
                if sample_sequences[sample][0] == sample_sequences[sample][1]:
                    if strand == '+':
                        genotype[sample] = ( str(sample_sequences[sample][0].toseq().translate())
                                            if len(sample_sequences[sample][0]) % 3 == 0
                                            else '!' )
                    else:
                        genotype[sample] = ( str(sample_sequences[sample][0].toseq().reverse_complement().translate())
                                            if len(sample_sequences[sample][0]) % 3 == 0
                                            else '!' )
                else:
                    if strand == '+':
                        genotype[sample] = "%s,%s" % (
                            ( str(sample_sequences[sample][0].toseq().translate())
                             if len(sample_sequences[sample][0]) % 3 == 0
                             else '!' ),
                            ( str(sample_sequences[sample][1].toseq().translate())
                             if len(sample_sequences[sample][1]) % 3 == 0
                             else '!' )
                        )
                    else:
                        genotype[sample] = "%s,%s" % (
                            ( str(sample_sequences[sample][0].toseq().reverse_complement().translate())
                             if len(sample_sequences[sample][0]) % 3 == 0
                             else '!' ),
                            ( str(sample_sequences[sample][1].toseq().reverse_complement().translate())
                             if len(sample_sequences[sample][1]) % 3 == 0
                             else '!' )
                        )
                
    if strand == '+':
        ref_haplotype = str(ref_sequence.translate())
    else:
        ref_haplotype = str(ref_sequence.reverse_complement().translate())

    return(genotype, ref_haplotype)

# %%
def call_all_haplotypes(grc_properties_fn=grc_properties_fn):
    results = collections.OrderedDict()
    fi = open(grc_properties_fn, 'r')
    for line in fi:
        if line.startswith('grc.locus'):
            locus_name = line.split('.')[2]
            line_type = line.split('.')[3].split('=')[0]
            if line_type == 'region':
                chrom = line.split('.')[3].split('=')[1].split(':')[0]
            if line_type == 'targets':
                targets = line.split('=')[1].split(',')
                for target in targets:
                    target_name = target.split('@')[0]
                    target_coords = target.split('@')[1]
                    if target_coords.startswith('-'):
                        strand = '-'
                        target_coords = target_coords[1:]
                    else:
                        strand = '+'
                    start, end = target_coords.split('-')
                    print("\n", target_name)
                    genotype, ref_haplotype = call_haplotypes(target_name, chrom, int(start), int(end), strand)
                    locus_name = "%s[%s]" % (target_name, ref_haplotype)
                    results[locus_name] = genotype
    fi.close()
    
    tbl_results = (etl
        .fromcolumns(
            [list(results['crt_72-76[CVMNK]'].keys()), list(results['crt_72-76[CVMNK]'].values())],
            header=['Sample', 'crt_72-76[CVMNK]']
        )
    )
    for locus_name in list(results.keys())[1:]:
        print(locus_name)
        tbl_results = tbl_results.addcolumn(locus_name, results[locus_name].values())
    
    return(tbl_results)

# %%
tbl_all_results = call_all_haplotypes()

# %%
# Sanity checking crt_97 that has very few het calls. This one was het by reads which said all reads aligned
# Will download bam to ascertain truth...
call_haplotypes('crt_97', 'Pf3D7_07_v3', 403687, 403689, '+', samples=['PA0093-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403687, REF=C, ALT=[T]) []
# Call(sample=PA0093-C, CallData(GT=0/0, AD=[41, 0], BCS=[None, None, None, None], DP=41, GQ=99, PL=[0, 99, 1485]))
# Record(CHROM=Pf3D7_07_v3, POS=403688, REF=A, ALT=[T]) []
# Call(sample=PA0093-C, CallData(GT=0/0, AD=[41, 0], BCS=[None, None, None, None], DP=41, GQ=99, PGT=None, PID=None, PL=[0, 99, 1485]))
# Record(CHROM=Pf3D7_07_v3, POS=403689, REF=C, ALT=[A, T]) []
# Call(sample=PA0093-C, CallData(GT=0/0, AD=[41, 0, 0], BCS=[None, None, None, None], DP=41, GQ=99, PGT=None, PID=None, PL=[0, 99, 1485, 99, 1485, 1485]))
# [MutableSeq('cac', Alphabet()), MutableSeq('cac', Alphabet())]
# (OrderedDict([('PA0093-C', 'H')]), 'H')

# %%
# !grep PA0093 /nfs/users/nfs_r/rp7/pf_60_mergelanes.txt
# Out:
# /lustre/scratch116/malaria/pfalciparum/output/9/7/4/2/36984/4_bam_mark_duplicates_v2/pe.1.markdup.bam	PA0093-C

# %%
# Sanity checking crt_97 that has very few het calls. This one was het by reads which said all reads aligned
# Will download bam to ascertain truth...
call_haplotypes('crt_97', 'Pf3D7_07_v3', 403687, 403689, '+', samples=['PH0905-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403687, REF=C, ALT=[T]) []
# Call(sample=PH0905-C, CallData(GT=0/0, AD=[35, 0], BCS=[None, None, None, None], DP=35, GQ=96, PL=[0, 96, 1440]))
# Record(CHROM=Pf3D7_07_v3, POS=403688, REF=A, ALT=[T]) []
# Call(sample=PH0905-C, CallData(GT=0/0, AD=[35, 0], BCS=[None, None, None, None], DP=35, GQ=31, PGT=None, PID=None, PL=[0, 31, 1110]))
# Record(CHROM=Pf3D7_07_v3, POS=403689, REF=C, ALT=[A, T]) []
# Call(sample=PH0905-C, CallData(GT=0/0, AD=[34, 0, 0], BCS=[None, None, None, None], DP=34, GQ=93, PGT=None, PID=None, PL=[0, 93, 1395, 93, 1395, 1395]))
# [MutableSeq('cac', Alphabet()), MutableSeq('cac', Alphabet())]
# (OrderedDict([('PH0905-C', 'H')]), 'H')

# %%
# !grep PH0905 /nfs/users/nfs_r/rp7/pf_60_mergelanes.txt
# Out:
# /lustre/scratch116/malaria/pfalciparum/output/4/e/d/3/41496/4_bam_mark_duplicates_v2/pe.1.markdup.bam	PH0905-C

# %%
# Sanity checking crt_97 that has very few het calls. This one was het by reads which said all reads aligned
# Will download bam to ascertain truth...
call_haplotypes('crt_97', 'Pf3D7_07_v3', 403687, 403689, '+', samples=['QG0155-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403687, REF=C, ALT=[T]) []
# Call(sample=QG0155-C, CallData(GT=0/0, AD=[67, 0], BCS=[None, None, None, None], DP=67, GQ=99, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403688, REF=A, ALT=[T]) []
# Call(sample=QG0155-C, CallData(GT=0/0, AD=[74, 0], BCS=[None, None, None, None], DP=74, GQ=0, PGT=None, PID=None, PL=[0, 0, 2147]))
# Record(CHROM=Pf3D7_07_v3, POS=403689, REF=C, ALT=[A, T]) []
# Call(sample=QG0155-C, CallData(GT=0/0, AD=[71, 0, 0], BCS=[None, None, None, None], DP=71, GQ=33, PGT=None, PID=None, PL=[0, 33, 2042, 33, 2042, 2042]))
# [MutableSeq('cac', Alphabet()), MutableSeq('cac', Alphabet())]
# (OrderedDict([('QG0155-C', 'H')]), 'H')

# %%
# !grep QG0155 /nfs/users/nfs_r/rp7/pf_60_mergelanes.txt
# Out:
# /lustre/scratch116/malaria/pfalciparum/output/0/1/4/3/44018/4_bam_mark_duplicates_v2/pe.1.markdup.bam	QG0155-C

# %%
# Sanity check that MDR2 working correctly
call_haplotypes('mdr2_484', 'Pf3D7_14_v3', 1956224, 1956226, '+', samples=['PF0146-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_14_v3, POS=1956225, REF=G, ALT=[A]) []
# Call(sample=PF0146-C, CallData(GT=0/0, AD=[29, 0], BCS=[None, None, None, None], DP=29, GQ=84, PGT=None, PID=None, PL=[0, 84, 992]))
# [MutableSeq('tgt', Alphabet()), MutableSeq('tgt', Alphabet())]
# (OrderedDict([('PF0146-C', 'C')]), 'C')

# %%
# Sanity check that MDR2 working correctly
call_haplotypes('mdr2_484', 'Pf3D7_14_v3', 1956224, 1956226, '-', samples=['PF0146-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_14_v3, POS=1956225, REF=G, ALT=[A]) []
# Call(sample=PF0146-C, CallData(GT=0/0, AD=[29, 0], BCS=[None, None, None, None], DP=29, GQ=84, PGT=None, PID=None, PL=[0, 84, 992]))
# [MutableSeq('tgt', Alphabet()), MutableSeq('tgt', Alphabet())]
# (OrderedDict([('PF0146-C', 'T')]), 'T')

# %%
# Sanity check that FD working correctly
call_haplotypes('fd_193', 'Pf3D7_13_v3', 748393, 748395, '+', samples=['PF0146-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_13_v3, POS=748395, REF=C, ALT=[A]) []
# Call(sample=PF0146-C, CallData(GT=0/0, AD=[21, 0], BCS=[None, None, None, None], DP=21, GQ=60, PL=[0, 60, 677]))
# [MutableSeq('gtc', Alphabet()), MutableSeq('gtc', Alphabet())]
# (OrderedDict([('PF0146-C', 'V')]), 'V')

# %%
# Sanity check that FD working correctly
call_haplotypes('fd_193', 'Pf3D7_13_v3', 748393, 748395, '-', samples=['PF0146-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_13_v3, POS=748395, REF=C, ALT=[A]) []
# Call(sample=PF0146-C, CallData(GT=0/0, AD=[21, 0], BCS=[None, None, None, None], DP=21, GQ=60, PL=[0, 60, 677]))
# [MutableSeq('gtc', Alphabet()), MutableSeq('gtc', Alphabet())]
# (OrderedDict([('PF0146-C', 'D')]), 'D')

# %%
# Can't quite decide what the right answer is here, but suspect Olivo's code is right
call_haplotypes(samples=['PV0174-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A]) []
# Call(sample=PV0174-C, CallData(GT=0/0, AD=[12, 0], BCS=[None, None, None, None], DP=12, GQ=30, PGT=None, PID=None, PL=[0, 30, 450]))
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C]) []
# Call(sample=PV0174-C, CallData(GT=0/0, AD=[12, 0, 0], BCS=[None, None, None, None], DP=12, GQ=30, PGT=None, PID=None, PL=[0, 30, 450, 30, 450, 450]))
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A]) []
# Call(sample=PV0174-C, CallData(GT=0/0, AD=[12, 0], BCS=[None, None, None, None], DP=12, GQ=30, PGT=None, PID=None, PL=[0, 30, 450]))
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT]) []
# Call(sample=PV0174-C, CallData(GT=0/1, AD=[4, 6], BCS=[370, 73, 117, 414], DP=10, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[179, 0, 187]))
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T]) []
# Call(sample=PV0174-C, CallData(GT=0/1, AD=[7, 3], BCS=[370, 73, 117, 414], DP=10, GQ=75, PGT=1|0, PID=403618_A_AT, PL=[75, 0, 282]))
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G]) []
# Call(sample=PV0174-C, CallData(GT=0/1, AD=[7, 3], BCS=[370, 73, 117, 414], DP=10, GQ=75, PGT=1|0, PID=403618_A_AT, PL=[75, 0, 282]))
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A]) []
# Call(sample=PV0174-C, CallData(GT=0/1, AD=[4, 6], BCS=[370, 73, 117, 414], DP=10, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[179, 0, 187]))
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA]) []
# Call(sample=PV0174-C, CallData(GT=0/1, AD=[4, 6, 0], BCS=[370, 73, 117, 414], DP=10, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[179, 0, 187, 191, 205, 395]))
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C]) []
# Call(sample=PV0174-C, CallData(GT=0/1, AD=[1, 9], BCS=[370, 73, 117, 414], DP=10, GQ=74, PGT=0|1, PID=403618_A_AT, PL=[375, 0, 74]))
# [MutableSeq('tgtgtaAtTGATAAa', Alphabet()), MutableSeq('tgtgtaATtGAAaCa', Alphabet())]
# (OrderedDict([('PV0174-C', 'CVIDK,CVIET')]), 'CVMNK')

# %%
# Assume these are really the haplotypes Olivo finds here, but not enough evidence to call hets
call_haplotypes(samples=['QG0211-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A]) []
# Call(sample=QG0211-C, CallData(GT=0/0, AD=[50, 4], BCS=[1833, 244, 606, 2070], DP=54, GQ=15, PGT=None, PID=None, PL=[0, 15, 1520]))
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C]) []
# Call(sample=QG0211-C, CallData(GT=0/0, AD=[53, 0, 0], BCS=[None, None, None, None], DP=53, GQ=99, PGT=None, PID=None, PL=[0, 120, 1800, 120, 1800, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A]) []
# Call(sample=QG0211-C, CallData(GT=0/0, AD=[53, 0], BCS=[None, None, None, None], DP=53, GQ=99, PGT=None, PID=None, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT]) []
# Call(sample=QG0211-C, CallData(GT=0/0, AD=[52, 2], BCS=[1867, 276, 608, 2028], DP=54, GQ=85, PGT=0|1, PID=403618_A_AT, PL=[0, 85, 3710]))
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T]) []
# Call(sample=QG0211-C, CallData(GT=0/0, AD=[57, 0], BCS=[None, None, None, None], DP=57, GQ=99, PGT=None, PID=None, PL=[0, 104, 1715]))
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G]) []
# Call(sample=QG0211-C, CallData(GT=0/0, AD=[57, 0], BCS=[None, None, None, None], DP=57, GQ=99, PGT=None, PID=None, PL=[0, 104, 1715]))
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A]) []
# Call(sample=QG0211-C, CallData(GT=0/0, AD=[56, 2], BCS=[1988, 316, 637, 2104], DP=58, GQ=91, PGT=0|1, PID=403618_A_AT, PL=[0, 91, 3786]))
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA]) []
# Call(sample=QG0211-C, CallData(GT=0/0, AD=[56, 2, 0], BCS=[1988, 316, 637, 2104], DP=58, GQ=91, PGT=0|1, PID=403618_A_AT, PL=[0, 91, 3786, 175, 3792, 3876]))
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C]) []
# Call(sample=QG0211-C, CallData(GT=0/1, AD=[52, 6], BCS=[1989, 324, 634, 2089], DP=58, GQ=60, PGT=None, PID=None, PL=[60, 0, 1463]))
# [MutableSeq('tgtgtaatgaataAa', Alphabet()), MutableSeq('tgtgtaatgaataCa', Alphabet())]
# (OrderedDict([('QG0211-C', 'CVMNK,CVMNT')]), 'CVMNK')

# %%
# Originally I was making a wrong call here because was using PGT rather than GT
call_haplotypes('dhps_436', 'Pf3D7_08_v3', 549681, 549683, '+', samples=['PF0146-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549681, REF=T, ALT=[G, C]) []
# Call(sample=PF0146-C, CallData(GT=0/0, AD=[37, 0, 0], BCS=[None, None, None, None], DP=37, GQ=78, PGT=None, PID=None, PL=[0, 78, 1171, 78, 1171, 1171]))
# Record(CHROM=Pf3D7_08_v3, POS=549682, REF=C, ALT=[T, G, A]) []
# Call(sample=PF0146-C, CallData(GT=0/3, AD=[2, 0, 0, 35], BCS=[381, 268, 261, 526], DP=37, GQ=57, PGT=0|1, PID=549682_C_A, PL=[1446, 1455, 1618, 1455, 1618, 1618, 0, 163, 163, 57]))
# Record(CHROM=Pf3D7_08_v3, POS=549683, REF=T, ALT=[C]) []
# Call(sample=PF0146-C, CallData(GT=0/0, AD=[38, 0], BCS=[None, None, None, None], DP=38, GQ=99, PL=[0, 102, 1530]))
# [MutableSeq('tCt', Alphabet()), MutableSeq('tAt', Alphabet())]
# (OrderedDict([('PF0146-C', 'S,Y')]), 'S')

# %%
# Get wrong call here becuase middle GT is 0/0. Would get correct call if we used PGT
call_haplotypes('dhps_436', 'Pf3D7_08_v3', 549681, 549683, '+', samples=['PH0919-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549681, REF=T, ALT=[G, C]) []
# Call(sample=PH0919-C, CallData(GT=0/1, AD=[2, 23, 0], BCS=[216, 156, 224, 327], DP=25, GQ=15, PGT=0|1, PID=549681_T_G, PL=[653, 0, 15, 659, 84, 743]))
# Record(CHROM=Pf3D7_08_v3, POS=549682, REF=C, ALT=[T, G, A]) []
# Call(sample=PH0919-C, CallData(GT=0/0, AD=[24, 2, 0, 0], BCS=[219, 162, 229, 343], DP=26, GQ=17, PGT=1|0, PID=549681_T_G, PL=[0, 17, 1025, 75, 1031, 1089, 75, 1031, 1089, 1089]))
# Record(CHROM=Pf3D7_08_v3, POS=549683, REF=T, ALT=[C]) []
# Call(sample=PH0919-C, CallData(GT=0/0, AD=[27, 0], BCS=[None, None, None, None], DP=27, GQ=61, PL=[0, 61, 887]))
# [MutableSeq('Tct', Alphabet()), MutableSeq('Gct', Alphabet())]
# (OrderedDict([('PH0919-C', 'S,A')]), 'S')

# %%
# Seems clear Olivo has it right here - final variant certainly looks like a het
call_haplotypes('dhps_540', 'Pf3D7_08_v3', 549993, 549995, '+', samples=['PH0566-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549993, REF=A, ALT=[G, T]) []
# Call(sample=PH0566-C, CallData(GT=0/1, AD=[5, 48, 0], BCS=[2474, 518, 616, 1503], DP=53, GQ=66, PGT=None, PID=None, PL=[1385, 0, 66, 1400, 210, 1610]))
# Record(CHROM=Pf3D7_08_v3, POS=549994, REF=A, ALT=[T]) []
# Call(sample=PH0566-C, CallData(GT=0/0, AD=[54, 0], BCS=[None, None, None, None], DP=54, GQ=99, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_08_v3, POS=549995, REF=A, ALT=[T, G]) []
# Call(sample=PH0566-C, CallData(GT=0/0, AD=[49, 5, 0], BCS=[2516, 528, 627, 1531], DP=54, GQ=7, PGT=None, PID=None, PL=[0, 7, 2011, 147, 2026, 2166]))
# [MutableSeq('Aaa', Alphabet()), MutableSeq('Gaa', Alphabet())]
# (OrderedDict([('PH0566-C', 'K,E')]), 'K')

# %%
# Seems clear Olivo has it right here - final variant certainly looks like a het
call_haplotypes('dhps_540', 'Pf3D7_08_v3', 549993, 549995, '+', samples=['PH0718-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549993, REF=A, ALT=[G, T]) []
# Call(sample=PH0718-C, CallData(GT=0/1, AD=[3, 40, 0], BCS=[1964, 417, 501, 1231], DP=43, GQ=6, PGT=None, PID=None, PL=[1267, 0, 6, 1276, 126, 1402]))
# Record(CHROM=Pf3D7_08_v3, POS=549994, REF=A, ALT=[T]) []
# Call(sample=PH0718-C, CallData(GT=0/0, AD=[45, 0], BCS=[None, None, None, None], DP=45, GQ=99, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_08_v3, POS=549995, REF=A, ALT=[T, G]) []
# Call(sample=PH0718-C, CallData(GT=0/0, AD=[41, 3, 0], BCS=[1996, 422, 507, 1257], DP=44, GQ=30, PGT=None, PID=None, PL=[0, 30, 1700, 123, 1709, 1802]))
# [MutableSeq('Aaa', Alphabet()), MutableSeq('Gaa', Alphabet())]
# (OrderedDict([('PH0718-C', 'K,E')]), 'K')

# %%
# Seems clear Olivo has it right here - final variant certainly looks like a het
call_haplotypes('dhps_540', 'Pf3D7_08_v3', 549993, 549995, '+', samples=['PH0905-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549993, REF=A, ALT=[G, T]) []
# Call(sample=PH0905-C, CallData(GT=0/1, AD=[4, 46, 0], BCS=[938, 330, 235, 507], DP=50, GQ=14, PGT=0|1, PID=549993_A_G, PL=[1399, 0, 14, 1411, 151, 1562]))
# Record(CHROM=Pf3D7_08_v3, POS=549994, REF=A, ALT=[T]) []
# Call(sample=PH0905-C, CallData(GT=0/0, AD=[50, 0], BCS=[None, None, None, None], DP=50, GQ=99, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_08_v3, POS=549995, REF=A, ALT=[T, G]) []
# Call(sample=PH0905-C, CallData(GT=0/0, AD=[46, 2, 0], BCS=[918, 322, 227, 499], DP=48, GQ=81, PGT=1|0, PID=549993_A_G, PL=[0, 81, 2003, 144, 2009, 2072]))
# [MutableSeq('Aaa', Alphabet()), MutableSeq('Gaa', Alphabet())]
# (OrderedDict([('PH0905-C', 'K,E')]), 'K')

# %%
# Seems clear Olivo has it right here - final variant certainly looks like a het
call_haplotypes('dhps_540', 'Pf3D7_08_v3', 549993, 549995, '+', samples=['PH1422-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549993, REF=A, ALT=[G, T]) []
# Call(sample=PH1422-C, CallData(GT=0/1, AD=[3, 41, 0], BCS=[817, 283, 201, 439], DP=44, GQ=4, PGT=0|1, PID=549993_A_G, PL=[1212, 0, 4, 1221, 126, 1347]))
# Record(CHROM=Pf3D7_08_v3, POS=549994, REF=A, ALT=[T]) []
# Call(sample=PH1422-C, CallData(GT=0/0, AD=[46, 0], BCS=[None, None, None, None], DP=46, GQ=99, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_08_v3, POS=549995, REF=A, ALT=[T, G]) []
# Call(sample=PH1422-C, CallData(GT=0/0, AD=[42, 3, 0], BCS=[828, 286, 202, 446], DP=45, GQ=24, PGT=1|0, PID=549993_A_G, PL=[0, 24, 1741, 126, 1750, 1852]))
# [MutableSeq('Aaa', Alphabet()), MutableSeq('Gaa', Alphabet())]
# (OrderedDict([('PH1422-C', 'K,E')]), 'K')

# %%
# Seems clear Olivo has it right here - final variant certainly looks like a het
call_haplotypes('dhps_540', 'Pf3D7_08_v3', 549993, 549995, '+', samples=['PD0009-01'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549993, REF=A, ALT=[G, T]) []
# Call(sample=PD0009-01, CallData(GT=0/1, AD=[8, 83, 0], BCS=[1586, 551, 396, 853], DP=91, GQ=71, PGT=0|1, PID=549993_A_G, PL=[2455, 0, 71, 2479, 319, 2798]))
# Record(CHROM=Pf3D7_08_v3, POS=549994, REF=A, ALT=[T]) []
# Call(sample=PD0009-01, CallData(GT=0/0, AD=[97, 0], BCS=[None, None, None, None], DP=97, GQ=99, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_08_v3, POS=549995, REF=A, ALT=[T, G]) []
# Call(sample=PD0009-01, CallData(GT=0/0, AD=[86, 7, 0], BCS=[1608, 556, 396, 870], DP=93, GQ=20, PGT=1|0, PID=549993_A_G, PL=[0, 20, 3524, 259, 3545, 3784]))
# [MutableSeq('Aaa', Alphabet()), MutableSeq('Gaa', Alphabet())]
# (OrderedDict([('PD0009-01', 'K,E')]), 'K')

# %%
# Originally got wrong call here becuase first variant doesn't have phasing information, though read counts show obvious phasing
call_haplotypes('dhps_436', 'Pf3D7_08_v3', 549681, 549683, '+', samples=['QP0024-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549681, REF=T, ALT=[G, C]) []
# Call(sample=QP0024-C, CallData(GT=0/1, AD=[152, 52, 0], BCS=[3636, 1730, 3029, 4877], DP=204, GQ=99, PGT=None, PID=None, PL=[964, 0, 6386, 1439, 6542, 7981]))
# Record(CHROM=Pf3D7_08_v3, POS=549682, REF=C, ALT=[T, G, A]) []
# Call(sample=QP0024-C, CallData(GT=0/1, AD=[52, 155, 0, 0], BCS=[3648, 1748, 3035, 4913], DP=207, GQ=99, PGT=0|1, PID=549682_C_T, PL=[6183, 0, 1748, 6345, 2229, 8574, 6345, 2229, 8574, 8574]))
# Record(CHROM=Pf3D7_08_v3, POS=549683, REF=T, ALT=[C]) []
# Call(sample=QP0024-C, CallData(GT=0/0, AD=[211, 0], BCS=[None, None, None, None], DP=211, GQ=99, PL=[0, 120, 1800]))
# [MutableSeq('TCt', Alphabet()), MutableSeq('GTt', Alphabet())]
# (OrderedDict([('QP0024-C', 'S,V')]), 'S')

# %%
# After changing code, now correctly marked as 'X'
call_haplotypes('dhps_436', 'Pf3D7_08_v3', 549681, 549683, '+', samples=['QP0024-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549681, REF=T, ALT=[G, C]) []
# Call(sample=QP0024-C, CallData(GT=0/1, AD=[152, 52, 0], BCS=[3636, 1730, 3029, 4877], DP=204, GQ=99, PGT=None, PID=None, PL=[964, 0, 6386, 1439, 6542, 7981]))
# Record(CHROM=Pf3D7_08_v3, POS=549682, REF=C, ALT=[T, G, A]) []
# Call(sample=QP0024-C, CallData(GT=0/1, AD=[52, 155, 0, 0], BCS=[3648, 1748, 3035, 4913], DP=207, GQ=99, PGT=0|1, PID=549682_C_T, PL=[6183, 0, 1748, 6345, 2229, 8574, 6345, 2229, 8574, 8574]))
# Sample QP0024-C unphased het followed by het
# Record(CHROM=Pf3D7_08_v3, POS=549683, REF=T, ALT=[C]) []
# Call(sample=QP0024-C, CallData(GT=0/0, AD=[211, 0], BCS=[None, None, None, None], DP=211, GQ=99, PL=[0, 120, 1800]))
# [MutableSeq('TCt', Alphabet()), MutableSeq('GTt', Alphabet())]
# (OrderedDict([('QP0024-C', 'X')]), 'S')

# %%
# Originally, unclear what phasing should be, and hence what correct call is here
call_haplotypes('dhps_436', 'Pf3D7_08_v3', 549681, 549683, '+', samples=['QQ0110-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549681, REF=T, ALT=[G, C]) []
# Call(sample=QQ0110-C, CallData(GT=0/1, AD=[120, 94, 0], BCS=[2825, 1682, 2734, 4179], DP=214, GQ=99, PGT=None, PID=None, PL=[2281, 0, 4302, 2642, 4583, 7225]))
# Record(CHROM=Pf3D7_08_v3, POS=549682, REF=C, ALT=[T, G, A]) []
# Call(sample=QQ0110-C, CallData(GT=0/1, AD=[137, 74, 0, 0], BCS=[2781, 1676, 2689, 4142], DP=211, GQ=99, PGT=0|1, PID=549682_C_T, PL=[2665, 0, 6357, 3083, 6583, 9666, 3083, 6583, 9666, 9666]))
# Record(CHROM=Pf3D7_08_v3, POS=549683, REF=T, ALT=[C]) []
# Call(sample=QQ0110-C, CallData(GT=0/0, AD=[210, 0], BCS=[None, None, None, None], DP=210, GQ=99, PL=[0, 120, 1800]))
# [MutableSeq('TCt', Alphabet()), MutableSeq('GTt', Alphabet())]
# (OrderedDict([('QQ0110-C', 'S,V')]), 'S')

# %%
# After changing code, now correctly marked as 'X'
call_haplotypes('dhps_436', 'Pf3D7_08_v3', 549681, 549683, '+', samples=['QQ0110-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549681, REF=T, ALT=[G, C]) []
# Call(sample=QQ0110-C, CallData(GT=0/1, AD=[120, 94, 0], BCS=[2825, 1682, 2734, 4179], DP=214, GQ=99, PGT=None, PID=None, PL=[2281, 0, 4302, 2642, 4583, 7225]))
# Record(CHROM=Pf3D7_08_v3, POS=549682, REF=C, ALT=[T, G, A]) []
# Call(sample=QQ0110-C, CallData(GT=0/1, AD=[137, 74, 0, 0], BCS=[2781, 1676, 2689, 4142], DP=211, GQ=99, PGT=0|1, PID=549682_C_T, PL=[2665, 0, 6357, 3083, 6583, 9666, 3083, 6583, 9666, 9666]))
# Sample QQ0110-C unphased het followed by het
# Record(CHROM=Pf3D7_08_v3, POS=549683, REF=T, ALT=[C]) []
# Call(sample=QQ0110-C, CallData(GT=0/0, AD=[210, 0], BCS=[None, None, None, None], DP=210, GQ=99, PL=[0, 120, 1800]))
# [MutableSeq('TCt', Alphabet()), MutableSeq('GTt', Alphabet())]
# (OrderedDict([('QQ0110-C', 'X')]), 'S')

# %%
call_haplotypes(samples=['FP0008-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A]) []
# Call(sample=FP0008-C, CallData(GT=0/0, AD=[26, 0], BCS=[None, None, None, None], DP=26, GQ=72, PGT=None, PID=None, PL=[0, 72, 1080]))
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C]) []
# Call(sample=FP0008-C, CallData(GT=0/0, AD=[26, 0, 0], BCS=[None, None, None, None], DP=26, GQ=72, PGT=None, PID=None, PL=[0, 72, 1080, 72, 1080, 1080]))
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A]) []
# Call(sample=FP0008-C, CallData(GT=0/0, AD=[26, 0], BCS=[None, None, None, None], DP=26, GQ=72, PGT=None, PID=None, PL=[0, 72, 1080]))
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT]) []
# Call(sample=FP0008-C, CallData(GT=0/1, AD=[3, 23], BCS=[965, 186, 308, 1060], DP=26, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[1083, 0, 219]))
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T]) []
# Call(sample=FP0008-C, CallData(GT=./., AD=[27, 0], BCS=[None, None, None, None], DP=27, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G]) []
# Call(sample=FP0008-C, CallData(GT=./., AD=[27, 0], BCS=[None, None, None, None], DP=27, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A]) []
# Call(sample=FP0008-C, CallData(GT=0/1, AD=[3, 27], BCS=[1092, 234, 339, 1157], DP=30, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[1140, 0, 213]))
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA]) []
# Call(sample=FP0008-C, CallData(GT=0/1, AD=[3, 27, 0], BCS=[1092, 234, 339, 1157], DP=30, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[1140, 0, 213, 1149, 297, 1447]))
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C]) []
# Call(sample=FP0008-C, CallData(GT=0/1, AD=[3, 28], BCS=[1122, 246, 346, 1181], DP=31, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[1140, 0, 213]))
# (OrderedDict([('FP0008-C', 'CVMNK,CVIET')]), 'CVMNK')

# %%
call_haplotypes(samples=['QV0090-C'], show_genotypes=True)
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A]) []
# Call(sample=QV0090-C, CallData(GT=0/0, AD=[64, 0], BCS=[None, None, None, None], DP=64, GQ=99, PGT=None, PID=None, PL=[0, 112, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C]) []
# Call(sample=QV0090-C, CallData(GT=0/0, AD=[64, 0, 0], BCS=[None, None, None, None], DP=64, GQ=99, PGT=None, PID=None, PL=[0, 112, 1800, 112, 1800, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A]) []
# Call(sample=QV0090-C, CallData(GT=0/0, AD=[64, 0], BCS=[None, None, None, None], DP=64, GQ=99, PGT=None, PID=None, PL=[0, 112, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT]) []
# Call(sample=QV0090-C, CallData(GT=0/1, AD=[3, 104], BCS=[3902, 722, 1251, 4330], DP=107, GQ=8, PGT=0|1, PID=403618_A_AT, PL=[4436, 0, 8]))
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T]) []
# Call(sample=QV0090-C, CallData(GT=./., AD=[110, 0], BCS=[None, None, None, None], DP=110, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G]) []
# Call(sample=QV0090-C, CallData(GT=./., AD=[110, 0], BCS=[None, None, None, None], DP=110, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A]) []
# Call(sample=QV0090-C, CallData(GT=1/1, AD=[3, 106], BCS=[3992, 794, 1258, 4314], DP=109, GQ=4, PGT=1|1, PID=403618_A_AT, PL=[4587, 4, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA]) []
# Call(sample=QV0090-C, CallData(GT=1/1, AD=[3, 106, 0], BCS=[3992, 794, 1258, 4314], DP=109, GQ=4, PGT=1|1, PID=403618_A_AT, PL=[4587, 4, 0, 4596, 334, 4926]))
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C]) []
# Call(sample=QV0090-C, CallData(GT=0/1, AD=[3, 108], BCS=[4052, 830, 1269, 4346], DP=111, GQ=2, PGT=0|1, PID=403618_A_AT, PL=[4514, 0, 2]))
# (OrderedDict([('QV0090-C', '!,CVIET')]), 'CVMNK')

# %%
temp = call_haplotypes('crt_24', 'Pf3D7_07_v3', 403291, 403293, '+')
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403291, REF=G, ALT=[T])
# []

# %%
call_haplotypes(samples=['PA0490-C'])
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A]) []
# Call(sample=PA0490-C, CallData(GT=0/0, AD=[91, 0], BCS=[None, None, None, None], DP=91, GQ=99, PGT=None, PID=None, PL=[0, 102, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C]) []
# Call(sample=PA0490-C, CallData(GT=0/0, AD=[91, 0, 0], BCS=[None, None, None, None], DP=91, GQ=99, PGT=None, PID=None, PL=[0, 102, 1800, 102, 1800, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A]) []
# Call(sample=PA0490-C, CallData(GT=0/0, AD=[91, 0], BCS=[None, None, None, None], DP=91, GQ=99, PGT=None, PID=None, PL=[0, 102, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT]) []
# Call(sample=PA0490-C, CallData(GT=1/1, AD=[4, 134], BCS=[5037, 1027, 1619, 5609], DP=138, GQ=25, PGT=1|1, PID=403618_A_AT, PL=[5667, 25, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T]) []
# Call(sample=PA0490-C, CallData(GT=./., AD=[139, 0], BCS=[None, None, None, None], DP=139, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G]) []
# Call(sample=PA0490-C, CallData(GT=./., AD=[139, 0], BCS=[None, None, None, None], DP=139, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A]) []
# Call(sample=PA0490-C, CallData(GT=0/1, AD=[5, 137], BCS=[5164, 1074, 1652, 5724], DP=142, GQ=20, PGT=0|1, PID=403618_A_AT, PL=[5809, 0, 20]))
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA]) []
# Call(sample=PA0490-C, CallData(GT=0/1, AD=[5, 137, 0], BCS=[5164, 1074, 1652, 5724], DP=142, GQ=20, PGT=0|1, PID=403618_A_AT, PL=[5809, 0, 20, 5824, 441, 6266]))
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C]) []
# Call(sample=PA0490-C, CallData(GT=0/1, AD=[4, 136], BCS=[5100, 1105, 1625, 5603], DP=140, GQ=26, PGT=0|1, PID=403618_A_AT, PL=[5740, 0, 26]))
# [MutableSeq('tgtgtaATtgaATAAa', Alphabet()), MutableSeq('tgtgtaATtgaAaCa', Alphabet())]
# /nfs/users/nfs_r/rp7/anaconda3/lib/python3.4/site-packages/Bio/Seq.py:2040: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   BiopythonWarning)
# (OrderedDict([('PA0490-C', 'CVIE*,CVIET')]), 'CVMNK')

# %%
call_haplotypes(samples=['PA0490-C'])
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C]) []
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT]) []
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G]) []
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA]) []
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C]) []
# /nfs/users/nfs_r/rp7/anaconda3/lib/python3.4/site-packages/Bio/Seq.py:2040: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   BiopythonWarning)
# (OrderedDict([('PA0490-C', 'CVIE*,CVIET')]), 'CVMNK')

# %%
_, _, sample_sequences = call_haplotypes(samples=['PA0490-C'])
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C]) []
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT]) []
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G]) []
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA]) []
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C]) []

# %%
call_haplotypes(samples=['PA0490-C'])
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C]) []
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT]) []
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G]) []
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA]) []
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C]) []
# (OrderedDict([('PA0490-C', '!!!!!,CVIET')]),
#  'CVMNK',
#  OrderedDict([('PA0490-C',
#                [MutableSeq('tgtgtaATtgaATAAa', Alphabet()),
#                 MutableSeq('tgtgtaATtgaAaCa', Alphabet())])]))

# %%
sample_sequences['PA0490-C']
# Out:
# [MutableSeq('tgtgtaATtgaATAAa', Alphabet()),
#  MutableSeq('tgtgtaATtgaAaCa', Alphabet())]

# %%
len(sample_sequences['PA0490-C'][0]) % 3
# Out:
# 1

# %%
len(sample_sequences['PA0490-C'][1]) % 3
# Out:
# 0

# %%
17 % 3
# Out:
# 2

# %%
call_haplotypes(samples=['PH0046-C'])
# Out:
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A]) []
# Call(sample=PH0046-C, CallData(GT=0/0, AD=[151, 0], BCS=[None, None, None, None], DP=151, GQ=99, PGT=None, PID=None, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C]) []
# Call(sample=PH0046-C, CallData(GT=0/0, AD=[151, 0, 0], BCS=[None, None, None, None], DP=151, GQ=99, PGT=None, PID=None, PL=[0, 120, 1800, 120, 1800, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A]) []
# Call(sample=PH0046-C, CallData(GT=0/0, AD=[151, 0], BCS=[None, None, None, None], DP=151, GQ=99, PGT=None, PID=None, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT]) []
# Call(sample=PH0046-C, CallData(GT=0/1, AD=[230, 43], BCS=[7694, 1394, 2654, 8890], DP=273, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[702, 0, 7429]))
# 1
# 2
# 6
# 7
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T]) []
# Call(sample=PH0046-C, CallData(GT=0/1, AD=[45, 237], BCS=[7963, 1499, 2725, 9118], DP=282, GQ=99, PGT=0|1, PID=403620_G_T, PL=[7512, 0, 723]))
# 1
# 2
# 6
# 8
# 9
# Sample PH0046-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G]) []
# Call(sample=PH0046-C, CallData(GT=0/1, AD=[46, 238], BCS=[8025, 1524, 2740, 9167], DP=284, GQ=99, PGT=0|1, PID=403620_G_T, PL=[7526, 0, 718]))
# 1
# 2
# 6
# 8
# 9
# Sample PH0046-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A]) []
# Call(sample=PH0046-C, CallData(GT=0/1, AD=[242, 46], BCS=[8142, 1566, 2768, 9263], DP=288, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[718, 0, 7546]))
# 1
# 2
# 6
# 8
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA]) []
# Call(sample=PH0046-C, CallData(GT=0/1, AD=[242, 46, 0], BCS=[8142, 1566, 2768, 9263], DP=288, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[718, 0, 7546, 1444, 7684, 9128]))
# 1
# 2
# 6
# 8
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C]) []
# Call(sample=PH0046-C, CallData(GT=1/1, AD=[0, 285], BCS=[8076, 1635, 2721, 9048], DP=285, GQ=99, PGT=None, PID=None, PL=[12966, 881, 0]))
# [MutableSeq('tgtgtaAtGAATACa', Alphabet()), MutableSeq('tgtgtaATtTGAaCa', Alphabet())]
# (OrderedDict([('PH0046-C', '?????')]), 'CVMNK')

# %%
call_haplotypes('dhps_436', 'Pf3D7_08_v3', 549681, 549683, samples=['PC0276-C'])
# Out:
# Record(CHROM=Pf3D7_08_v3, POS=549681, REF=T, ALT=[G, C]) []
# Call(sample=PC0276-C, CallData(GT=0/2, AD=[201, 0, 143], BCS=[3140, 2224, 2815, 4747], DP=344, GQ=99, PGT=None, PID=None, PL=[5375, 5980, 18795, 0, 12815, 12381]))
# 1
# 2
# 5
# Record(CHROM=Pf3D7_08_v3, POS=549682, REF=C, ALT=[T, G, A]) []
# Call(sample=PC0276-C, CallData(GT=0/3, AD=[198, 2, 0, 143], BCS=[3130, 2223, 2806, 4746], DP=343, GQ=99, PGT=None, PID=None, PL=[5375, 5928, 11999, 5971, 12004, 12048, 0, 6619, 6668, 12332]))
# 1
# 2
# 4
# Sample PC0276-C two unphased hets
# 5
# Record(CHROM=Pf3D7_08_v3, POS=549683, REF=T, ALT=[C]) []
# Call(sample=PC0276-C, CallData(GT=0/0, AD=[308, 0], BCS=[None, None, None, None], DP=308, GQ=99, PL=[0, 120, 1800]))
# [MutableSeq('TCt', Alphabet()), MutableSeq('CAt', Alphabet())]
# (OrderedDict([('PC0276-C', 'X')]), 'S')

# %%
temp = call_haplotypes('crt_24', 'Pf3D7_07_v3', 403291, 403293, '+')

# %%
temp[1]
# Out:
# 'D'

# %%
tbl_all_results = call_all_haplotypes()
# Out:
#  crt_72-76
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C]) []
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT]) []
# Sample PH0060-C unphased het followed by het
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T]) []
# Sample PH0046-C two PIDs
# Sample PH0242-C two PIDs
# Sample PV0303-C two PIDs
# Sample PV0323-C two PIDs
# Sample QE0396-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G]) []
# Sample PH0046-C two PIDs
# Sample PH0242-C two PIDs
# Sample PV0303-C two PIDs
# Sample PV0323-C two PIDs
# Sample QE0396-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A]) []
# Sample PH0060-C unphased het followed by het
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA]) []
# Sample PH0060-C unphased het followed by het
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C]) []
# Sample PN0008-C unphased het followed by het
# Sample PN0054-C unphased het followed by het
# Sample PN0075-C unphased het followed by het
# Sample PN0105-C unphased het followed by het
# Sample PN0112-C unphased het followed by het
#
#  crt_24
# Record(CHROM=Pf3D7_07_v3, POS=403291, REF=G, ALT=[T]) []
#
#  crt_97
# Record(CHROM=Pf3D7_07_v3, POS=403687, REF=C, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=403688, REF=A, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=403689, REF=C, ALT=[A, T]) []
#
#  crt_144
# Record(CHROM=Pf3D7_07_v3, POS=404007, REF=G, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=404008, REF=C, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=404009, REF=C, ALT=[T]) []
#
#  crt_148
# Record(CHROM=Pf3D7_07_v3, POS=404019, REF=C, ALT=[A]) []
#
#  crt_194
# Record(CHROM=Pf3D7_07_v3, POS=404330, REF=T, ALT=[C]) []
#
#  crt_220
# Record(CHROM=Pf3D7_07_v3, POS=404407, REF=G, ALT=[T]) []
#
#  crt_271
# Record(CHROM=Pf3D7_07_v3, POS=404836, REF=C, ALT=[G]) []
# Record(CHROM=Pf3D7_07_v3, POS=404838, REF=A, ALT=[G]) ['Low_VQSLOD']
#
#  crt_326
# Record(CHROM=Pf3D7_07_v3, POS=405361, REF=A, ALT=[G]) []
# Record(CHROM=Pf3D7_07_v3, POS=405362, REF=A, ALT=[G]) []
#
#  crt_333
# Record(CHROM=Pf3D7_07_v3, POS=405382, REF=A, ALT=[G]) []
# Record(CHROM=Pf3D7_07_v3, POS=405383, REF=C, ALT=[G]) []
# Sample PN0112-C unphased het followed by het
# Sample PN0117-C unphased het followed by het
# Sample PN0118-C unphased het followed by het
# Sample PN0167-C unphased het followed by het
# Record(CHROM=Pf3D7_07_v3, POS=405384, REF=C, ALT=[T]) []
#
#  crt_342
# Record(CHROM=Pf3D7_07_v3, POS=405557, REF=A, ALT=[G]) []
# Record(CHROM=Pf3D7_07_v3, POS=405559, REF=C, ALT=[A]) ['Low_VQSLOD']
#
#  crt_356
# Record(CHROM=Pf3D7_07_v3, POS=405599, REF=A, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=405600, REF=T, ALT=[C]) []
#
#  crt_371
# Record(CHROM=Pf3D7_07_v3, POS=405838, REF=G, ALT=[T, C]) []
#
#  dhfr_51
# Record(CHROM=Pf3D7_04_v3, POS=748239, REF=A, ALT=[T]) []
#
#  dhfr_59
# Record(CHROM=Pf3D7_04_v3, POS=748262, REF=T, ALT=[C]) []
# Record(CHROM=Pf3D7_04_v3, POS=748263, REF=G, ALT=[A]) []
#
#  dhfr_108
# Record(CHROM=Pf3D7_04_v3, POS=748410, REF=G, ALT=[A, C]) []
#
#  dhfr_164
# Record(CHROM=Pf3D7_04_v3, POS=748577, REF=A, ALT=[T]) []
# Record(CHROM=Pf3D7_04_v3, POS=748579, REF=A, ALT=[G]) []
#
#  dhps_436
# Record(CHROM=Pf3D7_08_v3, POS=549681, REF=T, ALT=[G, C]) []
# Record(CHROM=Pf3D7_08_v3, POS=549682, REF=C, ALT=[T, G, A]) []
# Sample PC0276-C unphased het followed by het
# Sample PE0142-C unphased het followed by het
# Sample PE0438-C unphased het followed by het
# Sample PF0230-C unphased het followed by het
# Sample PF0844-C unphased het followed by het
# Sample PF0903-C unphased het followed by het
# Sample PF1001-C unphased het followed by het
# Sample PF1129-Cx9 unphased het followed by het
# Sample PF1151-Cx unphased het followed by het
# Sample PF1152-C unphased het followed by het
# Sample PF1161-Cx7 unphased het followed by het
# Sample PK0048-C unphased het followed by het
# Sample PM0040-C unphased het followed by het
# Sample PM0417-C unphased het followed by het
# Sample QP0024-C unphased het followed by het
# Sample QQ0084-C unphased het followed by het
# Sample QQ0110-C unphased het followed by het
# Record(CHROM=Pf3D7_08_v3, POS=549683, REF=T, ALT=[C]) []
#
#  dhps_437
# Record(CHROM=Pf3D7_08_v3, POS=549685, REF=G, ALT=[C]) []
#
#  dhps_540
# Record(CHROM=Pf3D7_08_v3, POS=549993, REF=A, ALT=[G, T]) []
# Record(CHROM=Pf3D7_08_v3, POS=549994, REF=A, ALT=[T]) []
# Record(CHROM=Pf3D7_08_v3, POS=549995, REF=A, ALT=[T, G]) []
# Sample PD0021-C unphased het followed by het
# Sample PD0030-C unphased het followed by het
# Sample PD0469-C unphased het followed by het
# Sample PD0499-C unphased het followed by het
# Sample PD0517-C unphased het followed by het
# Sample PD0802-C unphased het followed by het
# Sample PD0882-C unphased het followed by het
# Sample PD0905-C unphased het followed by het
# Sample PD1036-C unphased het followed by het
# Sample PD1120-C unphased het followed by het
# Sample PD1379-C unphased het followed by het
# Sample PH0124-CW unphased het followed by het
# Sample PH0302-C unphased het followed by het
# Sample PH0324-C unphased het followed by het
# Sample PH0330-C unphased het followed by het
# Sample PH0461-C unphased het followed by het
# Sample PH0472-C unphased het followed by het
# Sample PH0478-C unphased het followed by het
# Sample PH0547-C unphased het followed by het
# Sample PH0548-C unphased het followed by het
# Sample PH0572-C unphased het followed by het
# Sample PH0724-C unphased het followed by het
# Sample PH0747-Cx unphased het followed by het
# Sample PH1087-C unphased het followed by het
# Sample PH1361-C unphased het followed by het
# Sample PV0225-C unphased het followed by het
# Sample PV0281-C unphased het followed by het
# Sample PV0338-C unphased het followed by het
#
#  dhps_581
# Record(CHROM=Pf3D7_08_v3, POS=550117, REF=C, ALT=[G]) []
# Record(CHROM=Pf3D7_08_v3, POS=550118, REF=G, ALT=[T]) []
#
#  dhps_613
# Record(CHROM=Pf3D7_08_v3, POS=550212, REF=G, ALT=[T, A]) []
#
#  mdr1_86
# Record(CHROM=Pf3D7_05_v3, POS=958145, REF=A, ALT=[T]) []
# Record(CHROM=Pf3D7_05_v3, POS=958146, REF=A, ALT=[T]) []
#
#  mdr1_184
# Record(CHROM=Pf3D7_05_v3, POS=958440, REF=A, ALT=[T]) []
#
#  mdr1_1246
# Record(CHROM=Pf3D7_05_v3, POS=961625, REF=G, ALT=[T]) []
#
#  arps10_127
# Record(CHROM=Pf3D7_14_v3, POS=2481070, REF=G, ALT=[A]) []
#
#  mdr2_484
# Record(CHROM=Pf3D7_14_v3, POS=1956225, REF=G, ALT=[A]) []
#
#  fd_193
# Record(CHROM=Pf3D7_13_v3, POS=748395, REF=C, ALT=[A]) []
#
#  exo_415
# Record(CHROM=Pf3D7_13_v3, POS=2504560, REF=A, ALT=[T, G]) []
# Record(CHROM=Pf3D7_13_v3, POS=2504561, REF=G, ALT=[A]) []
# crt_24[D]
# crt_97[H]
# crt_144[A]
# crt_148[L]
# crt_194[I]
# crt_220[A]
# crt_271[Q]
# crt_326[N]
# crt_333[T]
# crt_342[T]
# crt_356[I]
# crt_371[R]
# dhfr_51[N]
# dhfr_59[C]
# dhfr_108[S]
# dhfr_164[I]
# dhps_436[S]
# dhps_437[G]
# dhps_540[K]
# dhps_581[A]
# dhps_613[A]
# mdr1_86[N]
# mdr1_184[Y]
# mdr1_1246[D]
# arps10_127[V]
# mdr2_484[T]
# fd_193[D]
# exo_415[E]

# %%
tbl_all_results = call_all_haplotypes()
# Out:
#  crt_72-76
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C]) []
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT]) []
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T]) []
# Sample PH0046-C two PIDs
# Sample PH0242-C two PIDs
# Sample PV0303-C two PIDs
# Sample PV0323-C two PIDs
# Sample QE0396-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G]) []
# Sample PH0046-C two PIDs
# Sample PH0242-C two PIDs
# Sample PV0303-C two PIDs
# Sample PV0323-C two PIDs
# Sample QE0396-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A]) []
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA]) []
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C]) []
# Sample PN0008-C two unphased hets
# Sample PN0054-C two unphased hets
# Sample PN0075-C two unphased hets
# Sample PN0105-C two unphased hets
# Sample PN0112-C two unphased hets
#
#  crt_24
# Record(CHROM=Pf3D7_07_v3, POS=403291, REF=G, ALT=[T]) []
#
#  crt_97
# Record(CHROM=Pf3D7_07_v3, POS=403687, REF=C, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=403688, REF=A, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=403689, REF=C, ALT=[A, T]) []
#
#  crt_144
# Record(CHROM=Pf3D7_07_v3, POS=404007, REF=G, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=404008, REF=C, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=404009, REF=C, ALT=[T]) []
#
#  crt_148
# Record(CHROM=Pf3D7_07_v3, POS=404019, REF=C, ALT=[A]) []
#
#  crt_194
# Record(CHROM=Pf3D7_07_v3, POS=404330, REF=T, ALT=[C]) []
#
#  crt_220
# Record(CHROM=Pf3D7_07_v3, POS=404407, REF=G, ALT=[T]) []
#
#  crt_271
# Record(CHROM=Pf3D7_07_v3, POS=404836, REF=C, ALT=[G]) []
# Record(CHROM=Pf3D7_07_v3, POS=404838, REF=A, ALT=[G]) ['Low_VQSLOD']
#
#  crt_326
# Record(CHROM=Pf3D7_07_v3, POS=405361, REF=A, ALT=[G]) []
# Record(CHROM=Pf3D7_07_v3, POS=405362, REF=A, ALT=[G]) []
#
#  crt_333
# Record(CHROM=Pf3D7_07_v3, POS=405382, REF=A, ALT=[G]) []
# Record(CHROM=Pf3D7_07_v3, POS=405383, REF=C, ALT=[G]) []
# Sample PN0112-C two unphased hets
# Sample PN0117-C two unphased hets
# Sample PN0118-C two unphased hets
# Sample PN0167-C two unphased hets
# Record(CHROM=Pf3D7_07_v3, POS=405384, REF=C, ALT=[T]) []
#
#  crt_342
# Record(CHROM=Pf3D7_07_v3, POS=405557, REF=A, ALT=[G]) []
# Record(CHROM=Pf3D7_07_v3, POS=405559, REF=C, ALT=[A]) ['Low_VQSLOD']
#
#  crt_356
# Record(CHROM=Pf3D7_07_v3, POS=405599, REF=A, ALT=[T]) []
# Record(CHROM=Pf3D7_07_v3, POS=405600, REF=T, ALT=[C]) []
#
#  crt_371
# Record(CHROM=Pf3D7_07_v3, POS=405838, REF=G, ALT=[T, C]) []
#
#  dhfr_51
# Record(CHROM=Pf3D7_04_v3, POS=748239, REF=A, ALT=[T]) []
#
#  dhfr_59
# Record(CHROM=Pf3D7_04_v3, POS=748262, REF=T, ALT=[C]) []
# Record(CHROM=Pf3D7_04_v3, POS=748263, REF=G, ALT=[A]) []
#
#  dhfr_108
# Record(CHROM=Pf3D7_04_v3, POS=748410, REF=G, ALT=[A, C]) []
#
#  dhfr_164
# Record(CHROM=Pf3D7_04_v3, POS=748577, REF=A, ALT=[T]) []
# Record(CHROM=Pf3D7_04_v3, POS=748579, REF=A, ALT=[G]) []
#
#  dhps_436
# Record(CHROM=Pf3D7_08_v3, POS=549681, REF=T, ALT=[G, C]) []
# Record(CHROM=Pf3D7_08_v3, POS=549682, REF=C, ALT=[T, G, A]) []
# Sample PC0276-C two unphased hets
# Sample PE0142-C two unphased hets
# Sample PE0438-C two unphased hets
# Sample PF0844-C two unphased hets
# Sample PF1001-C two unphased hets
# Sample PF1129-Cx9 two unphased hets
# Sample PF1151-Cx two unphased hets
# Sample PF1152-C two unphased hets
# Sample PF1161-Cx7 two unphased hets
# Sample PM0040-C two unphased hets
# Sample QQ0084-C two unphased hets
# Record(CHROM=Pf3D7_08_v3, POS=549683, REF=T, ALT=[C]) []
#
#  dhps_437
# Record(CHROM=Pf3D7_08_v3, POS=549685, REF=G, ALT=[C]) []
#
#  dhps_540
# Record(CHROM=Pf3D7_08_v3, POS=549993, REF=A, ALT=[G, T]) []
# Record(CHROM=Pf3D7_08_v3, POS=549994, REF=A, ALT=[T]) []
# Record(CHROM=Pf3D7_08_v3, POS=549995, REF=A, ALT=[T, G]) []
# Sample PD0021-C two unphased hets
# Sample PD0030-C two unphased hets
# Sample PD0469-C two unphased hets
# Sample PD0499-C two unphased hets
# Sample PD0517-C two unphased hets
# Sample PD0802-C two unphased hets
# Sample PD0882-C two unphased hets
# Sample PD0905-C two unphased hets
# Sample PD1036-C two unphased hets
# Sample PD1120-C two unphased hets
# Sample PD1379-C two unphased hets
# Sample PH0124-CW two unphased hets
# Sample PH0302-C two unphased hets
# Sample PH0324-C two unphased hets
# Sample PH0330-C two unphased hets
# Sample PH0461-C two unphased hets
# Sample PH0472-C two unphased hets
# Sample PH0478-C two unphased hets
# Sample PH0547-C two unphased hets
# Sample PH0548-C two unphased hets
# Sample PH0572-C two unphased hets
# Sample PH0724-C two unphased hets
# Sample PH0747-Cx two unphased hets
# Sample PH1087-C two unphased hets
# Sample PH1361-C two unphased hets
# Sample PV0225-C two unphased hets
# Sample PV0281-C two unphased hets
# Sample PV0338-C two unphased hets
#
#  dhps_581
# Record(CHROM=Pf3D7_08_v3, POS=550117, REF=C, ALT=[G]) []
# Record(CHROM=Pf3D7_08_v3, POS=550118, REF=G, ALT=[T]) []
#
#  dhps_613
# Record(CHROM=Pf3D7_08_v3, POS=550212, REF=G, ALT=[T, A]) []
#
#  mdr1_86
# Record(CHROM=Pf3D7_05_v3, POS=958145, REF=A, ALT=[T]) []
# Record(CHROM=Pf3D7_05_v3, POS=958146, REF=A, ALT=[T]) []
#
#  mdr1_184
# Record(CHROM=Pf3D7_05_v3, POS=958440, REF=A, ALT=[T]) []
#
#  mdr1_1246
# Record(CHROM=Pf3D7_05_v3, POS=961625, REF=G, ALT=[T]) []
#
#  arps10_127
# Record(CHROM=Pf3D7_14_v3, POS=2481070, REF=G, ALT=[A]) []
#
#  mdr2_484
# Record(CHROM=Pf3D7_14_v3, POS=1956225, REF=G, ALT=[A]) []
#
#  fd_193
# Record(CHROM=Pf3D7_13_v3, POS=748395, REF=C, ALT=[A]) []
#
#  exo_415
# Record(CHROM=Pf3D7_13_v3, POS=2504560, REF=A, ALT=[T, G]) []
# Record(CHROM=Pf3D7_13_v3, POS=2504561, REF=G, ALT=[A]) []
# crt_24[D]
# crt_97[H]
# crt_144[A]
# crt_148[L]
# crt_194[I]
# crt_220[A]
# crt_271[Q]
# crt_326[N]
# crt_333[T]
# crt_342[T]
# crt_356[I]
# crt_371[R]
# dhfr_51[N]
# dhfr_59[C]
# dhfr_108[S]
# dhfr_164[I]
# dhps_436[S]
# dhps_437[G]
# dhps_540[K]
# dhps_581[A]
# dhps_613[A]
# mdr1_86[N]
# mdr1_184[Y]
# mdr1_1246[D]
# arps10_127[V]
# mdr2_484[T]
# fd_193[D]
# exo_415[E]

# %%
tbl_all_results = call_all_haplotypes()
# Out:
#  crt_72-76
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A])
# []
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C])
# []
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A])
# []
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT])
# []
# /nfs/users/nfs_r/rp7/anaconda3/lib/python3.4/site-packages/Bio/Seq.py:2040: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   BiopythonWarning)
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T])
# []
# Sample PH0046-C two PIDs
# Sample PH0242-C two PIDs
# Sample PV0303-C two PIDs
# Sample PV0323-C two PIDs
# Sample QE0396-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G])
# []
# Sample PH0046-C two PIDs
# Sample PH0242-C two PIDs
# Sample PV0303-C two PIDs
# Sample PV0323-C two PIDs
# Sample QE0396-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A])
# []
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA])
# []
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C])
# []
# Sample PN0008-C two unphased hets
# Sample PN0054-C two unphased hets
# Sample PN0075-C two unphased hets
# Sample PN0105-C two unphased hets
# Sample PN0112-C two unphased hets
#
#  crt_24
# Record(CHROM=Pf3D7_07_v3, POS=403291, REF=G, ALT=[T])
# []
#
#  crt_97
# Record(CHROM=Pf3D7_07_v3, POS=403687, REF=C, ALT=[T])
# []
# Record(CHROM=Pf3D7_07_v3, POS=403688, REF=A, ALT=[T])
# []
# Record(CHROM=Pf3D7_07_v3, POS=403689, REF=C, ALT=[A, T])
# []
#
#  crt_144
# Record(CHROM=Pf3D7_07_v3, POS=404007, REF=G, ALT=[T])
# []
# Record(CHROM=Pf3D7_07_v3, POS=404008, REF=C, ALT=[T])
# []
# Record(CHROM=Pf3D7_07_v3, POS=404009, REF=C, ALT=[T])
# []
#
#  crt_148
# Record(CHROM=Pf3D7_07_v3, POS=404019, REF=C, ALT=[A])
# []
#
#  crt_194
# Record(CHROM=Pf3D7_07_v3, POS=404330, REF=T, ALT=[C])
# []
#
#  crt_220
# Record(CHROM=Pf3D7_07_v3, POS=404407, REF=G, ALT=[T])
# []
#
#  crt_271
# Record(CHROM=Pf3D7_07_v3, POS=404836, REF=C, ALT=[G])
# []
# Record(CHROM=Pf3D7_07_v3, POS=404838, REF=A, ALT=[G])
# ['Low_VQSLOD']
#
#  crt_326
# Record(CHROM=Pf3D7_07_v3, POS=405361, REF=A, ALT=[G])
# []
# Record(CHROM=Pf3D7_07_v3, POS=405362, REF=A, ALT=[G])
# []
#
#  crt_333
# Record(CHROM=Pf3D7_07_v3, POS=405382, REF=A, ALT=[G])
# []
# Record(CHROM=Pf3D7_07_v3, POS=405383, REF=C, ALT=[G])
# []
# Sample PN0112-C two unphased hets
# Sample PN0117-C two unphased hets
# Sample PN0118-C two unphased hets
# Sample PN0167-C two unphased hets
# Record(CHROM=Pf3D7_07_v3, POS=405384, REF=C, ALT=[T])
# []
#
#  crt_342
# Record(CHROM=Pf3D7_07_v3, POS=405557, REF=A, ALT=[G])
# []
# Record(CHROM=Pf3D7_07_v3, POS=405559, REF=C, ALT=[A])
# ['Low_VQSLOD']
#
#  crt_356
# Record(CHROM=Pf3D7_07_v3, POS=405599, REF=A, ALT=[T])
# []
# Record(CHROM=Pf3D7_07_v3, POS=405600, REF=T, ALT=[C])
# []
#
#  crt_371
# Record(CHROM=Pf3D7_07_v3, POS=405838, REF=G, ALT=[T, C])
# []
#
#  dhfr_51
# Record(CHROM=Pf3D7_04_v3, POS=748239, REF=A, ALT=[T])
# []
#
#  dhfr_59
# Record(CHROM=Pf3D7_04_v3, POS=748262, REF=T, ALT=[C])
# []
# Record(CHROM=Pf3D7_04_v3, POS=748263, REF=G, ALT=[A])
# []
#
#  dhfr_108
# Record(CHROM=Pf3D7_04_v3, POS=748410, REF=G, ALT=[A, C])
# []
#
#  dhfr_164
# Record(CHROM=Pf3D7_04_v3, POS=748577, REF=A, ALT=[T])
# []
# Record(CHROM=Pf3D7_04_v3, POS=748579, REF=A, ALT=[G])
# []
#
#  dhps_436
# Record(CHROM=Pf3D7_08_v3, POS=549681, REF=T, ALT=[G, C])
# []
# Record(CHROM=Pf3D7_08_v3, POS=549682, REF=C, ALT=[T, G, A])
# []
# Sample PC0276-C two unphased hets
# Sample PE0142-C two unphased hets
# Sample PE0438-C two unphased hets
# Sample PF0844-C two unphased hets
# Sample PF1001-C two unphased hets
# Sample PF1129-Cx9 two unphased hets
# Sample PF1151-Cx two unphased hets
# Sample PF1152-C two unphased hets
# Sample PF1161-Cx7 two unphased hets
# Sample PM0040-C two unphased hets
# Sample QQ0084-C two unphased hets
# Record(CHROM=Pf3D7_08_v3, POS=549683, REF=T, ALT=[C])
# []
#
#  dhps_437
# Record(CHROM=Pf3D7_08_v3, POS=549685, REF=G, ALT=[C])
# []
#
#  dhps_540
# Record(CHROM=Pf3D7_08_v3, POS=549993, REF=A, ALT=[G, T])
# []
# Record(CHROM=Pf3D7_08_v3, POS=549994, REF=A, ALT=[T])
# []
# Record(CHROM=Pf3D7_08_v3, POS=549995, REF=A, ALT=[T, G])
# []
# Sample PD0021-C two unphased hets
# Sample PD0030-C two unphased hets
# Sample PD0469-C two unphased hets
# Sample PD0499-C two unphased hets
# Sample PD0517-C two unphased hets
# Sample PD0802-C two unphased hets
# Sample PD0882-C two unphased hets
# Sample PD0905-C two unphased hets
# Sample PD1036-C two unphased hets
# Sample PD1120-C two unphased hets
# Sample PD1379-C two unphased hets
# Sample PH0124-CW two unphased hets
# Sample PH0302-C two unphased hets
# Sample PH0324-C two unphased hets
# Sample PH0330-C two unphased hets
# Sample PH0461-C two unphased hets
# Sample PH0472-C two unphased hets
# Sample PH0478-C two unphased hets
# Sample PH0547-C two unphased hets
# Sample PH0548-C two unphased hets
# Sample PH0572-C two unphased hets
# Sample PH0724-C two unphased hets
# Sample PH0747-Cx two unphased hets
# Sample PH1087-C two unphased hets
# Sample PH1361-C two unphased hets
# Sample PV0225-C two unphased hets
# Sample PV0281-C two unphased hets
# Sample PV0338-C two unphased hets
#
#  dhps_581
# Record(CHROM=Pf3D7_08_v3, POS=550117, REF=C, ALT=[G])
# []
# Record(CHROM=Pf3D7_08_v3, POS=550118, REF=G, ALT=[T])
# []
#
#  dhps_613
# Record(CHROM=Pf3D7_08_v3, POS=550212, REF=G, ALT=[T, A])
# []
#
#  mdr1_86
# Record(CHROM=Pf3D7_05_v3, POS=958145, REF=A, ALT=[T])
# []
# Record(CHROM=Pf3D7_05_v3, POS=958146, REF=A, ALT=[T])
# []
#
#  mdr1_184
# Record(CHROM=Pf3D7_05_v3, POS=958440, REF=A, ALT=[T])
# []
#
#  mdr1_1246
# Record(CHROM=Pf3D7_05_v3, POS=961625, REF=G, ALT=[T])
# []
#
#  arps10_127
# Record(CHROM=Pf3D7_14_v3, POS=2481070, REF=G, ALT=[A])
# []
#
#  mdr2_484
# Record(CHROM=Pf3D7_14_v3, POS=1956225, REF=G, ALT=[A])
# []
#
#  fd_193
# Record(CHROM=Pf3D7_13_v3, POS=748395, REF=C, ALT=[A])
# []
#
#  exo_415
# Record(CHROM=Pf3D7_13_v3, POS=2504560, REF=A, ALT=[T, G])
# []
# Record(CHROM=Pf3D7_13_v3, POS=2504561, REF=G, ALT=[A])
# []
# crt_24[D]
# crt_97[H]
# crt_144[A]
# crt_148[L]
# crt_194[I]
# crt_220[A]
# crt_271[Q]
# crt_326[N]
# crt_333[T]
# crt_342[T]
# crt_356[I]
# crt_371[R]
# dhfr_51[N]
# dhfr_59[C]
# dhfr_108[S]
# dhfr_164[I]
# dhps_436[S]
# dhps_437[G]
# dhps_540[K]
# dhps_581[A]
# dhps_613[A]
# mdr1_86[N]
# mdr1_184[Y]
# mdr1_1246[D]
# arps10_127[V]
# mdr2_484[T]
# fd_193[D]
# exo_415[E]

# %%
tbl_all_results
# Out:
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# | Sample     | crt_72-76[CVMNK] | crt_24[D] | crt_97[H] | crt_144[A] | crt_148[L] | crt_194[I] | crt_220[A] | crt_271[Q] | crt_326[N] | crt_333[T] | crt_342[T] | crt_356[I] | crt_371[R] | dhfr_51[N] | dhfr_59[C] | dhfr_108[S] | dhfr_164[I] | dhps_436[S] | dhps_437[G] | dhps_540[K] | dhps_581[A] | dhps_613[A] | mdr1_86[N] | mdr1_184[Y] | mdr1_1246[D] | arps10_127[V] | mdr2_484[T] | fd_193[D] | exo_415[E] |
# +============+==================+===========+===========+============+============+============+============+============+============+============+============+============+============+============+============+=============+=============+=============+=============+=============+=============+=============+============+=============+==============+===============+=============+===========+============+
# | 'FP0008-C' | 'CVMNK,CVIET'    | 'D'       | 'H'       | 'A'        | 'L'        | 'I'        | 'A,S'      | 'E'        | 'N'        | 'T'        | 'T'        | 'I,T'      | 'R,I'      | 'N'        | 'C'        | 'S,N'       | 'I'         | 'S,A'       | 'G,A'       | 'K'         | 'A'         | 'A'         | 'N'        | 'Y,F'       | 'D'          | 'V'           | 'C'         | 'V'       | 'E'        |
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# | 'FP0009-C' | 'CVIET'          | 'D'       | 'H'       | 'A'        | 'L'        | 'I'        | 'S'        | 'E'        | 'N'        | 'T'        | 'T'        | 'T'        | 'I'        | 'I'        | 'R'        | 'N'         | 'I'         | 'A'         | 'A'         | 'K'         | 'A'         | 'A'         | 'Y'        | 'F'         | 'Y'          | 'V'           | 'C'         | 'V'       | 'E'        |
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# | 'FP0015-C' | 'CVIET'          | 'D'       | 'H'       | 'A'        | 'L'        | 'I'        | 'S'        | 'E'        | 'N'        | 'T'        | 'T'        | 'I'        | 'I'        | 'I'        | 'R'        | 'N'         | 'I'         | 'S,A'       | 'G,A'       | 'K'         | 'A'         | 'A'         | 'N'        | 'Y,F'       | 'D'          | 'V'           | 'C'         | 'V'       | 'E'        |
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# | 'FP0016-C' | 'CVMNK,CVIET'    | 'D'       | 'H'       | 'A'        | 'L'        | 'I'        | 'S'        | 'E'        | 'N'        | 'T'        | 'T'        | 'I'        | 'R,I'      | 'N'        | 'C'        | 'S'         | 'I'         | 'S'         | 'G'         | 'K'         | 'A'         | 'A'         | 'N'        | 'F'         | 'D'          | 'V'           | 'C'         | 'V'       | 'E'        |
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# | 'FP0017-C' | 'CVMNK'          | 'D'       | 'H'       | 'A'        | 'L'        | 'I'        | 'A'        | 'Q'        | 'N'        | 'T'        | 'T'        | 'I'        | 'R'        | 'N'        | 'C'        | 'S'         | 'I'         | 'F,A'       | 'A'         | 'K'         | 'A'         | 'A,S'       | 'N'        | 'Y'         | 'D'          | 'V'           | 'C'         | 'V'       | 'E'        |
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# ...

# %%
tbl_all_results
# Out:
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# | Sample     | crt_72-76[CVMNK] | crt_24[D] | crt_97[H] | crt_144[A] | crt_148[L] | crt_194[I] | crt_220[A] | crt_271[Q] | crt_326[N] | crt_333[T] | crt_342[T] | crt_356[I] | crt_371[R] | dhfr_51[N] | dhfr_59[C] | dhfr_108[S] | dhfr_164[I] | dhps_436[S] | dhps_437[G] | dhps_540[K] | dhps_581[A] | dhps_613[A] | mdr1_86[N] | mdr1_184[Y] | mdr1_1246[D] | arps10_127[V] | mdr2_484[T] | fd_193[D] | exo_415[E] |
# +============+==================+===========+===========+============+============+============+============+============+============+============+============+============+============+============+============+=============+=============+=============+=============+=============+=============+=============+============+=============+==============+===============+=============+===========+============+
# | 'FP0008-C' | '.....'          | 'D'       | 'H'       | 'A'        | 'L'        | 'I'        | 'A,S'      | 'E'        | 'N'        | 'T'        | 'T'        | 'I,T'      | 'R,I'      | 'N'        | 'C'        | 'S,N'       | 'I'         | 'S,A'       | 'G,A'       | 'K'         | 'A'         | 'A'         | 'N'        | 'Y,F'       | 'D'          | 'V'           | 'C'         | 'V'       | 'E'        |
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# | 'FP0009-C' | '.....'          | 'D'       | 'H'       | 'A'        | 'L'        | 'I'        | 'S'        | 'E'        | 'N'        | 'T'        | 'T'        | 'T'        | 'I'        | 'I'        | 'R'        | 'N'         | 'I'         | 'A'         | 'A'         | 'K'         | 'A'         | 'A'         | 'Y'        | 'F'         | 'Y'          | 'V'           | 'C'         | 'V'       | 'E'        |
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# | 'FP0015-C' | '.....'          | 'D'       | 'H'       | 'A'        | 'L'        | 'I'        | 'S'        | 'E'        | 'N'        | 'T'        | 'T'        | 'I'        | 'I'        | 'I'        | 'R'        | 'N'         | 'I'         | 'S,A'       | 'G,A'       | 'K'         | 'A'         | 'A'         | 'N'        | 'Y,F'       | 'D'          | 'V'           | 'C'         | 'V'       | 'E'        |
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# | 'FP0016-C' | '.....'          | 'D'       | 'H'       | 'A'        | 'L'        | 'I'        | 'S'        | 'E'        | 'N'        | 'T'        | 'T'        | 'I'        | 'R,I'      | 'N'        | 'C'        | 'S'         | 'I'         | 'S'         | 'G'         | 'K'         | 'A'         | 'A'         | 'N'        | 'F'         | 'D'          | 'V'           | 'C'         | 'V'       | 'E'        |
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# | 'FP0017-C' | 'CVMNK'          | 'D'       | 'H'       | 'A'        | 'L'        | 'I'        | 'A'        | 'Q'        | 'N'        | 'T'        | 'T'        | 'I'        | 'R'        | 'N'        | 'C'        | 'S'         | 'I'         | 'F,A'       | 'A'         | 'K'         | 'A'         | 'A,S'       | 'N'        | 'Y'         | 'D'          | 'V'           | 'C'         | 'V'       | 'E'        |
# +------------+------------------+-----------+-----------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+------------+-------------+-------------+-------------+-------------+-------------+-------------+-------------+------------+-------------+--------------+---------------+-------------+-----------+------------+
# ...

# %%
tbl_all_results.toxlsx(grc_from_vcf_fn)

# %%
list(all_results.keys())
# Out:
# ['crt_72-76',
#  'crt_24',
#  'crt_97',
#  'crt_144',
#  'crt_148',
#  'crt_194',
#  'crt_220',
#  'crt_271',
#  'crt_326',
#  'crt_333',
#  'crt_342',
#  'crt_356',
#  'crt_371',
#  'dhfr_51',
#  'dhfr_59',
#  'dhfr_108',
#  'dhfr_164',
#  'dhps_436',
#  'dhps_437',
#  'dhps_540',
#  'dhps_581',
#  'dhps_613',
#  'mdr1_86',
#  'mdr1_184',
#  'mdr1_1246',
#  'arps10_127',
#  'mdr2_484',
#  'fd_193',
#  'exo_415']

# %%
tbl_results = (etl
    .fromcolumns([list(all_results['crt_72-76'].keys()), list(all_results['crt_72-76'].values())], header=['Sample', 'crt_72-76'])
#     .reheader(['Sample', 'crt_72-76'])
)
for locus_name in list(all_results.keys())[1:]:
    print(locus_name)
    tbl_results = tbl_results.addcolumn(locus_name, all_results[locus_name].values())
tbl_results.head()
# Out:
# crt_24
# crt_97
# crt_144
# crt_148
# crt_194
# crt_220
# crt_271
# crt_326
# crt_333
# crt_342
# crt_356
# crt_371
# dhfr_51
# dhfr_59
# dhfr_108
# dhfr_164
# dhps_436
# dhps_437
# dhps_540
# dhps_581
# dhps_613
# mdr1_86
# mdr1_184
# mdr1_1246
# arps10_127
# mdr2_484
# fd_193
# exo_415
# +------------+---------------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+----------+----------+----------+----------+----------+----------+----------+---------+----------+-----------+------------+----------+--------+---------+
# | Sample     | crt_72-76     | crt_24 | crt_97 | crt_144 | crt_148 | crt_194 | crt_220 | crt_271 | crt_326 | crt_333 | crt_342 | crt_356 | crt_371 | dhfr_51 | dhfr_59 | dhfr_108 | dhfr_164 | dhps_436 | dhps_437 | dhps_540 | dhps_581 | dhps_613 | mdr1_86 | mdr1_184 | mdr1_1246 | arps10_127 | mdr2_484 | fd_193 | exo_415 |
# +============+===============+========+========+=========+=========+=========+=========+=========+=========+=========+=========+=========+=========+=========+=========+==========+==========+==========+==========+==========+==========+==========+=========+==========+===========+============+==========+========+=========+
# | 'FP0008-C' | 'CVMNK,CVIET' | 'D'    | 'H'    | 'A'     | 'L'     | 'I'     | 'A,S'   | 'E'     | 'N'     | 'T'     | 'T'     | 'I,T'   | 'R,I'   | 'N'     | 'C'     | 'S,N'    | 'I'      | 'S,A'    | 'G,A'    | 'K'      | 'A'      | 'A'      | 'N'     | 'Y,F'    | 'D'       | 'V'        | 'C'      | 'V'    | 'E'     |
# +------------+---------------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+----------+----------+----------+----------+----------+----------+----------+---------+----------+-----------+------------+----------+--------+---------+
# | 'FP0009-C' | 'CVIET'       | 'D'    | 'H'    | 'A'     | 'L'     | 'I'     | 'S'     | 'E'     | 'N'     | 'T'     | 'T'     | 'T'     | 'I'     | 'I'     | 'R'     | 'N'      | 'I'      | 'A'      | 'A'      | 'K'      | 'A'      | 'A'      | 'Y'     | 'F'      | 'Y'       | 'V'        | 'C'      | 'V'    | 'E'     |
# +------------+---------------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+----------+----------+----------+----------+----------+----------+----------+---------+----------+-----------+------------+----------+--------+---------+
# | 'FP0015-C' | 'CVIET'       | 'D'    | 'H'    | 'A'     | 'L'     | 'I'     | 'S'     | 'E'     | 'N'     | 'T'     | 'T'     | 'I'     | 'I'     | 'I'     | 'R'     | 'N'      | 'I'      | 'S,A'    | 'G,A'    | 'K'      | 'A'      | 'A'      | 'N'     | 'Y,F'    | 'D'       | 'V'        | 'C'      | 'V'    | 'E'     |
# +------------+---------------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+----------+----------+----------+----------+----------+----------+----------+---------+----------+-----------+------------+----------+--------+---------+
# | 'FP0016-C' | 'CVMNK,CVIET' | 'D'    | 'H'    | 'A'     | 'L'     | 'I'     | 'S'     | 'E'     | 'N'     | 'T'     | 'T'     | 'I'     | 'R,I'   | 'N'     | 'C'     | 'S'      | 'I'      | 'S'      | 'G'      | 'K'      | 'A'      | 'A'      | 'N'     | 'F'      | 'D'       | 'V'        | 'C'      | 'V'    | 'E'     |
# +------------+---------------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+----------+----------+----------+----------+----------+----------+----------+---------+----------+-----------+------------+----------+--------+---------+
# | 'FP0017-C' | 'CVMNK'       | 'D'    | 'H'    | 'A'     | 'L'     | 'I'     | 'A'     | 'Q'     | 'N'     | 'T'     | 'T'     | 'I'     | 'R'     | 'N'     | 'C'     | 'S'      | 'I'      | 'F,A'    | 'A'      | 'K'      | 'A'      | 'A,S'    | 'N'     | 'Y'      | 'D'       | 'V'        | 'C'      | 'V'    | 'E'     |
# +------------+---------------+--------+--------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+----------+----------+----------+----------+----------+----------+----------+---------+----------+-----------+------------+----------+--------+---------+

# %%
list(all_results['crt_72-76'].keys())
# Out:
# ['FP0008-C',
#  'FP0009-C',
#  'FP0015-C',
#  'FP0016-C',
#  'FP0017-C',
#  'FP0018-C',
#  'FP0020-C',
#  'FP0021-C',
#  'FP0022-C',
#  'FP0023-C',
#  'FP0024-C',
#  'FP0025-C',
#  'FP0026-C',
#  'FP0027-C',
#  'FP0028-C',
#  'FP0029-C',
#  'FP0030-C',
#  'FP0031-C',
#  'FP0032-C',
#  'FP0033-C',
#  'FP0034-C',
#  'FP0035-C',
#  'FP0038-C',
#  'FP0039-C',
#  'FP0040-C',
#  'FP0041-C',
#  'FP0042-C',
#  'FP0043-C',
#  'FP0044-C',
#  'FP0046-C',
#  'FP0047-C',
#  'FP0048-C',
#  'FP0051-C',
#  'FP0052-C',
#  'FP0054-C',
#  'FP0055-C',
#  'FP0056-C',
#  'FP0057-C',
#  'FP0058-C',
#  'FP0059-C',
#  'FP0061-C',
#  'FP0062-C',
#  'FP0063-C',
#  'FP0064-C',
#  'FP0065-C',
#  'FP0066-C',
#  'FP0067-C',
#  'FP0068-C',
#  'FP0069-C',
#  'FP0070-C',
#  'FP0073-C',
#  'FP0077-C',
#  'FP0078-C',
#  'FP0081-C',
#  'FP0082-C',
#  'FP0084-C',
#  'FP0089-C',
#  'FP0090-C',
#  'FP0092-C',
#  'FP0093-C',
#  'FP0095-C',
#  'FP0096-C',
#  'FP0097-C',
#  'FP0098-C',
#  'FP0101-C',
#  'FP0102-C',
#  'FP0103-C',
#  'FP0105-C',
#  'FP0106-C',
#  'FP0109-C',
#  'FP0110-C',
#  'FP0112-C',
#  'FP0113-C',
#  'FP0114-C',
#  'FP0116-C',
#  'FP0117-C',
#  'FP0119-C',
#  'FP0120-C',
#  'FP0123-C',
#  'FP0127-C',
#  'FP0128-C',
#  'FP0129-C',
#  'FP0132-C',
#  'FP0133-C',
#  'FP0136-C',
#  'FP0139-C',
#  'PA0007-C',
#  'PA0008-C',
#  'PA0011-C',
#  'PA0012-C',
#  'PA0013-C',
#  'PA0014-C',
#  'PA0015-C',
#  'PA0016-C',
#  'PA0017-C',
#  'PA0018-C',
#  'PA0020-C',
#  'PA0021-C',
#  'PA0022-C',
#  'PA0026-C',
#  'PA0027-C',
#  'PA0028-C',
#  'PA0029-C',
#  'PA0030-C',
#  'PA0032-C',
#  'PA0034-C',
#  'PA0035-C',
#  'PA0036-C',
#  'PA0037-C',
#  'PA0038-C',
#  'PA0039-C',
#  'PA0040-C',
#  'PA0041-C',
#  'PA0042-C',
#  'PA0044-C',
#  'PA0045-C',
#  'PA0046-C',
#  'PA0047-C',
#  'PA0049-C',
#  'PA0050-C',
#  'PA0051-C',
#  'PA0052-C',
#  'PA0053-C',
#  'PA0054-C',
#  'PA0056-C',
#  'PA0057-C',
#  'PA0059-C',
#  'PA0060-C',
#  'PA0061-C',
#  'PA0063-C',
#  'PA0064-C',
#  'PA0065-C',
#  'PA0066-C',
#  'PA0067-C',
#  'PA0068-C',
#  'PA0069-C',
#  'PA0071-C',
#  'PA0072-C',
#  'PA0073-C',
#  'PA0074-C',
#  'PA0075-C',
#  'PA0078-C',
#  'PA0079-C',
#  'PA0080-C',
#  'PA0081-C',
#  'PA0084-C',
#  'PA0085-C',
#  'PA0086-C',
#  'PA0087-C',
#  'PA0089-C',
#  'PA0090-C',
#  'PA0091-C',
#  'PA0092-C',
#  'PA0093-C',
#  'PA0094-C',
#  'PA0095-C',
#  'PA0097-C',
#  'PA0098-C',
#  'PA0099-C',
#  'PA0100-C',
#  'PA0101-C',
#  'PA0102-C',
#  'PA0103-C',
#  'PA0104-C',
#  'PA0105-C',
#  'PA0134-C',
#  'PA0136-C',
#  'PA0137-C',
#  'PA0138-C',
#  'PA0140-C',
#  'PA0141-C',
#  'PA0143-C',
#  'PA0144-C',
#  'PA0145-C',
#  'PA0146-C',
#  'PA0147-C',
#  'PA0148-C',
#  'PA0149-C',
#  'PA0150-C',
#  'PA0151-C',
#  'PA0152-C',
#  'PA0153-C',
#  'PA0154-C',
#  'PA0155-C',
#  'PA0156-C',
#  'PA0157-C',
#  'PA0158-C',
#  'PA0159-C',
#  'PA0160-C',
#  'PA0161-C',
#  'PA0162-C',
#  'PA0163-C',
#  'PA0164-C',
#  'PA0165-C',
#  'PA0166-C',
#  'PA0167-C',
#  'PA0168-C',
#  'PA0169-C',
#  'PA0170-C',
#  'PA0171-C',
#  'PA0172-C',
#  'PA0173-C',
#  'PA0174-C',
#  'PA0175-C',
#  'PA0176-C',
#  'PA0177-C',
#  'PA0178-C',
#  'PA0179-C',
#  'PA0180-C',
#  'PA0181-C',
#  'PA0182-C',
#  'PA0183-C',
#  'PA0184-C',
#  'PA0185-C',
#  'PA0186-C',
#  'PA0187-C',
#  'PA0188-C',
#  'PA0189-C',
#  'PA0190-C',
#  'PA0191-C',
#  'PA0192-C',
#  'PA0193-C',
#  'PA0194-C',
#  'PA0195-C',
#  'PA0196-C',
#  'PA0197-C',
#  'PA0198-C',
#  'PA0199-C',
#  'PA0200-C',
#  'PA0201-C',
#  'PA0202-C',
#  'PA0203-C',
#  'PA0204-C',
#  'PA0205-C',
#  'PA0206-C',
#  'PA0207-C',
#  'PA0208-C',
#  'PA0209-C',
#  'PA0210-C',
#  'PA0211-C',
#  'PA0212-C',
#  'PA0213-C',
#  'PA0214-C',
#  'PA0215-C',
#  'PA0216-C',
#  'PA0217-C',
#  'PA0218-C',
#  'PA0219-C',
#  'PA0220-C',
#  'PA0221-C',
#  'PA0222-C',
#  'PA0223-C',
#  'PA0224-C',
#  'PA0225-C',
#  'PA0226-C',
#  'PA0227-C',
#  'PA0228-C',
#  'PA0229-C',
#  'PA0230-C',
#  'PA0231-C',
#  'PA0232-C',
#  'PA0233-C',
#  'PA0234-C',
#  'PA0235-C',
#  'PA0236-C',
#  'PA0237-C',
#  'PA0238-C',
#  'PA0239-C',
#  'PA0240-C',
#  'PA0241-C',
#  'PA0242-C',
#  'PA0243-C',
#  'PA0244-C',
#  'PA0245-C',
#  'PA0246-C',
#  'PA0247-C',
#  'PA0248-C',
#  'PA0249-C',
#  'PA0250-C',
#  'PA0251-C',
#  'PA0252-C',
#  'PA0253-C',
#  'PA0254-C',
#  'PA0255-C',
#  'PA0256-C',
#  'PA0257-C',
#  'PA0258-C',
#  'PA0259-C',
#  'PA0260-C',
#  'PA0261-C',
#  'PA0262-C',
#  'PA0263-C',
#  'PA0264-C',
#  'PA0265-C',
#  'PA0266-C',
#  'PA0267-C',
#  'PA0268-C',
#  'PA0269-C',
#  'PA0270-C',
#  'PA0271-C',
#  'PA0272-C',
#  'PA0273-C',
#  'PA0280-CW',
#  'PA0281-CW',
#  'PA0283-CW',
#  'PA0284-CW',
#  'PA0285-CW',
#  'PA0288-CW',
#  'PA0289-C',
#  'PA0289-CW',
#  'PA0290-C',
#  'PA0291-CW',
#  'PA0292-CW',
#  'PA0293-CW',
#  'PA0294-CW',
#  'PA0295-CW',
#  'PA0297-CW',
#  'PA0298-C',
#  'PA0299-CW',
#  'PA0300-C',
#  'PA0302-C',
#  'PA0303-CW',
#  'PA0305-CW',
#  'PA0306-CW',
#  'PA0307-CW',
#  'PA0312-CW',
#  'PA0313-CW',
#  'PA0318-CW',
#  'PA0320-C',
#  'PA0321-CW',
#  'PA0322-C',
#  'PA0325-CW',
#  'PA0327-CW',
#  'PA0328-CW',
#  'PA0329-CW',
#  'PA0330-CW',
#  'PA0331-CW',
#  'PA0332-CW',
#  'PA0334-CW',
#  'PA0335-CW',
#  'PA0337-C',
#  'PA0339-CW',
#  'PA0340-CW',
#  'PA0341-C',
#  'PA0342-CW',
#  'PA0343-CW',
#  'PA0344-CW',
#  'PA0345-CW',
#  'PA0346-CW',
#  'PA0347-CW',
#  'PA0349-C',
#  'PA0350-CW',
#  'PA0351-CW',
#  'PA0353-CW',
#  'PA0354-CW',
#  'PA0356-CW',
#  'PA0357-CW',
#  'PA0358-CW',
#  'PA0362-CW',
#  'PA0363-CW',
#  'PA0364-CW',
#  'PA0369-CW',
#  'PA0370-C',
#  'PA0371-C',
#  'PA0372-C',
#  'PA0373-C',
#  'PA0374-C',
#  'PA0375-C',
#  'PA0376-C',
#  'PA0377-C',
#  'PA0378-C',
#  'PA0379-C',
#  'PA0382-C',
#  'PA0383-C',
#  'PA0384-C',
#  'PA0386-C',
#  'PA0387-C',
#  'PA0388-C',
#  'PA0389-C',
#  'PA0391-C',
#  'PA0392-C',
#  'PA0393-C',
#  'PA0394-C',
#  'PA0395-C',
#  'PA0396-C',
#  'PA0397-C',
#  'PA0398-C',
#  'PA0399-C',
#  'PA0400-C',
#  'PA0401-C',
#  'PA0402-C',
#  'PA0403-C',
#  'PA0404-C',
#  'PA0405-C',
#  'PA0406-C',
#  'PA0407-C',
#  'PA0409-C',
#  'PA0410-C',
#  'PA0411-C',
#  'PA0413-C',
#  'PA0414-C',
#  'PA0417-C',
#  'PA0419-C',
#  'PA0423-C',
#  'PA0424-C',
#  'PA0425-C',
#  'PA0431-C',
#  'PA0439-C',
#  'PA0440-C',
#  'PA0441-C',
#  'PA0443-C',
#  'PA0444-C',
#  'PA0445-C',
#  'PA0447-C',
#  'PA0449-C',
#  'PA0450-C',
#  'PA0453-C',
#  'PA0454-C',
#  'PA0455-C',
#  'PA0456-C',
#  'PA0457-C',
#  'PA0458-C',
#  'PA0459-C',
#  'PA0460-C',
#  'PA0461-C',
#  'PA0462-C',
#  'PA0464-C',
#  'PA0467-C',
#  'PA0468-C',
#  'PA0469-C',
#  'PA0470-C',
#  'PA0471-C',
#  'PA0472-C',
#  'PA0473-C',
#  'PA0474-C',
#  'PA0477-C',
#  'PA0478-C',
#  'PA0479-C',
#  'PA0480-C',
#  'PA0482-C',
#  'PA0484-C',
#  'PA0486-C',
#  'PA0488-C',
#  'PA0490-C',
#  'PA0491-C',
#  'PA0494-C',
#  'PA0496-C',
#  'PA0497-C',
#  'PA0500-C',
#  'PA0502-C',
#  'PA0505-C',
#  'PA0506-C',
#  'PA0507-C',
#  'PA0512-C',
#  'PA0513-C',
#  'PA0516-C',
#  'PA0519-C',
#  'PA0520-C',
#  'PA0521-C',
#  'PA0522-C',
#  'PA0524-C',
#  'PA0532-C',
#  'PA0534-C',
#  'PA0537-C',
#  'PA0540-C',
#  'PA0541-C',
#  'PA0542-C',
#  'PA0544-C',
#  'PA0550-C',
#  'PA0551-C',
#  'PA0554-C',
#  'PA0558-C',
#  'PA0561-C',
#  'PA0562-C',
#  'PA0563-C',
#  'PA0564-C',
#  'PA0572-C',
#  'PA0575-C',
#  'PA0576-C',
#  'PA0577-C',
#  'PA0582-C',
#  'PA0585-C',
#  'PA0586-C',
#  'PA0593-C',
#  'PA0594-C',
#  'PA0597-C',
#  'PA0599-C',
#  'PA0600-C',
#  'PA0603-C',
#  'PA0604-C',
#  'PA0605-C',
#  'PA0606-C',
#  'PA0610-C',
#  'PA0611-C',
#  'PA0612-C',
#  'PA0613-C',
#  'PA0615-C',
#  'PA0617-C',
#  'PA0618-C',
#  'PA0619-C',
#  'PA0620-C',
#  'PA0621-C',
#  'PA0622-C',
#  'PA0623-C',
#  'PA0625-C',
#  'PA0626-C',
#  'PA0627-C',
#  'PA0628-C',
#  'PA0629-C',
#  'PA0630-C',
#  'PA0631-C',
#  'PA0633-C',
#  'PA0634-C',
#  'PA0635-C',
#  'PA0636-C',
#  'PA0637-C',
#  'PA0638-C',
#  'PA0639-C',
#  'PA0640-C',
#  'PA0641-C',
#  'PA0642-C',
#  'PA0643-C',
#  'PA0644-C',
#  'PA0645-C',
#  'PA0648-C',
#  'PA0649-C',
#  'PA0651-C',
#  'PA0653-C',
#  'PA0654-C',
#  'PA0655-C',
#  'PA0658-CW',
#  'PA0672-CW',
#  'PA0673-CW',
#  'PA0675-CW',
#  'PA0677-CW',
#  'PA0683-CW',
#  'PA0686-CW',
#  'PA0689-CW',
#  'PA0699-CW',
#  'PA0701-CW',
#  'PA0704-CW',
#  'PA0706-CW',
#  'PA0715-CW',
#  'PA0716-CW',
#  'PA0719-CW',
#  'PA0723-CW',
#  'PA0724-CW',
#  'PA0781-CW',
#  'PA0807-CW',
#  'PA0808-CW',
#  'PA0809-CW',
#  'PA0815-CW',
#  'PA0819-CW',
#  'PA0823-CW',
#  'PA0825-CW',
#  'PA0826-CW',
#  'PA0827-CW',
#  'PA0829-CW',
#  'PA0837-CW',
#  'PA0867-CW',
#  'PA0870-CW',
#  'PC0001-C',
#  'PC0002-C',
#  'PC0003-01',
#  'PC0003-02',
#  'PC0004-01',
#  'PC0004-02',
#  'PC0005-Cx',
#  'PC0007-C',
#  'PC0008-01',
#  'PC0008-02',
#  'PC0009-C',
#  'PC0011-C',
#  'PC0012-01',
#  'PC0012-C',
#  'PC0013-C',
#  'PC0016-C',
#  'PC0019-C',
#  'PC0020-C',
#  'PC0021-C',
#  'PC0023-C',
#  'PC0025-C',
#  'PC0026-C',
#  'PC0030-C',
#  'PC0031-C',
#  'PC0032-C',
#  'PC0033-C',
#  'PC0034-C',
#  'PC0035-C',
#  'PC0037-C',
#  'PC0038-C',
#  'PC0044-C',
#  'PC0046-C',
#  'PC0047-C',
#  'PC0048-C',
#  'PC0049-C',
#  'PC0051-C',
#  'PC0053-C',
#  'PC0054-C',
#  'PC0056-C',
#  'PC0057-C',
#  'PC0058-C',
#  'PC0059-C',
#  'PC0061-C',
#  'PC0063-C',
#  'PC0064-C',
#  'PC0065-C',
#  'PC0066-C',
#  'PC0067-C',
#  'PC0068-C',
#  'PC0069-C',
#  'PC0070-C',
#  'PC0071-C',
#  'PC0073-C',
#  'PC0074-C',
#  'PC0075-C',
#  'PC0077-C',
#  'PC0078-C',
#  'PC0079-C',
#  'PC0080-C',
#  'PC0083-C',
#  'PC0085-C',
#  'PC0086-C',
#  'PC0097-C',
#  'PC0103-C',
#  'PC0104-C',
#  'PC0107-C',
#  'PC0109-C',
#  'PC0112-C',
#  'PC0113-C',
#  'PC0118-C',
#  'PC0122-C',
#  'PC0169-C',
#  'PC0172-C',
#  'PC0173-C',
#  'PC0174-C',
#  'PC0178-C',
#  'PC0180-C',
#  'PC0183-C',
#  'PC0184-C',
#  'PC0186-C',
#  'PC0187-C',
#  'PC0188-C',
#  'PC0189-C',
#  'PC0191-C',
#  'PC0193-C',
#  'PC0197-C',
#  'PC0198-C',
#  'PC0199-C',
#  'PC0200-C',
#  'PC0201-C',
#  'PC0202-C',
#  'PC0206-C',
#  'PC0208-C',
#  'PC0209-C',
#  'PC0213-C',
#  'PC0220-C',
#  'PC0229-C',
#  'PC0231-C',
#  'PC0232-C',
#  'PC0233-C',
#  'PC0236-C',
#  'PC0245-C',
#  'PC0246-C',
#  'PC0252-C',
#  'PC0254-C',
#  'PC0255-C',
#  'PC0256-C',
#  'PC0257-C',
#  'PC0258-C',
#  'PC0259-C',
#  'PC0262-C',
#  'PC0263-C',
#  'PC0268-C',
#  'PC0269-C',
#  'PC0273-C',
#  'PC0276-C',
#  'PC0277-C',
#  'PC0278-C',
#  'PC0282-C',
#  'PC0287-C',
#  'PC0288-C',
#  'PC0293-C',
#  'PC0295-C',
#  'PC0296-C',
#  'PC0301-C',
#  'PC0302-C',
#  'PC0305-C',
#  'PC0311-C',
#  'PC0314-C',
#  'PC0318-C',
#  'PC0337-C',
#  'PC0352-C',
#  'PD0003-C',
#  'PD0004-03',
#  'PD0004-C',
#  'PD0005-01',
#  'PD0005-C',
#  'PD0006-01',
#  'PD0007-01',
#  'PD0008-02',
#  'PD0009-01',
#  'PD0010-01',
#  'PD0011-01',
#  'PD0014-01',
#  'PD0015-02',
#  'PD0016-C',
#  'PD0017-C',
#  'PD0018-C',
#  'PD0019-C',
#  'PD0020-C',
#  'PD0021-C',
#  'PD0022-C',
#  'PD0023-C',
#  'PD0025-C',
#  'PD0026-C',
#  'PD0027-C',
#  'PD0028-C',
#  'PD0029-C',
#  'PD0030-C',
#  'PD0031-C',
#  'PD0032-C',
#  'PD0033-C',
#  'PD0034-C',
#  'PD0037-C',
#  'PD0038-C',
#  'PD0039-C',
#  'PD0040-C',
#  'PD0041-C',
#  'PD0042-C',
#  'PD0043-C',
#  'PD0044-C',
#  'PD0045-C',
#  'PD0046-C',
#  'PD0047-C',
#  'PD0048-C',
#  'PD0050-C',
#  'PD0051-C',
#  'PD0052-C',
#  'PD0053-C',
#  'PD0054-C',
#  'PD0055-C',
#  'PD0056-C',
#  'PD0057-C',
#  'PD0058-C',
#  'PD0059-C',
#  'PD0060-C',
#  'PD0061-C',
#  'PD0062-C',
#  'PD0064-C',
#  'PD0065-C',
#  'PD0066-C',
#  'PD0067-C',
#  'PD0068-C',
#  'PD0069-C',
#  'PD0070-C',
#  'PD0071-C',
#  'PD0072-C',
#  'PD0073-C',
#  'PD0074-C',
#  'PD0075-C',
#  'PD0076-C',
#  'PD0077-C',
#  'PD0078-C',
#  'PD0079-C',
#  'PD0080-C',
#  'PD0081-C',
#  'PD0082-C',
#  'PD0083-C',
#  'PD0084-C',
#  'PD0085-C',
#  'PD0086-C',
#  'PD0087-C',
#  'PD0088-C',
#  'PD0089-C',
#  'PD0090-C',
#  'PD0091-C',
#  'PD0092-C',
#  'PD0093-C',
#  'PD0094-C',
#  'PD0095-C',
#  'PD0096-C',
#  'PD0097-C',
#  'PD0098-C',
#  'PD0100-C',
#  'PD0101-C',
#  'PD0102-C',
#  'PD0103-C',
#  'PD0104-C',
#  'PD0105-C',
#  'PD0106-C',
#  'PD0107-C',
#  'PD0109-C',
#  'PD0110-C',
#  'PD0111-C',
#  'PD0112-C',
#  'PD0115-Cx',
#  'PD0116-C',
#  'PD0117-C',
#  'PD0118-C',
#  'PD0119-C',
#  'PD0121-C',
#  'PD0122-C',
#  'PD0123-C',
#  'PD0124-C',
#  'PD0125-C',
#  'PD0126-C',
#  'PD0127-C',
#  'PD0128-C',
#  'PD0129-C',
#  'PD0130-C',
#  'PD0131-C',
#  'PD0132-C',
#  'PD0133-C',
#  'PD0134-C',
#  'PD0135-C',
#  'PD0136-C',
#  'PD0138-C',
#  'PD0139-C',
#  'PD0140-C',
#  'PD0141-C',
#  'PD0142-C',
#  'PD0143-C',
#  'PD0144-C',
#  'PD0145-C',
#  'PD0146-C',
#  'PD0147-C',
#  'PD0148-C',
#  'PD0149-C',
#  'PD0150-C',
#  'PD0151-C',
#  'PD0152-C',
#  'PD0153-C',
#  'PD0154-C',
#  'PD0155-C',
#  'PD0156-C',
#  'PD0157-C',
#  'PD0158-C',
#  'PD0159-C',
#  'PD0161-C',
#  'PD0162-CW',
#  'PD0163-C',
#  'PD0164-C',
#  'PD0458-Cx',
#  'PD0459-Cx',
#  'PD0460-C',
#  'PD0461-C',
#  'PD0462-C',
#  'PD0463-Cx',
#  'PD0464-C',
#  'PD0465-Cx',
#  'PD0466-C',
#  'PD0467-C',
#  'PD0468-C',
#  'PD0469-C',
#  'PD0470-C',
#  'PD0471-C',
#  'PD0472-C',
#  'PD0473-C',
#  'PD0474-C',
#  'PD0475-C',
#  'PD0476-C',
#  'PD0477-C',
#  'PD0478-C',
#  'PD0479-C',
#  'PD0480-C',
#  'PD0481-C',
#  'PD0482-C',
#  'PD0483-C',
#  'PD0484-C',
#  'PD0485-C',
#  'PD0487-C',
#  'PD0488-C',
#  'PD0489-C',
#  'PD0490-C',
#  'PD0491-C',
#  'PD0492-C',
#  'PD0493-C',
#  'PD0494-C',
#  'PD0495-C',
#  'PD0496-C',
#  'PD0497-C',
#  'PD0498-C',
#  'PD0499-C',
#  'PD0500-C',
#  'PD0501-C',
#  'PD0502-C',
#  'PD0503-C',
#  'PD0504-C',
#  'PD0505-C',
#  'PD0506-C',
#  'PD0507-C',
#  'PD0508-C',
#  'PD0509-Cx',
#  'PD0509-Cx2',
#  'PD0510-C',
#  'PD0511-C',
#  'PD0512-C',
#  'PD0513-C',
#  'PD0514-C',
#  'PD0515-C',
#  'PD0516-C',
#  'PD0517-C',
#  'PD0518-C',
#  'PD0519-C',
#  'PD0520-C',
#  'PD0521-C',
#  'PD0522-C',
#  'PD0523-C',
#  'PD0524-C',
#  'PD0525-C',
#  'PD0526-C',
#  'PD0527-C',
#  'PD0528-C',
#  'PD0529-C',
#  'PD0530-C',
#  'PD0531-C',
#  'PD0532-C',
#  'PD0533-C',
#  'PD0534-C',
#  'PD0535-C',
#  'PD0536-C',
#  'PD0537-C',
#  'PD0538-C',
#  'PD0539-C',
#  'PD0540-C',
#  'PD0541-C',
#  'PD0543-C',
#  'PD0544-C',
#  'PD0545-C',
#  'PD0546-C',
#  'PD0547-C',
#  'PD0548-C',
#  'PD0549-C',
#  'PD0550-C',
#  'PD0552-C',
#  'PD0553-C',
#  'PD0554-C',
#  'PD0555-C',
#  'PD0556-C',
#  'PD0557-C',
#  'PD0558-C',
#  'PD0559-C',
#  'PD0560-Cx',
#  'PD0561-C',
#  'PD0562-C',
#  'PD0563-C',
#  'PD0564-C',
#  'PD0565-C',
#  'PD0566-C',
#  'PD0567-C',
#  'PD0569-C',
#  'PD0570-C',
#  'PD0571-C',
#  'PD0572-C',
#  'PD0573-C',
#  'PD0574-C',
#  'PD0575-C',
#  'PD0575-Cx',
#  'PD0576-C',
#  'PD0576-Cx',
#  'PD0577-C',
#  'PD0577-Cx',
#  'PD0578-C',
#  'PD0578-Cx',
#  'PD0579-C',
#  'PD0579-Cx',
#  'PD0580-C',
#  'PD0580-Cx',
#  'PD0581-C',
#  'PD0581-Cx',
#  'PD0582-C',
#  'PD0582-Cx',
#  'PD0583-C',
#  'PD0583-Cx',
#  'PD0584-C',
#  'PD0584-Cx',
#  'PD0585-C',
#  'PD0585-Cx',
#  'PD0586-C',
#  'PD0586-Cx',
#  'PD0587-C',
#  'PD0589-C',
#  'PD0590-C',
#  'PD0591-C',
#  'PD0592-C',
#  'PD0626-C',
#  'PD0627-C',
#  'PD0629-C',
#  'PD0630-C',
#  'PD0632-C',
#  'PD0635-C',
#  'PD0636-C',
#  'PD0637-C',
#  'PD0638-C',
#  'PD0639-C',
#  'PD0640-C',
#  'PD0641-C',
#  'PD0648-C',
#  'PD0651-C',
#  ...]

# %%
all_results['crt_72-76']
# Out:
# OrderedDict([('FP0008-C', 'CVMNK,CVIET'),
#              ('FP0009-C', 'CVIET'),
#              ('FP0015-C', 'CVIET'),
#              ('FP0016-C', 'CVMNK,CVIET'),
#              ('FP0017-C', 'CVMNK'),
#              ('FP0018-C', 'CVIET'),
#              ('FP0020-C', 'CVIET'),
#              ('FP0021-C', 'CVMNK'),
#              ('FP0022-C', 'CVMNK'),
#              ('FP0023-C', 'CVIET'),
#              ('FP0024-C', 'CVMNK,CVIET'),
#              ('FP0025-C', 'CVMNK,CVIET'),
#              ('FP0026-C', '.....'),
#              ('FP0027-C', '.....'),
#              ('FP0028-C', 'CVMNK'),
#              ('FP0029-C', 'CVIET'),
#              ('FP0030-C', 'CVIET'),
#              ('FP0031-C', 'CVIET'),
#              ('FP0032-C', 'CVIET'),
#              ('FP0033-C', 'CVIET'),
#              ('FP0034-C', 'CVMNK,CVIET'),
#              ('FP0035-C', 'CVIET'),
#              ('FP0038-C', 'CVIET'),
#              ('FP0039-C', 'CVMNK'),
#              ('FP0040-C', 'CVMNK,CVIET'),
#              ('FP0041-C', 'CVMNK,CVIET'),
#              ('FP0042-C', 'CVMNK,CVIET'),
#              ('FP0043-C', 'CVIET'),
#              ('FP0044-C', 'CVIET'),
#              ('FP0046-C', 'CVMNK'),
#              ('FP0047-C', 'CVMNK,CVIET'),
#              ('FP0048-C', 'CVIET'),
#              ('FP0051-C', 'CVMNK,CVIET'),
#              ('FP0052-C', 'CVMNK'),
#              ('FP0054-C', 'CVMNK'),
#              ('FP0055-C', 'CVMNK'),
#              ('FP0056-C', 'CVMNK'),
#              ('FP0057-C', 'CVMNK'),
#              ('FP0058-C', 'CVMNK,CVIET'),
#              ('FP0059-C', 'CVMNK'),
#              ('FP0061-C', 'CVMNK'),
#              ('FP0062-C', 'CVIET'),
#              ('FP0063-C', 'CVMNK'),
#              ('FP0064-C', 'CVIET'),
#              ('FP0065-C', 'CVIET'),
#              ('FP0066-C', 'CVIET'),
#              ('FP0067-C', 'CVIET'),
#              ('FP0068-C', 'CVIET'),
#              ('FP0069-C', 'CVMNK'),
#              ('FP0070-C', 'CVMNK'),
#              ('FP0073-C', 'CVIET'),
#              ('FP0077-C', 'CVMNK,CVIET'),
#              ('FP0078-C', 'CVMNK'),
#              ('FP0081-C', 'CVIET'),
#              ('FP0082-C', 'CVMNK,CVIET'),
#              ('FP0084-C', 'CVIET'),
#              ('FP0089-C', 'CVMNK'),
#              ('FP0090-C', 'CVIET'),
#              ('FP0092-C', 'CVIET'),
#              ('FP0093-C', 'CVMNK'),
#              ('FP0095-C', 'CVIET'),
#              ('FP0096-C', 'CVMNK'),
#              ('FP0097-C', 'CVMNK,CVIET'),
#              ('FP0098-C', 'CVMNK'),
#              ('FP0101-C', 'CVIET'),
#              ('FP0102-C', 'CVIET'),
#              ('FP0103-C', 'CVMNK'),
#              ('FP0105-C', 'CVMNK'),
#              ('FP0106-C', '.....'),
#              ('FP0109-C', '.....'),
#              ('FP0110-C', '.....'),
#              ('FP0112-C', 'CVIET'),
#              ('FP0113-C', 'CVIET'),
#              ('FP0114-C', 'CVMNK,CVIET'),
#              ('FP0116-C', 'CVMNK,CVIET'),
#              ('FP0117-C', 'CVMNK,CVIET'),
#              ('FP0119-C', 'CVMNK,CVIET'),
#              ('FP0120-C', 'CVIET'),
#              ('FP0123-C', 'CVIET'),
#              ('FP0127-C', 'CVIET'),
#              ('FP0128-C', 'CVMNK'),
#              ('FP0129-C', 'CVMNK,CVIET'),
#              ('FP0132-C', 'CVMNK'),
#              ('FP0133-C', '.....'),
#              ('FP0136-C', 'CVMNK,CVIET'),
#              ('FP0139-C', '.....'),
#              ('PA0007-C', 'CVIET'),
#              ('PA0008-C', 'CVMNK,CVIET'),
#              ('PA0011-C', 'CVIET'),
#              ('PA0012-C', 'CVIET'),
#              ('PA0013-C', 'CVIET'),
#              ('PA0014-C', 'CVMNK,CVIET'),
#              ('PA0015-C', 'CVMNK'),
#              ('PA0016-C', 'CVMNK'),
#              ('PA0017-C', 'CVIET'),
#              ('PA0018-C', 'CVIET'),
#              ('PA0020-C', 'CVIET'),
#              ('PA0021-C', 'CVIET'),
#              ('PA0022-C', 'CVIET'),
#              ('PA0026-C', 'CVIET'),
#              ('PA0027-C', 'CVIET'),
#              ('PA0028-C', 'CVIET'),
#              ('PA0029-C', 'CVIET'),
#              ('PA0030-C', 'CVMNK'),
#              ('PA0032-C', 'CVIET'),
#              ('PA0034-C', 'CVIET'),
#              ('PA0035-C', 'CVIET'),
#              ('PA0036-C', 'CVIET'),
#              ('PA0037-C', 'CVIET'),
#              ('PA0038-C', 'CVMNK'),
#              ('PA0039-C', 'CVIET'),
#              ('PA0040-C', 'CVMNK'),
#              ('PA0041-C', 'CVMNK'),
#              ('PA0042-C', 'CVMNK'),
#              ('PA0044-C', 'CVIET'),
#              ('PA0045-C', 'CVIET'),
#              ('PA0046-C', 'CVIET'),
#              ('PA0047-C', 'CVMNK'),
#              ('PA0049-C', 'CVIET'),
#              ('PA0050-C', 'CVIET'),
#              ('PA0051-C', 'CVIET'),
#              ('PA0052-C', 'CVIET'),
#              ('PA0053-C', 'CVIET'),
#              ('PA0054-C', 'CVIET'),
#              ('PA0056-C', 'CVIET'),
#              ('PA0057-C', 'CVIET'),
#              ('PA0059-C', 'CVMNK'),
#              ('PA0060-C', 'CVIET'),
#              ('PA0061-C', 'CVIET'),
#              ('PA0063-C', 'CVIET'),
#              ('PA0064-C', 'CVIET'),
#              ('PA0065-C', 'CVIET'),
#              ('PA0066-C', 'CVIET'),
#              ('PA0067-C', 'CVMNK'),
#              ('PA0068-C', 'CVIET'),
#              ('PA0069-C', 'CVIET'),
#              ('PA0071-C', 'CVIET'),
#              ('PA0072-C', 'CVIET'),
#              ('PA0073-C', 'CVIET'),
#              ('PA0074-C', 'CVIET'),
#              ('PA0075-C', 'CVIET'),
#              ('PA0078-C', 'CVIET'),
#              ('PA0079-C', 'CVIET'),
#              ('PA0080-C', 'CVMNK'),
#              ('PA0081-C', 'CVMNK'),
#              ('PA0084-C', 'CVMNK'),
#              ('PA0085-C', 'CVIET'),
#              ('PA0086-C', '.....'),
#              ('PA0087-C', 'CVIET'),
#              ('PA0089-C', 'CVMNK'),
#              ('PA0090-C', 'CVMNK'),
#              ('PA0091-C', 'CVIET'),
#              ('PA0092-C', 'CVMNK'),
#              ('PA0093-C', 'CVIET'),
#              ('PA0094-C', 'CVMNK,CVIET'),
#              ('PA0095-C', 'CVMNK'),
#              ('PA0097-C', 'CVIET'),
#              ('PA0098-C', 'CVMNK'),
#              ('PA0099-C', 'CVMNK'),
#              ('PA0100-C', 'CVIET'),
#              ('PA0101-C', 'CVIET'),
#              ('PA0102-C', 'CVMNK'),
#              ('PA0103-C', 'CVIET'),
#              ('PA0104-C', 'CVMNK'),
#              ('PA0105-C', 'CVMNK'),
#              ('PA0134-C', 'CVIET'),
#              ('PA0136-C', 'CVMNK'),
#              ('PA0137-C', 'CVIET'),
#              ('PA0138-C', 'CVIET'),
#              ('PA0140-C', 'CVMNK'),
#              ('PA0141-C', 'CVMNK'),
#              ('PA0143-C', '.....'),
#              ('PA0144-C', 'CVIET'),
#              ('PA0145-C', 'CVMNK'),
#              ('PA0146-C', 'CVMNK,CVIET'),
#              ('PA0147-C', 'CVMNK,CVIET'),
#              ('PA0148-C', 'CVIET'),
#              ('PA0149-C', 'CVIET'),
#              ('PA0150-C', 'CVIET'),
#              ('PA0151-C', 'CVIET'),
#              ('PA0152-C', 'CVIET'),
#              ('PA0153-C', 'CVMNK'),
#              ('PA0154-C', 'CVIET'),
#              ('PA0155-C', 'CVMNK,CVIET'),
#              ('PA0156-C', 'CVIET'),
#              ('PA0157-C', 'CVIET'),
#              ('PA0158-C', 'CVMNK'),
#              ('PA0159-C', 'CVIET'),
#              ('PA0160-C', 'CVMNK,CVIET'),
#              ('PA0161-C', 'CVIET'),
#              ('PA0162-C', 'CVMNK,CVIET'),
#              ('PA0163-C', 'CVIET'),
#              ('PA0164-C', 'CVIET'),
#              ('PA0165-C', 'CVIET'),
#              ('PA0166-C', '.....'),
#              ('PA0167-C', 'CVMNK'),
#              ('PA0168-C', 'CVIET'),
#              ('PA0169-C', 'CVIET'),
#              ('PA0170-C', 'CVIET'),
#              ('PA0171-C', 'CVMNK,CVIET'),
#              ('PA0172-C', 'CVMNK'),
#              ('PA0173-C', 'CVIET'),
#              ('PA0174-C', '.....'),
#              ('PA0175-C', 'CVIET'),
#              ('PA0176-C', 'CVMNK'),
#              ('PA0177-C', 'CVIET'),
#              ('PA0178-C', 'CVIET'),
#              ('PA0179-C', 'CVMNK'),
#              ('PA0180-C', 'CVIET'),
#              ('PA0181-C', 'CVIET'),
#              ('PA0182-C', 'CVIET'),
#              ('PA0183-C', 'CVIET'),
#              ('PA0184-C', 'CVIET'),
#              ('PA0185-C', 'CVMNK,CVIET'),
#              ('PA0186-C', 'CVIET'),
#              ('PA0187-C', 'CVIET'),
#              ('PA0188-C', 'CVIET'),
#              ('PA0189-C', 'CVMNK'),
#              ('PA0190-C', 'CVIET'),
#              ('PA0191-C', 'CVIET'),
#              ('PA0192-C', 'CVMNK'),
#              ('PA0193-C', 'CVMNK,CVIET'),
#              ('PA0194-C', '.....'),
#              ('PA0195-C', 'CVIET'),
#              ('PA0196-C', 'CVIET'),
#              ('PA0197-C', 'CVMNK'),
#              ('PA0198-C', 'CVIET'),
#              ('PA0199-C', 'CVMNK,CVIET'),
#              ('PA0200-C', 'CVIET'),
#              ('PA0201-C', 'CVIET'),
#              ('PA0202-C', 'CVMNK'),
#              ('PA0203-C', 'CVIET'),
#              ('PA0204-C', 'CVIET'),
#              ('PA0205-C', 'CVIET'),
#              ('PA0206-C', 'CVIET'),
#              ('PA0207-C', 'CVMNK'),
#              ('PA0208-C', 'CVIET'),
#              ('PA0209-C', 'CVIET'),
#              ('PA0210-C', 'CVMNK,CVIET'),
#              ('PA0211-C', 'CVIET'),
#              ('PA0212-C', 'CVIET'),
#              ('PA0213-C', 'CVIET'),
#              ('PA0214-C', 'CVIET'),
#              ('PA0215-C', 'CVIET'),
#              ('PA0216-C', 'CVIET'),
#              ('PA0217-C', 'CVMNK'),
#              ('PA0218-C', 'CVMNK,CVIET'),
#              ('PA0219-C', 'CVIET'),
#              ('PA0220-C', 'CVMNK,CVIET'),
#              ('PA0221-C', 'CVIET'),
#              ('PA0222-C', 'CVIET'),
#              ('PA0223-C', 'CVIET'),
#              ('PA0224-C', 'CVIET'),
#              ('PA0225-C', 'CVIET'),
#              ('PA0226-C', 'CVIET'),
#              ('PA0227-C', 'CVIET'),
#              ('PA0228-C', 'CVMNK,CVIET'),
#              ('PA0229-C', 'CVMNK'),
#              ('PA0230-C', 'CVMNK'),
#              ('PA0231-C', 'CVMNK,CVIET'),
#              ('PA0232-C', 'CVIET'),
#              ('PA0233-C', 'CVMNK,CVIET'),
#              ('PA0234-C', 'CVMNK,CVIET'),
#              ('PA0235-C', '.....'),
#              ('PA0236-C', '.....'),
#              ('PA0237-C', 'CVIET'),
#              ('PA0238-C', 'CVIET'),
#              ('PA0239-C', 'CVIET'),
#              ('PA0240-C', 'CVIET'),
#              ('PA0241-C', '.....'),
#              ('PA0242-C', 'CVMNK,CVIET'),
#              ('PA0243-C', 'CVIET'),
#              ('PA0244-C', '.....'),
#              ('PA0245-C', 'CVIET'),
#              ('PA0246-C', 'CVMNK'),
#              ('PA0247-C', '.....'),
#              ('PA0248-C', '.....'),
#              ('PA0249-C', 'CVMNK,CVIET'),
#              ('PA0250-C', '.....'),
#              ('PA0251-C', 'CVMNK'),
#              ('PA0252-C', '.....'),
#              ('PA0253-C', 'CVMNK,CVIET'),
#              ('PA0254-C', 'CVIET'),
#              ('PA0255-C', 'CVMNK,CVIET'),
#              ('PA0256-C', 'CVIET'),
#              ('PA0257-C', 'CVMNK,CVIET'),
#              ('PA0258-C', 'CVMNK'),
#              ('PA0259-C', '.....'),
#              ('PA0260-C', 'CVIET'),
#              ('PA0261-C', 'CVIET'),
#              ('PA0262-C', 'CVIET'),
#              ('PA0263-C', 'CVIET'),
#              ('PA0264-C', 'CVMNK'),
#              ('PA0265-C', '.....'),
#              ('PA0266-C', 'CVIET'),
#              ('PA0267-C', 'CVIET'),
#              ('PA0268-C', 'CVMNK'),
#              ('PA0269-C', 'CVMNK,CVIET'),
#              ('PA0270-C', 'CVMNK'),
#              ('PA0271-C', '.....'),
#              ('PA0272-C', 'CVMNK'),
#              ('PA0273-C', '.....'),
#              ('PA0280-CW', 'CVMNK'),
#              ('PA0281-CW', 'CVMNK'),
#              ('PA0283-CW', 'CVMNK'),
#              ('PA0284-CW', 'CVIET'),
#              ('PA0285-CW', '.....'),
#              ('PA0288-CW', 'CVMNK'),
#              ('PA0289-C', 'CVMNK,CVIET'),
#              ('PA0289-CW', 'CVIET'),
#              ('PA0290-C', 'CVIET'),
#              ('PA0291-CW', 'CVMNK,CVIET'),
#              ('PA0292-CW', '.....'),
#              ('PA0293-CW', 'CVMNK'),
#              ('PA0294-CW', 'CVIET'),
#              ('PA0295-CW', 'CVIET'),
#              ('PA0297-CW', 'CVMNK'),
#              ('PA0298-C', 'CVIET'),
#              ('PA0299-CW', 'CVMNK'),
#              ('PA0300-C', 'CVMNK'),
#              ('PA0302-C', 'CVIET'),
#              ('PA0303-CW', 'CVIET'),
#              ('PA0305-CW', 'CVIET'),
#              ('PA0306-CW', 'CVIET'),
#              ('PA0307-CW', 'CVIET'),
#              ('PA0312-CW', 'CVMNK,CVIET'),
#              ('PA0313-CW', 'CVMNK,CVIET'),
#              ('PA0318-CW', 'CVIET'),
#              ('PA0320-C', 'CVMNK'),
#              ('PA0321-CW', 'CVMNK'),
#              ('PA0322-C', '.....'),
#              ('PA0325-CW', 'CVMNK'),
#              ('PA0327-CW', '.....'),
#              ('PA0328-CW', 'CVMNK,CVIET'),
#              ('PA0329-CW', 'CVMNK'),
#              ('PA0330-CW', 'CVMNK'),
#              ('PA0331-CW', 'CVMNK'),
#              ('PA0332-CW', 'CVMNK'),
#              ('PA0334-CW', 'CVMNK'),
#              ('PA0335-CW', 'CVMNK'),
#              ('PA0337-C', 'CVIET'),
#              ('PA0339-CW', 'CVMNK,CVIET'),
#              ('PA0340-CW', 'CVMNK'),
#              ('PA0341-C', 'CVMNK'),
#              ('PA0342-CW', 'CVMNK,CVIET'),
#              ('PA0343-CW', 'CVMNK'),
#              ('PA0344-CW', 'CVMNK'),
#              ('PA0345-CW', 'CVIET'),
#              ('PA0346-CW', 'CVIET'),
#              ('PA0347-CW', 'CVIET'),
#              ('PA0349-C', 'CVMNK'),
#              ('PA0350-CW', 'CVMNK'),
#              ('PA0351-CW', '.....'),
#              ('PA0353-CW', '.....'),
#              ('PA0354-CW', 'CVMNK,CVIET'),
#              ('PA0356-CW', 'CVMNK'),
#              ('PA0357-CW', 'CVMNK,CVIET'),
#              ('PA0358-CW', 'CVIET'),
#              ('PA0362-CW', '.....'),
#              ('PA0363-CW', 'CVIET'),
#              ('PA0364-CW', '.....'),
#              ('PA0369-CW', '.....'),
#              ('PA0370-C', 'CVMNK'),
#              ('PA0371-C', 'CVIET'),
#              ('PA0372-C', 'CVMNK'),
#              ('PA0373-C', 'CVMNK'),
#              ('PA0374-C', 'CVIET'),
#              ('PA0375-C', 'CVMNK'),
#              ('PA0376-C', 'CVIET'),
#              ('PA0377-C', 'CVIET'),
#              ('PA0378-C', 'CVMNK,CVIET'),
#              ('PA0379-C', 'CVMNK'),
#              ('PA0382-C', 'CVIET'),
#              ('PA0383-C', 'CVMNK'),
#              ('PA0384-C', 'CVIET'),
#              ('PA0386-C', '.....'),
#              ('PA0387-C', 'CVIET'),
#              ('PA0388-C', 'CVIET'),
#              ('PA0389-C', 'CVIET'),
#              ('PA0391-C', 'CVIET'),
#              ('PA0392-C', 'CVMNK'),
#              ('PA0393-C', 'CVIET'),
#              ('PA0394-C', 'CVMNK,CVIET'),
#              ('PA0395-C', 'CVIET'),
#              ('PA0396-C', 'CVMNK'),
#              ('PA0397-C', 'CVIET'),
#              ('PA0398-C', 'CVIET'),
#              ('PA0399-C', 'CVMNK'),
#              ('PA0400-C', 'CVMNK'),
#              ('PA0401-C', 'CVMNK'),
#              ('PA0402-C', 'CVIET'),
#              ('PA0403-C', 'CVMNK'),
#              ('PA0404-C', 'CVMNK'),
#              ('PA0405-C', 'CVIET'),
#              ('PA0406-C', 'CVMNK'),
#              ('PA0407-C', 'CVMNK'),
#              ('PA0409-C', 'CVIET'),
#              ('PA0410-C', 'CVIET'),
#              ('PA0411-C', 'CVIET'),
#              ('PA0413-C', 'CVIET'),
#              ('PA0414-C', 'CVMNK'),
#              ('PA0417-C', 'CVMNK'),
#              ('PA0419-C', 'CVMNK'),
#              ('PA0423-C', 'CVMNK'),
#              ('PA0424-C', 'CVIET'),
#              ('PA0425-C', 'CVIET'),
#              ('PA0431-C', 'CVIET'),
#              ('PA0439-C', 'CVIET'),
#              ('PA0440-C', 'CVIET'),
#              ('PA0441-C', 'CVIET'),
#              ('PA0443-C', 'CVMNK,CVIET'),
#              ('PA0444-C', 'CVIET'),
#              ('PA0445-C', 'CVIET'),
#              ('PA0447-C', 'CVMNK,CVIET'),
#              ('PA0449-C', 'CVIET'),
#              ('PA0450-C', 'CVIET'),
#              ('PA0453-C', 'CVIET'),
#              ('PA0454-C', 'CVIET'),
#              ('PA0455-C', 'CVIET'),
#              ('PA0456-C', 'CVMNK'),
#              ('PA0457-C', 'CVMNK'),
#              ('PA0458-C', 'CVMNK,CVIET'),
#              ('PA0459-C', 'CVIET'),
#              ('PA0460-C', 'CVIET'),
#              ('PA0461-C', 'CVIET'),
#              ('PA0462-C', 'CVIET'),
#              ('PA0464-C', 'CVIET'),
#              ('PA0467-C', 'CVMNK,CVIET'),
#              ('PA0468-C', 'CVIET'),
#              ('PA0469-C', 'CVIET'),
#              ('PA0470-C', 'CVIET'),
#              ('PA0471-C', 'CVIET'),
#              ('PA0472-C', 'CVMNK'),
#              ('PA0473-C', 'CVIET'),
#              ('PA0474-C', 'CVIET'),
#              ('PA0477-C', 'CVIET'),
#              ('PA0478-C', 'CVIET'),
#              ('PA0479-C', 'CVIET'),
#              ('PA0480-C', 'CVIET'),
#              ('PA0482-C', 'CVIET'),
#              ('PA0484-C', 'CVIET'),
#              ('PA0486-C', 'CVIET'),
#              ('PA0488-C', 'CVIET'),
#              ('PA0490-C', 'CVIE*,CVIET'),
#              ('PA0491-C', 'CVIET'),
#              ('PA0494-C', 'CVIET'),
#              ('PA0496-C', 'CVIET'),
#              ('PA0497-C', 'CVIET'),
#              ('PA0500-C', 'CVMNK,CVIET'),
#              ('PA0502-C', 'CVIET'),
#              ('PA0505-C', 'CVMNK,CVIET'),
#              ('PA0506-C', 'CVMNK'),
#              ('PA0507-C', 'CVMNK'),
#              ('PA0512-C', 'CVMNK,CVIET'),
#              ('PA0513-C', 'CVIET'),
#              ('PA0516-C', 'CVIET'),
#              ('PA0519-C', 'CVMNK'),
#              ('PA0520-C', 'CVMNK'),
#              ('PA0521-C', 'CVIET'),
#              ('PA0522-C', 'CVIET'),
#              ('PA0524-C', 'CVMNK,CVIET'),
#              ('PA0532-C', 'CVMNK'),
#              ('PA0534-C', 'CVIET'),
#              ('PA0537-C', 'CVMNK'),
#              ('PA0540-C', 'CVMNK'),
#              ('PA0541-C', 'CVMNK,CVIET'),
#              ('PA0542-C', 'CVMNK'),
#              ('PA0544-C', 'CVIET'),
#              ('PA0550-C', 'CVMNK'),
#              ('PA0551-C', 'CVIET'),
#              ('PA0554-C', 'CVIET'),
#              ('PA0558-C', 'CVIET'),
#              ('PA0561-C', 'CVIET'),
#              ('PA0562-C', 'CVIET'),
#              ('PA0563-C', 'CVIET'),
#              ('PA0564-C', 'CVMNK,CVIET'),
#              ('PA0572-C', 'CVIET'),
#              ('PA0575-C', 'CVIET'),
#              ('PA0576-C', 'CVMNK'),
#              ('PA0577-C', 'CVIET'),
#              ('PA0582-C', '.....'),
#              ('PA0585-C', 'CVMNK'),
#              ('PA0586-C', 'CVMNK'),
#              ('PA0593-C', '.....'),
#              ('PA0594-C', '.....'),
#              ('PA0597-C', 'CVIET'),
#              ('PA0599-C', 'CVIET'),
#              ('PA0600-C', '.....'),
#              ('PA0603-C', 'CVMNK,CVIET'),
#              ('PA0604-C', 'CVIET'),
#              ('PA0605-C', 'CVMNK'),
#              ('PA0606-C', 'CVMNK'),
#              ('PA0610-C', '.....'),
#              ('PA0611-C', 'CVMNK'),
#              ('PA0612-C', 'CVMNK'),
#              ('PA0613-C', '.....'),
#              ('PA0615-C', '.....'),
#              ('PA0617-C', 'CVMNK'),
#              ('PA0618-C', 'CVMNK'),
#              ('PA0619-C', 'CVIET'),
#              ('PA0620-C', 'CVIET'),
#              ('PA0621-C', 'CVMNK'),
#              ('PA0622-C', 'CVMNK'),
#              ('PA0623-C', 'CVMNK'),
#              ('PA0625-C', 'CVIET'),
#              ('PA0626-C', 'CVIET'),
#              ('PA0627-C', 'CVIET'),
#              ('PA0628-C', 'CVIET'),
#              ('PA0629-C', 'CVIET'),
#              ('PA0630-C', 'CVIET'),
#              ('PA0631-C', 'CVMNK'),
#              ('PA0633-C', 'CVMNK'),
#              ('PA0634-C', 'CVIET'),
#              ('PA0635-C', '.....'),
#              ('PA0636-C', 'CVIET'),
#              ('PA0637-C', 'CVMNK,CVIET'),
#              ('PA0638-C', 'CVMNK,CVIET'),
#              ('PA0639-C', 'CVIET'),
#              ('PA0640-C', '.....'),
#              ('PA0641-C', 'CVMNK,CVIET'),
#              ('PA0642-C', 'CVIET'),
#              ('PA0643-C', 'CVIET'),
#              ('PA0644-C', 'CVIET'),
#              ('PA0645-C', 'CVIET'),
#              ('PA0648-C', '.....'),
#              ('PA0649-C', 'CVIET'),
#              ('PA0651-C', 'CVIET'),
#              ('PA0653-C', 'CVIET'),
#              ('PA0654-C', 'CVIET'),
#              ('PA0655-C', 'CVIET'),
#              ('PA0658-CW', '.....'),
#              ('PA0672-CW', '.....'),
#              ('PA0673-CW', '.....'),
#              ('PA0675-CW', '.....'),
#              ('PA0677-CW', 'CVMNK,CVIET'),
#              ('PA0683-CW', '.....'),
#              ('PA0686-CW', '.....'),
#              ('PA0689-CW', '.....'),
#              ('PA0699-CW', 'CVMNK'),
#              ('PA0701-CW', '.....'),
#              ('PA0704-CW', '.....'),
#              ('PA0706-CW', '.....'),
#              ('PA0715-CW', '.....'),
#              ('PA0716-CW', '.....'),
#              ('PA0719-CW', '.....'),
#              ('PA0723-CW', '.....'),
#              ('PA0724-CW', '.....'),
#              ('PA0781-CW', '.....'),
#              ('PA0807-CW', '.....'),
#              ('PA0808-CW', '.....'),
#              ('PA0809-CW', 'CVMNK,CVIET'),
#              ('PA0815-CW', '.....'),
#              ('PA0819-CW', '.....'),
#              ('PA0823-CW', '.....'),
#              ('PA0825-CW', '.....'),
#              ('PA0826-CW', '.....'),
#              ('PA0827-CW', '.....'),
#              ('PA0829-CW', '.....'),
#              ('PA0837-CW', '.....'),
#              ('PA0867-CW', '.....'),
#              ('PA0870-CW', '.....'),
#              ('PC0001-C', 'CVMNK'),
#              ('PC0002-C', 'CVMNK'),
#              ('PC0003-01', 'CVMNK'),
#              ('PC0003-02', 'CVMNK'),
#              ('PC0004-01', 'CVIET'),
#              ('PC0004-02', 'CVIET'),
#              ('PC0005-Cx', 'CVMNK'),
#              ('PC0007-C', 'CVIET'),
#              ('PC0008-01', 'CVIET'),
#              ('PC0008-02', 'CVMNK,CVIET'),
#              ('PC0009-C', 'CVIET'),
#              ('PC0011-C', 'CVMNK'),
#              ('PC0012-01', 'CVIET'),
#              ('PC0012-C', 'CVMNK,CVIET'),
#              ('PC0013-C', 'CVIET'),
#              ('PC0016-C', 'CVIET'),
#              ('PC0019-C', 'CVMNK'),
#              ('PC0020-C', 'CVIET'),
#              ('PC0021-C', 'CVIET'),
#              ('PC0023-C', 'CVMNK'),
#              ('PC0025-C', 'CVIET'),
#              ('PC0026-C', 'CVMNK'),
#              ('PC0030-C', 'CVMNK'),
#              ('PC0031-C', 'CVMNK'),
#              ('PC0032-C', 'CVIET,CVMNK'),
#              ('PC0033-C', 'CVMNK'),
#              ('PC0034-C', '.....'),
#              ('PC0035-C', 'CVMNK'),
#              ('PC0037-C', 'CVIET'),
#              ('PC0038-C', 'CVMNK'),
#              ('PC0044-C', 'CVMNK'),
#              ('PC0046-C', 'CVIET'),
#              ('PC0047-C', 'CVIET'),
#              ('PC0048-C', '.....'),
#              ('PC0049-C', 'CVMNK'),
#              ('PC0051-C', 'CVMNK'),
#              ('PC0053-C', 'CVMNK'),
#              ('PC0054-C', 'CVIET'),
#              ('PC0056-C', 'CVMNK'),
#              ('PC0057-C', 'CVMNK'),
#              ('PC0058-C', 'CVMNK'),
#              ('PC0059-C', 'CVMNK'),
#              ('PC0061-C', 'CVMNK'),
#              ('PC0063-C', 'CVMNK'),
#              ('PC0064-C', 'CVIET'),
#              ('PC0065-C', 'CVMNK'),
#              ('PC0066-C', 'CVMNK'),
#              ('PC0067-C', 'CVMNK'),
#              ('PC0068-C', 'CVMNK'),
#              ('PC0069-C', 'CVMNK'),
#              ('PC0070-C', 'CVMNK'),
#              ('PC0071-C', 'CVMNK'),
#              ('PC0073-C', 'CVMNK'),
#              ('PC0074-C', 'CVMNK'),
#              ('PC0075-C', 'CVIET'),
#              ('PC0077-C', 'CVMNK'),
#              ('PC0078-C', 'CVMNK'),
#              ('PC0079-C', 'CVMNK'),
#              ('PC0080-C', 'CVIET'),
#              ('PC0083-C', 'CVIET'),
#              ('PC0085-C', 'CVMNK'),
#              ('PC0086-C', '.....'),
#              ('PC0097-C', 'CVIET'),
#              ('PC0103-C', 'CVMNK'),
#              ('PC0104-C', 'CVMNK'),
#              ('PC0107-C', 'CVIET'),
#              ('PC0109-C', '.....'),
#              ('PC0112-C', '.....'),
#              ('PC0113-C', 'CVMNK,CVIET'),
#              ('PC0118-C', 'CVIET'),
#              ('PC0122-C', 'CVIET'),
#              ('PC0169-C', 'CVMNK'),
#              ('PC0172-C', 'CVMNK'),
#              ('PC0173-C', 'CVMNK'),
#              ('PC0174-C', 'CVMNK'),
#              ('PC0178-C', 'CVMNK,CVIET'),
#              ('PC0180-C', 'CVMNK'),
#              ('PC0183-C', 'CVMNK'),
#              ('PC0184-C', 'CVMNK'),
#              ('PC0186-C', 'CVMNK'),
#              ('PC0187-C', 'CVMNK'),
#              ('PC0188-C', 'CVMNK'),
#              ('PC0189-C', 'CVMNK'),
#              ('PC0191-C', 'CVMNK'),
#              ('PC0193-C', 'CVMNK'),
#              ('PC0197-C', 'CVIET'),
#              ('PC0198-C', 'CVMNK'),
#              ('PC0199-C', 'CVMNK'),
#              ('PC0200-C', 'CVMNK'),
#              ('PC0201-C', 'CVMNK'),
#              ('PC0202-C', 'CVMNK,CVIET'),
#              ('PC0206-C', 'CVMNK'),
#              ('PC0208-C', 'CVMNK'),
#              ('PC0209-C', 'CVMNK'),
#              ('PC0213-C', 'CVMNK'),
#              ('PC0220-C', 'CVMNK'),
#              ('PC0229-C', 'CVMNK'),
#              ('PC0231-C', 'CVMNK'),
#              ('PC0232-C', 'CVMNK'),
#              ('PC0233-C', 'CVMNK'),
#              ('PC0236-C', 'CVMNK'),
#              ('PC0245-C', 'CVMNK'),
#              ('PC0246-C', 'CVMNK'),
#              ('PC0252-C', 'CVMNK'),
#              ('PC0254-C', 'CVMNK'),
#              ('PC0255-C', 'CVMNK'),
#              ('PC0256-C', 'CVMNK,CVIET'),
#              ('PC0257-C', 'CVMNK'),
#              ('PC0258-C', 'CVMNK'),
#              ('PC0259-C', 'CVMNK'),
#              ('PC0262-C', 'CVMNK'),
#              ('PC0263-C', 'CVMNK,CVIET'),
#              ('PC0268-C', 'CVMNK'),
#              ('PC0269-C', 'CVMNK'),
#              ('PC0273-C', 'CVMNK'),
#              ('PC0276-C', 'CVMNK,CVIET'),
#              ('PC0277-C', 'CVIET'),
#              ('PC0278-C', 'CVMNK'),
#              ('PC0282-C', 'CVMNK'),
#              ('PC0287-C', 'CVMNK'),
#              ('PC0288-C', 'CVMNK'),
#              ('PC0293-C', 'CVMNK'),
#              ('PC0295-C', 'CVMNK'),
#              ('PC0296-C', 'CVMNK,CVIET'),
#              ('PC0301-C', 'CVMNK'),
#              ('PC0302-C', 'CVMNK'),
#              ('PC0305-C', 'CVMNK'),
#              ('PC0311-C', 'CVMNK'),
#              ('PC0314-C', 'CVMNK'),
#              ('PC0318-C', 'CVMNK'),
#              ('PC0337-C', 'CVMNK'),
#              ('PC0352-C', 'CVMNK'),
#              ('PD0003-C', 'CVIET'),
#              ('PD0004-03', 'CVIET'),
#              ('PD0004-C', 'CVIET'),
#              ('PD0005-01', '.....'),
#              ('PD0005-C', 'CVIET'),
#              ('PD0006-01', 'CVIET'),
#              ('PD0007-01', 'CVIET'),
#              ('PD0008-02', 'CVIET'),
#              ('PD0009-01', 'CVIET'),
#              ('PD0010-01', '.....'),
#              ('PD0011-01', 'CVIET'),
#              ('PD0014-01', '.....'),
#              ('PD0015-02', 'CVIET'),
#              ('PD0016-C', 'CVIET'),
#              ('PD0017-C', 'CVIET'),
#              ('PD0018-C', 'CVIET'),
#              ('PD0019-C', 'CVIET'),
#              ('PD0020-C', 'CVIET'),
#              ('PD0021-C', 'CVIET'),
#              ('PD0022-C', 'CVIET'),
#              ('PD0023-C', 'CVIET'),
#              ('PD0025-C', 'CVIET'),
#              ('PD0026-C', 'CVIET'),
#              ('PD0027-C', 'CVIET'),
#              ('PD0028-C', 'CVIET'),
#              ('PD0029-C', 'CVIET'),
#              ('PD0030-C', 'CVIET'),
#              ('PD0031-C', 'CVIET'),
#              ('PD0032-C', 'CVIET'),
#              ('PD0033-C', 'CVIET'),
#              ('PD0034-C', 'CVIET'),
#              ('PD0037-C', 'CVIET'),
#              ('PD0038-C', 'CVIET'),
#              ('PD0039-C', 'CVMNK'),
#              ('PD0040-C', 'CVIET'),
#              ('PD0041-C', 'CVIET'),
#              ('PD0042-C', 'CVIET'),
#              ('PD0043-C', 'CVIET'),
#              ('PD0044-C', 'CVIET'),
#              ('PD0045-C', 'CVIET'),
#              ('PD0046-C', 'CVIET'),
#              ('PD0047-C', '.....'),
#              ('PD0048-C', 'CVIET'),
#              ('PD0050-C', 'CVIET'),
#              ('PD0051-C', 'CVIET'),
#              ('PD0052-C', 'CVIET'),
#              ('PD0053-C', 'CVIET'),
#              ('PD0054-C', 'CVIET'),
#              ('PD0055-C', 'CVIET'),
#              ('PD0056-C', 'CVIET'),
#              ('PD0057-C', 'CVIET'),
#              ('PD0058-C', 'CVIET'),
#              ('PD0059-C', '.....'),
#              ('PD0060-C', 'CVIET'),
#              ('PD0061-C', 'CVIET'),
#              ('PD0062-C', 'CVIET'),
#              ('PD0064-C', 'CVIET'),
#              ('PD0065-C', 'CVIET'),
#              ('PD0066-C', 'CVIET'),
#              ('PD0067-C', 'CVIET'),
#              ('PD0068-C', 'CVIET'),
#              ('PD0069-C', 'CVIET'),
#              ('PD0070-C', 'CVIET'),
#              ('PD0071-C', 'CVIET'),
#              ('PD0072-C', 'CVIET'),
#              ('PD0073-C', 'CVIET'),
#              ('PD0074-C', 'CVIET'),
#              ('PD0075-C', 'CVIET'),
#              ('PD0076-C', 'CVIET'),
#              ('PD0077-C', 'CVIET'),
#              ('PD0078-C', 'CVIET'),
#              ('PD0079-C', 'CVIET'),
#              ('PD0080-C', 'CVIET'),
#              ('PD0081-C', 'CVIET'),
#              ('PD0082-C', 'CVIET'),
#              ('PD0083-C', 'CVIET'),
#              ('PD0084-C', 'CVIET'),
#              ('PD0085-C', 'CVIET'),
#              ('PD0086-C', 'CVIET'),
#              ('PD0087-C', 'CVIET'),
#              ('PD0088-C', 'CVIET'),
#              ('PD0089-C', 'CVIET'),
#              ('PD0090-C', 'CVIET'),
#              ('PD0091-C', 'CVIET'),
#              ('PD0092-C', 'CVIET'),
#              ('PD0093-C', 'CVIET'),
#              ('PD0094-C', 'CVIET'),
#              ('PD0095-C', 'CVIET'),
#              ('PD0096-C', 'CVIET'),
#              ('PD0097-C', 'CVIET'),
#              ('PD0098-C', 'CVIET'),
#              ('PD0100-C', 'CVMNK'),
#              ('PD0101-C', 'CVIET'),
#              ('PD0102-C', 'CVIET'),
#              ('PD0103-C', 'CVIET'),
#              ('PD0104-C', 'CVIET'),
#              ('PD0105-C', 'CVIET'),
#              ('PD0106-C', 'CVIET'),
#              ('PD0107-C', 'CVIET'),
#              ('PD0109-C', 'CVIET'),
#              ('PD0110-C', 'CVIET'),
#              ('PD0111-C', 'CVIET'),
#              ('PD0112-C', 'CVIET'),
#              ('PD0115-Cx', 'CVIET'),
#              ('PD0116-C', 'CVIET'),
#              ('PD0117-C', 'CVIET'),
#              ('PD0118-C', 'CVIET'),
#              ('PD0119-C', 'CVIET'),
#              ('PD0121-C', 'CVIET'),
#              ('PD0122-C', 'CVIET'),
#              ('PD0123-C', 'CVIET'),
#              ('PD0124-C', 'CVIET'),
#              ('PD0125-C', 'CVIET'),
#              ('PD0126-C', 'CVIET'),
#              ('PD0127-C', 'CVIET'),
#              ('PD0128-C', 'CVIET'),
#              ('PD0129-C', 'CVIET'),
#              ('PD0130-C', 'CVIET'),
#              ('PD0131-C', 'CVIET'),
#              ('PD0132-C', 'CVIET'),
#              ('PD0133-C', 'CVIET'),
#              ('PD0134-C', 'CVIET'),
#              ('PD0135-C', 'CVIET'),
#              ('PD0136-C', 'CVIET'),
#              ('PD0138-C', 'CVIET'),
#              ('PD0139-C', 'CVIET'),
#              ('PD0140-C', 'CVIET'),
#              ('PD0141-C', 'CVIET'),
#              ('PD0142-C', 'CVIET'),
#              ('PD0143-C', 'CVIET'),
#              ('PD0144-C', 'CVMNK,CVIET'),
#              ('PD0145-C', 'CVIET'),
#              ('PD0146-C', 'CVIET'),
#              ('PD0147-C', 'CVIET'),
#              ('PD0148-C', '.....'),
#              ('PD0149-C', '.....'),
#              ('PD0150-C', 'CVIET'),
#              ('PD0151-C', '.....'),
#              ('PD0152-C', 'CVIET'),
#              ('PD0153-C', '.....'),
#              ('PD0154-C', '.....'),
#              ('PD0155-C', '.....'),
#              ('PD0156-C', '.....'),
#              ('PD0157-C', 'CVIET'),
#              ('PD0158-C', '.....'),
#              ('PD0159-C', '.....'),
#              ('PD0161-C', '.....'),
#              ('PD0162-CW', 'CVIET'),
#              ('PD0163-C', 'CVIET'),
#              ('PD0164-C', '.....'),
#              ('PD0458-Cx', '.....'),
#              ('PD0459-Cx', 'CVIET'),
#              ('PD0460-C', 'CVIET'),
#              ('PD0461-C', 'CVIET'),
#              ('PD0462-C', 'CVIET'),
#              ('PD0463-Cx', '.....'),
#              ('PD0464-C', 'CVIET'),
#              ('PD0465-Cx', 'CVIET'),
#              ('PD0466-C', 'CVIET'),
#              ('PD0467-C', 'CVIET'),
#              ('PD0468-C', 'CVIET'),
#              ('PD0469-C', 'CVIET'),
#              ('PD0470-C', 'CVIET'),
#              ('PD0471-C', 'CVIET'),
#              ('PD0472-C', 'CVIET'),
#              ('PD0473-C', 'CVIET'),
#              ('PD0474-C', 'CVIET'),
#              ('PD0475-C', 'CVIET'),
#              ('PD0476-C', 'CVIET'),
#              ('PD0477-C', 'CVIET'),
#              ('PD0478-C', 'CVIET'),
#              ('PD0479-C', 'CVIET'),
#              ('PD0480-C', 'CVIET'),
#              ('PD0481-C', 'CVIET'),
#              ('PD0482-C', 'CVIET'),
#              ('PD0483-C', 'CVIET'),
#              ('PD0484-C', 'CVIET'),
#              ('PD0485-C', 'CVIET'),
#              ('PD0487-C', 'CVIET'),
#              ('PD0488-C', 'CVIET'),
#              ('PD0489-C', 'CVIET'),
#              ('PD0490-C', 'CVIET'),
#              ('PD0491-C', 'CVIET'),
#              ('PD0492-C', 'CVIET'),
#              ('PD0493-C', 'CVIET'),
#              ('PD0494-C', 'CVIET'),
#              ('PD0495-C', 'CVIET'),
#              ('PD0496-C', 'CVIET'),
#              ('PD0497-C', 'CVIET'),
#              ('PD0498-C', 'CVIET'),
#              ('PD0499-C', 'CVIET'),
#              ('PD0500-C', 'CVIET'),
#              ('PD0501-C', 'CVIET'),
#              ('PD0502-C', 'CVIET'),
#              ('PD0503-C', 'CVIET'),
#              ('PD0504-C', 'CVIET'),
#              ('PD0505-C', 'CVIET'),
#              ('PD0506-C', 'CVIET'),
#              ('PD0507-C', 'CVIET'),
#              ('PD0508-C', 'CVIET'),
#              ('PD0509-Cx', 'CVIET'),
#              ('PD0509-Cx2', 'CVIET'),
#              ('PD0510-C', 'CVIET'),
#              ('PD0511-C', 'CVIET'),
#              ('PD0512-C', 'CVIET'),
#              ('PD0513-C', 'CVIET'),
#              ('PD0514-C', 'CVIET'),
#              ('PD0515-C', 'CVIET'),
#              ('PD0516-C', 'CVIET'),
#              ('PD0517-C', 'CVIET'),
#              ('PD0518-C', 'CVIET'),
#              ('PD0519-C', 'CVIET'),
#              ('PD0520-C', 'CVIET'),
#              ('PD0521-C', 'CVIET'),
#              ('PD0522-C', 'CVIET'),
#              ('PD0523-C', 'CVIET'),
#              ('PD0524-C', 'CVIET'),
#              ('PD0525-C', 'CVIET'),
#              ('PD0526-C', 'CVIET'),
#              ('PD0527-C', 'CVIET'),
#              ('PD0528-C', 'CVIET'),
#              ('PD0529-C', 'CVIET'),
#              ('PD0530-C', 'CVIET'),
#              ('PD0531-C', 'CVIET'),
#              ('PD0532-C', 'CVIET'),
#              ('PD0533-C', 'CVIET'),
#              ('PD0534-C', 'CVIET'),
#              ('PD0535-C', 'CVIET'),
#              ('PD0536-C', 'CVIET'),
#              ('PD0537-C', 'CVIET'),
#              ('PD0538-C', 'CVIET'),
#              ('PD0539-C', 'CVIET'),
#              ('PD0540-C', 'CVIET'),
#              ('PD0541-C', 'CVIET'),
#              ('PD0543-C', 'CVIET'),
#              ('PD0544-C', 'CVIET'),
#              ('PD0545-C', 'CVIET'),
#              ('PD0546-C', 'CVIET'),
#              ('PD0547-C', 'CVIET'),
#              ('PD0548-C', 'CVIET'),
#              ('PD0549-C', 'CVIET'),
#              ('PD0550-C', 'CVIET'),
#              ('PD0552-C', 'CVIET'),
#              ('PD0553-C', 'CVIET'),
#              ('PD0554-C', 'CVIET'),
#              ('PD0555-C', 'CVIET'),
#              ('PD0556-C', 'CVIET'),
#              ('PD0557-C', 'CVIET'),
#              ('PD0558-C', 'CVIET'),
#              ('PD0559-C', 'CVIET'),
#              ('PD0560-Cx', '.....'),
#              ('PD0561-C', 'CVIET'),
#              ('PD0562-C', 'CVIET'),
#              ('PD0563-C', 'CVIET'),
#              ('PD0564-C', 'CVIET'),
#              ('PD0565-C', 'CVIET'),
#              ('PD0566-C', 'CVIET'),
#              ('PD0567-C', 'CVIET'),
#              ('PD0569-C', 'CVIET'),
#              ('PD0570-C', 'CVIET'),
#              ('PD0571-C', 'CVIET'),
#              ('PD0572-C', 'CVIET'),
#              ('PD0573-C', 'CVIET'),
#              ('PD0574-C', 'CVIET'),
#              ('PD0575-C', 'CVIET'),
#              ('PD0575-Cx', 'CVIET'),
#              ('PD0576-C', 'CVIET'),
#              ('PD0576-Cx', 'CVIET'),
#              ('PD0577-C', 'CVIDT,CVIET'),
#              ('PD0577-Cx', 'CVIDT,CVIET'),
#              ('PD0578-C', 'CVIET'),
#              ('PD0578-Cx', 'CVIET'),
#              ('PD0579-C', 'CVIET'),
#              ('PD0579-Cx', 'CVIET'),
#              ('PD0580-C', 'CVIET'),
#              ('PD0580-Cx', 'CVIET'),
#              ('PD0581-C', 'CVIET'),
#              ('PD0581-Cx', 'CVIET'),
#              ('PD0582-C', 'CVIET'),
#              ('PD0582-Cx', 'CVIET'),
#              ('PD0583-C', 'CVIET'),
#              ('PD0583-Cx', 'CVIET'),
#              ('PD0584-C', 'CVIET'),
#              ('PD0584-Cx', 'CVIET'),
#              ('PD0585-C', 'CVIET'),
#              ('PD0585-Cx', 'CVIET'),
#              ('PD0586-C', 'CVIET'),
#              ('PD0586-Cx', 'CVIET'),
#              ('PD0587-C', 'CVIET'),
#              ('PD0589-C', 'CVIET'),
#              ('PD0590-C', 'CVIET'),
#              ('PD0591-C', 'CVIET'),
#              ('PD0592-C', 'CVIET'),
#              ('PD0626-C', 'CVIET'),
#              ('PD0627-C', 'CVIET'),
#              ('PD0629-C', 'CVIET'),
#              ('PD0630-C', 'CVIET'),
#              ('PD0632-C', 'CVIET'),
#              ('PD0635-C', 'CVIET'),
#              ('PD0636-C', 'CVIET'),
#              ('PD0637-C', 'CVIET'),
#              ('PD0638-C', 'CVIET'),
#              ('PD0639-C', 'CVIET'),
#              ('PD0640-C', 'CVIET'),
#              ('PD0641-C', 'CVIET'),
#              ('PD0648-C', 'CVIET'),
#              ('PD0651-C', 'CVIET'),
#              ...])

# %%
np.unique(list(all_results['crt_342'].values()), return_counts=True)
# Out:
# (array(['.', 'A', 'T', 'T,T'],
#        dtype='<U3'), array([ 285,    8, 6888,    1]))

# %%
all_results['crt_342']['PV0035-C']
# Out:
# 'T'

# %%
list(all_results.keys())
# Out:
# ['crt_72-76',
#  'crt_24',
#  'crt_97',
#  'crt_144',
#  'crt_148',
#  'crt_194',
#  'crt_220',
#  'crt_271',
#  'crt_326',
#  'crt_333',
#  'crt_342',
#  'crt_356',
#  'crt_371',
#  'dhfr_51',
#  'dhfr_59',
#  'dhfr_108',
#  'dhfr_164',
#  'dhps_436',
#  'dhps_437',
#  'dhps_540',
#  'dhps_581',
#  'dhps_613',
#  'mdr1_86',
#  'mdr1_184',
#  'mdr1_1246',
#  'arps10_127',
#  'mdr2_484',
#  'fd_193',
#  'exo_415']

# %%
call_all_haplotypes()
# Out:
# crt_core
# crt_core
# crt_core
# crt_ex01
# crt_ex01
# crt_ex01
# crt_ex02
# crt_ex02
# crt_ex02
# crt_ex03
# crt_ex03
# crt_ex03
# crt_ex04
# crt_ex04
# crt_ex04
# crt_ex06
# crt_ex06
# crt_ex06
# crt_ex09
# crt_ex09
# crt_ex09
# crt_ex10
# crt_ex10
# crt_ex10
# crt_ex11
# crt_ex11
# crt_ex11
# dhfr_1
# dhfr_1
# dhfr_1
# dhfr_2
# dhfr_2
# dhfr_2
# dhfr_3
# dhfr_3
# dhfr_3
# dhps_1
# dhps_1
# dhps_1
# dhps_2
# dhps_2
# dhps_2
# dhps_3
# dhps_3
# dhps_3
# dhps_4
# dhps_4
# dhps_4
# mdr1_1
# mdr1_1
# mdr1_1
# mdr1_2
# mdr1_2
# mdr1_2
# mdr1_3
# mdr1_3
# mdr1_3
# arps10
# arps10
# arps10
# mdr2
# mdr2
# mdr2
# fd
# fd
# fd
# exo
# exo
# exo

# %%
temp = call_haplotypes()
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# 1
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A])
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C])
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A])
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT])
# /nfs/users/nfs_r/rp7/anaconda3/lib/python3.4/site-packages/Bio/Seq.py:2040: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   BiopythonWarning)
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T])
# Sample PH0046-C two PIDs
# Sample PH0242-C two PIDs
# Sample PV0303-C two PIDs
# Sample PV0323-C two PIDs
# Sample QE0396-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G])
# Sample PH0046-C two PIDs
# Sample PH0242-C two PIDs
# Sample PV0303-C two PIDs
# Sample PV0323-C two PIDs
# Sample QE0396-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A])
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA])
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C])
# Sample PN0008-C two unphased hets
# Sample PN0054-C two unphased hets
# Sample PN0075-C two unphased hets
# Sample PN0105-C two unphased hets
# Sample PN0112-C two unphased hets

# %%
temp = call_haplotypes()
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# 1
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A])
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C])
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A])
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT])
# /nfs/users/nfs_r/rp7/anaconda3/lib/python3.4/site-packages/Bio/Seq.py:2040: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   BiopythonWarning)
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T])
# Sample PH0046-C two PIDs
# Sample PH0242-C two PIDs
# Sample PV0303-C two PIDs
# Sample PV0323-C two PIDs
# Sample QE0396-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G])
# Sample PH0046-C two PIDs
# Sample PH0242-C two PIDs
# Sample PV0303-C two PIDs
# Sample PV0323-C two PIDs
# Sample QE0396-C two PIDs
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A])
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA])
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C])
# Sample PN0008-C two unphased hets
# Sample PN0054-C two unphased hets
# Sample PN0075-C two unphased hets
# Sample PN0105-C two unphased hets
# Sample PN0112-C two unphased hets

# %%
temp_dhfr_51 = call_haplotypes('dhfr_51', 'Pf3D7_04_v3', 748238, 748240, '+')
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_04_v3.combined.filtered.vcf.gz
# Record(CHROM=Pf3D7_04_v3, POS=748239, REF=A, ALT=[T])

# %%
np.unique(list(temp_dhfr_51.values()), return_counts=True)
# Out:
# (array(['.', 'I', 'N', 'N,I'],
#        dtype='<U3'), array([ 289, 5226, 1103,  564]))

# %%
temp
# Out:
# OrderedDict([('FP0008-C', 'CVMNK,CVIET'),
#              ('FP0009-C', 'CVIET'),
#              ('FP0015-C', 'CVIET'),
#              ('FP0016-C', 'CVMNK,CVIET'),
#              ('FP0017-C', 'CVMNK'),
#              ('FP0018-C', 'CVIET'),
#              ('FP0020-C', 'CVIET'),
#              ('FP0021-C', 'CVMNK'),
#              ('FP0022-C', 'CVMNK'),
#              ('FP0023-C', 'CVIET'),
#              ('FP0024-C', 'CVMNK,CVIET'),
#              ('FP0025-C', 'CVMNK,CVIET'),
#              ('FP0026-C', 'CVMNK'),
#              ('FP0027-C', 'CVMNK'),
#              ('FP0028-C', 'CVMNK'),
#              ('FP0029-C', 'CVIET'),
#              ('FP0030-C', 'CVIET'),
#              ('FP0031-C', 'CVIET'),
#              ('FP0032-C', 'CVIET'),
#              ('FP0033-C', 'CVIET'),
#              ('FP0034-C', 'CVMNK,CVIET'),
#              ('FP0035-C', 'CVIET'),
#              ('FP0038-C', 'CVIET'),
#              ('FP0039-C', 'CVMNK'),
#              ('FP0040-C', 'CVMNK,CVIET'),
#              ('FP0041-C', 'CVMNK,CVIET'),
#              ('FP0042-C', 'CVMNK,CVIET'),
#              ('FP0043-C', 'CVIET'),
#              ('FP0044-C', 'CVIET'),
#              ('FP0046-C', 'CVMNK'),
#              ('FP0047-C', 'CVMNK,CVIET'),
#              ('FP0048-C', 'CVIET'),
#              ('FP0051-C', 'CVMNK,CVIET'),
#              ('FP0052-C', 'CVMNK'),
#              ('FP0054-C', 'CVMNK'),
#              ('FP0055-C', 'CVMNK'),
#              ('FP0056-C', 'CVMNK'),
#              ('FP0057-C', 'CVMNK'),
#              ('FP0058-C', 'CVMNK,CVIET'),
#              ('FP0059-C', 'CVMNK'),
#              ('FP0061-C', 'CVMNK'),
#              ('FP0062-C', 'CVIET'),
#              ('FP0063-C', 'CVMNK'),
#              ('FP0064-C', 'CVIET'),
#              ('FP0065-C', 'CVIET'),
#              ('FP0066-C', 'CVIET'),
#              ('FP0067-C', 'CVIET'),
#              ('FP0068-C', 'CVIET'),
#              ('FP0069-C', 'CVMNK'),
#              ('FP0070-C', 'CVMNK'),
#              ('FP0073-C', 'CVIET'),
#              ('FP0077-C', 'CVMNK,CVIET'),
#              ('FP0078-C', 'CVMNK'),
#              ('FP0081-C', 'CVIET'),
#              ('FP0082-C', 'CVMNK,CVIET'),
#              ('FP0084-C', 'CVIET'),
#              ('FP0089-C', 'CVMNK'),
#              ('FP0090-C', 'CVIET'),
#              ('FP0092-C', 'CVIET'),
#              ('FP0093-C', 'CVMNK'),
#              ('FP0095-C', 'CVIET'),
#              ('FP0096-C', 'CVMNK'),
#              ('FP0097-C', 'CVMNK,CVIET'),
#              ('FP0098-C', 'CVMNK'),
#              ('FP0101-C', 'CVIET'),
#              ('FP0102-C', 'CVIET'),
#              ('FP0103-C', 'CVMNK'),
#              ('FP0105-C', 'CVMNK'),
#              ('FP0106-C', 'CVMNK'),
#              ('FP0109-C', 'CVMNK'),
#              ('FP0110-C', 'CVMNK'),
#              ('FP0112-C', 'CVIET'),
#              ('FP0113-C', 'CVIET'),
#              ('FP0114-C', 'CVMNK,CVIET'),
#              ('FP0116-C', 'CVMNK,CVIET'),
#              ('FP0117-C', 'CVMNK,CVIET'),
#              ('FP0119-C', 'CVMNK,CVIET'),
#              ('FP0120-C', 'CVIET'),
#              ('FP0123-C', 'CVIET'),
#              ('FP0127-C', 'CVIET'),
#              ('FP0128-C', 'CVMNK'),
#              ('FP0129-C', 'CVMNK,CVIET'),
#              ('FP0132-C', 'CVMNK'),
#              ('FP0133-C', 'CVMNK'),
#              ('FP0136-C', 'CVMNK,CVIET'),
#              ('FP0139-C', 'CVMNK'),
#              ('PA0007-C', 'CVIET'),
#              ('PA0008-C', 'CVMNK,CVIET'),
#              ('PA0011-C', 'CVIET'),
#              ('PA0012-C', 'CVIET'),
#              ('PA0013-C', 'CVIET'),
#              ('PA0014-C', 'CVMNK,CVIET'),
#              ('PA0015-C', 'CVMNK'),
#              ('PA0016-C', 'CVMNK'),
#              ('PA0017-C', 'CVIET'),
#              ('PA0018-C', 'CVIET'),
#              ('PA0020-C', 'CVIET'),
#              ('PA0021-C', 'CVIET'),
#              ('PA0022-C', 'CVIET'),
#              ('PA0026-C', 'CVIET'),
#              ('PA0027-C', 'CVIET'),
#              ('PA0028-C', 'CVIET'),
#              ('PA0029-C', 'CVIET'),
#              ('PA0030-C', 'CVMNK'),
#              ('PA0032-C', 'CVIET'),
#              ('PA0034-C', 'CVIET'),
#              ('PA0035-C', 'CVIET'),
#              ('PA0036-C', 'CVIET'),
#              ('PA0037-C', 'CVIET'),
#              ('PA0038-C', 'CVMNK'),
#              ('PA0039-C', 'CVIET'),
#              ('PA0040-C', 'CVMNK'),
#              ('PA0041-C', 'CVMNK'),
#              ('PA0042-C', 'CVMNK'),
#              ('PA0044-C', 'CVIET'),
#              ('PA0045-C', 'CVIET'),
#              ('PA0046-C', 'CVIET'),
#              ('PA0047-C', 'CVMNK'),
#              ('PA0049-C', 'CVIET'),
#              ('PA0050-C', 'CVIET'),
#              ('PA0051-C', 'CVIET'),
#              ('PA0052-C', 'CVIET'),
#              ('PA0053-C', 'CVIET'),
#              ('PA0054-C', 'CVIET'),
#              ('PA0056-C', 'CVIET'),
#              ('PA0057-C', 'CVIET'),
#              ('PA0059-C', 'CVMNK'),
#              ('PA0060-C', 'CVIET'),
#              ('PA0061-C', 'CVIET'),
#              ('PA0063-C', 'CVIET'),
#              ('PA0064-C', 'CVIET'),
#              ('PA0065-C', 'CVIET'),
#              ('PA0066-C', 'CVIET'),
#              ('PA0067-C', 'CVMNK'),
#              ('PA0068-C', 'CVIET'),
#              ('PA0069-C', 'CVIET'),
#              ('PA0071-C', 'CVIET'),
#              ('PA0072-C', 'CVIET'),
#              ('PA0073-C', 'CVIET'),
#              ('PA0074-C', 'CVIET'),
#              ('PA0075-C', 'CVIET'),
#              ('PA0078-C', 'CVIET'),
#              ('PA0079-C', 'CVIET'),
#              ('PA0080-C', 'CVMNK'),
#              ('PA0081-C', 'CVMNK'),
#              ('PA0084-C', 'CVMNK'),
#              ('PA0085-C', 'CVIET'),
#              ('PA0086-C', 'CVMNK'),
#              ('PA0087-C', 'CVIET'),
#              ('PA0089-C', 'CVMNK'),
#              ('PA0090-C', 'CVMNK'),
#              ('PA0091-C', 'CVIET'),
#              ('PA0092-C', 'CVMNK'),
#              ('PA0093-C', 'CVIET'),
#              ('PA0094-C', 'CVMNK,CVIET'),
#              ('PA0095-C', 'CVMNK'),
#              ('PA0097-C', 'CVIET'),
#              ('PA0098-C', 'CVMNK'),
#              ('PA0099-C', 'CVMNK'),
#              ('PA0100-C', 'CVIET'),
#              ('PA0101-C', 'CVIET'),
#              ('PA0102-C', 'CVMNK'),
#              ('PA0103-C', 'CVIET'),
#              ('PA0104-C', 'CVMNK'),
#              ('PA0105-C', 'CVMNK'),
#              ('PA0134-C', 'CVIET'),
#              ('PA0136-C', 'CVMNK'),
#              ('PA0137-C', 'CVIET'),
#              ('PA0138-C', 'CVIET'),
#              ('PA0140-C', 'CVMNK'),
#              ('PA0141-C', 'CVMNK'),
#              ('PA0143-C', 'CVMNK'),
#              ('PA0144-C', 'CVIET'),
#              ('PA0145-C', 'CVMNK'),
#              ('PA0146-C', 'CVMNK,CVIET'),
#              ('PA0147-C', 'CVMNK,CVIET'),
#              ('PA0148-C', 'CVIET'),
#              ('PA0149-C', 'CVIET'),
#              ('PA0150-C', 'CVIET'),
#              ('PA0151-C', 'CVIET'),
#              ('PA0152-C', 'CVIET'),
#              ('PA0153-C', 'CVMNK'),
#              ('PA0154-C', 'CVIET'),
#              ('PA0155-C', 'CVMNK,CVIET'),
#              ('PA0156-C', 'CVIET'),
#              ('PA0157-C', 'CVIET'),
#              ('PA0158-C', 'CVMNK'),
#              ('PA0159-C', 'CVIET'),
#              ('PA0160-C', 'CVMNK,CVIET'),
#              ('PA0161-C', 'CVIET'),
#              ('PA0162-C', 'CVMNK,CVIET'),
#              ('PA0163-C', 'CVIET'),
#              ('PA0164-C', 'CVIET'),
#              ('PA0165-C', 'CVIET'),
#              ('PA0166-C', 'CVMNK'),
#              ('PA0167-C', 'CVMNK'),
#              ('PA0168-C', 'CVIET'),
#              ('PA0169-C', 'CVIET'),
#              ('PA0170-C', 'CVIET'),
#              ('PA0171-C', 'CVMNK,CVIET'),
#              ('PA0172-C', 'CVMNK'),
#              ('PA0173-C', 'CVIET'),
#              ('PA0174-C', 'CVMNK'),
#              ('PA0175-C', 'CVIET'),
#              ('PA0176-C', 'CVMNK'),
#              ('PA0177-C', 'CVIET'),
#              ('PA0178-C', 'CVIET'),
#              ('PA0179-C', 'CVMNK'),
#              ('PA0180-C', 'CVIET'),
#              ('PA0181-C', 'CVIET'),
#              ('PA0182-C', 'CVIET'),
#              ('PA0183-C', 'CVIET'),
#              ('PA0184-C', 'CVIET'),
#              ('PA0185-C', 'CVMNK,CVIET'),
#              ('PA0186-C', 'CVIET'),
#              ('PA0187-C', 'CVIET'),
#              ('PA0188-C', 'CVIET'),
#              ('PA0189-C', 'CVMNK'),
#              ('PA0190-C', 'CVIET'),
#              ('PA0191-C', 'CVIET'),
#              ('PA0192-C', 'CVMNK'),
#              ('PA0193-C', 'CVMNK,CVIET'),
#              ('PA0194-C', 'CVMNK'),
#              ('PA0195-C', 'CVIET'),
#              ('PA0196-C', 'CVIET'),
#              ('PA0197-C', 'CVMNK'),
#              ('PA0198-C', 'CVIET'),
#              ('PA0199-C', 'CVMNK,CVIET'),
#              ('PA0200-C', 'CVIET'),
#              ('PA0201-C', 'CVIET'),
#              ('PA0202-C', 'CVMNK'),
#              ('PA0203-C', 'CVIET'),
#              ('PA0204-C', 'CVIET'),
#              ('PA0205-C', 'CVIET'),
#              ('PA0206-C', 'CVIET'),
#              ('PA0207-C', 'CVMNK'),
#              ('PA0208-C', 'CVIET'),
#              ('PA0209-C', 'CVIET'),
#              ('PA0210-C', 'CVMNK,CVIET'),
#              ('PA0211-C', 'CVIET'),
#              ('PA0212-C', 'CVIET'),
#              ('PA0213-C', 'CVIET'),
#              ('PA0214-C', 'CVIET'),
#              ('PA0215-C', 'CVIET'),
#              ('PA0216-C', 'CVIET'),
#              ('PA0217-C', 'CVMNK'),
#              ('PA0218-C', 'CVMNK,CVIET'),
#              ('PA0219-C', 'CVIET'),
#              ('PA0220-C', 'CVMNK,CVIET'),
#              ('PA0221-C', 'CVIET'),
#              ('PA0222-C', 'CVIET'),
#              ('PA0223-C', 'CVIET'),
#              ('PA0224-C', 'CVIET'),
#              ('PA0225-C', 'CVIET'),
#              ('PA0226-C', 'CVIET'),
#              ('PA0227-C', 'CVIET'),
#              ('PA0228-C', 'CVMNK,CVIET'),
#              ('PA0229-C', 'CVMNK'),
#              ('PA0230-C', 'CVMNK'),
#              ('PA0231-C', 'CVMNK,CVIET'),
#              ('PA0232-C', 'CVIET'),
#              ('PA0233-C', 'CVMNK,CVIET'),
#              ('PA0234-C', 'CVMNK,CVIET'),
#              ('PA0235-C', 'CVMNK'),
#              ('PA0236-C', 'CVMNK'),
#              ('PA0237-C', 'CVIET'),
#              ('PA0238-C', 'CVIET'),
#              ('PA0239-C', 'CVIET'),
#              ('PA0240-C', 'CVIET'),
#              ('PA0241-C', 'CVMNK'),
#              ('PA0242-C', 'CVMNK,CVIET'),
#              ('PA0243-C', 'CVIET'),
#              ('PA0244-C', 'CVMNK'),
#              ('PA0245-C', 'CVIET'),
#              ('PA0246-C', 'CVMNK'),
#              ('PA0247-C', 'CVMNK'),
#              ('PA0248-C', 'CVMNK'),
#              ('PA0249-C', 'CVMNK,CVIET'),
#              ('PA0250-C', 'CVMNK'),
#              ('PA0251-C', 'CVMNK'),
#              ('PA0252-C', 'CVMNK'),
#              ('PA0253-C', 'CVMNK,CVIET'),
#              ('PA0254-C', 'CVIET'),
#              ('PA0255-C', 'CVMNK,CVIET'),
#              ('PA0256-C', 'CVIET'),
#              ('PA0257-C', 'CVMNK,CVIET'),
#              ('PA0258-C', 'CVMNK'),
#              ('PA0259-C', 'CVMNK'),
#              ('PA0260-C', 'CVIET'),
#              ('PA0261-C', 'CVIET'),
#              ('PA0262-C', 'CVIET'),
#              ('PA0263-C', 'CVIET'),
#              ('PA0264-C', 'CVMNK'),
#              ('PA0265-C', 'CVMNK'),
#              ('PA0266-C', 'CVIET'),
#              ('PA0267-C', 'CVIET'),
#              ('PA0268-C', 'CVMNK'),
#              ('PA0269-C', 'CVMNK,CVIET'),
#              ('PA0270-C', 'CVMNK'),
#              ('PA0271-C', 'CVMNK'),
#              ('PA0272-C', 'CVMNK'),
#              ('PA0273-C', 'CVMNK'),
#              ('PA0280-CW', 'CVMNK'),
#              ('PA0281-CW', 'CVMNK'),
#              ('PA0283-CW', 'CVMNK'),
#              ('PA0284-CW', 'CVIET'),
#              ('PA0285-CW', 'CVMNK'),
#              ('PA0288-CW', 'CVMNK'),
#              ('PA0289-C', 'CVMNK,CVIET'),
#              ('PA0289-CW', 'CVIET'),
#              ('PA0290-C', 'CVIET'),
#              ('PA0291-CW', 'CVMNK,CVIET'),
#              ('PA0292-CW', 'CVMNK'),
#              ('PA0293-CW', 'CVMNK'),
#              ('PA0294-CW', 'CVIET'),
#              ('PA0295-CW', 'CVIET'),
#              ('PA0297-CW', 'CVMNK'),
#              ('PA0298-C', 'CVIET'),
#              ('PA0299-CW', 'CVMNK'),
#              ('PA0300-C', 'CVMNK'),
#              ('PA0302-C', 'CVIET'),
#              ('PA0303-CW', 'CVIET'),
#              ('PA0305-CW', 'CVIET'),
#              ('PA0306-CW', 'CVIET'),
#              ('PA0307-CW', 'CVIET'),
#              ('PA0312-CW', 'CVMNK,CVIET'),
#              ('PA0313-CW', 'CVMNK,CVIET'),
#              ('PA0318-CW', 'CVIET'),
#              ('PA0320-C', 'CVMNK'),
#              ('PA0321-CW', 'CVMNK'),
#              ('PA0322-C', 'CVMNK'),
#              ('PA0325-CW', 'CVMNK'),
#              ('PA0327-CW', 'CVMNK'),
#              ('PA0328-CW', 'CVMNK,CVIET'),
#              ('PA0329-CW', 'CVMNK'),
#              ('PA0330-CW', 'CVMNK'),
#              ('PA0331-CW', 'CVMNK'),
#              ('PA0332-CW', 'CVMNK'),
#              ('PA0334-CW', 'CVMNK'),
#              ('PA0335-CW', 'CVMNK'),
#              ('PA0337-C', 'CVIET'),
#              ('PA0339-CW', 'CVMNK,CVIET'),
#              ('PA0340-CW', 'CVMNK'),
#              ('PA0341-C', 'CVMNK'),
#              ('PA0342-CW', 'CVMNK,CVIET'),
#              ('PA0343-CW', 'CVMNK'),
#              ('PA0344-CW', 'CVMNK'),
#              ('PA0345-CW', 'CVIET'),
#              ('PA0346-CW', 'CVIET'),
#              ('PA0347-CW', 'CVIET'),
#              ('PA0349-C', 'CVMNK'),
#              ('PA0350-CW', 'CVMNK'),
#              ('PA0351-CW', 'CVMNK'),
#              ('PA0353-CW', 'CVMNK'),
#              ('PA0354-CW', 'CVMNK,CVIET'),
#              ('PA0356-CW', 'CVMNK'),
#              ('PA0357-CW', 'CVMNK,CVIET'),
#              ('PA0358-CW', 'CVIET'),
#              ('PA0362-CW', 'CVMNK'),
#              ('PA0363-CW', 'CVIET'),
#              ('PA0364-CW', 'CVMNK'),
#              ('PA0369-CW', 'CVMNK'),
#              ('PA0370-C', 'CVMNK'),
#              ('PA0371-C', 'CVIET'),
#              ('PA0372-C', 'CVMNK'),
#              ('PA0373-C', 'CVMNK'),
#              ('PA0374-C', 'CVIET'),
#              ('PA0375-C', 'CVMNK'),
#              ('PA0376-C', 'CVIET'),
#              ('PA0377-C', 'CVIET'),
#              ('PA0378-C', 'CVMNK,CVIET'),
#              ('PA0379-C', 'CVMNK'),
#              ('PA0382-C', 'CVIET'),
#              ('PA0383-C', 'CVMNK'),
#              ('PA0384-C', 'CVIET'),
#              ('PA0386-C', 'CVMNK'),
#              ('PA0387-C', 'CVIET'),
#              ('PA0388-C', 'CVIET'),
#              ('PA0389-C', 'CVIET'),
#              ('PA0391-C', 'CVIET'),
#              ('PA0392-C', 'CVMNK'),
#              ('PA0393-C', 'CVIET'),
#              ('PA0394-C', 'CVMNK,CVIET'),
#              ('PA0395-C', 'CVIET'),
#              ('PA0396-C', 'CVMNK'),
#              ('PA0397-C', 'CVIET'),
#              ('PA0398-C', 'CVIET'),
#              ('PA0399-C', 'CVMNK'),
#              ('PA0400-C', 'CVMNK'),
#              ('PA0401-C', 'CVMNK'),
#              ('PA0402-C', 'CVIET'),
#              ('PA0403-C', 'CVMNK'),
#              ('PA0404-C', 'CVMNK'),
#              ('PA0405-C', 'CVIET'),
#              ('PA0406-C', 'CVMNK'),
#              ('PA0407-C', 'CVMNK'),
#              ('PA0409-C', 'CVIET'),
#              ('PA0410-C', 'CVIET'),
#              ('PA0411-C', 'CVIET'),
#              ('PA0413-C', 'CVIET'),
#              ('PA0414-C', 'CVMNK'),
#              ('PA0417-C', 'CVMNK'),
#              ('PA0419-C', 'CVMNK'),
#              ('PA0423-C', 'CVMNK'),
#              ('PA0424-C', 'CVIET'),
#              ('PA0425-C', 'CVIET'),
#              ('PA0431-C', 'CVIET'),
#              ('PA0439-C', 'CVIET'),
#              ('PA0440-C', 'CVIET'),
#              ('PA0441-C', 'CVIET'),
#              ('PA0443-C', 'CVMNK,CVIET'),
#              ('PA0444-C', 'CVIET'),
#              ('PA0445-C', 'CVIET'),
#              ('PA0447-C', 'CVMNK,CVIET'),
#              ('PA0449-C', 'CVIET'),
#              ('PA0450-C', 'CVIET'),
#              ('PA0453-C', 'CVIET'),
#              ('PA0454-C', 'CVIET'),
#              ('PA0455-C', 'CVIET'),
#              ('PA0456-C', 'CVMNK'),
#              ('PA0457-C', 'CVMNK'),
#              ('PA0458-C', 'CVMNK,CVIET'),
#              ('PA0459-C', 'CVIET'),
#              ('PA0460-C', 'CVIET'),
#              ('PA0461-C', 'CVIET'),
#              ('PA0462-C', 'CVIET'),
#              ('PA0464-C', 'CVIET'),
#              ('PA0467-C', 'CVMNK,CVIET'),
#              ('PA0468-C', 'CVIET'),
#              ('PA0469-C', 'CVIET'),
#              ('PA0470-C', 'CVIET'),
#              ('PA0471-C', 'CVIET'),
#              ('PA0472-C', 'CVMNK'),
#              ('PA0473-C', 'CVIET'),
#              ('PA0474-C', 'CVIET'),
#              ('PA0477-C', 'CVIET'),
#              ('PA0478-C', 'CVIET'),
#              ('PA0479-C', 'CVIET'),
#              ('PA0480-C', 'CVIET'),
#              ('PA0482-C', 'CVIET'),
#              ('PA0484-C', 'CVIET'),
#              ('PA0486-C', 'CVIET'),
#              ('PA0488-C', 'CVIET'),
#              ('PA0490-C', 'CVIE*,CVIET'),
#              ('PA0491-C', 'CVIET'),
#              ('PA0494-C', 'CVIET'),
#              ('PA0496-C', 'CVIET'),
#              ('PA0497-C', 'CVIET'),
#              ('PA0500-C', 'CVMNK,CVIET'),
#              ('PA0502-C', 'CVIET'),
#              ('PA0505-C', 'CVMNK,CVIET'),
#              ('PA0506-C', 'CVMNK'),
#              ('PA0507-C', 'CVMNK'),
#              ('PA0512-C', 'CVMNK,CVIET'),
#              ('PA0513-C', 'CVIET'),
#              ('PA0516-C', 'CVIET'),
#              ('PA0519-C', 'CVMNK'),
#              ('PA0520-C', 'CVMNK'),
#              ('PA0521-C', 'CVIET'),
#              ('PA0522-C', 'CVIET'),
#              ('PA0524-C', 'CVMNK,CVIET'),
#              ('PA0532-C', 'CVMNK'),
#              ('PA0534-C', 'CVIET'),
#              ('PA0537-C', 'CVMNK'),
#              ('PA0540-C', 'CVMNK'),
#              ('PA0541-C', 'CVMNK,CVIET'),
#              ('PA0542-C', 'CVMNK'),
#              ('PA0544-C', 'CVIET'),
#              ('PA0550-C', 'CVMNK'),
#              ('PA0551-C', 'CVIET'),
#              ('PA0554-C', 'CVIET'),
#              ('PA0558-C', 'CVIET'),
#              ('PA0561-C', 'CVIET'),
#              ('PA0562-C', 'CVIET'),
#              ('PA0563-C', 'CVIET'),
#              ('PA0564-C', 'CVMNK,CVIET'),
#              ('PA0572-C', 'CVIET'),
#              ('PA0575-C', 'CVIET'),
#              ('PA0576-C', 'CVMNK'),
#              ('PA0577-C', 'CVIET'),
#              ('PA0582-C', 'CVMNK'),
#              ('PA0585-C', 'CVMNK'),
#              ('PA0586-C', 'CVMNK'),
#              ('PA0593-C', 'CVMNK'),
#              ('PA0594-C', 'CVMNK'),
#              ('PA0597-C', 'CVIET'),
#              ('PA0599-C', 'CVIET'),
#              ('PA0600-C', 'CVMNK'),
#              ('PA0603-C', 'CVMNK,CVIET'),
#              ('PA0604-C', 'CVIET'),
#              ('PA0605-C', 'CVMNK'),
#              ('PA0606-C', 'CVMNK'),
#              ('PA0610-C', 'CVMNK'),
#              ('PA0611-C', 'CVMNK'),
#              ('PA0612-C', 'CVMNK'),
#              ('PA0613-C', 'CVMNK'),
#              ('PA0615-C', 'CVMNK'),
#              ('PA0617-C', 'CVMNK'),
#              ('PA0618-C', 'CVMNK'),
#              ('PA0619-C', 'CVIET'),
#              ('PA0620-C', 'CVIET'),
#              ('PA0621-C', 'CVMNK'),
#              ('PA0622-C', 'CVMNK'),
#              ('PA0623-C', 'CVMNK'),
#              ('PA0625-C', 'CVIET'),
#              ('PA0626-C', 'CVIET'),
#              ('PA0627-C', 'CVIET'),
#              ('PA0628-C', 'CVIET'),
#              ('PA0629-C', 'CVIET'),
#              ('PA0630-C', 'CVIET'),
#              ('PA0631-C', 'CVMNK'),
#              ('PA0633-C', 'CVMNK'),
#              ('PA0634-C', 'CVIET'),
#              ('PA0635-C', 'CVMNK'),
#              ('PA0636-C', 'CVIET'),
#              ('PA0637-C', 'CVMNK,CVIET'),
#              ('PA0638-C', 'CVMNK,CVIET'),
#              ('PA0639-C', 'CVIET'),
#              ('PA0640-C', 'CVMNK'),
#              ('PA0641-C', 'CVMNK,CVIET'),
#              ('PA0642-C', 'CVIET'),
#              ('PA0643-C', 'CVIET'),
#              ('PA0644-C', 'CVIET'),
#              ('PA0645-C', 'CVIET'),
#              ('PA0648-C', 'CVMNK'),
#              ('PA0649-C', 'CVIET'),
#              ('PA0651-C', 'CVIET'),
#              ('PA0653-C', 'CVIET'),
#              ('PA0654-C', 'CVIET'),
#              ('PA0655-C', 'CVIET'),
#              ('PA0658-CW', 'CVMNK'),
#              ('PA0672-CW', 'CVMNK'),
#              ('PA0673-CW', 'CVMNK'),
#              ('PA0675-CW', 'CVMNK'),
#              ('PA0677-CW', 'CVMNK,CVIET'),
#              ('PA0683-CW', 'CVMNK'),
#              ('PA0686-CW', 'CVMNK'),
#              ('PA0689-CW', 'CVMNK'),
#              ('PA0699-CW', 'CVMNK'),
#              ('PA0701-CW', 'CVMNK'),
#              ('PA0704-CW', 'CVMNK'),
#              ('PA0706-CW', 'CVMNK'),
#              ('PA0715-CW', 'CVMNK'),
#              ('PA0716-CW', 'CVMNK'),
#              ('PA0719-CW', 'CVMNK'),
#              ('PA0723-CW', 'CVMNK'),
#              ('PA0724-CW', 'CVMNK'),
#              ('PA0781-CW', 'CVMNK'),
#              ('PA0807-CW', 'CVMNK'),
#              ('PA0808-CW', 'CVMNK'),
#              ('PA0809-CW', 'CVMNK,CVIET'),
#              ('PA0815-CW', 'CVMNK'),
#              ('PA0819-CW', 'CVMNK'),
#              ('PA0823-CW', 'CVMNK'),
#              ('PA0825-CW', 'CVMNK'),
#              ('PA0826-CW', 'CVMNK'),
#              ('PA0827-CW', 'CVMNK'),
#              ('PA0829-CW', 'CVMNK'),
#              ('PA0837-CW', 'CVMNK'),
#              ('PA0867-CW', 'CVMNK'),
#              ('PA0870-CW', 'CVMNK'),
#              ('PC0001-C', 'CVMNK'),
#              ('PC0002-C', 'CVMNK'),
#              ('PC0003-01', 'CVMNK'),
#              ('PC0003-02', 'CVMNK'),
#              ('PC0004-01', 'CVIET'),
#              ('PC0004-02', 'CVIET'),
#              ('PC0005-Cx', 'CVMNK'),
#              ('PC0007-C', 'CVIET'),
#              ('PC0008-01', 'CVIET'),
#              ('PC0008-02', 'CVMNK,CVIET'),
#              ('PC0009-C', 'CVIET'),
#              ('PC0011-C', 'CVMNK'),
#              ('PC0012-01', 'CVIET'),
#              ('PC0012-C', 'CVMNK,CVIET'),
#              ('PC0013-C', 'CVIET'),
#              ('PC0016-C', 'CVIET'),
#              ('PC0019-C', 'CVMNK'),
#              ('PC0020-C', 'CVIET'),
#              ('PC0021-C', 'CVIET'),
#              ('PC0023-C', 'CVMNK'),
#              ('PC0025-C', 'CVIET'),
#              ('PC0026-C', 'CVMNK'),
#              ('PC0030-C', 'CVMNK'),
#              ('PC0031-C', 'CVMNK'),
#              ('PC0032-C', 'CVIET,CVMNK'),
#              ('PC0033-C', 'CVMNK'),
#              ('PC0034-C', 'CVMNK'),
#              ('PC0035-C', 'CVMNK'),
#              ('PC0037-C', 'CVIET'),
#              ('PC0038-C', 'CVMNK'),
#              ('PC0044-C', 'CVMNK'),
#              ('PC0046-C', 'CVIET'),
#              ('PC0047-C', 'CVIET'),
#              ('PC0048-C', 'CVMNK'),
#              ('PC0049-C', 'CVMNK'),
#              ('PC0051-C', 'CVMNK'),
#              ('PC0053-C', 'CVMNK'),
#              ('PC0054-C', 'CVIET'),
#              ('PC0056-C', 'CVMNK'),
#              ('PC0057-C', 'CVMNK'),
#              ('PC0058-C', 'CVMNK'),
#              ('PC0059-C', 'CVMNK'),
#              ('PC0061-C', 'CVMNK'),
#              ('PC0063-C', 'CVMNK'),
#              ('PC0064-C', 'CVIET'),
#              ('PC0065-C', 'CVMNK'),
#              ('PC0066-C', 'CVMNK'),
#              ('PC0067-C', 'CVMNK'),
#              ('PC0068-C', 'CVMNK'),
#              ('PC0069-C', 'CVMNK'),
#              ('PC0070-C', 'CVMNK'),
#              ('PC0071-C', 'CVMNK'),
#              ('PC0073-C', 'CVMNK'),
#              ('PC0074-C', 'CVMNK'),
#              ('PC0075-C', 'CVIET'),
#              ('PC0077-C', 'CVMNK'),
#              ('PC0078-C', 'CVMNK'),
#              ('PC0079-C', 'CVMNK'),
#              ('PC0080-C', 'CVIET'),
#              ('PC0083-C', 'CVIET'),
#              ('PC0085-C', 'CVMNK'),
#              ('PC0086-C', 'CVMNK'),
#              ('PC0097-C', 'CVIET'),
#              ('PC0103-C', 'CVMNK'),
#              ('PC0104-C', 'CVMNK'),
#              ('PC0107-C', 'CVIET'),
#              ('PC0109-C', 'CVMNK'),
#              ('PC0112-C', 'CVMNK'),
#              ('PC0113-C', 'CVMNK,CVIET'),
#              ('PC0118-C', 'CVIET'),
#              ('PC0122-C', 'CVIET'),
#              ('PC0169-C', 'CVMNK'),
#              ('PC0172-C', 'CVMNK'),
#              ('PC0173-C', 'CVMNK'),
#              ('PC0174-C', 'CVMNK'),
#              ('PC0178-C', 'CVMNK,CVIET'),
#              ('PC0180-C', 'CVMNK'),
#              ('PC0183-C', 'CVMNK'),
#              ('PC0184-C', 'CVMNK'),
#              ('PC0186-C', 'CVMNK'),
#              ('PC0187-C', 'CVMNK'),
#              ('PC0188-C', 'CVMNK'),
#              ('PC0189-C', 'CVMNK'),
#              ('PC0191-C', 'CVMNK'),
#              ('PC0193-C', 'CVMNK'),
#              ('PC0197-C', 'CVIET'),
#              ('PC0198-C', 'CVMNK'),
#              ('PC0199-C', 'CVMNK'),
#              ('PC0200-C', 'CVMNK'),
#              ('PC0201-C', 'CVMNK'),
#              ('PC0202-C', 'CVMNK,CVIET'),
#              ('PC0206-C', 'CVMNK'),
#              ('PC0208-C', 'CVMNK'),
#              ('PC0209-C', 'CVMNK'),
#              ('PC0213-C', 'CVMNK'),
#              ('PC0220-C', 'CVMNK'),
#              ('PC0229-C', 'CVMNK'),
#              ('PC0231-C', 'CVMNK'),
#              ('PC0232-C', 'CVMNK'),
#              ('PC0233-C', 'CVMNK'),
#              ('PC0236-C', 'CVMNK'),
#              ('PC0245-C', 'CVMNK'),
#              ('PC0246-C', 'CVMNK'),
#              ('PC0252-C', 'CVMNK'),
#              ('PC0254-C', 'CVMNK'),
#              ('PC0255-C', 'CVMNK'),
#              ('PC0256-C', 'CVMNK,CVIET'),
#              ('PC0257-C', 'CVMNK'),
#              ('PC0258-C', 'CVMNK'),
#              ('PC0259-C', 'CVMNK'),
#              ('PC0262-C', 'CVMNK'),
#              ('PC0263-C', 'CVMNK,CVIET'),
#              ('PC0268-C', 'CVMNK'),
#              ('PC0269-C', 'CVMNK'),
#              ('PC0273-C', 'CVMNK'),
#              ('PC0276-C', 'CVMNK,CVIET'),
#              ('PC0277-C', 'CVIET'),
#              ('PC0278-C', 'CVMNK'),
#              ('PC0282-C', 'CVMNK'),
#              ('PC0287-C', 'CVMNK'),
#              ('PC0288-C', 'CVMNK'),
#              ('PC0293-C', 'CVMNK'),
#              ('PC0295-C', 'CVMNK'),
#              ('PC0296-C', 'CVMNK,CVIET'),
#              ('PC0301-C', 'CVMNK'),
#              ('PC0302-C', 'CVMNK'),
#              ('PC0305-C', 'CVMNK'),
#              ('PC0311-C', 'CVMNK'),
#              ('PC0314-C', 'CVMNK'),
#              ('PC0318-C', 'CVMNK'),
#              ('PC0337-C', 'CVMNK'),
#              ('PC0352-C', 'CVMNK'),
#              ('PD0003-C', 'CVIET'),
#              ('PD0004-03', 'CVIET'),
#              ('PD0004-C', 'CVIET'),
#              ('PD0005-01', 'CVMNK'),
#              ('PD0005-C', 'CVIET'),
#              ('PD0006-01', 'CVIET'),
#              ('PD0007-01', 'CVIET'),
#              ('PD0008-02', 'CVIET'),
#              ('PD0009-01', 'CVIET'),
#              ('PD0010-01', 'CVMNK'),
#              ('PD0011-01', 'CVIET'),
#              ('PD0014-01', 'CVMNK'),
#              ('PD0015-02', 'CVIET'),
#              ('PD0016-C', 'CVIET'),
#              ('PD0017-C', 'CVIET'),
#              ('PD0018-C', 'CVIET'),
#              ('PD0019-C', 'CVIET'),
#              ('PD0020-C', 'CVIET'),
#              ('PD0021-C', 'CVIET'),
#              ('PD0022-C', 'CVIET'),
#              ('PD0023-C', 'CVIET'),
#              ('PD0025-C', 'CVIET'),
#              ('PD0026-C', 'CVIET'),
#              ('PD0027-C', 'CVIET'),
#              ('PD0028-C', 'CVIET'),
#              ('PD0029-C', 'CVIET'),
#              ('PD0030-C', 'CVIET'),
#              ('PD0031-C', 'CVIET'),
#              ('PD0032-C', 'CVIET'),
#              ('PD0033-C', 'CVIET'),
#              ('PD0034-C', 'CVIET'),
#              ('PD0037-C', 'CVIET'),
#              ('PD0038-C', 'CVIET'),
#              ('PD0039-C', 'CVMNK'),
#              ('PD0040-C', 'CVIET'),
#              ('PD0041-C', 'CVIET'),
#              ('PD0042-C', 'CVIET'),
#              ('PD0043-C', 'CVIET'),
#              ('PD0044-C', 'CVIET'),
#              ('PD0045-C', 'CVIET'),
#              ('PD0046-C', 'CVIET'),
#              ('PD0047-C', 'CVMNK'),
#              ('PD0048-C', 'CVIET'),
#              ('PD0050-C', 'CVIET'),
#              ('PD0051-C', 'CVIET'),
#              ('PD0052-C', 'CVIET'),
#              ('PD0053-C', 'CVIET'),
#              ('PD0054-C', 'CVIET'),
#              ('PD0055-C', 'CVIET'),
#              ('PD0056-C', 'CVIET'),
#              ('PD0057-C', 'CVIET'),
#              ('PD0058-C', 'CVIET'),
#              ('PD0059-C', 'CVMNK'),
#              ('PD0060-C', 'CVIET'),
#              ('PD0061-C', 'CVIET'),
#              ('PD0062-C', 'CVIET'),
#              ('PD0064-C', 'CVIET'),
#              ('PD0065-C', 'CVIET'),
#              ('PD0066-C', 'CVIET'),
#              ('PD0067-C', 'CVIET'),
#              ('PD0068-C', 'CVIET'),
#              ('PD0069-C', 'CVIET'),
#              ('PD0070-C', 'CVIET'),
#              ('PD0071-C', 'CVIET'),
#              ('PD0072-C', 'CVIET'),
#              ('PD0073-C', 'CVIET'),
#              ('PD0074-C', 'CVIET'),
#              ('PD0075-C', 'CVIET'),
#              ('PD0076-C', 'CVIET'),
#              ('PD0077-C', 'CVIET'),
#              ('PD0078-C', 'CVIET'),
#              ('PD0079-C', 'CVIET'),
#              ('PD0080-C', 'CVIET'),
#              ('PD0081-C', 'CVIET'),
#              ('PD0082-C', 'CVIET'),
#              ('PD0083-C', 'CVIET'),
#              ('PD0084-C', 'CVIET'),
#              ('PD0085-C', 'CVIET'),
#              ('PD0086-C', 'CVIET'),
#              ('PD0087-C', 'CVIET'),
#              ('PD0088-C', 'CVIET'),
#              ('PD0089-C', 'CVIET'),
#              ('PD0090-C', 'CVIET'),
#              ('PD0091-C', 'CVIET'),
#              ('PD0092-C', 'CVIET'),
#              ('PD0093-C', 'CVIET'),
#              ('PD0094-C', 'CVIET'),
#              ('PD0095-C', 'CVIET'),
#              ('PD0096-C', 'CVIET'),
#              ('PD0097-C', 'CVIET'),
#              ('PD0098-C', 'CVIET'),
#              ('PD0100-C', 'CVMNK'),
#              ('PD0101-C', 'CVIET'),
#              ('PD0102-C', 'CVIET'),
#              ('PD0103-C', 'CVIET'),
#              ('PD0104-C', 'CVIET'),
#              ('PD0105-C', 'CVIET'),
#              ('PD0106-C', 'CVIET'),
#              ('PD0107-C', 'CVIET'),
#              ('PD0109-C', 'CVIET'),
#              ('PD0110-C', 'CVIET'),
#              ('PD0111-C', 'CVIET'),
#              ('PD0112-C', 'CVIET'),
#              ('PD0115-Cx', 'CVIET'),
#              ('PD0116-C', 'CVIET'),
#              ('PD0117-C', 'CVIET'),
#              ('PD0118-C', 'CVIET'),
#              ('PD0119-C', 'CVIET'),
#              ('PD0121-C', 'CVIET'),
#              ('PD0122-C', 'CVIET'),
#              ('PD0123-C', 'CVIET'),
#              ('PD0124-C', 'CVIET'),
#              ('PD0125-C', 'CVIET'),
#              ('PD0126-C', 'CVIET'),
#              ('PD0127-C', 'CVIET'),
#              ('PD0128-C', 'CVIET'),
#              ('PD0129-C', 'CVIET'),
#              ('PD0130-C', 'CVIET'),
#              ('PD0131-C', 'CVIET'),
#              ('PD0132-C', 'CVIET'),
#              ('PD0133-C', 'CVIET'),
#              ('PD0134-C', 'CVIET'),
#              ('PD0135-C', 'CVIET'),
#              ('PD0136-C', 'CVIET'),
#              ('PD0138-C', 'CVIET'),
#              ('PD0139-C', 'CVIET'),
#              ('PD0140-C', 'CVIET'),
#              ('PD0141-C', 'CVIET'),
#              ('PD0142-C', 'CVIET'),
#              ('PD0143-C', 'CVIET'),
#              ('PD0144-C', 'CVMNK,CVIET'),
#              ('PD0145-C', 'CVIET'),
#              ('PD0146-C', 'CVIET'),
#              ('PD0147-C', 'CVIET'),
#              ('PD0148-C', 'CVMNK'),
#              ('PD0149-C', 'CVMNK'),
#              ('PD0150-C', 'CVIET'),
#              ('PD0151-C', 'CVMNK'),
#              ('PD0152-C', 'CVIET'),
#              ('PD0153-C', 'CVMNK'),
#              ('PD0154-C', 'CVMNK'),
#              ('PD0155-C', 'CVMNK'),
#              ('PD0156-C', 'CVMNK'),
#              ('PD0157-C', 'CVIET'),
#              ('PD0158-C', 'CVMNK'),
#              ('PD0159-C', 'CVMNK'),
#              ('PD0161-C', 'CVMNK'),
#              ('PD0162-CW', 'CVIET'),
#              ('PD0163-C', 'CVIET'),
#              ('PD0164-C', 'CVMNK'),
#              ('PD0458-Cx', 'CVMNK'),
#              ('PD0459-Cx', 'CVIET'),
#              ('PD0460-C', 'CVIET'),
#              ('PD0461-C', 'CVIET'),
#              ('PD0462-C', 'CVIET'),
#              ('PD0463-Cx', 'CVMNK'),
#              ('PD0464-C', 'CVIET'),
#              ('PD0465-Cx', 'CVIET'),
#              ('PD0466-C', 'CVIET'),
#              ('PD0467-C', 'CVIET'),
#              ('PD0468-C', 'CVIET'),
#              ('PD0469-C', 'CVIET'),
#              ('PD0470-C', 'CVIET'),
#              ('PD0471-C', 'CVIET'),
#              ('PD0472-C', 'CVIET'),
#              ('PD0473-C', 'CVIET'),
#              ('PD0474-C', 'CVIET'),
#              ('PD0475-C', 'CVIET'),
#              ('PD0476-C', 'CVIET'),
#              ('PD0477-C', 'CVIET'),
#              ('PD0478-C', 'CVIET'),
#              ('PD0479-C', 'CVIET'),
#              ('PD0480-C', 'CVIET'),
#              ('PD0481-C', 'CVIET'),
#              ('PD0482-C', 'CVIET'),
#              ('PD0483-C', 'CVIET'),
#              ('PD0484-C', 'CVIET'),
#              ('PD0485-C', 'CVIET'),
#              ('PD0487-C', 'CVIET'),
#              ('PD0488-C', 'CVIET'),
#              ('PD0489-C', 'CVIET'),
#              ('PD0490-C', 'CVIET'),
#              ('PD0491-C', 'CVIET'),
#              ('PD0492-C', 'CVIET'),
#              ('PD0493-C', 'CVIET'),
#              ('PD0494-C', 'CVIET'),
#              ('PD0495-C', 'CVIET'),
#              ('PD0496-C', 'CVIET'),
#              ('PD0497-C', 'CVIET'),
#              ('PD0498-C', 'CVIET'),
#              ('PD0499-C', 'CVIET'),
#              ('PD0500-C', 'CVIET'),
#              ('PD0501-C', 'CVIET'),
#              ('PD0502-C', 'CVIET'),
#              ('PD0503-C', 'CVIET'),
#              ('PD0504-C', 'CVIET'),
#              ('PD0505-C', 'CVIET'),
#              ('PD0506-C', 'CVIET'),
#              ('PD0507-C', 'CVIET'),
#              ('PD0508-C', 'CVIET'),
#              ('PD0509-Cx', 'CVIET'),
#              ('PD0509-Cx2', 'CVIET'),
#              ('PD0510-C', 'CVIET'),
#              ('PD0511-C', 'CVIET'),
#              ('PD0512-C', 'CVIET'),
#              ('PD0513-C', 'CVIET'),
#              ('PD0514-C', 'CVIET'),
#              ('PD0515-C', 'CVIET'),
#              ('PD0516-C', 'CVIET'),
#              ('PD0517-C', 'CVIET'),
#              ('PD0518-C', 'CVIET'),
#              ('PD0519-C', 'CVIET'),
#              ('PD0520-C', 'CVIET'),
#              ('PD0521-C', 'CVIET'),
#              ('PD0522-C', 'CVIET'),
#              ('PD0523-C', 'CVIET'),
#              ('PD0524-C', 'CVIET'),
#              ('PD0525-C', 'CVIET'),
#              ('PD0526-C', 'CVIET'),
#              ('PD0527-C', 'CVIET'),
#              ('PD0528-C', 'CVIET'),
#              ('PD0529-C', 'CVIET'),
#              ('PD0530-C', 'CVIET'),
#              ('PD0531-C', 'CVIET'),
#              ('PD0532-C', 'CVIET'),
#              ('PD0533-C', 'CVIET'),
#              ('PD0534-C', 'CVIET'),
#              ('PD0535-C', 'CVIET'),
#              ('PD0536-C', 'CVIET'),
#              ('PD0537-C', 'CVIET'),
#              ('PD0538-C', 'CVIET'),
#              ('PD0539-C', 'CVIET'),
#              ('PD0540-C', 'CVIET'),
#              ('PD0541-C', 'CVIET'),
#              ('PD0543-C', 'CVIET'),
#              ('PD0544-C', 'CVIET'),
#              ('PD0545-C', 'CVIET'),
#              ('PD0546-C', 'CVIET'),
#              ('PD0547-C', 'CVIET'),
#              ('PD0548-C', 'CVIET'),
#              ('PD0549-C', 'CVIET'),
#              ('PD0550-C', 'CVIET'),
#              ('PD0552-C', 'CVIET'),
#              ('PD0553-C', 'CVIET'),
#              ('PD0554-C', 'CVIET'),
#              ('PD0555-C', 'CVIET'),
#              ('PD0556-C', 'CVIET'),
#              ('PD0557-C', 'CVIET'),
#              ('PD0558-C', 'CVIET'),
#              ('PD0559-C', 'CVIET'),
#              ('PD0560-Cx', 'CVMNK'),
#              ('PD0561-C', 'CVIET'),
#              ('PD0562-C', 'CVIET'),
#              ('PD0563-C', 'CVIET'),
#              ('PD0564-C', 'CVIET'),
#              ('PD0565-C', 'CVIET'),
#              ('PD0566-C', 'CVIET'),
#              ('PD0567-C', 'CVIET'),
#              ('PD0569-C', 'CVIET'),
#              ('PD0570-C', 'CVIET'),
#              ('PD0571-C', 'CVIET'),
#              ('PD0572-C', 'CVIET'),
#              ('PD0573-C', 'CVIET'),
#              ('PD0574-C', 'CVIET'),
#              ('PD0575-C', 'CVIET'),
#              ('PD0575-Cx', 'CVIET'),
#              ('PD0576-C', 'CVIET'),
#              ('PD0576-Cx', 'CVIET'),
#              ('PD0577-C', 'CVIDT,CVIET'),
#              ('PD0577-Cx', 'CVIDT,CVIET'),
#              ('PD0578-C', 'CVIET'),
#              ('PD0578-Cx', 'CVIET'),
#              ('PD0579-C', 'CVIET'),
#              ('PD0579-Cx', 'CVIET'),
#              ('PD0580-C', 'CVIET'),
#              ('PD0580-Cx', 'CVIET'),
#              ('PD0581-C', 'CVIET'),
#              ('PD0581-Cx', 'CVIET'),
#              ('PD0582-C', 'CVIET'),
#              ('PD0582-Cx', 'CVIET'),
#              ('PD0583-C', 'CVIET'),
#              ('PD0583-Cx', 'CVIET'),
#              ('PD0584-C', 'CVIET'),
#              ('PD0584-Cx', 'CVIET'),
#              ('PD0585-C', 'CVIET'),
#              ('PD0585-Cx', 'CVIET'),
#              ('PD0586-C', 'CVIET'),
#              ('PD0586-Cx', 'CVIET'),
#              ('PD0587-C', 'CVIET'),
#              ('PD0589-C', 'CVIET'),
#              ('PD0590-C', 'CVIET'),
#              ('PD0591-C', 'CVIET'),
#              ('PD0592-C', 'CVIET'),
#              ('PD0626-C', 'CVIET'),
#              ('PD0627-C', 'CVIET'),
#              ('PD0629-C', 'CVIET'),
#              ('PD0630-C', 'CVIET'),
#              ('PD0632-C', 'CVIET'),
#              ('PD0635-C', 'CVIET'),
#              ('PD0636-C', 'CVIET'),
#              ('PD0637-C', 'CVIET'),
#              ('PD0638-C', 'CVIET'),
#              ('PD0639-C', 'CVIET'),
#              ('PD0640-C', 'CVIET'),
#              ('PD0641-C', 'CVIET'),
#              ('PD0648-C', 'CVIET'),
#              ('PD0651-C', 'CVIET'),
#              ...])

# %%
temp = call_haplotype(sample='PA0281-CW')
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# tgtgtaatgaataaa
# CVMNK
# 0/0 T [A] 1 1 1
# None
# 0/0 G [A, C] 2 1 1
# None
# 0/0 G [A] 1 1 1
# None
# 0/0 A [AT] 1 1 2
# None
# 0/0 G [T] 1 1 1
# None
# 0/0 A [G] 1 1 1
# None
# 0/0 AT [A] 1 2 1
# None
# 0/0 TA [*, AA] 2 2 1
# None
# 0/0 A [C] 1 1 1
# None
# CVMNK
# CVMNK

# %%
temp = call_haplotype(sample='PA0291-CW')
temp
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# tgtgtaatgaataaa
# CVMNK
# 0/0 T [A] 1 1 1
# None
# 0/0 G [A, C] 2 1 1
# None
# 0/0 G [A] 1 1 1
# None
# 0/1 A [AT] 1 1 2
# 0|1
# [0, 0]
# [MutableSeq('tgtgtaAtgaataaa', Alphabet()), MutableSeq('tgtgtaatgaataaa', Alphabet())]
# [0, 1]
# [MutableSeq('tgtgtaAtgaataaa', Alphabet()), MutableSeq('tgtgtaATtgaataaa', Alphabet())]
# ./. G [T] 1 1 1
# None
# ./. A [G] 1 1 1
# None
# 0/1 AT [A] 1 2 1
# 0|1
# [0, 1]
# [MutableSeq('tgtgtaAtgaATaaa', Alphabet()), MutableSeq('tgtgtaATtgaataaa', Alphabet())]
# [0, 0]
# [MutableSeq('tgtgtaAtgaATaaa', Alphabet()), MutableSeq('tgtgtaATtgaAaaa', Alphabet())]
# 0/1 TA [*, AA] 2 2 1
# 0|1
# [0, 0]
# [MutableSeq('tgtgtaAtgaATAaa', Alphabet()), MutableSeq('tgtgtaATtgaAaaa', Alphabet())]
# [0, 0]
# [MutableSeq('tgtgtaAtgaATAaa', Alphabet()), MutableSeq('tgtgtaATtgaAaaa', Alphabet())]
# 0/1 A [C] 1 1 1
# 0|1
# [0, 0]
# [MutableSeq('tgtgtaAtgaATAAa', Alphabet()), MutableSeq('tgtgtaATtgaAaaa', Alphabet())]
# [0, 0]
# [MutableSeq('tgtgtaAtgaATAAa', Alphabet()), MutableSeq('tgtgtaATtgaAaCa', Alphabet())]
# CVMNK
# CVIET

# %%
temp = call_haplotype(sample='PA0291-CW')
temp
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# tgtgtaatgaataaa
# CVMNK
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A])
# 0/0 T [A] 1 1 1
# Call(sample=PA0291-CW, CallData(GT=0/0, AD=[64, 0], BCS=[None, None, None, None], DP=64, GQ=99, PGT=None, PID=None, PL=[0, 109, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C])
# 0/0 G [A, C] 2 1 1
# Call(sample=PA0291-CW, CallData(GT=0/0, AD=[64, 0, 0], BCS=[None, None, None, None], DP=64, GQ=99, PGT=None, PID=None, PL=[0, 109, 1800, 109, 1800, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A])
# 0/0 G [A] 1 1 1
# Call(sample=PA0291-CW, CallData(GT=0/0, AD=[64, 0], BCS=[None, None, None, None], DP=64, GQ=99, PGT=None, PID=None, PL=[0, 109, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT])
# 0/1 A [AT] 1 1 2
# Call(sample=PA0291-CW, CallData(GT=0/1, AD=[16, 69], BCS=[3129, 595, 998, 3502], DP=85, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[2905, 0, 1366]))
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T])
# ./. G [T] 1 1 1
# Call(sample=PA0291-CW, CallData(GT=./., AD=[86, 0], BCS=[None, None, None, None], DP=86, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G])
# ./. A [G] 1 1 1
# Call(sample=PA0291-CW, CallData(GT=./., AD=[86, 0], BCS=[None, None, None, None], DP=86, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A])
# 0/1 AT [A] 1 2 1
# Call(sample=PA0291-CW, CallData(GT=0/1, AD=[15, 68], BCS=[3079, 615, 977, 3398], DP=83, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[2873, 0, 1397]))
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA])
# 0/1 TA [*, AA] 2 2 1
# Call(sample=PA0291-CW, CallData(GT=0/1, AD=[15, 68, 0], BCS=[3079, 615, 977, 3398], DP=83, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[2873, 0, 1397, 2924, 1608, 4532]))
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C])
# 0/1 A [C] 1 1 1
# Call(sample=PA0291-CW, CallData(GT=0/1, AD=[16, 67], BCS=[3079, 625, 975, 3385], DP=83, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[2807, 0, 1377]))
# CVMNK
# CVIET
# 'CVMNK,CVIET'

# %%
temp = call_haplotype(sample='PH0046-C')
temp
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# tgtgtaatgaataaa
# CVMNK
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A])
# 0/0 T [A] 1 1 1
# Call(sample=PH0046-C, CallData(GT=0/0, AD=[151, 0], BCS=[None, None, None, None], DP=151, GQ=99, PGT=None, PID=None, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C])
# 0/0 G [A, C] 2 1 1
# Call(sample=PH0046-C, CallData(GT=0/0, AD=[151, 0, 0], BCS=[None, None, None, None], DP=151, GQ=99, PGT=None, PID=None, PL=[0, 120, 1800, 120, 1800, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A])
# 0/0 G [A] 1 1 1
# Call(sample=PH0046-C, CallData(GT=0/0, AD=[151, 0], BCS=[None, None, None, None], DP=151, GQ=99, PGT=None, PID=None, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT])
# 0/1 A [AT] 1 1 2
# Call(sample=PH0046-C, CallData(GT=0/1, AD=[230, 43], BCS=[7694, 1394, 2654, 8890], DP=273, GQ=99, PGT=0|1, PID=403618_A_AT, PL=[702, 0, 7429]))
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T])
# 0/1 G [T] 1 1 1
# Call(sample=PH0046-C, CallData(GT=0/1, AD=[45, 237], BCS=[7963, 1499, 2725, 9118], DP=282, GQ=99, PGT=0|1, PID=403620_G_T, PL=[7512, 0, 723]))
# AA = 5
# '?????'

# %%
temp = call_haplotype(sample='PH0003-C')
temp
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# tgtgtaatgaataaa
# CVMNK
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A])
# 0/0 T [A] 1 1 1
# Call(sample=PH0003-C, CallData(GT=0/0, AD=[52, 0], BCS=[None, None, None, None], DP=52, GQ=99, PGT=None, PID=None, PL=[0, 105, 1575]))
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C])
# 0/0 G [A, C] 2 1 1
# Call(sample=PH0003-C, CallData(GT=0/0, AD=[52, 0, 0], BCS=[None, None, None, None], DP=52, GQ=99, PGT=None, PID=None, PL=[0, 105, 1575, 105, 1575, 1575]))
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A])
# 0/0 G [A] 1 1 1
# Call(sample=PH0003-C, CallData(GT=0/0, AD=[52, 0], BCS=[None, None, None, None], DP=52, GQ=99, PGT=None, PID=None, PL=[0, 105, 1575]))
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT])
# 0/0 A [AT] 1 1 2
# Call(sample=PH0003-C, CallData(GT=0/0, AD=[52, 0], BCS=[None, None, None, None], DP=52, GQ=99, PGT=None, PID=None, PL=[0, 105, 1575]))
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T])
# 1/1 G [T] 1 1 1
# Call(sample=PH0003-C, CallData(GT=1/1, AD=[0, 95], BCS=[1173, 211, 481, 1361], DP=95, GQ=99, PGT=1|1, PID=403620_G_T, PL=[4375, 301, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G])
# 1/1 A [G] 1 1 1
# Call(sample=PH0003-C, CallData(GT=1/1, AD=[0, 93], BCS=[1196, 221, 471, 1342], DP=93, GQ=99, PGT=1|1, PID=403620_G_T, PL=[4613, 325, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A])
# 0/0 AT [A] 1 2 1
# Call(sample=PH0003-C, CallData(GT=0/0, AD=[96, 0], BCS=[None, None, None, None], DP=96, GQ=99, PGT=None, PID=None, PL=[0, 120, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA])
# 0/0 TA [*, AA] 2 2 1
# Call(sample=PH0003-C, CallData(GT=0/0, AD=[96, 0, 0], BCS=[None, None, None, None], DP=96, GQ=99, PGT=None, PID=None, PL=[0, 120, 1800, 120, 1800, 1800]))
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C])
# 1/1 A [C] 1 1 1
# Call(sample=PH0003-C, CallData(GT=1/1, AD=[0, 109], BCS=[1466, 289, 535, 1542], DP=109, GQ=99, PGT=1|1, PID=403620_G_T, PL=[4636, 328, 0]))
# CVIDT
# CVIDT
# 'CVIDT'

# %%
temp = call_haplotype(sample='PW0001-C')
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# tgtgtaatgaataaa
# CVMNK
# 1/1 A [G] 1 1 1
# [0]
# [MutableSeq('tgtgtaatgGataaa', Alphabet())]
# 2/2 TA [*, AA] 2 2 1
# [0]
# [MutableSeq('tgtgtaatgGaAAaa', Alphabet())]
# 1/1 A [C] 1 1 1
# [0]
# [MutableSeq('tgtgtaatgGaAACa', Alphabet())]
# CVMET

# %%
temp = call_haplotype(sample='PG0121-C')
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# tgtgtaatgaataaa
# CVMNK
# 1/1 G [T] 1 1 1
# [0]
# [MutableSeq('tgtgtaatTaataaa', Alphabet())]
# 2/2 TA [*, AA] 2 2 1
# [0]
# [MutableSeq('tgtgtaatTaaAAaa', Alphabet())]
# 1/1 A [C] 1 1 1
# [0]
# [MutableSeq('tgtgtaatTaaAACa', Alphabet())]
# CVIKT

# %%
temp = call_haplotype(sample='PP0002-C')
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# tgtgtaatgaataaa
# CVMNK
# 1/1 A [C] 1 1 1
# [0]
# [MutableSeq('tgtgtaatgaataCa', Alphabet())]
# CVMNT

# %%
temp = call_haplotype(sample='PA0582-C')
temp
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# tgtgtaatgaataaa
# CVMNK
# Record(CHROM=Pf3D7_07_v3, POS=403612, REF=T, ALT=[A])
# ./. T [A] 1 1 1
# Call(sample=PA0582-C, CallData(GT=./., AD=[0, 0], BCS=[None, None, None, None], DP=0, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403613, REF=G, ALT=[A, C])
# ./. G [A, C] 2 1 1
# Call(sample=PA0582-C, CallData(GT=./., AD=[0, 0, 0], BCS=[None, None, None, None], DP=0, GQ=None, PGT=None, PID=None, PL=[0, 0, 0, 0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403615, REF=G, ALT=[A])
# ./. G [A] 1 1 1
# Call(sample=PA0582-C, CallData(GT=./., AD=[0, 0], BCS=[None, None, None, None], DP=0, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403618, REF=A, ALT=[AT])
# ./. A [AT] 1 1 2
# Call(sample=PA0582-C, CallData(GT=./., AD=[0, 0], BCS=[None, None, None, None], DP=0, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403620, REF=G, ALT=[T])
# ./. G [T] 1 1 1
# Call(sample=PA0582-C, CallData(GT=./., AD=[0, 0], BCS=[None, None, None, None], DP=0, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403621, REF=A, ALT=[G])
# ./. A [G] 1 1 1
# Call(sample=PA0582-C, CallData(GT=./., AD=[0, 0], BCS=[None, None, None, None], DP=0, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403622, REF=AT, ALT=[A])
# ./. AT [A] 1 2 1
# Call(sample=PA0582-C, CallData(GT=./., AD=[0, 0], BCS=[None, None, None, None], DP=0, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403623, REF=TA, ALT=[*, AA])
# ./. TA [*, AA] 2 2 1
# Call(sample=PA0582-C, CallData(GT=./., AD=[0, 0, 0], BCS=[None, None, None, None], DP=0, GQ=None, PGT=None, PID=None, PL=[0, 0, 0, 0, 0, 0]))
# Record(CHROM=Pf3D7_07_v3, POS=403625, REF=A, ALT=[C])
# ./. A [C] 1 1 1
# Call(sample=PA0582-C, CallData(GT=./., AD=[0, 0], BCS=[None, None, None, None], DP=0, GQ=None, PGT=None, PID=None, PL=[0, 0, 0]))
# CVMNK
# CVMNK
# 'CVMNK'

# %%
temp = call_haplotype(sample='PJ0129-CW')
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# tgtgtaatgaataaa
# CVMNK
# 1/1 T [A] 1 1 1
# [0]
# [MutableSeq('Agtgtaatgaataaa', Alphabet())]
# 1/1 A [C] 1 1 1
# [0]
# [MutableSeq('AgtgtaatgaataCa', Alphabet())]
# SVMNT

# %%
temp = call_haplotype(sample='PH1189-C')
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# tgtgtaatgaataaa
# CVMNK
# 1/1 G [A, C] 2 1 1
# [0]
# [MutableSeq('tAtgtaatgaataaa', Alphabet())]
# 1/1 A [AT] 1 1 2
# [1]
# [MutableSeq('tAtgtaATtgaataaa', Alphabet())]
# 1/1 AT [A] 1 2 1
# [0]
# [MutableSeq('tAtgtaATtgaAaaa', Alphabet())]
# 1/1 TA [*, AA] 2 2 1
# [0]
# [MutableSeq('tAtgtaATtgaAaaa', Alphabet())]
# 1/1 A [C] 1 1 1
# [0]
# [MutableSeq('tAtgtaATtgaAaCa', Alphabet())]
# YVIET

# %%
call_haplotype(sample='PA0291-CW')
# Out:
# /nfs/team112_internal/production_files/Pf/6_0/vcf/SNP_INDEL_Pf3D7_07_v3.combined.filtered.vcf.gz
# CVMNK
# A [AT] 1 1 2
# AT [A] 1 2 1
# TA [*, AA] 2 2 1
# A [C] 1 1 1

# %%
str(temp)
# Out:
# 'tgtgtaatgaataaa'

# %%
call_haplotype('mdr2_484', 'Pf3D7_14_v3', 1956224, 1956226, '-')
